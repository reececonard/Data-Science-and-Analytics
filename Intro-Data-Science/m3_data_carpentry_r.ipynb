# %% [markdown]
# # Data Carpentry for a Mini Analysis (`R`)

# %% [markdown]
# **Exercise 1:** Read in the dataset, `/dsa/data/all_datasets/baseball-databank/data/Master.csv`. Call this data frame, `df`.

# %%
library(dplyr)
library(tidyr)
library(lubridate)

# %%
# Code for Exercise 1 goes here
# -----------------------------

df = read.csv('/dsa/data/all_datasets/baseball-databank/data/Master.csv')

head(df)
# Out:
#   playerID  birthYear birthMonth birthDay birthCountry birthState birthCity
# 1 aardsda01 1981      12         27       USA          CO         Denver
# 2 aaronha01 1934       2          5       USA          AL         Mobile
# 3 aaronto01 1939       8          5       USA          AL         Mobile
# 4 aasedo01  1954       9          8       USA          CA         Orange
# 5 abadan01  1972       8         25       USA          FL         Palm Beach
# 6 abadfe01  1985      12         17       D.R.         La Romana  La Romana
#   deathYear deathMonth deathDay ⋯ nameLast nameGiven        weight height bats
# 1   NA      NA         NA       ⋯ Aardsma  David Allan      220    75     R
# 2   NA      NA         NA       ⋯ Aaron    Henry Louis      180    72     R
# 3 1984       8         16       ⋯ Aaron    Tommie Lee       190    75     R
# 4   NA      NA         NA       ⋯ Aase     Donald William   190    75     R
# 5   NA      NA         NA       ⋯ Abad     Fausto Andres    184    73     L
# 6   NA      NA         NA       ⋯ Abad     Fernando Antonio 220    73     L
#   throws debut      finalGame  retroID  bbrefID
# 1 R      2004-04-06 2015-08-23 aardd001 aardsda01
# 2 R      1954-04-13 1976-10-03 aaroh101 aaronha01
# 3 R      1962-04-10 1971-09-26 aarot101 aaronto01
# 4 R      1977-07-26 1990-10-03 aased001 aasedo01
# 5 L      2001-09-10 2006-04-13 abada001 abadan01
# 6 L      2010-07-28 2015-10-03 abadf001 abadfe01

# %% [markdown]
# We are not interested in the columns dealing with death for these exercises. Let's go ahead and get rid of them.

# %% [markdown]
# **Exercise 2:** Remove the `deathYear`, `deathMonth`, `deathDay`, `deathCountry`, `deathState`, and `deathCity` columns from the data frame. Rename the data frame without these columns, `players`.

# %%
# Code for Exercise 2 goes here
# -----------------------------

library(dplyr)

players = subset(df, select = -c(deathYear, deathMonth, deathDay, deathCountry, deathState, deathCity))

head(players)
# Out:
#   playerID  birthYear birthMonth birthDay birthCountry birthState birthCity
# 1 aardsda01 1981      12         27       USA          CO         Denver
# 2 aaronha01 1934       2          5       USA          AL         Mobile
# 3 aaronto01 1939       8          5       USA          AL         Mobile
# 4 aasedo01  1954       9          8       USA          CA         Orange
# 5 abadan01  1972       8         25       USA          FL         Palm Beach
# 6 abadfe01  1985      12         17       D.R.         La Romana  La Romana
#   nameFirst nameLast nameGiven        weight height bats throws debut
# 1 David     Aardsma  David Allan      220    75     R    R      2004-04-06
# 2 Hank      Aaron    Henry Louis      180    72     R    R      1954-04-13
# 3 Tommie    Aaron    Tommie Lee       190    75     R    R      1962-04-10
# 4 Don       Aase     Donald William   190    75     R    R      1977-07-26
# 5 Andy      Abad     Fausto Andres    184    73     L    L      2001-09-10
# 6 Fernando  Abad     Fernando Antonio 220    73     L    L      2010-07-28
#   finalGame  retroID  bbrefID
# 1 2015-08-23 aardd001 aardsda01
# 2 1976-10-03 aaroh101 aaronha01
# 3 1971-09-26 aarot101 aaronto01
# 4 1990-10-03 aased001 aasedo01
# 5 2006-04-13 abada001 abadan01
# 6 2015-10-03 abadf001 abadfe01

# %% [markdown]
# **Exercise 3:** Create a date column called `players$birthdate` by combining the `birthYear`, `birthMonth` and `birthDay` columns, then delete these columns.

# %%
# Code for Exercise 3 goes here
# -----------------------------

players <-
players %>%
mutate(birthdate = make_date(birthYear, birthMonth, birthDay))
select(players, -birthYear, -birthMonth, -birthDay)
head(players)
# Out:
#       playerID  birthCountry birthState birthCity        nameFirst nameLast
# 1     aardsda01 USA          CO         Denver           David     Aardsma
# 2     aaronha01 USA          AL         Mobile           Hank      Aaron
# 3     aaronto01 USA          AL         Mobile           Tommie    Aaron
# 4     aasedo01  USA          CA         Orange           Don       Aase
# 5     abadan01  USA          FL         Palm Beach       Andy      Abad
# 6     abadfe01  D.R.         La Romana  La Romana        Fernando  Abad
# 7     abadijo01 USA          PA         Philadelphia     John      Abadie
# 8     abbated01 USA          PA         Latrobe          Ed        Abbaticchio
# 9     abbeybe01 USA          VT         Essex            Bert      Abbey
# 10    abbeych01 USA          NE         Falls City       Charlie   Abbey
# 11    abbotda01 USA          OH         Portage          Dan       Abbott
# 12    abbotfr01 USA          OH         Versailles       Fred      Abbott
# 13    abbotgl01 USA          AR         Little Rock      Glenn     Abbott
# 14    abbotje01 USA          GA         Atlanta          Jeff      Abbott
# 15    abbotji01 USA          MI         Flint            Jim       Abbott
# 16    abbotku01 USA          OH         Zanesville       Kurt      Abbott
# 17    abbotky01 USA          MA         Newburyport      Kyle      Abbott
# 18    abbotod01 USA          PA         New Eagle        Ody       Abbott
# 19    abbotpa01 USA          CA         Van Nuys         Paul      Abbott
# 20    aberal01  USA          OH         Cleveland        Al        Aber
# 21    abercda01 USA          OK         Fort Towson      Frank     Abercrombie
# 22    abercre01 USA          GA         Columbus         Reggie    Abercrombie
# 23    abernbi01 USA          CA         Torrance         Bill      Abernathie
# 24    abernbr01 USA          GA         Atlanta          Brent     Abernathy
# 25    abernte01 USA          NC         Bynum            Ted       Abernathy
# 26    abernte02 USA          NC         Stanley          Ted       Abernathy
# 27    abernwo01 USA          NC         Forest City      Woody     Abernathy
# 28    aberscl01 USA          IL         Chicago          Cliff     Aberson
# 29    ablesha01 USA          TX         Terrell          Harry     Ables
# 30    abnersh01 USA          OH         Hamilton         Shawn     Abner
# ⋮     ⋮         ⋮            ⋮          ⋮                ⋮         ⋮
# 18817 zimmejo02 USA          WI         Auburndale       Jordan    Zimmermann
# 18818 zimmero01 USA          PA         Pine Grove       Roy       Zimmerman
# 18819 zimmery01 USA          NC         Washington       Ryan      Zimmerman
# 18820 zinkch01  USA          CA         Carmichael       Charlie   Zink
# 18821 zinkwa01  USA          MA         Pittsfield       Walter    Zink
# 18822 zinnfr01  USA          PA         Phoenixville     Frank     Zinn
# 18823 zinngu01  USA          WV         Holbrook         Guy       Zinn
# 18824 zinnji01  USA          AR         Benton           Jimmy     Zinn
# 18825 zinsebi01 USA          NY         Astoria          Bill      Zinser
# 17    abbok001 abbotky01 1968-02-18
# 18    abboo101 abbotod01 1888-09-05
# 19    abbop001 abbotpa01 1967-09-15
# 20    abera101 aberal01  1927-07-31
# 21    aberd101 abercda01 1850-01-02
# 22    aberr001 abercre01 1980-07-15
# 23    aberb101 abernbi01 1929-01-30
# 24    aberb001 abernbr01 1977-09-23
# 25    abert102 abernte01 1921-10-30
# 26    abert101 abernte02 1933-03-06
# 27    aberw101 abernwo01 1915-02-01
# 28    aberc101 aberscl01 1921-08-28
# 29    ableh101 ablesha01 1883-10-04
# 30    abnes001 abnersh01 1966-06-17
# ⋮     ⋮        ⋮         ⋮
# 18817 zimmj003 zimmejo02 1986-05-23
# 18818 zimmr101 zimmero01 1916-09-13
# 18819 zimmr001 zimmery01 1984-09-28
# 18820 zinkc001 zinkch01  1979-08-26
# 18821 zinkw101 zinkwa01  1898-11-21
# 18822 zinnf101 zinnfr01  1865-12-21
# 18823 zinng101 zinngu01  1887-02-13
# 18824 zinnj101 zinnji01  1895-01-21
# 18825 zinsb101 zinsebi01 1918-01-06
# 18826 zinta001 zinteal01 1968-05-19
# 18827 zipfb101 zipfebu01 1938-11-18
# 18828 ziskr101 ziskri01  1949-02-06
# 18829 zitob001 zitoba01  1978-05-13
# 18830 zitzb101 zitzmbi01 1895-11-19
# 18831 zmice101 zmiched01 1884-10-01
# 18832 zobrb001 zobribe01 1981-05-26
# 18833 zoccp001 zoccope01 1977-02-06
# 18834 zolds101 zoldasa01 1918-12-08
# 18835 zoske001 zoskyed01 1968-02-10
# 18836 zubeb101 zuberbi01 1913-03-26
# 18837 zubej001 zuberjo01 1969-12-10
# 18838 zulej001 zuletju01 1975-03-28
# 18839 zumaj001 zumayjo01 1984-11-09
# 18840 zunim001 zuninmi01 1991-03-25
# 18841 zupcb001 zupcibo01 1966-08-18
# 18842 zupof101 zupofr01  1939-08-29
# 18843 zuvep001 zuvelpa01 1958-10-31
# 18844 zuveg101 zuverge01 1924-08-20
# 18845 zwild101 zwilldu01 1888-11-02
# 18846 zycht001 zychto01  1990-08-07
#   playerID  birthYear birthMonth birthDay birthCountry birthState birthCity
# 1 aardsda01 1981      12         27       USA          CO         Denver
# 2 aaronha01 1934       2          5       USA          AL         Mobile
# 3 aaronto01 1939       8          5       USA          AL         Mobile
# 4 aasedo01  1954       9          8       USA          CA         Orange
# 5 abadan01  1972       8         25       USA          FL         Palm Beach
# 6 abadfe01  1985      12         17       D.R.         La Romana  La Romana
#   nameFirst nameLast nameGiven        weight height bats throws debut
# 1 David     Aardsma  David Allan      220    75     R    R      2004-04-06
# 2 Hank      Aaron    Henry Louis      180    72     R    R      1954-04-13
# 3 Tommie    Aaron    Tommie Lee       190    75     R    R      1962-04-10
# 4 Don       Aase     Donald William   190    75     R    R      1977-07-26
# 5 Andy      Abad     Fausto Andres    184    73     L    L      2001-09-10
# 6 Fernando  Abad     Fernando Antonio 220    73     L    L      2010-07-28
#   finalGame  retroID  bbrefID   birthdate
# 1 2015-08-23 aardd001 aardsda01 1981-12-27
# 2 1976-10-03 aaroh101 aaronha01 1934-02-05
# 3 1971-09-26 aarot101 aaronto01 1939-08-05
# 4 1990-10-03 aased001 aasedo01  1954-09-08
# 5 2006-04-13 abada001 abadan01  1972-08-25
# 6 2015-10-03 abadf001 abadfe01  1985-12-17

# %% [markdown]
# **Exercise 4**: Now convert the `players$debut` and `players$finalGame` columns to date columns.

# %%
# Code for Exercise 4 goes here
# -----------------------------

players = 
    players%>%
    mutate(debut = ymd(debut))

head(players$debut)

players =
    players%>%
    mutate(finalGame = ymd(finalGame))

head(players$finalGame)
# Out:
# [1] "2004-04-06" "1954-04-13" "1962-04-10" "1977-07-26" "2001-09-10"
# [6] "2010-07-28"
# [1] "2015-08-23" "1976-10-03" "1971-09-26" "1990-10-03" "2006-04-13"
# [6] "2015-10-03"

# %% [markdown]
# This is a good time to discuss how to calculate differences between times. `lubridate` provides some convenient ways to do this by simply subtracting one date from another. See the example below.

# %%
delta<-dmy("01-03-2017")-mdy("August 1st, 2000")
delta
# Out:
# Time difference of 6056 days

# %% [markdown]
# **Exercise 5**: Create a new column in the players data frame called `debut_age` that finds the difference in days between a players birth and their debut.

# %%
# Code for Exercise 5 goes here
# -----------------------------

players$debut_age = players$debut - players$birthdate

head(players)
# Out:
#   playerID  birthYear birthMonth birthDay birthCountry birthState birthCity
# 1 aardsda01 1981      12         27       USA          CO         Denver
# 2 aaronha01 1934       2          5       USA          AL         Mobile
# 3 aaronto01 1939       8          5       USA          AL         Mobile
# 4 aasedo01  1954       9          8       USA          CA         Orange
# 5 abadan01  1972       8         25       USA          FL         Palm Beach
# 6 abadfe01  1985      12         17       D.R.         La Romana  La Romana
#   nameFirst nameLast nameGiven        weight height bats throws debut
# 1 David     Aardsma  David Allan      220    75     R    R      2004-04-06
# 2 Hank      Aaron    Henry Louis      180    72     R    R      1954-04-13
# 3 Tommie    Aaron    Tommie Lee       190    75     R    R      1962-04-10
# 4 Don       Aase     Donald William   190    75     R    R      1977-07-26
# 5 Andy      Abad     Fausto Andres    184    73     L    L      2001-09-10
# 6 Fernando  Abad     Fernando Antonio 220    73     L    L      2010-07-28
#   finalGame  retroID  bbrefID   birthdate  debut_age
# 1 2015-08-23 aardd001 aardsda01 1981-12-27  8136 days
# 2 1976-10-03 aaroh101 aaronha01 1934-02-05  7372 days
# 3 1971-09-26 aarot101 aaronto01 1939-08-05  8284 days
# 4 1990-10-03 aased001 aasedo01  1954-09-08  8357 days
# 5 2006-04-13 abada001 abadan01  1972-08-25 10608 days
# 6 2015-10-03 abadf001 abadfe01  1985-12-17  8989 days

# %% [markdown]
# **Exercise 6**: Find the mean age in years of the `debut_age` column. (Hint: you may have to use the `as.numeric()` function on the `debut_age` column to remove the language around each value. Also, when finding the mean, you may need to use the `na.rm` parameter. Finally, remember,the `debut_age` values are currently in days but we want years)

# %%
# Code for Exercise 6 goes here
# -----------------------------

nums = as.numeric(as.character(players$debut_age))
m = mean(nums, na.rm=TRUE)
print(m)
print("Debut Age in Years.")
print(m/365)
# Out:
# [1] 8876.519
# [1] "Debut Age in Years."
# [1] 24.31923

# %% [markdown]
# # Save your notebook, then `File > Close and Halt`
