# %% [markdown]
# # Nested Query Exercise
#
# Please remember to use the `EXPLAIN` before you execute a query to help avoid unnecessary load on the DBMS and indefinite waits by you for results.
#
# Therefore, for each question, we are providing a cell for the `EXPLAIN` as well as the final SQL.
#
#
# ## Our practice schema:
#
# We will use the same database as in the Day 1 practice.
#
# A PDF of the _Entity-Relationship Diagrams_ (ERD) is available [here](https://indigo.sgn.missouri.edu/static/PDF/DVD_Rental_ERD2.pdf).
# Printing is recommended.
#
#
# <span style="font-weight:900; background:yellow">Each query should be implemented with at least one nested query.</span>

# %%
# %load_ext sql
# %sql postgres://dsa_ro_user:readonly@pgsql.dsa.lan/dvdrental
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# 'Connected: dsa_ro_user@dvdrental'

# %% [markdown]
# # 1
#
# ### Which films have no rentals on the date of 2005-05-31
#
# **HINT:** PostgreSQL can cast a _timestamp_ to a _date_ as so: `rental.rental_date::date`.

# %%
# %%sql
# EXPLAIN
# SELECT film_id, title
# from film
# WHERE film_id not in (
#     SELECT film_id
#     from rental join inventory using (inventory_id)
#     WHERE rental.rental_date::date = '2005-05-31'
# );
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 8 rows affected.
# [('Seq Scan on film  (cost=574.86..641.36 rows=500 width=19)',),
#  ('  Filter: (NOT (hashed SubPlan 1))',),
#  ('  SubPlan 1',),
#  ('    ->  Nested Loop  (cost=0.28..574.66 rows=80 width=2)',),
#  ('          ->  Seq Scan on rental  (cost=0.00..390.66 rows=80 width=4)',),
#  ("                Filter: ((rental_date)::date = '2005-05-31'::date)",),
#  ('          ->  Index Scan using inventory_pkey on inventory  (cost=0.28..2.30 rows=1 width=6)',),
#  ('                Index Cond: (inventory_id = rental.inventory_id)',)]

# %%
# %%sql
# SELECT film_id, title
# from film
# WHERE film_id not in (
#     SELECT film_id
#     from rental join inventory using (inventory_id)
#     WHERE rental.rental_date::date = '2005-05-31'
# );
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 851 rows affected.
# [(133, 'Chamber Italian'),
#  (384, 'Grosse Wonderful'),
#  (98, 'Bright Encounters'),
#  (1, 'Academy Dinosaur'),
#  (2, 'Ace Goldfinger'),
#  (5, 'African Egg'),
#  (6, 'Agent Truman'),
#  (7, 'Airplane Sierra'),
#  (9, 'Alabama Devil'),
#  (10, 'Aladdin Calendar'),
#  (11, 'Alamo Videotape'),
#  (12, 'Alaska Phantom'),
#  (213, 'Date Speed'),
#  (13, 'Ali Forever'),
#  (14, 'Alice Fantasia'),
#  (15, 'Alien Center'),
#  (16, 'Alley Evolution'),
#  (17, 'Alone Trip'),
#  (18, 'Alter Victory'),
#  (19, 'Amadeus Holy'),
#  (20, 'Amelie Hellfighters'),
#  (21, 'American Circus'),
#  (22, 'Amistad Midsummer'),
#  (24, 'Analyze Hoosiers'),
#  (25, 'Angels Life'),
#  (27, 'Anonymous Human'),
#  (28, 'Anthem Luke'),
#  (30, 'Anything Savannah'),
#  (32, 'Apocalypse Flamingos'),
#  (33, 'Apollo Teen'),
#  (34, 'Arabia Dogma'),
#  (35, 'Arachnophobia Rollercoaster'),
#  (36, 'Argonauts Town'),
#  (37, 'Arizona Bang'),
#  (38, 'Ark Ridgemont'),
#  (39, 'Armageddon Lost'),
#  (40, 'Army Flintstones'),
#  (41, 'Arsenic Independence'),
#  (42, 'Artist Coldblooded'),
#  (265, 'Dying Maker'),
#  (43, 'Atlantis Cause'),
#  (44, 'Attacks Hate'),
#  (45, 'Attraction Newton'),
#  (46, 'Autumn Crow'),
#  (49, 'Badman Dawn'),
#  (50, 'Baked Cleopatra'),
#  (126, 'Casualties Encino'),
#  (51, 'Balloon Homeward'),
#  (52, 'Ballroom Mockingbird'),
#  (53, 'Bang Kwai'),
#  (54, 'Banger Pinocchio'),
#  (55, 'Barbarella Streetcar'),
#  (56, 'Barefoot Manchurian'),
#  (57, 'Basic Easy'),
#  (58, 'Beach Heartbreakers'),
#  (60, 'Beast Hunchback'),
#  (61, 'Beauty Grease'),
#  (62, 'Bed Highball'),
#  (63, 'Bedazzled Married'),
#  (64, 'Beethoven Exorcist'),
#  (65, 'Behavior Runaway'),
#  (66, 'Beneath Rush'),
#  (67, 'Berets Agent'),
#  (69, 'Beverly Outlaw'),
#  (70, 'Bikini Borrowers'),
#  (72, 'Bill Others'),
#  (73, 'Bingo Talented'),
#  (74, 'Birch Antitrust'),
#  (75, 'Bird Independence'),
#  (76, 'Birdcage Casper'),
#  (77, 'Birds Perdition'),
#  (79, 'Blade Polish'),
#  (80, 'Blanket Beverly'),
#  (81, 'Blindness Gun'),
#  (82, 'Blood Argonauts'),
#  (83, 'Blues Instinct'),
#  (84, 'Boiled Dares'),
#  (86, 'Boogie Amelie'),
#  (87, 'Boondock Ballroom'),
#  (88, 'Born Spinal'),
#  (89, 'Borrowers Bedazzled'),
#  (90, 'Boulevard Mob'),
#  (91, 'Bound Cheaper'),
#  (92, 'Bowfinger Gables'),
#  (93, 'Brannigan Sunrise'),
#  (94, 'Braveheart Human'),
#  (96, 'Breaking Home'),
#  (97, 'Bride Intrigue'),
#  (99, 'Bringing Hysterical'),
#  (100, 'Brooklyn Desert'),
#  (102, 'Bubble Grosse'),
#  (104, 'Bugsy Song'),
#  (105, 'Bull Shawshank'),
#  (106, 'Bulworth Commandments'),
#  (107, 'Bunch Minds'),
#  (108, 'Butch Panther'),
#  (109, 'Butterfly Chocolat'),
#  (110, 'Cabin Flash'),
#  (112, 'Calendar Gunfight'),
#  (113, 'California Birds'),
#  (114, 'Camelot Vacation'),
#  (116, 'Candidate Perdition'),
#  (117, 'Candles Grapes'),
#  (118, 'Canyon Stock'),
#  (119, 'Caper Motions'),
#  (120, 'Caribbean Liberty'),
#  (121, 'Carol Texas'),
#  (122, 'Carrie Bunch'),
#  (123, 'Casablanca Super'),
#  (124, 'Casper Dragonfly'),
#  (125, 'Cassidy Wyoming'),
#  (127, 'Cat Coneheads'),
#  (128, 'Catch Amistad'),
#  (129, 'Cause Date'),
#  (130, 'Celebrity Horn'),
#  (131, 'Center Dinosaur'),
#  (132, 'Chainsaw Uptown'),
#  (134, 'Champion Flatliners'),
#  (154, 'Clash Freddy'),
#  (136, 'Chaplin License'),
#  (138, 'Chariots Conspiracy'),
#  (139, 'Chasing Fight'),
#  (140, 'Cheaper Clyde'),
#  (141, 'Chicago North'),
#  (142, 'Chicken Hellfighters'),
#  (143, 'Chill Luck'),
#  (144, 'Chinatown Gladiator'),
#  (146, 'Chitty Lock'),
#  (147, 'Chocolat Harry'),
#  (148, 'Chocolate Duck'),
#  (149, 'Christmas Moonshine'),
#  (151, 'Cincinatti Whisperer'),
#  (152, 'Circus Youth'),
#  (153, 'Citizen Shrek'),
#  (156, 'Clerks Angels'),
#  (157, 'Clockwork Paradise'),
#  (158, 'Clones Pinocchio'),
#  (160, 'Club Graffiti'),
#  (161, 'Clue Grail'),
#  (162, 'Clueless Bucket'),
#  (163, 'Clyde Theory'),
#  (164, 'Coast Rainbow'),
#  (165, 'Coldblooded Darling'),
#  (166, 'Color Philadelphia'),
#  (168, 'Comancheros Enemy'),
#  (169, 'Comforts Rush'),
#  (170, 'Command Darling'),
#  (171, 'Commandments Express'),
#  (172, 'Coneheads Smoochy'),
#  (173, 'Confessions Maguire'),
#  (174, 'Confidential Interview'),
#  (175, 'Confused Candles'),
#  (177, 'Connecticut Tramp'),
#  (178, 'Connection Microcosmos'),
#  (179, 'Conquerer Nuts'),
#  (180, 'Conspiracy Spirit'),
#  (181, 'Contact Anonymous'),
#  (182, 'Control Anthem'),
#  (183, 'Conversation Downhill'),
#  (185, 'Cowboy Doom'),
#  (186, 'Craft Outfield'),
#  (187, 'Cranes Reservoir'),
#  (188, 'Crazy Home'),
#  (189, 'Creatures Shakespeare'),
#  (190, 'Creepers Kane'),
#  (191, 'Crooked Frogmen'),
#  (192, 'Crossing Divorce'),
#  (193, 'Crossroads Casualties'),
#  (194, 'Crow Grease'),
#  (195, 'Crowds Telemark'),
#  (196, 'Cruelty Unforgiven'),
#  (197, 'Crusade Honey'),
#  (198, 'Crystal Breaking'),
#  (199, 'Cupboard Sinners'),
#  (200, 'Curtain Videotape'),
#  (201, 'Cyclone Family'),
#  (202, 'Daddy Pittsburgh'),
#  (206, 'Dancing Fever'),
#  (207, 'Dangerous Uptown'),
#  (208, 'Dares Pluto'),
#  (209, 'Darkness War'),
#  (210, 'Darko Dorado'),
#  (212, 'Darn Forrester'),
#  (214, 'Daughter Madigan'),
#  (216, 'Day Unfaithful'),
#  (217, 'Dazed Punk'),
#  (218, 'Deceiver Betrayed'),
#  (219, 'Deep Crusade'),
#  (220, 'Deer Virginian'),
#  (221, 'Deliverance Mulholland'),
#  (222, 'Desert Poseidon'),
#  (223, 'Desire Alien'),
#  (224, 'Desperate Trainspotting'),
#  (225, 'Destination Jerk'),
#  (226, 'Destiny Saturday'),
#  (227, 'Details Packer'),
#  (228, 'Detective Vision'),
#  (230, 'Diary Panic'),
#  (231, 'Dinosaur Secretary'),
#  (232, 'Dirty Ace'),
#  (233, 'Disciple Mother'),
#  (235, 'Divide Monster'),
#  (236, 'Divine Resurrection'),
#  (238, 'Doctor Grail'),
#  (239, 'Dogma Family'),
#  (240, 'Dolls Rage'),
#  (241, 'Donnie Alley'),
#  (242, 'Doom Dancing'),
#  (243, 'Doors President'),
#  (244, 'Dorado Notting'),
#  (245, 'Double Wrath'),
#  (246, 'Doubtfire Labyrinth'),
#  (247, 'Downhill Enough'),
#  (248, 'Dozen Lion'),
#  (249, 'Dracula Crystal'),
#  (250, 'Dragon Squad'),
#  (253, 'Drifter Commandments'),
#  (254, 'Driver Annie'),
#  (255, 'Driving Polish'),
#  (256, 'Drop Waterfront'),
#  (257, 'Drumline Cyclone'),
#  (258, 'Drums Dynamite'),
#  (259, 'Duck Racer'),
#  (261, 'Duffel Apocalypse'),
#  (262, 'Dumbo Lust'),
#  (263, 'Durham Panky'),
#  (264, 'Dwarfs Alter'),
#  (266, 'Dynamite Tarzan'),
#  (267, 'Eagles Panky'),
#  (268, 'Early Home'),
#  (269, 'Earring Instinct'),
#  (270, 'Earth Vision'),
#  (271, 'Easy Gladiator'),
#  (272, 'Edge Kissing'),
#  (273, 'Effect Gladiator'),
#  (275, 'Egypt Tenenbaums'),
#  (276, 'Element Freddy'),
#  (278, 'Elf Murder'),
#  (279, 'Elizabeth Shane'),
#  (280, 'Empire Malkovich'),
#  (281, 'Encino Elf'),
#  (282, 'Encounters Curtain'),
#  (283, 'Ending Crowds'),
#  (285, 'English Bulworth'),
#  (286, 'Enough Raging'),
#  (287, 'Entrapment Satisfaction'),
#  (288, 'Escape Metropolis'),
#  (289, 'Eve Resurrection'),
#  (290, 'Everyone Craft'),
#  (291, 'Evolution Alter'),
#  (292, 'Excitement Eve'),
#  (293, 'Exorcist Sting'),
#  (294, 'Expecations Natural'),
#  (295, 'Expendable Stallion'),
#  (296, 'Express Lonely'),
#  (297, 'Extraordinary Conquerer'),
#  (298, 'Eyes Driving'),
#  (300, 'Falcon Volume'),
#  (302, 'Fantasia Park'),
#  (303, 'Fantasy Troopers'),
#  (304, 'Fargo Gandhi'),
#  (306, 'Feathers Metal'),
#  (307, 'Fellowship Autumn'),
#  (308, 'Ferris Mother'),
#  (309, 'Feud Frogmen'),
#  (310, 'Fever Empire'),
#  (311, 'Fiction Christmas'),
#  (312, 'Fiddler Lost'),
#  (313, 'Fidelity Devil'),
#  (314, 'Fight Jawbreaker'),
#  (315, 'Finding Anaconda'),
#  (316, 'Fire Wolves'),
#  (318, 'Firehouse Vietnam'),
#  (319, 'Fish Opus'),
#  (320, 'Flamingos Connecticut'),
#  (321, 'Flash Wars'),
#  (322, 'Flatliners Killer'),
#  (323, 'Flight Lies'),
#  (324, 'Flintstones Happiness'),
#  (325, 'Floats Garden'),
#  (326, 'Flying Hook'),
#  (329, 'Forrest Sons'),
#  (330, 'Forrester Comancheros'),
#  (331, 'Forward Temple'),
#  (332, 'Frankenstein Stranger'),
#  (333, 'Freaky Pocus'),
#  (334, 'Freddy Storm'),
#  (335, 'Freedom Cleopatra'),
#  (336, 'French Holiday'),
#  (337, 'Frida Slipper'),
#  (338, 'Frisco Forrest'),
#  (339, 'Frogmen Breaking'),
#  (340, 'Frontier Cabin'),
#  (341, 'Frost Head'),
#  (342, 'Fugitive Maguire'),
#  (343, 'Full Flatliners'),
#  (344, 'Fury Murder'),
#  (345, 'Gables Metropolis'),
#  (347, 'Games Bowfinger'),
#  (350, 'Garden Island'),
#  (351, 'Gaslight Crusade'),
#  (352, 'Gathering Calendar'),
#  (354, 'Ghost Groundhog'),
#  (355, 'Ghostbusters Elf'),
#  (357, 'Gilbert Pelican'),
#  (359, 'Gladiator Westward'),
#  (360, 'Glass Dying'),
#  (361, 'Gleaming Jawbreaker'),
#  (362, 'Glory Tracy'),
#  (363, 'Go Purple'),
#  (364, 'Godfather Diary'),
#  (365, 'Gold River'),
#  (366, 'Goldfinger Sensibility'),
#  (367, 'Goldmine Tycoon'),
#  (368, 'Gone Trouble'),
#  (370, 'Gorgeous Bingo'),
#  (371, 'Gosford Donnie'),
#  (372, 'Graceland Dynamite'),
#  (374, 'Graffiti Love'),
#  (375, 'Grail Frankenstein'),
#  (376, 'Grapes Fury'),
#  (377, 'Grease Youth'),
#  (378, 'Greatest North'),
#  (379, 'Greedy Roots'),
#  (380, 'Greek Everyone'),
#  (381, 'Grinch Massage'),
#  (383, 'Groove Fiction'),
#  (386, 'Gump Date'),
#  (387, 'Gun Bonnie'),
#  (388, 'Gunfight Moon'),
#  (389, 'Gunfighter Mussolini'),
#  (390, 'Guys Falcon'),
#  (391, 'Half Outfield'),
#  (392, 'Hall Cassidy'),
#  (393, 'Halloween Nuts'),
#  (394, 'Hamlet Wisdom'),
#  (449, 'Identity Lover'),
#  (395, 'Handicap Boondock'),
#  (396, 'Hanging Deep'),
#  (397, 'Hanky October'),
#  (398, 'Hanover Galaxy'),
#  (399, 'Happiness United'),
#  (400, 'Hardly Robbers'),
#  (401, 'Harold French'),
#  (402, 'Harper Dying'),
#  (403, 'Harry Idaho'),
#  (404, 'Hate Handicap'),
#  (405, 'Haunted Antitrust'),
#  (406, 'Haunting Pianist'),
#  (407, 'Hawk Chill'),
#  (408, 'Head Stranger'),
#  (409, 'Heartbreakers Bright'),
#  (410, 'Heaven Freedom'),
#  (411, 'Heavenly Gun'),
#  (412, 'Heavyweights Beast'),
#  (413, 'Hedwig Alter'),
#  (414, 'Hellfighters Sierra'),
#  (415, 'High Encino'),
#  (416, 'Highball Potter'),
#  (417, 'Hills Neighbors'),
#  (419, 'Hocus Frida'),
#  (420, 'Holes Brannigan'),
#  (421, 'Holiday Games'),
#  (422, 'Hollow Jeopardy'),
#  (423, 'Hollywood Anonymous'),
#  (424, 'Holocaust Highball'),
#  (425, 'Holy Tadpole'),
#  (426, 'Home Pity'),
#  (427, 'Homeward Cider'),
#  (428, 'Homicide Peach'),
#  (429, 'Honey Ties'),
#  (430, 'Hook Chariots'),
#  (431, 'Hoosiers Birdcage'),
#  (432, 'Hope Tootsie'),
#  (434, 'Horror Reign'),
#  (435, 'Hotel Happiness'),
#  (436, 'Hours Rage'),
#  (437, 'House Dynamite'),
#  (438, 'Human Graffiti'),
#  (439, 'Hunchback Impossible'),
#  (440, 'Hunger Roof'),
#  (441, 'Hunter Alter'),
#  (443, 'Hurricane Affair'),
#  (444, 'Hustler Party'),
#  (446, 'Hysterical Grail'),
#  (447, 'Ice Crossing'),
#  (448, 'Idaho Love'),
#  (453, 'Image Princess'),
#  (454, 'Impact Aladdin'),
#  (455, 'Impossible Prejudice'),
#  (456, 'Inch Jet'),
#  (457, 'Independence Hotel'),
#  (458, 'Indian Love'),
#  (459, 'Informer Double'),
#  (460, 'Innocent Usual'),
#  (461, 'Insects Stone'),
#  (462, 'Insider Arizona'),
#  (464, 'Intentions Empire'),
#  (465, 'Interview Liaisons'),
#  (468, 'Invasion Cyclone'),
#  (469, 'Iron Moon'),
#  (470, 'Ishtar Rocketeer'),
#  (471, 'Island Exorcist'),
#  (472, 'Italian African'),
#  (474, 'Jade Bunch'),
#  (475, 'Japanese Run'),
#  (476, 'Jason Trap'),
#  (477, 'Jawbreaker Brooklyn'),
#  (478, 'Jaws Harry'),
#  (479, 'Jedi Beneath'),
#  (480, 'Jeepers Wedding'),
#  (482, 'Jeopardy Encino'),
#  (483, 'Jericho Mulan'),
#  (484, 'Jerk Paycheck'),
#  (485, 'Jersey Sassy'),
#  (486, 'Jet Neighbors'),
#  (487, 'Jingle Sagebrush'),
#  (488, 'Joon Northwest'),
#  (489, 'Juggler Hardly'),
#  (490, 'Jumanji Blade'),
#  (491, 'Jumping Wrath'),
#  (492, 'Jungle Closer'),
#  (495, 'Kentuckian Giant'),
#  (497, 'Kill Brotherhood'),
#  (498, 'Killer Innocent'),
#  (499, 'King Evolution'),
#  (500, 'Kiss Glory'),
#  (501, 'Kissing Dolls'),
#  (503, 'Kramer Chocolate'),
#  (505, 'Labyrinth League'),
#  (753, 'Rush Goodfellas'),
#  (506, 'Lady Stage'),
#  (507, 'Ladybugs Armageddon'),
#  (508, 'Lambs Cincinatti'),
#  (509, 'Language Cowboy'),
#  (511, 'Lawrence Love'),
#  (512, 'League Hellfighters'),
#  (513, 'Leathernecks Dwarfs'),
#  (514, 'Lebowski Soldiers'),
#  (515, 'Legally Secretary'),
#  (516, 'Legend Jedi'),
#  (517, 'Lesson Cleopatra'),
#  (519, 'Liberty Magnificent'),
#  (521, 'Lies Treatment'),
#  (523, 'Lights Deer'),
#  (524, 'Lion Uncut'),
#  (525, 'Loathing Legally'),
#  (527, 'Lola Agent'),
#  (528, 'Lolita World'),
#  (529, 'Lonely Elephant'),
#  (530, 'Lord Arizona'),
#  (531, 'Lose Inch'),
#  (532, 'Loser Hustler'),
#  (533, 'Lost Bird'),
#  (534, 'Louisiana Harry'),
#  (536, 'Lovely Jingle'),
#  (537, 'Lover Truman'),
#  (538, 'Loverboy Attacks'),
#  (539, 'Luck Opus'),
#  (540, 'Lucky Flying'),
#  (541, 'Luke Mummy'),
#  (542, 'Lust Lock'),
#  (546, 'Madre Gables'),
#  (547, 'Magic Mallrats'),
#  (548, 'Magnificent Chitty'),
#  (549, 'Magnolia Forrester'),
#  (550, 'Maguire Apache'),
#  (552, 'Majestic Floats'),
#  (553, 'Maker Gables'),
#  (555, 'Mallrats United'),
#  (556, 'Maltese Hope'),
#  (557, 'Manchurian Curtain'),
#  (558, 'Mannequin Worst'),
#  (562, 'Masked Bubble'),
#  (564, 'Massage Image'),
#  (565, 'Matrix Snowman'),
#  (566, 'Maude Mod'),
#  (567, 'Meet Chocolate'),
#  (568, 'Memento Zoolander'),
#  (569, 'Menagerie Rushmore'),
#  (570, 'Mermaid Insects'),
#  (571, 'Metal Armageddon'),
#  (572, 'Metropolis Coma'),
#  (573, 'Microcosmos Paradise'),
#  (574, 'Midnight Westward'),
#  (575, 'Midsummer Groundhog'),
#  (576, 'Mighty Luck'),
#  (578, 'Million Ace'),
#  (579, 'Minds Truman'),
#  (580, 'Mine Titans'),
#  (581, 'Minority Kiss'),
#  (583, 'Mission Zoolander'),
#  (584, 'Mixed Doors'),
#  (585, 'Mob Duffel'),
#  (586, 'Mockingbird Hollywood'),
#  (588, 'Model Fish'),
#  (589, 'Modern Dorado'),
#  (590, 'Money Harold'),
#  (591, 'Monsoon Cause'),
#  (592, 'Monster Spartacus'),
#  (593, 'Monterey Labyrinth'),
#  (594, 'Montezuma Command'),
#  (595, 'Moon Bunch'),
#  (600, 'Motions Details'),
#  (601, 'Moulin Wake'),
#  (602, 'Mourning Purple'),
#  (603, 'Movie Shakespeare'),
#  (604, 'Mulan Moon'),
#  (605, 'Mulholland Beast'),
#  (606, 'Mummy Creatures'),
#  (607, 'Muppet Mile'),
#  (609, 'Muscle Bright'),
#  (610, 'Music Boondock'),
#  (611, 'Musketeers Wait'),
#  (612, 'Mussolini Spoilers'),
#  (613, 'Mystic Truman'),
#  (614, 'Name Detective'),
#  (615, 'Nash Chocolat'),
#  (616, 'National Story'),
#  (618, 'Necklace Outbreak'),
#  (619, 'Neighbors Charade'),
#  (620, 'Nemo Campus'),
#  (621, 'Network Peak'),
#  (622, 'Newsies Story'),
#  (623, 'Newton Labyrinth'),
#  (624, 'Nightmare Chill'),
#  (625, 'None Spiking'),
#  (626, 'Noon Papi'),
#  (627, 'North Tequila'),
#  (628, 'Northwest Polish'),
#  (629, 'Notorious Reunion'),
#  (630, 'Notting Speakeasy'),
#  (631, 'Novocaine Flight'),
#  (632, 'Nuts Ties'),
#  (633, 'October Submarine'),
#  (634, 'Odds Boogie'),
#  (635, 'Oklahoma Jumanji'),
#  (636, 'Oleander Clue'),
#  (638, 'Operation Operation'),
#  (640, 'Opus Ice'),
#  (641, 'Orange Grapes'),
#  (642, 'Order Betrayed'),
#  (643, 'Orient Closer'),
#  (644, 'Oscar Gold'),
#  (646, 'Outbreak Divine'),
#  (647, 'Outfield Massacre'),
#  (648, 'Outlaw Hanky'),
#  (649, 'Oz Liaisons'),
#  (650, 'Pacific Amistad'),
#  (651, 'Packer Madigan'),
#  (652, 'Pajama Jawbreaker'),
#  (653, 'Panic Club'),
#  (654, 'Panky Submarine'),
#  (655, 'Panther Reds'),
#  (656, 'Papi Necklace'),
#  (657, 'Paradise Sabrina'),
#  (658, 'Paris Weekend'),
#  (659, 'Park Citizen'),
#  (660, 'Party Knock'),
#  (661, 'Past Suicides'),
#  (662, 'Paths Control'),
#  (663, 'Patient Sister'),
#  (664, 'Patriot Roman'),
#  (665, 'Patton Interview'),
#  (666, 'Paycheck Wait'),
#  (668, 'Peak Forever'),
#  (669, 'Pearl Destiny'),
#  (670, 'Pelican Comforts'),
#  (671, 'Perdition Fargo'),
#  (673, 'Personal Ladybugs'),
#  (674, 'Pet Haunting'),
#  (675, 'Phantom Glory'),
#  (676, 'Philadelphia Wife'),
#  (677, 'Pianist Outfield'),
#  (678, 'Pickup Driving'),
#  (679, 'Pilot Hoosiers'),
#  (680, 'Pinocchio Simon'),
#  (681, 'Pirates Roxanne'),
#  (682, 'Pittsburgh Hunchback'),
#  (683, 'Pity Bound'),
#  (684, 'Pizza Jumanji'),
#  (686, 'Pluto Oleander'),
#  (687, 'Pocus Pulp'),
#  (688, 'Polish Brooklyn'),
#  (690, 'Pond Seattle'),
#  (691, 'Poseidon Forever'),
#  (692, 'Potluck Mixed'),
#  (694, 'Prejudice Oleander'),
#  (695, 'President Bang'),
#  (697, 'Primary Glass'),
#  (699, 'Private Drop'),
#  (700, 'Prix Undefeated'),
#  (701, 'Psycho Shrunk'),
#  (702, 'Pulp Beverly'),
#  (703, 'Punk Divorce'),
#  (704, 'Pure Runner'),
#  (705, 'Purple Movie'),
#  (706, 'Queen Luke'),
#  (707, 'Quest Mussolini'),
#  (708, 'Quills Bull'),
#  (709, 'Racer Egg'),
#  (710, 'Rage Games'),
#  (711, 'Raging Airplane'),
#  (712, 'Raiders Antitrust'),
#  (713, 'Rainbow Shock'),
#  (714, 'Random Go'),
#  (715, 'Range Moonwalker'),
#  (716, 'Reap Unfaithful'),
#  (718, 'Rebel Airport'),
#  (719, 'Records Zorro'),
#  (720, 'Redemption Comforts'),
#  (721, 'Reds Pocus'),
#  (722, 'Reef Salute'),
#  (723, 'Reign Gentlemen'),
#  (724, 'Remember Diary'),
#  (725, 'Requiem Tycoon'),
#  (726, 'Reservoir Adaptation'),
#  (727, 'Resurrection Silverado'),
#  (729, 'Rider Caddyshack'),
#  (730, 'Ridgemont Submarine'),
#  (731, 'Right Cranes'),
#  (733, 'River Outlaw'),
#  (734, 'Road Roxanne'),
#  (735, 'Robbers Joon'),
#  (736, 'Robbery Bright'),
#  (737, 'Rock Instinct'),
#  (738, 'Rocketeer Mother'),
#  (739, 'Rocky War'),
#  (740, 'Rollercoaster Bringing'),
#  (742, 'Roof Champion'),
#  (743, 'Room Roman'),
#  (744, 'Roots Remember'),
#  (747, 'Roxanne Rebel'),
#  (748, 'Rugrats Shakespeare'),
#  (749, 'Rules Human'),
#  (751, 'Runaway Tenenbaums'),
#  (752, 'Runner Madigan'),
#  (754, 'Rushmore Mermaid'),
#  (755, 'Sabrina Midnight'),
#  (757, 'Sagebrush Clueless'),
#  (758, 'Saints Bride'),
#  (761, 'Santa Paris'),
#  (762, 'Sassy Packer'),
#  (763, 'Satisfaction Confidential'),
#  (765, 'Saturn Name'),
#  (766, 'Savannah Town'),
#  (767, 'Scalawag Duck'),
#  (768, 'Scarface Bang'),
#  (769, 'School Jacket'),
#  (770, 'Scissorhands Slums'),
#  (788, 'Ship Wonderland'),
#  (771, 'Scorpion Apollo'),
#  (772, 'Sea Virgin'),
#  (773, 'Seabiscuit Punk'),
#  (774, 'Searchers Wait'),
#  (775, 'Seattle Expecations'),
#  (776, 'Secret Groundhog'),
#  (777, 'Secretary Rouge'),
#  (778, 'Secrets Paradise'),
#  (779, 'Sense Greek'),
#  (780, 'Sensibility Rear'),
#  (781, 'Seven Swarm'),
#  (782, 'Shakespeare Saddle'),
#  (783, 'Shane Darkness'),
#  (784, 'Shanghai Tycoon'),
#  (785, 'Shawshank Bubble'),
#  (786, 'Shepherd Midsummer'),
#  (787, 'Shining Roses'),
#  (789, 'Shock Cabin'),
#  (790, 'Shootist Superfly'),
#  (791, 'Show Lord'),
#  (792, 'Shrek License'),
#  (793, 'Shrunk Divine'),
#  (794, 'Side Ark'),
#  (795, 'Siege Madre'),
#  (796, 'Sierra Divide'),
#  (797, 'Silence Kane'),
#  (798, 'Silverado Goldfinger'),
#  (799, 'Simon North'),
#  (800, 'Sinners Atlantis'),
#  (801, 'Sister Freddy'),
#  (802, 'Sky Miracle'),
#  (803, 'Slacker Liaisons'),
#  (804, 'Sleeping Suspects'),
#  (806, 'Sleepy Japanese'),
#  (807, 'Sleuth Orient'),
#  (808, 'Sling Luke'),
#  (809, 'Slipper Fidelity'),
#  (811, 'Smile Earring'),
#  (812, 'Smoking Barbarella'),
#  (813, 'Smoochy Control'),
#  (814, 'Snatch Slipper'),
#  (815, 'Snatchers Montezuma'),
#  (817, 'Soldiers Evolution'),
#  (818, 'Something Duck'),
#  (819, 'Song Hedwig'),
#  (820, 'Sons Interview'),
#  (821, 'Sorority Queen'),
#  (822, 'Soup Wisdom'),
#  (823, 'South Wait'),
#  (824, 'Spartacus Cheaper'),
#  (825, 'Speakeasy Date'),
#  (826, 'Speed Suit'),
#  (827, 'Spice Sorority'),
#  (829, 'Spinal Rocky'),
#  (830, 'Spirit Flintstones'),
#  (831, 'Spirited Casualties'),
#  (832, 'Splash Gump'),
#  (833, 'Splendor Patton'),
#  (835, 'Spy Mile'),
#  (836, 'Squad Fish'),
#  (837, 'Stage World'),
#  (838, 'Stagecoach Armageddon'),
#  (839, 'Stallion Sundance'),
#  (840, 'Stampede Disturbing'),
#  (841, 'Star Operation'),
#  (842, 'State Wasteland'),
#  (844, 'Steers Armageddon'),
#  (845, 'Stepmom Dream'),
#  (846, 'Sting Personal'),
#  (847, 'Stock Glass'),
#  (848, 'Stone Fire'),
#  (849, 'Storm Happiness'),
#  (850, 'Story Side'),
#  (851, 'Straight Hours'),
#  (852, 'Strangelove Desire'),
#  (853, 'Stranger Strangers'),
#  (890, 'Tights Dawn'),
#  (855, 'Streak Ridgemont'),
#  (856, 'Streetcar Intentions'),
#  (857, 'Strictly Scarface'),
#  (858, 'Submarine Bed'),
#  (860, 'Suicides Silence'),
#  (862, 'Summer Scarface'),
#  (863, 'Sun Confessions'),
#  (865, 'Sunrise League'),
#  (867, 'Super Wyoming'),
#  (868, 'Superfly Trip'),
#  (871, 'Sweden Shining'),
#  (891, 'Timberland Sky'),
#  (873, 'Sweethearts Suspects'),
#  (874, 'Tadpole Park'),
#  (875, 'Talented Homicide'),
#  (876, 'Tarzan Videotape'),
#  (877, 'Taxi Kick'),
#  (878, 'Teen Apollo'),
#  (880, 'Telemark Heartbreakers'),
#  (881, 'Temple Attraction'),
#  (882, 'Tenenbaums Command'),
#  (883, 'Tequila Past'),
#  (884, 'Terminator Club'),
#  (885, 'Texas Watch'),
#  (886, 'Theory Mermaid'),
#  (887, 'Thief Pelican'),
#  (888, 'Thin Sagebrush'),
#  (889, 'Ties Hunger'),
#  (892, 'Titanic Boondock'),
#  (893, 'Titans Jerk'),
#  (894, 'Tomatoes Hellfighters'),
#  (896, 'Tootsie Pilot'),
#  (898, 'Tourist Pelican'),
#  (899, 'Towers Hurricane'),
#  (900, 'Town Ark'),
#  (901, 'Tracy Cider'),
#  (902, 'Trading Pinocchio'),
#  (903, 'Traffic Hobbit'),
#  (904, 'Train Bunch'),
#  (905, 'Trainspotting Strangers'),
#  (906, 'Tramp Others'),
#  (907, 'Translation Summer'),
#  (908, 'Trap Guys'),
#  (909, 'Treasure Command'),
#  (910, 'Treatment Jekyll'),
#  (912, 'Trojan Tomorrow'),
#  (913, 'Troopers Metal'),
#  (914, 'Trouble Date'),
#  (915, 'Truman Crazy'),
#  (916, 'Turn Star'),
#  (917, 'Tuxedo Mile'),
#  (918, 'Twisted Pirates'),
#  (919, 'Tycoon Gathering'),
#  (920, 'Unbreakable Karate'),
#  (921, 'Uncut Suicides'),
#  (923, 'Unfaithful Kill'),
#  (924, 'Unforgiven Zoolander'),
#  (925, 'United Pilot'),
#  (926, 'Untouchables Sunrise'),
#  (927, 'Uprising Uptown'),
#  (928, 'Uptown Young'),
#  (930, 'Vacation Boondock'),
#  (931, 'Valentine Vanishing'),
#  (932, 'Valley Packer'),
#  (933, 'Vampire Whale'),
#  (934, 'Vanilla Day'),
#  (935, 'Vanished Garden'),
#  (936, 'Vanishing Rocky'),
#  (937, 'Varsity Trip'),
#  (938, 'Velvet Terminator'),
#  (939, 'Vertigo Northwest'),
#  (940, 'Victory Academy'),
#  (941, 'Videotape Arsenic'),
#  (942, 'Vietnam Smoochy'),
#  (943, 'Villain Desperate'),
#  (944, 'Virgin Daisy'),
#  (945, 'Virginian Pluto'),
#  (946, 'Virtual Spoilers'),
#  (947, 'Vision Torque'),
#  (948, 'Voice Peach'),
#  (949, 'Volcano Texas'),
#  (950, 'Volume House'),
#  (951, 'Voyage Legally'),
#  (952, 'Wagon Jaws'),
#  (953, 'Wait Cider'),
#  (954, 'Wake Jaws'),
#  (955, 'Walls Artist'),
#  (956, 'Wanda Chamber'),
#  (957, 'War Notting'),
#  (958, 'Wardrobe Phantom'),
#  (959, 'Warlock Werewolf'),
#  (960, 'Wars Pluto'),
#  (961, 'Wash Heavenly'),
#  (963, 'Watch Tracy'),
#  (965, 'Watership Frontier'),
#  (966, 'Wedding Apollo'),
#  (967, 'Weekend Personal'),
#  (968, 'Werewolf Lola'),
#  (970, 'Westward Seabiscuit'),
#  (971, 'Whale Bikini'),
#  (972, 'Whisperer Giant'),
#  (973, 'Wife Turn'),
#  (974, 'Wild Apollo'),
#  (975, 'Willow Tracy'),
#  (976, 'Wind Phantom'),
#  (977, 'Window Side'),
#  (978, 'Wisdom Worker'),
#  (980, 'Wizard Coldblooded'),
#  (981, 'Wolves Desire'),
#  (982, 'Women Dorado'),
#  (983, 'Won Dares'),
#  (984, 'Wonderful Drop'),
#  (986, 'Wonka Sea'),
#  (988, 'Worker Tarzan'),
#  (989, 'Working Microcosmos'),
#  (990, 'World Leathernecks'),
#  (991, 'Worst Banger'),
#  (993, 'Wrong Behavior'),
#  (994, 'Wyoming Storm'),
#  (996, 'Young Language'),
#  (997, 'Youth Kick'),
#  (998, 'Zhivago Core'),
#  (999, 'Zoolander Fiction')]

# %% [markdown]
# [Helpful Hints](https://youtu.be/MWpp2ioeAb8)
#
#
# ---
#
# # 2
#
# ### Which customers (name, phone number) have outstanding rentals (film name, rental_date)?

# %%
# %%sql
# EXPLAIN
# SELECT c.first_name, c.last_name, a.phone
# from address a
# JOIN customer as c USING (address_id)
# WHERE last_name in (
#     SELECT last_name
#     from rental join customer using (customer_id)
#     WHERE rental.return_date is NULL
# );
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 14 rows affected.
# [('Hash Join  (cost=356.57..374.69 rows=183 width=25)',),
#  ('  Hash Cond: (a.address_id = c.address_id)',),
#  ('  ->  Seq Scan on address a  (cost=0.00..14.03 rows=603 width=16)',),
#  ('  ->  Hash  (cost=354.28..354.28 rows=183 width=15)',),
#  ('        ->  Hash Semi Join  (cost=335.69..354.28 rows=183 width=15)',),
#  ('              Hash Cond: ((c.last_name)::text = (customer.last_name)::text)',),
#  ('              ->  Seq Scan on customer c  (cost=0.00..14.99 rows=599 width=15)',),
#  ('              ->  Hash  (cost=333.40..333.40 rows=183 width=7)',),
#  ('                    ->  Hash Join  (cost=22.48..333.40 rows=183 width=7)',),
#  ('                          Hash Cond: (rental.customer_id = customer.customer_id)',),
#  ('                          ->  Seq Scan on rental  (cost=0.00..310.44 rows=183 width=2)',),
#  ('                                Filter: (return_date IS NULL)',),
#  ('                          ->  Hash  (cost=14.99..14.99 rows=599 width=11)',),
#  ('                                ->  Seq Scan on customer  (cost=0.00..14.99 rows=599 width=11)',)]

# %%
# %%sql
# SELECT c.first_name, c.last_name, a.phone
# from address a
# JOIN customer as c USING (address_id)
# WHERE last_name in (
#     SELECT last_name
#     from rental join customer using (customer_id)
#     WHERE rental.return_date is NULL
# );
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 159 rows affected.
# [('Elizabeth', 'Brown', '10655648674'),
#  ('Margaret', 'Moore', '380657522649'),
#  ('Lisa', 'Anderson', '635297277345'),
#  ('Betty', 'White', '517338314235'),
#  ('Helen', 'Harris', '990911107354'),
#  ('Michelle', 'Clark', '892775750063'),
#  ('Laura', 'Rodriguez', '161968374323'),
#  ('Sarah', 'Lewis', '902731229323'),
#  ('Cynthia', 'Young', '678220867005'),
#  ('Angela', 'Hernandez', '18461860151'),
#  ('Anna', 'Hill', '911872220378'),
#  ('Stephanie', 'Mitchell', '42384721397'),
#  ('Carolyn', 'Perez', '471675840679'),
#  ('Christine', 'Roberts', '539758313890'),
#  ('Marie', 'Turner', '177727722820'),
#  ('Julie', 'Sanchez', '680428310138'),
#  ('Heather', 'Morris', '697760867968'),
#  ('Gloria', 'Cook', '347487831378'),
#  ('Jean', 'Bell', '212869228936'),
#  ('Mildred', 'Bailey', '250767749542'),
#  ('Judith', 'Cox', '333489324603'),
#  ('Judy', 'Gray', '107137400143'),
#  ('Beverly', 'Brooks', '427454485876'),
#  ('Tammy', 'Sanders', '251164340471'),
#  ('Marilyn', 'Ross', '701457319790'),
#  ('Louise', 'Jenkins', '800716535041'),
#  ('Wanda', 'Patterson', '198123170793'),
#  ('Lois', 'Butler', '345679835036'),
#  ('Norma', 'Gonzales', '835433605312'),
#  ('Emily', 'Diaz', '333339908719'),
#  ('Robin', 'Hayes', '942570536750'),
#  ('Peggy', 'Myers', '196568435814'),
#  ('Florence', 'Woods', '330838016880'),
#  ('Tracy', 'Cole', '371490777743'),
#  ('Carmen', 'Owens', '272234298332'),
#  ('Grace', 'Ellis', '886636413768'),
#  ('Wendy', 'Harrison', '867546627903'),
#  ('Sylvia', 'Ortiz', '765345144779'),
#  ('Juanita', 'Mason', '90921003005'),
#  ('April', 'Burns', '581174211853'),
#  ('Alicia', 'Mills', '761379480249'),
#  ('Gail', 'Knight', '904253967161'),
#  ('Lauren', 'Hudson', '168476538960'),
#  ('Cathy', 'Spencer', '819416131190'),
#  ('Regina', 'Berry', '201705577290'),
#  ('Annette', 'Olson', '230250973122'),
#  ('Marion', 'Snyder', '391065549876'),
#  ('Stacy', 'Cunningham', '104150372603'),
#  ('Ana', 'Bradley', '72136330362'),
#  ('Holly', 'Fox', '760171523969'),
#  ('Melanie', 'Armstrong', '650752094490'),
#  ('Yolanda', 'Weaver', '352469351088'),
#  ('Jeanette', 'Greene', '812824036424'),
#  ('Laurie', 'Lawrence', '956188728558'),
#  ('Katie', 'Elliott', '940830176580'),
#  ('Beth', 'Franklin', '470884141195'),
#  ('Jeanne', 'Lawson', '764477681869'),
#  ('Lucy', 'Wheeler', '49677664184'),
#  ('Stacey', 'Montgomery', '408304391718'),
#  ('Gina', 'Williamson', '584316724815'),
#  ('Kristin', 'Johnston', '785881412500'),
#  ('Jessie', 'Banks', '352679173732'),
#  ('Natalie', 'Meyer', '873492228462'),
#  ('Willie', 'Howell', '991802825778'),
#  ('Colleen', 'Burton', '669828224459'),
#  ('Allison', 'Stanley', '594319417514'),
#  ('Tamara', 'Nguyen', '22326410776'),
#  ('Claudia', 'Fuller', '630424482919'),
#  ('Marcia', 'Dean', '727785483194'),
#  ('Viola', 'Hanson', '569868543137'),
#  ('Courtney', 'Day', '890289150158'),
#  ('Vickie', 'Brewer', '567359279425'),
#  ('Mattie', 'Hoffman', '246810237916'),
#  ('Hilda', 'Hopkins', '322888976727'),
#  ('Gwendolyn', 'May', '303967439816'),
#  ('Margie', 'Wade', '192459639410'),
#  ('Cassandra', 'Walters', '685010736240'),
#  ('Naomi', 'Jennings', '959949395183'),
#  ('Dianne', 'Shelton', '117592274996'),
#  ('Jenny', 'Castro', '62781725285'),
#  ('Sonia', 'Gregory', '195003555232'),
#  ('Becky', 'Miles', '648482415405'),
#  ('Daisy', 'Bates', '816436065431'),
#  ('Ramona', 'Hale', '429925609431'),
#  ('John', 'Farnsworth', '51917807050'),
#  ('Kenneth', 'Gooden', '508800331065'),
#  ('Edward', 'Baugh', '46568045367'),
#  ('Gary', 'Coy', '168884817145'),
#  ('Larry', 'Thrasher', '834418779292'),
#  ('Scott', 'Shelley', '165450987037'),
#  ('Raymond', 'Mcwhorter', '834626715837'),
#  ('Gregory', 'Mauldin', '80303246192'),
#  ('Joshua', 'Mark', '869507847714'),
#  ('Jerry', 'Jordon', '647899404952'),
#  ('Joe', 'Gilliland', '53912826864'),
#  ('Albert', 'Crouse', '256546485220'),
#  ('Justin', 'Ngo', '764680915323'),
#  ('Terry', 'Grissom', '142596392389'),
#  ('Willie', 'Markham', '296394569728'),
#  ('Lawrence', 'Lawton', '845378657301'),
#  ('Brandon', 'Huey', '99883471275'),
#  ('Fred', 'Wheat', '561729882725'),
#  ('Louis', 'Leone', '45554316010'),
#  ('Jeremy', 'Hurtado', '600264533987'),
#  ('Craig', 'Morrell', '426255288071'),
#  ('Chris', 'Brothers', '537374465982'),
#  ('Leonard', 'Schofield', '779461480495'),
#  ('Curtis', 'Irby', '615964523510'),
#  ('Norman', 'Currier', '598912394463'),
#  ('Allen', 'Butterfield', '129953030512'),
#  ('Travis', 'Estep', '214976066017'),
#  ('Lee', 'Hawks', '270456873752'),
#  ('Melvin', 'Ellington', '368284120423'),
#  ('Kyle', 'Spurlock', '736517327853'),
#  ('Joel', 'Francisco', '82619513349'),
#  ('Barry', 'Lovelace', '689681677428'),
#  ('Bernard', 'Colby', '82088937724'),
#  ('Mario', 'Cheatham', '406784385440'),
#  ('Miguel', 'Betancourt', '72524459905'),
#  ('Jay', 'Robb', '834061016202'),
#  ('Tom', 'Milner', '985109775584'),
#  ('Bill', 'Gavin', '924663855568'),
#  ('Greg', 'Robins', '206060652238'),
#  ('Dustin', 'Gillette', '131912793873'),
#  ('Derrick', 'Bourque', '856872225376'),
#  ('Zachary', 'Hite', '191958435142'),
#  ('Brent', 'Harkins', '854259976812'),
#  ('Charlie', 'Bess', '962020153680'),
#  ('Tyler', 'Wren', '211256301880'),
#  ('Gilbert', 'Sledge', '959467760895'),
#  ('Rafael', 'Abney', '82671830126'),
#  ('Milton', 'Howland', '441628280920'),
#  ('Cecil', 'Vines', '879347453467'),
#  ('Elmer', 'Noe', '448876499197'),
#  ('Roland', 'South', '25865528181'),
#  ('Adrian', 'Clary', '182059202712'),
#  ('Cory', 'Meehan', '338244023543'),
#  ('Darryl', 'Ashcraft', '717566026669'),
#  ('Neil', 'Renner', '478380208348'),
#  ('Jessie', 'Milam', '383353187467'),
#  ('Christian', 'Jung', '122981120653'),
#  ('Clinton', 'Buford', '484500282381'),
#  ('Allan', 'Cornish', '50898428626'),
#  ('Guy', 'Brownlee', '978430786151'),
#  ('Dwayne', 'Olvera', '62127829280'),
#  ('Felix', 'Gaffney', '107092893983'),
#  ('Jordan', 'Archuleta', '817740355461'),
#  ('Ian', 'Still', '239357986667'),
#  ('Alberto', 'Henning', '618156722572'),
#  ('Ivan', 'Cromwell', '203804046132'),
#  ('Morris', 'Mccarter', '278669994384'),
#  ('Daryl', 'Larue', '954786054144'),
#  ('Andy', 'Vanhorn', '995527378381'),
#  ('Perry', 'Swafford', '914466027044'),
#  ('Sergio', 'Stanfield', '387448063440'),
#  ('Seth', 'Hannon', '864392582257'),
#  ('Terrance', 'Roush', '437829801725'),
#  ('Enrique', 'Forsythe', '199514580428'),
#  ('Freddie', 'Duggan', '644021380889')]

# %% [markdown]
# # 3
#
# ### List the movies that are not categorized as children's movies.

# %%
# %%sql
# EXPLAIN
# select f.film_id, f.title
# from film f
# where f.film_id not in (
#     select film_id
#     from category c join film_category using (category_id)
#     where c.name = 'Children'
# );
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 9 rows affected.
# [('Seq Scan on film f  (cost=20.68..87.18 rows=500 width=19)',),
#  ('  Filter: (NOT (hashed SubPlan 1))',),
#  ('  SubPlan 1',),
#  ('    ->  Hash Join  (cost=1.21..20.53 rows=62 width=2)',),
#  ('          Hash Cond: (film_category.category_id = c.category_id)',),
#  ('          ->  Seq Scan on film_category  (cost=0.00..16.00 rows=1000 width=4)',),
#  ('          ->  Hash  (cost=1.20..1.20 rows=1 width=4)',),
#  ('                ->  Seq Scan on category c  (cost=0.00..1.20 rows=1 width=4)',),
#  ("                      Filter: ((name)::text = 'Children'::text)",)]

# %%
# %%sql
# select f.film_id, f.title
# from film f
# where f.film_id not in (
#     select film_id
#     from category c join film_category using (category_id)
#     where c.name = 'Children'
# );
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 940 rows affected.
# [(133, 'Chamber Italian'),
#  (384, 'Grosse Wonderful'),
#  (8, 'Airport Pollock'),
#  (98, 'Bright Encounters'),
#  (1, 'Academy Dinosaur'),
#  (2, 'Ace Goldfinger'),
#  (3, 'Adaptation Holes'),
#  (4, 'Affair Prejudice'),
#  (5, 'African Egg'),
#  (6, 'Agent Truman'),
#  (7, 'Airplane Sierra'),
#  (9, 'Alabama Devil'),
#  (10, 'Aladdin Calendar'),
#  (11, 'Alamo Videotape'),
#  (12, 'Alaska Phantom'),
#  (213, 'Date Speed'),
#  (13, 'Ali Forever'),
#  (14, 'Alice Fantasia'),
#  (15, 'Alien Center'),
#  (16, 'Alley Evolution'),
#  (17, 'Alone Trip'),
#  (18, 'Alter Victory'),
#  (19, 'Amadeus Holy'),
#  (20, 'Amelie Hellfighters'),
#  (21, 'American Circus'),
#  (22, 'Amistad Midsummer'),
#  (23, 'Anaconda Confessions'),
#  (24, 'Analyze Hoosiers'),
#  (25, 'Angels Life'),
#  (26, 'Annie Identity'),
#  (27, 'Anonymous Human'),
#  (28, 'Anthem Luke'),
#  (29, 'Antitrust Tomatoes'),
#  (30, 'Anything Savannah'),
#  (31, 'Apache Divine'),
#  (32, 'Apocalypse Flamingos'),
#  (33, 'Apollo Teen'),
#  (34, 'Arabia Dogma'),
#  (35, 'Arachnophobia Rollercoaster'),
#  (36, 'Argonauts Town'),
#  (37, 'Arizona Bang'),
#  (38, 'Ark Ridgemont'),
#  (39, 'Armageddon Lost'),
#  (40, 'Army Flintstones'),
#  (41, 'Arsenic Independence'),
#  (42, 'Artist Coldblooded'),
#  (265, 'Dying Maker'),
#  (43, 'Atlantis Cause'),
#  (44, 'Attacks Hate'),
#  (45, 'Attraction Newton'),
#  (46, 'Autumn Crow'),
#  (47, 'Baby Hall'),
#  (49, 'Badman Dawn'),
#  (50, 'Baked Cleopatra'),
#  (126, 'Casualties Encino'),
#  (51, 'Balloon Homeward'),
#  (52, 'Ballroom Mockingbird'),
#  (53, 'Bang Kwai'),
#  (54, 'Banger Pinocchio'),
#  (55, 'Barbarella Streetcar'),
#  (56, 'Barefoot Manchurian'),
#  (57, 'Basic Easy'),
#  (58, 'Beach Heartbreakers'),
#  (60, 'Beast Hunchback'),
#  (61, 'Beauty Grease'),
#  (62, 'Bed Highball'),
#  (63, 'Bedazzled Married'),
#  (64, 'Beethoven Exorcist'),
#  (65, 'Behavior Runaway'),
#  (67, 'Berets Agent'),
#  (69, 'Beverly Outlaw'),
#  (70, 'Bikini Borrowers'),
#  (71, 'Bilko Anonymous'),
#  (72, 'Bill Others'),
#  (73, 'Bingo Talented'),
#  (74, 'Birch Antitrust'),
#  (75, 'Bird Independence'),
#  (76, 'Birdcage Casper'),
#  (77, 'Birds Perdition'),
#  (78, 'Blackout Private'),
#  (79, 'Blade Polish'),
#  (80, 'Blanket Beverly'),
#  (81, 'Blindness Gun'),
#  (82, 'Blood Argonauts'),
#  (83, 'Blues Instinct'),
#  (84, 'Boiled Dares'),
#  (85, 'Bonnie Holocaust'),
#  (86, 'Boogie Amelie'),
#  (87, 'Boondock Ballroom'),
#  (88, 'Born Spinal'),
#  (89, 'Borrowers Bedazzled'),
#  (90, 'Boulevard Mob'),
#  (91, 'Bound Cheaper'),
#  (92, 'Bowfinger Gables'),
#  (93, 'Brannigan Sunrise'),
#  (94, 'Braveheart Human'),
#  (95, 'Breakfast Goldfinger'),
#  (96, 'Breaking Home'),
#  (97, 'Bride Intrigue'),
#  (99, 'Bringing Hysterical'),
#  (100, 'Brooklyn Desert'),
#  (101, 'Brotherhood Blanket'),
#  (102, 'Bubble Grosse'),
#  (103, 'Bucket Brotherhood'),
#  (104, 'Bugsy Song'),
#  (105, 'Bull Shawshank'),
#  (106, 'Bulworth Commandments'),
#  (107, 'Bunch Minds'),
#  (108, 'Butch Panther'),
#  (109, 'Butterfly Chocolat'),
#  (111, 'Caddyshack Jedi'),
#  (112, 'Calendar Gunfight'),
#  (113, 'California Birds'),
#  (114, 'Camelot Vacation'),
#  (115, 'Campus Remember'),
#  (116, 'Candidate Perdition'),
#  (117, 'Candles Grapes'),
#  (118, 'Canyon Stock'),
#  (119, 'Caper Motions'),
#  (120, 'Caribbean Liberty'),
#  (121, 'Carol Texas'),
#  (122, 'Carrie Bunch'),
#  (123, 'Casablanca Super'),
#  (125, 'Cassidy Wyoming'),
#  (127, 'Cat Coneheads'),
#  (128, 'Catch Amistad'),
#  (129, 'Cause Date'),
#  (130, 'Celebrity Horn'),
#  (131, 'Center Dinosaur'),
#  (132, 'Chainsaw Uptown'),
#  (134, 'Champion Flatliners'),
#  (135, 'Chance Resurrection'),
#  (154, 'Clash Freddy'),
#  (136, 'Chaplin License'),
#  (137, 'Charade Duffel'),
#  (138, 'Chariots Conspiracy'),
#  (139, 'Chasing Fight'),
#  (140, 'Cheaper Clyde'),
#  (141, 'Chicago North'),
#  (142, 'Chicken Hellfighters'),
#  (143, 'Chill Luck'),
#  (144, 'Chinatown Gladiator'),
#  (145, 'Chisum Behavior'),
#  (146, 'Chitty Lock'),
#  (147, 'Chocolat Harry'),
#  (148, 'Chocolate Duck'),
#  (150, 'Cider Desire'),
#  (151, 'Cincinatti Whisperer'),
#  (153, 'Citizen Shrek'),
#  (155, 'Cleopatra Devil'),
#  (156, 'Clerks Angels'),
#  (158, 'Clones Pinocchio'),
#  (159, 'Closer Bang'),
#  (160, 'Club Graffiti'),
#  (161, 'Clue Grail'),
#  (162, 'Clueless Bucket'),
#  (163, 'Clyde Theory'),
#  (164, 'Coast Rainbow'),
#  (184, 'Core Suit'),
#  (165, 'Coldblooded Darling'),
#  (166, 'Color Philadelphia'),
#  (167, 'Coma Head'),
#  (169, 'Comforts Rush'),
#  (170, 'Command Darling'),
#  (171, 'Commandments Express'),
#  (172, 'Coneheads Smoochy'),
#  (173, 'Confessions Maguire'),
#  (174, 'Confidential Interview'),
#  (175, 'Confused Candles'),
#  (176, 'Congeniality Quest'),
#  (177, 'Connecticut Tramp'),
#  (178, 'Connection Microcosmos'),
#  (179, 'Conquerer Nuts'),
#  (180, 'Conspiracy Spirit'),
#  (181, 'Contact Anonymous'),
#  (182, 'Control Anthem'),
#  (183, 'Conversation Downhill'),
#  (185, 'Cowboy Doom'),
#  (186, 'Craft Outfield'),
#  (187, 'Cranes Reservoir'),
#  (188, 'Crazy Home'),
#  (189, 'Creatures Shakespeare'),
#  (190, 'Creepers Kane'),
#  (192, 'Crossing Divorce'),
#  (193, 'Crossroads Casualties'),
#  (194, 'Crow Grease'),
#  (195, 'Crowds Telemark'),
#  (196, 'Cruelty Unforgiven'),
#  (197, 'Crusade Honey'),
#  (198, 'Crystal Breaking'),
#  (199, 'Cupboard Sinners'),
#  (200, 'Curtain Videotape'),
#  (201, 'Cyclone Family'),
#  (202, 'Daddy Pittsburgh'),
#  (203, 'Daisy Menagerie'),
#  (204, 'Dalmations Sweden'),
#  (205, 'Dances None'),
#  (206, 'Dancing Fever'),
#  (207, 'Dangerous Uptown'),
#  (208, 'Dares Pluto'),
#  (209, 'Darkness War'),
#  (210, 'Darko Dorado'),
#  (211, 'Darling Breaking'),
#  (212, 'Darn Forrester'),
#  (215, 'Dawn Pond'),
#  (216, 'Day Unfaithful'),
#  (217, 'Dazed Punk'),
#  (218, 'Deceiver Betrayed'),
#  (219, 'Deep Crusade'),
#  (220, 'Deer Virginian'),
#  (221, 'Deliverance Mulholland'),
#  (222, 'Desert Poseidon'),
#  (223, 'Desire Alien'),
#  (224, 'Desperate Trainspotting'),
#  (225, 'Destination Jerk'),
#  (226, 'Destiny Saturday'),
#  (227, 'Details Packer'),
#  (228, 'Detective Vision'),
#  (229, 'Devil Desire'),
#  (230, 'Diary Panic'),
#  (231, 'Dinosaur Secretary'),
#  (232, 'Dirty Ace'),
#  (233, 'Disciple Mother'),
#  (234, 'Disturbing Scarface'),
#  (235, 'Divide Monster'),
#  (236, 'Divine Resurrection'),
#  (237, 'Divorce Shining'),
#  (239, 'Dogma Family'),
#  (240, 'Dolls Rage'),
#  (241, 'Donnie Alley'),
#  (242, 'Doom Dancing'),
#  (243, 'Doors President'),
#  (244, 'Dorado Notting'),
#  (245, 'Double Wrath'),
#  (246, 'Doubtfire Labyrinth'),
#  (247, 'Downhill Enough'),
#  (248, 'Dozen Lion'),
#  (249, 'Dracula Crystal'),
#  (250, 'Dragon Squad'),
#  (251, 'Dragonfly Strangers'),
#  (252, 'Dream Pickup'),
#  (253, 'Drifter Commandments'),
#  (254, 'Driver Annie'),
#  (255, 'Driving Polish'),
#  (256, 'Drop Waterfront'),
#  (257, 'Drumline Cyclone'),
#  (258, 'Drums Dynamite'),
#  (259, 'Duck Racer'),
#  (260, 'Dude Blindness'),
#  (261, 'Duffel Apocalypse'),
#  (262, 'Dumbo Lust'),
#  (263, 'Durham Panky'),
#  (264, 'Dwarfs Alter'),
#  (266, 'Dynamite Tarzan'),
#  (267, 'Eagles Panky'),
#  (268, 'Early Home'),
#  (269, 'Earring Instinct'),
#  (270, 'Earth Vision'),
#  (271, 'Easy Gladiator'),
#  (272, 'Edge Kissing'),
#  (273, 'Effect Gladiator'),
#  (274, 'Egg Igby'),
#  (275, 'Egypt Tenenbaums'),
#  (276, 'Element Freddy'),
#  (277, 'Elephant Trojan'),
#  (278, 'Elf Murder'),
#  (279, 'Elizabeth Shane'),
#  (281, 'Encino Elf'),
#  (282, 'Encounters Curtain'),
#  (283, 'Ending Crowds'),
#  (284, 'Enemy Odds'),
#  (285, 'English Bulworth'),
#  (286, 'Enough Raging'),
#  (287, 'Entrapment Satisfaction'),
#  (288, 'Escape Metropolis'),
#  (289, 'Eve Resurrection'),
#  (290, 'Everyone Craft'),
#  (291, 'Evolution Alter'),
#  (292, 'Excitement Eve'),
#  (293, 'Exorcist Sting'),
#  (294, 'Expecations Natural'),
#  (295, 'Expendable Stallion'),
#  (296, 'Express Lonely'),
#  (297, 'Extraordinary Conquerer'),
#  (298, 'Eyes Driving'),
#  (299, 'Factory Dragon'),
#  (300, 'Falcon Volume'),
#  (301, 'Family Sweet'),
#  (302, 'Fantasia Park'),
#  (303, 'Fantasy Troopers'),
#  (305, 'Fatal Haunted'),
#  (306, 'Feathers Metal'),
#  (307, 'Fellowship Autumn'),
#  (308, 'Ferris Mother'),
#  (309, 'Feud Frogmen'),
#  (310, 'Fever Empire'),
#  (311, 'Fiction Christmas'),
#  (312, 'Fiddler Lost'),
#  (313, 'Fidelity Devil'),
#  (314, 'Fight Jawbreaker'),
#  (315, 'Finding Anaconda'),
#  (316, 'Fire Wolves'),
#  (317, 'Fireball Philadelphia'),
#  (318, 'Firehouse Vietnam'),
#  (319, 'Fish Opus'),
#  (320, 'Flamingos Connecticut'),
#  (321, 'Flash Wars'),
#  (322, 'Flatliners Killer'),
#  (323, 'Flight Lies'),
#  (324, 'Flintstones Happiness'),
#  (325, 'Floats Garden'),
#  (326, 'Flying Hook'),
#  (327, 'Fool Mockingbird'),
#  (329, 'Forrest Sons'),
#  (330, 'Forrester Comancheros'),
#  (331, 'Forward Temple'),
#  (332, 'Frankenstein Stranger'),
#  (333, 'Freaky Pocus'),
#  (334, 'Freddy Storm'),
#  (335, 'Freedom Cleopatra'),
#  (336, 'French Holiday'),
#  (337, 'Frida Slipper'),
#  (338, 'Frisco Forrest'),
#  (339, 'Frogmen Breaking'),
#  (340, 'Frontier Cabin'),
#  (341, 'Frost Head'),
#  (342, 'Fugitive Maguire'),
#  (345, 'Gables Metropolis'),
#  (346, 'Galaxy Sweethearts'),
#  (347, 'Games Bowfinger'),
#  (348, 'Gandhi Kwai'),
#  (349, 'Gangs Pride'),
#  (350, 'Garden Island'),
#  (351, 'Gaslight Crusade'),
#  (352, 'Gathering Calendar'),
#  (353, 'Gentlemen Stage'),
#  (355, 'Ghostbusters Elf'),
#  (357, 'Gilbert Pelican'),
#  (358, 'Gilmore Boiled'),
#  (359, 'Gladiator Westward'),
#  (360, 'Glass Dying'),
#  (361, 'Gleaming Jawbreaker'),
#  (362, 'Glory Tracy'),
#  (363, 'Go Purple'),
#  (364, 'Godfather Diary'),
#  (365, 'Gold River'),
#  (366, 'Goldfinger Sensibility'),
#  (367, 'Goldmine Tycoon'),
#  (368, 'Gone Trouble'),
#  (369, 'Goodfellas Salute'),
#  (371, 'Gosford Donnie'),
#  (372, 'Graceland Dynamite'),
#  (374, 'Graffiti Love'),
#  (375, 'Grail Frankenstein'),
#  (376, 'Grapes Fury'),
#  (377, 'Grease Youth'),
#  (378, 'Greatest North'),
#  (379, 'Greedy Roots'),
#  (380, 'Greek Everyone'),
#  (381, 'Grinch Massage'),
#  (382, 'Grit Clockwork'),
#  (383, 'Groove Fiction'),
#  (385, 'Groundhog Uncut'),
#  (386, 'Gump Date'),
#  (387, 'Gun Bonnie'),
#  (388, 'Gunfight Moon'),
#  (389, 'Gunfighter Mussolini'),
#  (390, 'Guys Falcon'),
#  (391, 'Half Outfield'),
#  (393, 'Halloween Nuts'),
#  (394, 'Hamlet Wisdom'),
#  (449, 'Identity Lover'),
#  (395, 'Handicap Boondock'),
#  (396, 'Hanging Deep'),
#  (397, 'Hanky October'),
#  (398, 'Hanover Galaxy'),
#  (399, 'Happiness United'),
#  (400, 'Hardly Robbers'),
#  (401, 'Harold French'),
#  (402, 'Harper Dying'),
#  (403, 'Harry Idaho'),
#  (404, 'Hate Handicap'),
#  (405, 'Haunted Antitrust'),
#  (406, 'Haunting Pianist'),
#  (407, 'Hawk Chill'),
#  (408, 'Head Stranger'),
#  (410, 'Heaven Freedom'),
#  (411, 'Heavenly Gun'),
#  (412, 'Heavyweights Beast'),
#  (413, 'Hedwig Alter'),
#  (414, 'Hellfighters Sierra'),
#  (415, 'High Encino'),
#  (416, 'Highball Potter'),
#  (417, 'Hills Neighbors'),
#  (418, 'Hobbit Alien'),
#  (419, 'Hocus Frida'),
#  (420, 'Holes Brannigan'),
#  (421, 'Holiday Games'),
#  (422, 'Hollow Jeopardy'),
#  (425, 'Holy Tadpole'),
#  (426, 'Home Pity'),
#  (427, 'Homeward Cider'),
#  (428, 'Homicide Peach'),
#  (429, 'Honey Ties'),
#  (430, 'Hook Chariots'),
#  (431, 'Hoosiers Birdcage'),
#  (432, 'Hope Tootsie'),
#  (433, 'Horn Working'),
#  (434, 'Horror Reign'),
#  (435, 'Hotel Happiness'),
#  (436, 'Hours Rage'),
#  (437, 'House Dynamite'),
#  (438, 'Human Graffiti'),
#  (439, 'Hunchback Impossible'),
#  (440, 'Hunger Roof'),
#  (441, 'Hunter Alter'),
#  (442, 'Hunting Musketeers'),
#  (443, 'Hurricane Affair'),
#  (444, 'Hustler Party'),
#  (445, 'Hyde Doctor'),
#  (446, 'Hysterical Grail'),
#  (447, 'Ice Crossing'),
#  (448, 'Idaho Love'),
#  (451, 'Igby Maker'),
#  (452, 'Illusion Amelie'),
#  (453, 'Image Princess'),
#  (454, 'Impact Aladdin'),
#  (455, 'Impossible Prejudice'),
#  (456, 'Inch Jet'),
#  (457, 'Independence Hotel'),
#  (458, 'Indian Love'),
#  (459, 'Informer Double'),
#  (460, 'Innocent Usual'),
#  (461, 'Insects Stone'),
#  (462, 'Insider Arizona'),
#  (463, 'Instinct Airport'),
#  (464, 'Intentions Empire'),
#  (465, 'Interview Liaisons'),
#  (466, 'Intolerable Intentions'),
#  (467, 'Intrigue Worst'),
#  (469, 'Iron Moon'),
#  (470, 'Ishtar Rocketeer'),
#  (471, 'Island Exorcist'),
#  (472, 'Italian African'),
#  (473, 'Jacket Frisco'),
#  (474, 'Jade Bunch'),
#  (475, 'Japanese Run'),
#  (476, 'Jason Trap'),
#  (477, 'Jawbreaker Brooklyn'),
#  (478, 'Jaws Harry'),
#  (479, 'Jedi Beneath'),
#  (480, 'Jeepers Wedding'),
#  (481, 'Jekyll Frogmen'),
#  (482, 'Jeopardy Encino'),
#  (483, 'Jericho Mulan'),
#  (484, 'Jerk Paycheck'),
#  (486, 'Jet Neighbors'),
#  (487, 'Jingle Sagebrush'),
#  (488, 'Joon Northwest'),
#  (489, 'Juggler Hardly'),
#  (490, 'Jumanji Blade'),
#  (492, 'Jungle Closer'),
#  (493, 'Kane Exorcist'),
#  (494, 'Karate Moon'),
#  (495, 'Kentuckian Giant'),
#  (496, 'Kick Savannah'),
#  (497, 'Kill Brotherhood'),
#  (498, 'Killer Innocent'),
#  (499, 'King Evolution'),
#  (500, 'Kiss Glory'),
#  (501, 'Kissing Dolls'),
#  (502, 'Knock Warlock'),
#  (503, 'Kramer Chocolate'),
#  (504, 'Kwai Homeward'),
#  (753, 'Rush Goodfellas'),
#  (506, 'Lady Stage'),
#  (507, 'Ladybugs Armageddon'),
#  (508, 'Lambs Cincinatti'),
#  (510, 'Lawless Vision'),
#  (511, 'Lawrence Love'),
#  (512, 'League Hellfighters'),
#  (513, 'Leathernecks Dwarfs'),
#  (514, 'Lebowski Soldiers'),
#  (516, 'Legend Jedi'),
#  (517, 'Lesson Cleopatra'),
#  (518, 'Liaisons Sweet'),
#  (519, 'Liberty Magnificent'),
#  (520, 'License Weekend'),
#  (521, 'Lies Treatment'),
#  (522, 'Life Twisted'),
#  (523, 'Lights Deer'),
#  (560, 'Mars Roman'),
#  (524, 'Lion Uncut'),
#  (525, 'Loathing Legally'),
#  (526, 'Lock Rear'),
#  (527, 'Lola Agent'),
#  (528, 'Lolita World'),
#  (529, 'Lonely Elephant'),
#  (530, 'Lord Arizona'),
#  (531, 'Lose Inch'),
#  (532, 'Loser Hustler'),
#  (533, 'Lost Bird'),
#  (534, 'Louisiana Harry'),
#  (535, 'Love Suicides'),
#  (536, 'Lovely Jingle'),
#  (537, 'Lover Truman'),
#  (538, 'Loverboy Attacks'),
#  (539, 'Luck Opus'),
#  (540, 'Lucky Flying'),
#  (541, 'Luke Mummy'),
#  (561, 'Mask Peach'),
#  (542, 'Lust Lock'),
#  (543, 'Madigan Dorado'),
#  (544, 'Madison Trap'),
#  (545, 'Madness Attacks'),
#  (546, 'Madre Gables'),
#  (548, 'Magnificent Chitty'),
#  (549, 'Magnolia Forrester'),
#  (550, 'Maguire Apache'),
#  (551, 'Maiden Home'),
#  (552, 'Majestic Floats'),
#  (554, 'Malkovich Pet'),
#  (555, 'Mallrats United'),
#  (556, 'Maltese Hope'),
#  (557, 'Manchurian Curtain'),
#  (558, 'Mannequin Worst'),
#  (559, 'Married Go'),
#  (562, 'Masked Bubble'),
#  (563, 'Massacre Usual'),
#  (564, 'Massage Image'),
#  (565, 'Matrix Snowman'),
#  (566, 'Maude Mod'),
#  (567, 'Meet Chocolate'),
#  (568, 'Memento Zoolander'),
#  (569, 'Menagerie Rushmore'),
#  (570, 'Mermaid Insects'),
#  (571, 'Metal Armageddon'),
#  (572, 'Metropolis Coma'),
#  (574, 'Midnight Westward'),
#  (575, 'Midsummer Groundhog'),
#  (576, 'Mighty Luck'),
#  (577, 'Mile Mulan'),
#  (578, 'Million Ace'),
#  (579, 'Minds Truman'),
#  (580, 'Mine Titans'),
#  (581, 'Minority Kiss'),
#  (582, 'Miracle Virtual'),
#  (583, 'Mission Zoolander'),
#  (584, 'Mixed Doors'),
#  (585, 'Mob Duffel'),
#  (586, 'Mockingbird Hollywood'),
#  (587, 'Mod Secretary'),
#  (589, 'Modern Dorado'),
#  (590, 'Money Harold'),
#  (591, 'Monsoon Cause'),
#  (592, 'Monster Spartacus'),
#  (593, 'Monterey Labyrinth'),
#  (594, 'Montezuma Command'),
#  (595, 'Moon Bunch'),
#  (596, 'Moonshine Cabin'),
#  (597, 'Moonwalker Fool'),
#  (598, 'Mosquito Armageddon'),
#  (599, 'Mother Oleander'),
#  (600, 'Motions Details'),
#  (601, 'Moulin Wake'),
#  (602, 'Mourning Purple'),
#  (603, 'Movie Shakespeare'),
#  (604, 'Mulan Moon'),
#  (605, 'Mulholland Beast'),
#  (606, 'Mummy Creatures'),
#  (607, 'Muppet Mile'),
#  (609, 'Muscle Bright'),
#  (610, 'Music Boondock'),
#  (611, 'Musketeers Wait'),
#  (612, 'Mussolini Spoilers'),
#  (613, 'Mystic Truman'),
#  (614, 'Name Detective'),
#  (615, 'Nash Chocolat'),
#  (616, 'National Story'),
#  (617, 'Natural Stock'),
#  (618, 'Necklace Outbreak'),
#  (619, 'Neighbors Charade'),
#  (620, 'Nemo Campus'),
#  (621, 'Network Peak'),
#  (622, 'Newsies Story'),
#  (623, 'Newton Labyrinth'),
#  (624, 'Nightmare Chill'),
#  (625, 'None Spiking'),
#  (627, 'North Tequila'),
#  (628, 'Northwest Polish'),
#  (629, 'Notorious Reunion'),
#  (630, 'Notting Speakeasy'),
#  (631, 'Novocaine Flight'),
#  (632, 'Nuts Ties'),
#  (633, 'October Submarine'),
#  (634, 'Odds Boogie'),
#  (635, 'Oklahoma Jumanji'),
#  (636, 'Oleander Clue'),
#  (637, 'Open African'),
#  (638, 'Operation Operation'),
#  (639, 'Opposite Necklace'),
#  (640, 'Opus Ice'),
#  (641, 'Orange Grapes'),
#  (642, 'Order Betrayed'),
#  (643, 'Orient Closer'),
#  (644, 'Oscar Gold'),
#  (645, 'Others Soup'),
#  (646, 'Outbreak Divine'),
#  (647, 'Outfield Massacre'),
#  (648, 'Outlaw Hanky'),
#  (649, 'Oz Liaisons'),
#  (650, 'Pacific Amistad'),
#  (651, 'Packer Madigan'),
#  (652, 'Pajama Jawbreaker'),
#  (653, 'Panic Club'),
#  (654, 'Panky Submarine'),
#  (655, 'Panther Reds'),
#  (656, 'Papi Necklace'),
#  (657, 'Paradise Sabrina'),
#  (658, 'Paris Weekend'),
#  (659, 'Park Citizen'),
#  (660, 'Party Knock'),
#  (661, 'Past Suicides'),
#  (662, 'Paths Control'),
#  (663, 'Patient Sister'),
#  (664, 'Patriot Roman'),
#  (665, 'Patton Interview'),
#  (666, 'Paycheck Wait'),
#  (667, 'Peach Innocent'),
#  (668, 'Peak Forever'),
#  (669, 'Pearl Destiny'),
#  (670, 'Pelican Comforts'),
#  (671, 'Perdition Fargo'),
#  (672, 'Perfect Groove'),
#  (673, 'Personal Ladybugs'),
#  (674, 'Pet Haunting'),
#  (675, 'Phantom Glory'),
#  (676, 'Philadelphia Wife'),
#  (677, 'Pianist Outfield'),
#  (678, 'Pickup Driving'),
#  (679, 'Pilot Hoosiers'),
#  (680, 'Pinocchio Simon'),
#  (681, 'Pirates Roxanne'),
#  (682, 'Pittsburgh Hunchback'),
#  (683, 'Pity Bound'),
#  (684, 'Pizza Jumanji'),
#  (685, 'Platoon Instinct'),
#  (686, 'Pluto Oleander'),
#  (687, 'Pocus Pulp'),
#  (689, 'Pollock Deliverance'),
#  (690, 'Pond Seattle'),
#  (691, 'Poseidon Forever'),
#  (692, 'Potluck Mixed'),
#  (693, 'Potter Connecticut'),
#  (694, 'Prejudice Oleander'),
#  (695, 'President Bang'),
#  (696, 'Pride Alamo'),
#  (697, 'Primary Glass'),
#  (698, 'Princess Giant'),
#  (699, 'Private Drop'),
#  (700, 'Prix Undefeated'),
#  (701, 'Psycho Shrunk'),
#  (702, 'Pulp Beverly'),
#  (703, 'Punk Divorce'),
#  (704, 'Pure Runner'),
#  (705, 'Purple Movie'),
#  (706, 'Queen Luke'),
#  (707, 'Quest Mussolini'),
#  (708, 'Quills Bull'),
#  (709, 'Racer Egg'),
#  (710, 'Rage Games'),
#  (711, 'Raging Airplane'),
#  (712, 'Raiders Antitrust'),
#  (713, 'Rainbow Shock'),
#  (714, 'Random Go'),
#  (715, 'Range Moonwalker'),
#  (716, 'Reap Unfaithful'),
#  (717, 'Rear Trading'),
#  (718, 'Rebel Airport'),
#  (719, 'Records Zorro'),
#  (720, 'Redemption Comforts'),
#  (721, 'Reds Pocus'),
#  (722, 'Reef Salute'),
#  (723, 'Reign Gentlemen'),
#  (724, 'Remember Diary'),
#  (725, 'Requiem Tycoon'),
#  (726, 'Reservoir Adaptation'),
#  (727, 'Resurrection Silverado'),
#  (728, 'Reunion Witches'),
#  (729, 'Rider Caddyshack'),
#  (730, 'Ridgemont Submarine'),
#  (731, 'Right Cranes'),
#  (732, 'Rings Heartbreakers'),
#  (733, 'River Outlaw'),
#  (734, 'Road Roxanne'),
#  (736, 'Robbery Bright'),
#  (737, 'Rock Instinct'),
#  (738, 'Rocketeer Mother'),
#  (739, 'Rocky War'),
#  (740, 'Rollercoaster Bringing'),
#  (741, 'Roman Punk'),
#  (742, 'Roof Champion'),
#  (743, 'Room Roman'),
#  (744, 'Roots Remember'),
#  (745, 'Roses Treasure'),
#  (746, 'Rouge Squad'),
#  (747, 'Roxanne Rebel'),
#  (748, 'Rugrats Shakespeare'),
#  (749, 'Rules Human'),
#  (750, 'Run Pacific'),
#  (751, 'Runaway Tenenbaums'),
#  (752, 'Runner Madigan'),
#  (754, 'Rushmore Mermaid'),
#  (756, 'Saddle Antitrust'),
#  (757, 'Sagebrush Clueless'),
#  (758, 'Saints Bride'),
#  (759, 'Salute Apollo'),
#  (760, 'Samurai Lion'),
#  (762, 'Sassy Packer'),
#  (763, 'Satisfaction Confidential'),
#  (764, 'Saturday Lambs'),
#  (765, 'Saturn Name'),
#  (766, 'Savannah Town'),
#  (767, 'Scalawag Duck'),
#  (769, 'School Jacket'),
#  (770, 'Scissorhands Slums'),
#  (788, 'Ship Wonderland'),
#  (771, 'Scorpion Apollo'),
#  (772, 'Sea Virgin'),
#  (773, 'Seabiscuit Punk'),
#  (774, 'Searchers Wait'),
#  (775, 'Seattle Expecations'),
#  (776, 'Secret Groundhog'),
#  (777, 'Secretary Rouge'),
#  (778, 'Secrets Paradise'),
#  (779, 'Sense Greek'),
#  (780, 'Sensibility Rear'),
#  (781, 'Seven Swarm'),
#  (782, 'Shakespeare Saddle'),
#  (783, 'Shane Darkness'),
#  (784, 'Shanghai Tycoon'),
#  (785, 'Shawshank Bubble'),
#  (787, 'Shining Roses'),
#  (789, 'Shock Cabin'),
#  (790, 'Shootist Superfly'),
#  (791, 'Show Lord'),
#  (792, 'Shrek License'),
#  (793, 'Shrunk Divine'),
#  (794, 'Side Ark'),
#  (795, 'Siege Madre'),
#  (796, 'Sierra Divide'),
#  (797, 'Silence Kane'),
#  (798, 'Silverado Goldfinger'),
#  (799, 'Simon North'),
#  (800, 'Sinners Atlantis'),
#  (802, 'Sky Miracle'),
#  (803, 'Slacker Liaisons'),
#  (804, 'Sleeping Suspects'),
#  (805, 'Sleepless Monsoon'),
#  (806, 'Sleepy Japanese'),
#  (807, 'Sleuth Orient'),
#  (808, 'Sling Luke'),
#  (809, 'Slipper Fidelity'),
#  (810, 'Slums Duck'),
#  (811, 'Smile Earring'),
#  (812, 'Smoking Barbarella'),
#  (813, 'Smoochy Control'),
#  (814, 'Snatch Slipper'),
#  (815, 'Snatchers Montezuma'),
#  (816, 'Snowman Rollercoaster'),
#  (817, 'Soldiers Evolution'),
#  (818, 'Something Duck'),
#  (819, 'Song Hedwig'),
#  (820, 'Sons Interview'),
#  (821, 'Sorority Queen'),
#  (822, 'Soup Wisdom'),
#  (823, 'South Wait'),
#  (824, 'Spartacus Cheaper'),
#  (825, 'Speakeasy Date'),
#  (826, 'Speed Suit'),
#  (827, 'Spice Sorority'),
#  (828, 'Spiking Element'),
#  (829, 'Spinal Rocky'),
#  (830, 'Spirit Flintstones'),
#  (831, 'Spirited Casualties'),
#  (832, 'Splash Gump'),
#  (834, 'Spoilers Hellfighters'),
#  (835, 'Spy Mile'),
#  (836, 'Squad Fish'),
#  (837, 'Stage World'),
#  (838, 'Stagecoach Armageddon'),
#  (839, 'Stallion Sundance'),
#  (840, 'Stampede Disturbing'),
#  (841, 'Star Operation'),
#  (842, 'State Wasteland'),
#  (843, 'Steel Santa'),
#  (844, 'Steers Armageddon'),
#  (845, 'Stepmom Dream'),
#  (846, 'Sting Personal'),
#  (847, 'Stock Glass'),
#  (848, 'Stone Fire'),
#  (849, 'Storm Happiness'),
#  (850, 'Story Side'),
#  (851, 'Straight Hours'),
#  (890, 'Tights Dawn'),
#  (854, 'Strangers Graffiti'),
#  (855, 'Streak Ridgemont'),
#  (856, 'Streetcar Intentions'),
#  (857, 'Strictly Scarface'),
#  (858, 'Submarine Bed'),
#  (859, 'Sugar Wonka'),
#  (860, 'Suicides Silence'),
#  (861, 'Suit Walls'),
#  (862, 'Summer Scarface'),
#  (863, 'Sun Confessions'),
#  (865, 'Sunrise League'),
#  (866, 'Sunset Racer'),
#  (867, 'Super Wyoming'),
#  (868, 'Superfly Trip'),
#  (869, 'Suspects Quills'),
#  (870, 'Swarm Gold'),
#  (871, 'Sweden Shining'),
#  (891, 'Timberland Sky'),
#  (872, 'Sweet Brotherhood'),
#  (874, 'Tadpole Park'),
#  (875, 'Talented Homicide'),
#  (876, 'Tarzan Videotape'),
#  (877, 'Taxi Kick'),
#  (878, 'Teen Apollo'),
#  (879, 'Telegraph Voyage'),
#  (880, 'Telemark Heartbreakers'),
#  (881, 'Temple Attraction'),
#  (882, 'Tenenbaums Command'),
#  (884, 'Terminator Club'),
#  (885, 'Texas Watch'),
#  (886, 'Theory Mermaid'),
#  (887, 'Thief Pelican'),
#  (888, 'Thin Sagebrush'),
#  (892, 'Titanic Boondock'),
#  (893, 'Titans Jerk'),
#  (894, 'Tomatoes Hellfighters'),
#  (895, 'Tomorrow Hustler'),
#  (897, 'Torque Bound'),
#  (898, 'Tourist Pelican'),
#  (899, 'Towers Hurricane'),
#  (900, 'Town Ark'),
#  (901, 'Tracy Cider'),
#  (902, 'Trading Pinocchio'),
#  (903, 'Traffic Hobbit'),
#  (904, 'Train Bunch'),
#  (905, 'Trainspotting Strangers'),
#  (906, 'Tramp Others'),
#  (907, 'Translation Summer'),
#  (908, 'Trap Guys'),
#  (909, 'Treasure Command'),
#  (910, 'Treatment Jekyll'),
#  (911, 'Trip Newton'),
#  (912, 'Trojan Tomorrow'),
#  (913, 'Troopers Metal'),
#  (914, 'Trouble Date'),
#  (915, 'Truman Crazy'),
#  (916, 'Turn Star'),
#  (917, 'Tuxedo Mile'),
#  (919, 'Tycoon Gathering'),
#  (920, 'Unbreakable Karate'),
#  (921, 'Uncut Suicides'),
#  (922, 'Undefeated Dalmations'),
#  (923, 'Unfaithful Kill'),
#  (924, 'Unforgiven Zoolander'),
#  (925, 'United Pilot'),
#  (926, 'Untouchables Sunrise'),
#  (927, 'Uprising Uptown'),
#  (929, 'Usual Untouchables'),
#  (930, 'Vacation Boondock'),
#  (931, 'Valentine Vanishing'),
#  (932, 'Valley Packer'),
#  (933, 'Vampire Whale'),
#  (934, 'Vanilla Day'),
#  (935, 'Vanished Garden'),
#  (936, 'Vanishing Rocky'),
#  (937, 'Varsity Trip'),
#  (938, 'Velvet Terminator'),
#  (939, 'Vertigo Northwest'),
#  (940, 'Victory Academy'),
#  (941, 'Videotape Arsenic'),
#  (942, 'Vietnam Smoochy'),
#  (943, 'Villain Desperate'),
#  (944, 'Virgin Daisy'),
#  (945, 'Virginian Pluto'),
#  (946, 'Virtual Spoilers'),
#  (947, 'Vision Torque'),
#  (948, 'Voice Peach'),
#  (949, 'Volcano Texas'),
#  (950, 'Volume House'),
#  (951, 'Voyage Legally'),
#  (952, 'Wagon Jaws'),
#  (953, 'Wait Cider'),
#  (954, 'Wake Jaws'),
#  (956, 'Wanda Chamber'),
#  (957, 'War Notting'),
#  (958, 'Wardrobe Phantom'),
#  (960, 'Wars Pluto'),
#  (961, 'Wash Heavenly'),
#  (962, 'Wasteland Divine'),
#  (963, 'Watch Tracy'),
#  (964, 'Waterfront Deliverance'),
#  (965, 'Watership Frontier'),
#  (966, 'Wedding Apollo'),
#  (967, 'Weekend Personal'),
#  (968, 'Werewolf Lola'),
#  (969, 'West Lion'),
#  (970, 'Westward Seabiscuit'),
#  (971, 'Whale Bikini'),
#  (972, 'Whisperer Giant'),
#  (973, 'Wife Turn'),
#  (974, 'Wild Apollo'),
#  (975, 'Willow Tracy'),
#  (976, 'Wind Phantom'),
#  (977, 'Window Side'),
#  (978, 'Wisdom Worker'),
#  (979, 'Witches Panic'),
#  (980, 'Wizard Coldblooded'),
#  (981, 'Wolves Desire'),
#  (982, 'Women Dorado'),
#  (983, 'Won Dares'),
#  (984, 'Wonderful Drop'),
#  (985, 'Wonderland Christmas'),
#  (986, 'Wonka Sea'),
#  (987, 'Words Hunter'),
#  (988, 'Worker Tarzan'),
#  (989, 'Working Microcosmos'),
#  (990, 'World Leathernecks'),
#  (991, 'Worst Banger'),
#  (992, 'Wrath Mile'),
#  (994, 'Wyoming Storm'),
#  (995, 'Yentl Idaho'),
#  (996, 'Young Language'),
#  (997, 'Youth Kick'),
#  (998, 'Zhivago Core'),
#  (1000, 'Zorro Ark')]

# %% [markdown]
# [Helpful Hints](https://youtu.be/9WR0ByMn__E)
#
#
# ---
#
# # 4
#
# ### List the names of the customers who have rented the 5 least popular movies.
#
# **The five least populat movies are those movies with the least film rentals**
#
# (Do not include movies that have never been rented, also do not worry about ties go with the 5 even though there may be other movies rented the same amount of times as some in the 5 least popular.)

# %%
# %%sql
# SELECT film_id, count(film_id)
#     from inventory join rental using (inventory_id)
#     GROUP BY film_id
#     ORDER BY count ASC
#     LIMIT 5
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 5 rows affected.
# [(584, 4), (400, 4), (904, 4), (180, 5), (699, 5)]

# %%
# %%sql
# EXPLAIN
# select first_name, last_name
# from customer
#     join rental USING (customer_id)
#     join inventory USING (inventory_id)
# WHERE film_id in (
#     SELECT film_id
#     from inventory i join rental using (inventory_id)
#     WHERE film_id = '584' or
#     film_id = '400'or
#     film_id = '904' or
#     film_id = '180' or
#     film_id = '699'
# );
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 18 rows affected.
# [('Hash Join  (cost=508.21..693.99 rows=616 width=13)',),
#  ('  Hash Cond: (rental.customer_id = customer.customer_id)',),
#  ('  ->  Nested Loop  (cost=485.73..669.88 rows=616 width=2)',),
#  ('        ->  Hash Join  (cost=485.45..570.24 rows=176 width=4)',),
#  ('              Hash Cond: (inventory.film_id = i.film_id)',),
#  ('              ->  Seq Scan on inventory  (cost=0.00..70.81 rows=4581 width=6)',),
#  ('              ->  Hash  (cost=485.17..485.17 rows=22 width=2)',),
#  ('                    ->  HashAggregate  (cost=484.95..485.17 rows=22 width=2)',),
#  ('                          Group Key: i.film_id',),
#  ('                          ->  Nested Loop  (cost=0.29..484.76 rows=77 width=2)',),
#  ('                                ->  Seq Scan on inventory i  (cost=0.00..128.07 rows=22 width=6)',),
#  ("                                      Filter: ((film_id = '584'::smallint) OR (film_id = '400'::smallint) OR (film_id = '904'::smallint) OR (film_id = '180'::smallint) OR (film_id = '699'::smallint))",),
#  ('                                ->  Index Only Scan using idx_fk_inventory_id on rental rental_1  (cost=0.29..16.17 rows=4 width=4)',),
#  ('                                      Index Cond: (inventory_id = i.inventory_id)',),
#  ('        ->  Index Scan using idx_fk_inventory_id on rental  (cost=0.29..0.53 rows=4 width=6)',),
#  ('              Index Cond: (inventory_id = inventory.inventory_id)',),
#  ('  ->  Hash  (cost=14.99..14.99 rows=599 width=17)',),
#  ('        ->  Seq Scan on customer  (cost=0.00..14.99 rows=599 width=17)',)]

# %%
# %%sql
# select first_name, last_name
# from customer
#     join rental USING (customer_id)
#     join inventory USING (inventory_id)
# WHERE film_id in (
#     SELECT film_id
#     from inventory i join rental using (inventory_id)
#     WHERE film_id = '584' or
#     film_id = '400'or
#     film_id = '904' or
#     film_id = '180' or
#     film_id = '699'
# );
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 22 rows affected.
# [('Ramon', 'Choate'),
#  ('William', 'Satterfield'),
#  ('Raul', 'Fortier'),
#  ('Hector', 'Poindexter'),
#  ('Craig', 'Morrell'),
#  ('Marsha', 'Douglas'),
#  ('April', 'Burns'),
#  ('Bob', 'Pfeiffer'),
#  ('Julia', 'Flores'),
#  ('Pauline', 'Henry'),
#  ('Dana', 'Hart'),
#  ('Edgar', 'Rhoads'),
#  ('Myrtle', 'Fleming'),
#  ('Morris', 'Mccarter'),
#  ('Jay', 'Robb'),
#  ('Minnie', 'Romero'),
#  ('Mark', 'Rinehart'),
#  ('Ethel', 'Webb'),
#  ('Betty', 'White'),
#  ('Rhonda', 'Kennedy'),
#  ('David', 'Royal'),
#  ('Eduardo', 'Hiatt')]

# %% [markdown]
# # 5
#
# ### List the movies that have been rented by the top ten renters.

# %%
# %%sql
# SELECT customer_id, count(customer_id)
#     from rental
#     GROUP BY customer_id
#     ORDER BY count DESC
#     LIMIT 10
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 10 rows affected.
# [(148, 46),
#  (526, 45),
#  (144, 42),
#  (236, 42),
#  (75, 41),
#  (469, 40),
#  (197, 40),
#  (468, 39),
#  (137, 39),
#  (178, 39)]

# %%
# %%sql
# EXPLAIN
# SELECT distinct title
# from film
# join inventory USING (film_id)
# join rental USING (inventory_id)
# WHere customer_id in (
#     SELECT customer_id
#     from rental join inventory USING (inventory_id)
#     WHERE customer_id = '148' or
#     customer_id = '526' or
#     customer_id = '144' or
#     customer_id = '236' or
#     customer_id = '75' or
#     customer_id = '469' or
#     customer_id = '197' or
#     customer_id = '468' or
#     customer_id = '137' or
#     customer_id = '178'
# );
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 22 rows affected.
# [('HashAggregate  (cost=1606.52..1616.52 rows=1000 width=15)',),
#  ('  Group Key: film.title',),
#  ('  ->  Hash Join  (cost=1043.93..1578.72 rows=11120 width=15)',),
#  ('        Hash Cond: (inventory.film_id = film.film_id)',),
#  ('        ->  Hash Join  (cost=967.43..1472.91 rows=11120 width=2)',),
#  ('              Hash Cond: (rental.inventory_id = inventory.inventory_id)',),
#  ('              ->  Hash Join  (cost=839.36..1315.63 rows=11120 width=4)',),
#  ('                    Hash Cond: (rental.customer_id = rental_1.customer_id)',),
#  ('                    ->  Seq Scan on rental  (cost=0.00..310.44 rows=16044 width=6)',),
#  ('                    ->  Hash  (cost=835.62..835.62 rows=299 width=2)',),
#  ('                          ->  HashAggregate  (cost=832.63..835.62 rows=299 width=2)',),
#  ('                                Group Key: rental_1.customer_id',),
#  ('                                ->  Hash Join  (cost=716.64..831.61 rows=408 width=2)',),
#  ('                                      Hash Cond: (inventory_1.inventory_id = rental_1.inventory_id)',),
#  ('                                      ->  Seq Scan on inventory inventory_1  (cost=0.00..70.81 rows=4581 width=4)',),
#  ('                                      ->  Hash  (cost=711.54..711.54 rows=408 width=6)',),
#  ('                                            ->  Seq Scan on rental rental_1  (cost=0.00..711.54 rows=408 width=6)',),
#  ("                                                  Filter: ((customer_id = '148'::smallint) OR (customer_id = '526'::smallint) OR (customer_id = '144' ... (107 characters truncated) ... mallint) OR (customer_id = '197'::smallint) OR (customer_id = '468'::smallint) OR (customer_id = '137'::smallint) OR (customer_id = '178'::smallint))",),
#  ('              ->  Hash  (cost=70.81..70.81 rows=4581 width=6)',),
#  ('                    ->  Seq Scan on inventory  (cost=0.00..70.81 rows=4581 width=6)',),
#  ('        ->  Hash  (cost=64.00..64.00 rows=1000 width=19)',),
#  ('              ->  Seq Scan on film  (cost=0.00..64.00 rows=1000 width=19)',)]

# %%
# %%sql
# SELECT distinct title
# from film
# join inventory USING (film_id)
# join rental USING (inventory_id)
# WHERE customer_id in (
#     SELECT customer_id
#     from rental join inventory USING (inventory_id)
#     WHERE customer_id = '148' or
#     customer_id = '526' or
#     customer_id = '144' or
#     customer_id = '236' or
#     customer_id = '75' or
#     customer_id = '469' or
#     customer_id = '197' or
#     customer_id = '468' or
#     customer_id = '137' or
#     customer_id = '178'
# );
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 324 rows affected.
# [('Graceland Dynamite',),
#  ('Wonderful Drop',),
#  ('Purple Movie',),
#  ('Fantasy Troopers',),
#  ('Sunset Racer',),
#  ('Carol Texas',),
#  ('Minds Truman',),
#  ('Stepmom Dream',),
#  ('Arabia Dogma',),
#  ('Baked Cleopatra',),
#  ('Closer Bang',),
#  ('Innocent Usual',),
#  ('Wizard Coldblooded',),
#  ('Lonely Elephant',),
#  ('Garden Island',),
#  ('Patriot Roman',),
#  ('Novocaine Flight',),
#  ('Sleeping Suspects',),
#  ('Insects Stone',),
#  ('Loser Hustler',),
#  ('Heavyweights Beast',),
#  ('Entrapment Satisfaction',),
#  ('Cabin Flash',),
#  ('Cyclone Family',),
#  ('Jaws Harry',),
#  ('Bringing Hysterical',),
#  ('Haunting Pianist',),
#  ('Double Wrath',),
#  ('Invasion Cyclone',),
#  ('Congeniality Quest',),
#  ('Reef Salute',),
#  ('French Holiday',),
#  ('Highball Potter',),
#  ('Translation Summer',),
#  ('Rouge Squad',),
#  ('Nash Chocolat',),
#  ('Pure Runner',),
#  ('Anthem Luke',),
#  ('Impossible Prejudice',),
#  ('Music Boondock',),
#  ('Chisum Behavior',),
#  ('Daisy Menagerie',),
#  ('Conversation Downhill',),
#  ('Dumbo Lust',),
#  ('Chance Resurrection',),
#  ('Fight Jawbreaker',),
#  ('Forrester Comancheros',),
#  ('Graffiti Love',),
#  ('Pickup Driving',),
#  ('Forward Temple',),
#  ('Spice Sorority',),
#  ('Massage Image',),
#  ('Boulevard Mob',),
#  ('Suspects Quills',),
#  ('Soldiers Evolution',),
#  ('Westward Seabiscuit',),
#  ('Million Ace',),
#  ('Coneheads Smoochy',),
#  ('Ali Forever',),
#  ('Bird Independence',),
#  ('Mask Peach',),
#  ('Scissorhands Slums',),
#  ('Boiled Dares',),
#  ('Majestic Floats',),
#  ('Sagebrush Clueless',),
#  ('Reap Unfaithful',),
#  ('Vietnam Smoochy',),
#  ('Head Stranger',),
#  ('Quest Mussolini',),
#  ('Fool Mockingbird',),
#  ('Panther Reds',),
#  ('Holocaust Highball',),
#  ('Adaptation Holes',),
#  ('Fatal Haunted',),
#  ('Rage Games',),
#  ('Uprising Uptown',),
#  ('Jason Trap',),
#  ('Creatures Shakespeare',),
#  ('Snatchers Montezuma',),
#  ('Island Exorcist',),
#  ('Seattle Expecations',),
#  ('Gun Bonnie',),
#  ('Alabama Devil',),
#  ('Train Bunch',),
#  ('Clyde Theory',),
#  ('Troopers Metal',),
#  ('Affair Prejudice',),
#  ('Fury Murder',),
#  ('Dinosaur Secretary',),
#  ('Freedom Cleopatra',),
#  ('Greek Everyone',),
#  ('Hanging Deep',),
#  ('War Notting',),
#  ('Instinct Airport',),
#  ('Bikini Borrowers',),
#  ('Pelican Comforts',),
#  ('Madre Gables',),
#  ('Groove Fiction',),
#  ('Window Side',),
#  ('Natural Stock',),
#  ('Karate Moon',),
#  ('Racer Egg',),
#  ('Sabrina Midnight',),
#  ('Roxanne Rebel',),
#  ('Fidelity Devil',),
#  ('Madness Attacks',),
#  ('Sweethearts Suspects',),
#  ('Lola Agent',),
#  ('Won Dares',),
#  ('Encino Elf',),
#  ('Hustler Party',),
#  ('Details Packer',),
#  ('Butterfly Chocolat',),
#  ('Queen Luke',),
#  ('Desire Alien',),
#  ('Pollock Deliverance',),
#  ('Cowboy Doom',),
#  ('Prejudice Oleander',),
#  ('Confidential Interview',),
#  ('Armageddon Lost',),
#  ('Half Outfield',),
#  ('Oscar Gold',),
#  ('Chocolat Harry',),
#  ('Random Go',),
#  ('American Circus',),
#  ('Rear Trading',),
#  ('Artist Coldblooded',),
#  ('Champion Flatliners',),
#  ('Moulin Wake',),
#  ('Princess Giant',),
#  ('Lebowski Soldiers',),
#  ('South Wait',),
#  ('Wedding Apollo',),
#  ('Dawn Pond',),
#  ('Coma Head',),
#  ('Disciple Mother',),
#  ('Paris Weekend',),
#  ('Bill Others',),
#  ('Network Peak',),
#  ('Jade Bunch',),
#  ('Name Detective',),
#  ('Outfield Massacre',),
#  ('Strangelove Desire',),
#  ('Egypt Tenenbaums',),
#  ('Oz Liaisons',),
#  ('Whale Bikini',),
#  ('Moonwalker Fool',),
#  ('Watch Tracy',),
#  ('Lust Lock',),
#  ('Outbreak Divine',),
#  ('Requiem Tycoon',),
#  ('National Story',),
#  ('Chamber Italian',),
#  ('Moon Bunch',),
#  ('Honey Ties',),
#  ('Hurricane Affair',),
#  ('Shootist Superfly',),
#  ('Shepherd Midsummer',),
#  ('Family Sweet',),
#  ('Wait Cider',),
#  ('Encounters Curtain',),
#  ('Phantom Glory',),
#  ('Arizona Bang',),
#  ('Midsummer Groundhog',),
#  ('Attraction Newton',),
#  ('Earth Vision',),
#  ('Slums Duck',),
#  ('Wardrobe Phantom',),
#  ('Gangs Pride',),
#  ('Games Bowfinger',),
#  ('Ladybugs Armageddon',),
#  ('Darko Dorado',),
#  ('Lion Uncut',),
#  ('Northwest Polish',),
#  ('Robbery Bright',),
#  ('Spy Mile',),
#  ('Destiny Saturday',),
#  ('Galaxy Sweethearts',),
#  ('Groundhog Uncut',),
#  ('Santa Paris',),
#  ('Pittsburgh Hunchback',),
#  ('Untouchables Sunrise',),
#  ('English Bulworth',),
#  ('Roots Remember',),
#  ('Airport Pollock',),
#  ('Date Speed',),
#  ('Thief Pelican',),
#  ('Moonshine Cabin',),
#  ('Malkovich Pet',),
#  ('Heavenly Gun',),
#  ('Outlaw Hanky',),
#  ('Blues Instinct',),
#  ('Hellfighters Sierra',),
#  ('Bucket Brotherhood',),
#  ('School Jacket',),
#  ('Inch Jet',),
#  ('Tourist Pelican',),
#  ('Goodfellas Salute',),
#  ('Stagecoach Armageddon',),
#  ('Amistad Midsummer',),
#  ('League Hellfighters',),
#  ('Reign Gentlemen',),
#  ('Wash Heavenly',),
#  ('Tights Dawn',),
#  ('Cider Desire',),
#  ('Fargo Gandhi',),
#  ('Harry Idaho',),
#  ('Contact Anonymous',),
#  ('Mission Zoolander',),
#  ('Alone Trip',),
#  ('Crow Grease',),
#  ('Sun Confessions',),
#  ('Philadelphia Wife',),
#  ('Holes Brannigan',),
#  ('Wife Turn',),
#  ('Horror Reign',),
#  ('Color Philadelphia',),
#  ('Trap Guys',),
#  ('Neighbors Charade',),
#  ('Grit Clockwork',),
#  ('Effect Gladiator',),
#  ('Stone Fire',),
#  ('Darn Forrester',),
#  ('Splendor Patton',),
#  ('Mermaid Insects',),
#  ('Brannigan Sunrise',),
#  ('High Encino',),
#  ('Lose Inch',),
#  ('Everyone Craft',),
#  ('Virtual Spoilers',),
#  ('Ice Crossing',),
#  ('Betrayed Rear',),
#  ('Analyze Hoosiers',),
#  ('Working Microcosmos',),
#  ('Splash Gump',),
#  ('Comancheros Enemy',),
#  ('Cause Date',),
#  ('Curtain Videotape',),
#  ('Holiday Games',),
#  ('Gables Metropolis',),
#  ('Words Hunter',),
#  ('Records Zorro',),
#  ('Spirited Casualties',),
#  ('Beach Heartbreakers',),
#  ('Something Duck',),
#  ('Trouble Date',),
#  ('Coast Rainbow',),
#  ('Hollywood Anonymous',),
#  ('Mummy Creatures',),
#  ('Room Roman',),
#  ('Frontier Cabin',),
#  ('Wasteland Divine',),
#  ('Dares Pluto',),
#  ('Pinocchio Simon',),
#  ('Wolves Desire',),
#  ('Juggler Hardly',),
#  ('Labyrinth League',),
#  ('Brotherhood Blanket',),
#  ('Poseidon Forever',),
#  ('Strictly Scarface',),
#  ('Jedi Beneath',),
#  ('Ridgemont Submarine',),
#  ('Chariots Conspiracy',),
#  ('Interview Liaisons',),
#  ('Steers Armageddon',),
#  ('Range Moonwalker',),
#  ('Remember Diary',),
#  ('Opposite Necklace',),
#  ('Illusion Amelie',),
#  ('Jerk Paycheck',),
#  ('Sleepy Japanese',),
#  ('Pulp Beverly',),
#  ('Quills Bull',),
#  ('Dragonfly Strangers',),
#  ('Lady Stage',),
#  ('Storm Happiness',),
#  ('Sinners Atlantis',),
#  ('Driving Polish',),
#  ('Terminator Club',),
#  ('Deer Virginian',),
#  ('Alter Victory',),
#  ('Swarm Gold',),
#  ('Married Go',),
#  ('Badman Dawn',),
#  ('Feud Frogmen',),
#  ('Timberland Sky',),
#  ('Reservoir Adaptation',),
#  ('Celebrity Horn',),
#  ('Goldmine Tycoon',),
#  ('Straight Hours',),
#  ('Liaisons Sweet',),
#  ('Others Soup',),
#  ('Metal Armageddon',),
#  ('Goldfinger Sensibility',),
#  ('Whisperer Giant',),
#  ('Sting Personal',),
#  ('Dogma Family',),
#  ('Salute Apollo',),
#  ('Durham Panky',),
#  ('Movie Shakespeare',),
#  ('Madigan Dorado',),
#  ('Stranger Strangers',),
#  ('Connection Microcosmos',),
#  ('State Wasteland',),
#  ('Confused Candles',),
#  ('Muscle Bright',),
#  ('Hollow Jeopardy',),
#  ('Snowman Rollercoaster',),
#  ('Mulholland Beast',),
#  ('Birds Perdition',),
#  ('Maude Mod',),
#  ('Dying Maker',),
#  ('Tomorrow Hustler',),
#  ('Park Citizen',),
#  ('Full Flatliners',),
#  ('Anaconda Confessions',),
#  ('Secret Groundhog',),
#  ('Intolerable Intentions',),
#  ('River Outlaw',),
#  ('Detective Vision',),
#  ('Christmas Moonshine',),
#  ('Lover Truman',),
#  ('Gathering Calendar',),
#  ('Pond Seattle',)]

# %% [markdown]
# # 6
#
# ### Consider the previous question and the answer SQL.  Now add two columns to the result: a) number of rentals per film and b) number of rentals by the _top-ten renters_ per film.

# %%
# %%sql
# EXPLAIN
# select title, top_ten_count, total_count
# from film f join (
#     SELECT title, count(rental_rate) as top_ten_count
#     FROM film join film_category using (film_id)
#     GROUP BY title
#     ORDER BY title, MIN(rental_rate) DESC)
#     as TableA USING (title)
#
#     join (
#     SELECT title, count(*) as total_count
#     FROM film join inventory using (film_id)
#         join rental using (inventory_id)
#     GROUP BY title
#     ORDER BY title
#
#     ) as TableB USING (title)
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 31 rows affected.
# [('Hash Join  (cost=951.98..1021.25 rows=1000 width=31)',),
#  ('  Hash Cond: ((f.title)::text = (tableb.title)::text)',),
#  ('  ->  Hash Join  (cost=187.47..254.10 rows=1000 width=38)',),
#  ('        Hash Cond: ((f.title)::text = (tablea.title)::text)',),
#  ('        ->  Seq Scan on film f  (cost=0.00..64.00 rows=1000 width=15)',),
#  ('        ->  Hash  (cost=174.97..174.97 rows=1000 width=23)',),
#  ('              ->  Subquery Scan on tablea  (cost=162.47..174.97 rows=1000 width=23)',),
#  ('                    ->  Sort  (cost=162.47..164.97 rows=1000 width=55)',),
#  ('                          Sort Key: film.title, (min(film.rental_rate)) DESC',),
#  ('                          ->  HashAggregate  (cost=102.64..112.64 rows=1000 width=55)',),
#  ('                                Group Key: film.title',),
#  ('                                ->  Hash Join  (cost=76.50..95.14 rows=1000 width=21)',),
#  ('                                      Hash Cond: (film_category.film_id = film.film_id)',),
#  ('                                      ->  Seq Scan on film_category  (cost=0.00..16.00 rows=1000 width=2)',),
#  ('                                      ->  Hash  (cost=64.00..64.00 rows=1000 width=25)',),
#  ('                                            ->  Seq Scan on film  (cost=0.00..64.00 rows=1000 width=25)',),
#  ('  ->  Hash  (cost=752.01..752.01 rows=1000 width=23)',),
#  ('        ->  Subquery Scan on tableb  (cost=739.51..752.01 rows=1000 width=23)',),
#  ('              ->  Sort  (cost=739.51..742.01 rows=1000 width=23)',),
#  ('                    Sort Key: film_1.title',),
#  ('                    ->  HashAggregate  (cost=679.69..689.69 rows=1000 width=23)',),
#  ('                          Group Key: film_1.title',),
#  ('                          ->  Hash Join  (cost=204.57..599.47 rows=16044 width=15)',),
#  ('                                Hash Cond: (inventory.film_id = film_1.film_id)',),
#  ('                                ->  Hash Join  (cost=128.07..480.67 rows=16044 width=2)',),
#  ('                                      Hash Cond: (rental.inventory_id = inventory.inventory_id)',),
#  ('                                      ->  Seq Scan on rental  (cost=0.00..310.44 rows=16044 width=4)',),
#  ('                                      ->  Hash  (cost=70.81..70.81 rows=4581 width=6)',),
#  ('                                            ->  Seq Scan on inventory  (cost=0.00..70.81 rows=4581 width=6)',),
#  ('                                ->  Hash  (cost=64.00..64.00 rows=1000 width=19)',),
#  ('                                      ->  Seq Scan on film film_1  (cost=0.00..64.00 rows=1000 width=19)',)]

# %%
# %%sql
# select title, top_ten_count, total_count
# from film f join (
#     SELECT title, count(rental_rate) as top_ten_count
#     FROM film join film_category using (film_id)
#     GROUP BY title
#     ORDER BY title, MIN(rental_rate) DESC)
#     as TableA USING (title)
#
#     join (
#     SELECT title, count(*) as total_count
#     FROM film join inventory using (film_id)
#         join rental using (inventory_id)
#     GROUP BY title
#     ORDER BY title
#
#     ) as TableB USING (title)
# USING()
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 958 rows affected.
# [('Chamber Italian', 1, 13),
#  ('Grosse Wonderful', 1, 8),
#  ('Airport Pollock', 1, 18),
#  ('Bright Encounters', 1, 13),
#  ('Academy Dinosaur', 1, 23),
#  ('Ace Goldfinger', 1, 7),
#  ('Adaptation Holes', 1, 12),
#  ('Affair Prejudice', 1, 23),
#  ('African Egg', 1, 12),
#  ('Agent Truman', 1, 21),
#  ('Airplane Sierra', 1, 15),
#  ('Alabama Devil', 1, 12),
#  ('Aladdin Calendar', 1, 23),
#  ('Alamo Videotape', 1, 24),
#  ('Alaska Phantom', 1, 26),
#  ('Date Speed', 1, 13),
#  ('Ali Forever', 1, 9),
#  ('Alien Center', 1, 22),
#  ('Alley Evolution', 1, 14),
#  ('Alone Trip', 1, 18),
#  ('Alter Victory', 1, 22),
#  ('Amadeus Holy', 1, 21),
#  ('Amelie Hellfighters', 1, 10),
#  ('American Circus', 1, 22),
#  ('Amistad Midsummer', 1, 21),
#  ('Anaconda Confessions', 1, 21),
#  ('Analyze Hoosiers', 1, 14),
#  ('Angels Life', 1, 22),
#  ('Annie Identity', 1, 22),
#  ('Anonymous Human', 1, 13),
#  ('Anthem Luke', 1, 15),
#  ('Antitrust Tomatoes', 1, 10),
#  ('Anything Savannah', 1, 9),
#  ('Apache Divine', 1, 31),
#  ('Apocalypse Flamingos', 1, 6),
#  ('Arabia Dogma', 1, 13),
#  ('Arachnophobia Rollercoaster', 1, 24),
#  ('Arizona Bang', 1, 21),
#  ('Armageddon Lost', 1, 21),
#  ('Army Flintstones', 1, 16),
#  ('Artist Coldblooded', 1, 16),
#  ('Dying Maker', 1, 17),
#  ('Atlantis Cause', 1, 24),
#  ('Attacks Hate', 1, 16),
#  ('Attraction Newton', 1, 24),
#  ('Autumn Crow', 1, 11),
#  ('Baby Hall', 1, 8),
#  ('Backlash Undefeated', 1, 19),
#  ('Badman Dawn', 1, 21),
#  ('Baked Cleopatra', 1, 16),
#  ('Casualties Encino', 1, 9),
#  ('Balloon Homeward', 1, 23),
#  ('Ballroom Mockingbird', 1, 8),
#  ('Bang Kwai', 1, 7),
#  ('Banger Pinocchio', 1, 22),
#  ('Barbarella Streetcar', 1, 25),
#  ('Barefoot Manchurian', 1, 18),
#  ('Basic Easy', 1, 21),
#  ('Beach Heartbreakers', 1, 17),
#  ('Bear Graceland', 1, 22),
#  ('Beast Hunchback', 1, 11),
#  ('Beauty Grease', 1, 22),
#  ('Bed Highball', 1, 6),
#  ('Bedazzled Married', 1, 13),
#  ('Beethoven Exorcist', 1, 11),
#  ('Behavior Runaway', 1, 13),
#  ('Beneath Rush', 1, 10),
#  ('Berets Agent', 1, 21),
#  ('Betrayed Rear', 1, 15),
#  ('Beverly Outlaw', 1, 21),
#  ('Bikini Borrowers', 1, 17),
#  ('Bilko Anonymous', 1, 13),
#  ('Bill Others', 1, 19),
#  ('Bingo Talented', 1, 29),
#  ('Birch Antitrust', 1, 11),
#  ('Bird Independence', 1, 11),
#  ('Birdcage Casper', 1, 9),
#  ('Birds Perdition', 1, 18),
#  ('Blackout Private', 1, 27),
#  ('Blade Polish', 1, 22),
#  ('Blanket Beverly', 1, 12),
#  ('Blindness Gun', 1, 14),
#  ('Blood Argonauts', 1, 10),
#  ('Blues Instinct', 1, 21),
#  ('Boiled Dares', 1, 15),
#  ('Bonnie Holocaust', 1, 16),
#  ('Boogie Amelie', 1, 29),
#  ('Born Spinal', 1, 12),
#  ('Borrowers Bedazzled', 1, 22),
#  ('Boulevard Mob', 1, 18),
#  ('Bound Cheaper', 1, 24),
#  ('Bowfinger Gables', 1, 11),
#  ('Brannigan Sunrise', 1, 12),
#  ('Braveheart Human', 1, 5),
#  ('Breakfast Goldfinger', 1, 17),
#  ('Breaking Home', 1, 13),
#  ('Bride Intrigue', 1, 19),
#  ('Bringing Hysterical', 1, 20),
#  ('Brooklyn Desert', 1, 21),
#  ('Brotherhood Blanket', 1, 26),
#  ('Bubble Grosse', 1, 6),
#  ('Bucket Brotherhood', 1, 34),
#  ('Bugsy Song', 1, 11),
#  ('Bull Shawshank', 1, 16),
#  ('Bulworth Commandments', 1, 7),
#  ('Bunch Minds', 1, 5),
#  ('Butterfly Chocolat', 1, 30),
#  ('Cabin Flash', 1, 15),
#  ('Caddyshack Jedi', 1, 16),
#  ('Calendar Gunfight', 1, 21),
#  ('California Birds', 1, 12),
#  ('Camelot Vacation', 1, 27),
#  ('Campus Remember', 1, 19),
#  ('Candidate Perdition', 1, 18),
#  ('Candles Grapes', 1, 23),
#  ('Canyon Stock', 1, 19),
#  ('Caper Motions', 1, 24),
#  ('Caribbean Liberty', 1, 9),
#  ('Carol Texas', 1, 18),
#  ('Carrie Bunch', 1, 23),
#  ('Casablanca Super', 1, 16),
#  ('Casper Dragonfly', 1, 8),
#  ('Cassidy Wyoming', 1, 6),
#  ('Cat Coneheads', 1, 30),
#  ('Cause Date', 1, 21),
#  ('Celebrity Horn', 1, 24),
#  ('Center Dinosaur', 1, 24),
#  ('Chainsaw Uptown', 1, 21),
#  ('Champion Flatliners', 1, 13),
#  ('Chance Resurrection', 1, 27),
#  ('Clash Freddy', 1, 25),
#  ('Chaplin License', 1, 8),
#  ('Charade Duffel', 1, 15),
#  ('Chariots Conspiracy', 1, 21),
#  ('Chasing Fight', 1, 20),
#  ('Cheaper Clyde', 1, 20),
#  ('Chicago North', 1, 16),
#  ('Chicken Hellfighters', 1, 22),
#  ('Chill Luck', 1, 22),
#  ('Chisum Behavior', 1, 13),
#  ('Chitty Lock', 1, 8),
#  ('Chocolat Harry', 1, 20),
#  ('Christmas Moonshine', 1, 21),
#  ('Cider Desire', 1, 19),
#  ('Cincinatti Whisperer', 1, 13),
#  ('Circus Youth', 1, 15),
#  ('Citizen Shrek', 1, 13),
#  ('Cleopatra Devil', 1, 18),
#  ('Clerks Angels', 1, 7),
#  ('Clockwork Paradise', 1, 10),
#  ('Clones Pinocchio', 1, 19),
#  ('Closer Bang', 1, 28),
#  ('Club Graffiti', 1, 19),
#  ('Clue Grail', 1, 7),
#  ('Clueless Bucket', 1, 25),
#  ('Clyde Theory', 1, 8),
#  ('Coast Rainbow', 1, 21),
#  ('Core Suit', 1, 18),
#  ('Coldblooded Darling', 1, 16),
#  ('Color Philadelphia', 1, 24),
#  ('Coma Head', 1, 26),
#  ('Comancheros Enemy', 1, 6),
#  ('Comforts Rush', 1, 17),
#  ('Command Darling', 1, 16),
#  ('Coneheads Smoochy', 1, 25),
#  ('Confessions Maguire', 1, 14),
#  ('Confidential Interview', 1, 29),
#  ('Confused Candles', 1, 17),
#  ('Congeniality Quest', 1, 22),
#  ('Connecticut Tramp', 1, 13),
#  ('Connection Microcosmos', 1, 7),
#  ('Conquerer Nuts', 1, 16),
#  ('Conspiracy Spirit', 1, 5),
#  ('Contact Anonymous', 1, 26),
#  ('Control Anthem', 1, 7),
#  ('Conversation Downhill', 1, 17),
#  ('Cowboy Doom', 1, 7),
#  ('Craft Outfield', 1, 16),
#  ('Cranes Reservoir', 1, 11),
#  ('Crazy Home', 1, 9),
#  ('Creatures Shakespeare', 1, 16),
#  ('Creepers Kane', 1, 14),
#  ('Crooked Frogmen', 1, 23),
#  ('Crossroads Casualties', 1, 21),
#  ('Crow Grease', 1, 12),
#  ('Cruelty Unforgiven', 1, 7),
#  ('Crusade Honey', 1, 8),
#  ('Cupboard Sinners', 1, 23),
#  ('Curtain Videotape', 1, 27),
#  ('Cyclone Family', 1, 15),
#  ('Daddy Pittsburgh', 1, 13),
#  ('Daisy Menagerie', 1, 16),
#  ('Dalmations Sweden', 1, 20),
#  ('Dances None', 1, 14),
#  ('Dancing Fever', 1, 27),
#  ('Dangerous Uptown', 1, 12),
#  ('Dares Pluto', 1, 9),
#  ('Darkness War', 1, 13),
#  ('Darko Dorado', 1, 11),
#  ('Darling Breaking', 1, 9),
#  ('Darn Forrester', 1, 18),
#  ('Daughter Madigan', 1, 9),
#  ('Dawn Pond', 1, 18),
#  ('Day Unfaithful', 1, 14),
#  ('Deceiver Betrayed', 1, 21),
#  ('Deep Crusade', 1, 14),
#  ('Deer Virginian', 1, 29),
#  ('Desert Poseidon', 1, 19),
#  ('Desire Alien', 1, 8),
#  ('Desperate Trainspotting', 1, 6),
#  ('Destination Jerk', 1, 8),
#  ('Destiny Saturday', 1, 16),
#  ('Details Packer', 1, 19),
#  ('Detective Vision', 1, 27),
#  ('Devil Desire', 1, 15),
#  ('Diary Panic', 1, 9),
#  ('Dinosaur Secretary', 1, 20),
#  ('Dirty Ace', 1, 15),
#  ('Disciple Mother', 1, 19),
#  ('Disturbing Scarface', 1, 26),
#  ('Divide Monster', 1, 21),
#  ('Divine Resurrection', 1, 15),
#  ('Divorce Shining', 1, 7),
#  ('Doctor Grail', 1, 7),
#  ('Dogma Family', 1, 30),
#  ('Dolls Rage', 1, 9),
#  ('Donnie Alley', 1, 14),
#  ('Doom Dancing', 1, 21),
#  ('Doors President', 1, 19),
#  ('Dorado Notting', 1, 27),
#  ('Double Wrath', 1, 25),
#  ('Doubtfire Labyrinth', 1, 10),
#  ('Downhill Enough', 1, 25),
#  ('Dozen Lion', 1, 7),
#  ('Dracula Crystal', 1, 21),
#  ('Dragon Squad', 1, 11),
#  ('Dragonfly Strangers', 1, 18),
#  ('Dream Pickup', 1, 22),
#  ('Drifter Commandments', 1, 24),
#  ('Driver Annie', 1, 18),
#  ('Driving Polish', 1, 21),
#  ('Drop Waterfront', 1, 9),
#  ('Drumline Cyclone', 1, 11),
#  ('Drums Dynamite', 1, 13),
#  ('Duck Racer', 1, 6),
#  ('Dude Blindness', 1, 16),
#  ('Duffel Apocalypse', 1, 7),
#  ('Dumbo Lust', 1, 6),
#  ('Durham Panky', 1, 26),
#  ('Dwarfs Alter', 1, 9),
#  ('Dynamite Tarzan', 1, 25),
#  ('Eagles Panky', 1, 22),
#  ('Early Home', 1, 7),
#  ('Earring Instinct', 1, 19),
#  ('Earth Vision', 1, 23),
#  ('Easy Gladiator', 1, 23),
#  ('Edge Kissing', 1, 15),
#  ('Effect Gladiator', 1, 25),
#  ('Egg Igby', 1, 21),
#  ('Egypt Tenenbaums', 1, 17),
#  ('Element Freddy', 1, 10),
#  ('Elephant Trojan', 1, 14),
#  ('Elf Murder', 1, 7),
#  ('Elizabeth Shane', 1, 10),
#  ('Empire Malkovich', 1, 21),
#  ('Encino Elf', 1, 19),
#  ('Encounters Curtain', 1, 19),
#  ('Ending Crowds', 1, 11),
#  ('Enemy Odds', 1, 29),
#  ('English Bulworth', 1, 30),
#  ('Enough Raging', 1, 18),
#  ('Entrapment Satisfaction', 1, 15),
#  ('Escape Metropolis', 1, 25),
#  ('Eve Resurrection', 1, 7),
#  ('Everyone Craft', 1, 13),
#  ('Evolution Alter', 1, 12),
#  ('Excitement Eve', 1, 21),
#  ('Exorcist Sting', 1, 13),
#  ('Expecations Natural', 1, 18),
#  ('Expendable Stallion', 1, 28),
#  ('Express Lonely', 1, 13),
#  ('Extraordinary Conquerer', 1, 6),
#  ('Eyes Driving', 1, 19),
#  ('Factory Dragon', 1, 17),
#  ('Falcon Volume', 1, 22),
#  ('Family Sweet', 1, 29),
#  ('Fantasia Park', 1, 19),
#  ('Fantasy Troopers', 1, 26),
#  ('Fargo Gandhi', 1, 24),
#  ('Fatal Haunted', 1, 28),
#  ('Feathers Metal', 1, 11),
#  ('Fellowship Autumn', 1, 26),
#  ('Ferris Mother', 1, 17),
#  ('Feud Frogmen', 1, 25),
#  ('Fever Empire', 1, 5),
#  ('Fiction Christmas', 1, 19),
#  ('Fiddler Lost', 1, 10),
#  ('Fidelity Devil', 1, 21),
#  ('Fight Jawbreaker', 1, 22),
#  ('Finding Anaconda', 1, 12),
#  ('Fire Wolves', 1, 7),
#  ('Fireball Philadelphia', 1, 21),
#  ('Fish Opus', 1, 25),
#  ('Flamingos Connecticut', 1, 23),
#  ('Flash Wars', 1, 13),
#  ('Flatliners Killer', 1, 22),
#  ('Flight Lies', 1, 12),
#  ('Flintstones Happiness', 1, 17),
#  ('Flying Hook', 1, 20),
#  ('Fool Mockingbird', 1, 23),
#  ('Forever Candidate', 1, 13),
#  ('Forrest Sons', 1, 18),
#  ('Forrester Comancheros', 1, 27),
#  ('Forward Temple', 1, 32),
#  ('Freaky Pocus', 1, 17),
#  ('Freddy Storm', 1, 23),
#  ('Freedom Cleopatra', 1, 5),
#  ('French Holiday', 1, 17),
#  ('Frida Slipper', 1, 11),
#  ('Frisco Forrest', 1, 9),
#  ('Frogmen Breaking', 1, 10),
#  ('Frontier Cabin', 1, 6),
#  ('Frost Head', 1, 30),
#  ('Fugitive Maguire', 1, 11),
#  ('Full Flatliners', 1, 5),
#  ('Fury Murder', 1, 19),
#  ('Gables Metropolis', 1, 19),
#  ('Galaxy Sweethearts', 1, 18),
#  ('Games Bowfinger', 1, 14),
#  ('Gandhi Kwai', 1, 17),
#  ('Gangs Pride', 1, 27),
#  ('Garden Island', 1, 20),
#  ('Gaslight Crusade', 1, 16),
#  ('Gathering Calendar', 1, 11),
#  ('Gentlemen Stage', 1, 23),
#  ('Ghost Groundhog', 1, 21),
#  ('Ghostbusters Elf', 1, 9),
#  ('Giant Troopers', 1, 28),
#  ('Gilbert Pelican', 1, 9),
#  ('Gilmore Boiled', 1, 28),
#  ('Glass Dying', 1, 14),
#  ('Gleaming Jawbreaker', 1, 29),
#  ('Glory Tracy', 1, 5),
#  ('Go Purple', 1, 20),
#  ('Godfather Diary', 1, 8),
#  ('Gold River', 1, 14),
#  ('Goldfinger Sensibility', 1, 24),
#  ('Goldmine Tycoon', 1, 27),
#  ('Gone Trouble', 1, 10),
#  ('Goodfellas Salute', 1, 31),
#  ('Gorgeous Bingo', 1, 19),
#  ('Gosford Donnie', 1, 8),
#  ('Graceland Dynamite', 1, 6),
#  ('Graduate Lord', 1, 16),
#  ('Graffiti Love', 1, 30),
#  ('Grail Frankenstein', 1, 10),
#  ('Grapes Fury', 1, 22),
#  ('Grease Youth', 1, 21),
#  ('Greatest North', 1, 29),
#  ('Greedy Roots', 1, 14),
#  ('Greek Everyone', 1, 17),
#  ('Grinch Massage', 1, 14),
#  ('Grit Clockwork', 1, 32),
#  ('Groove Fiction', 1, 18),
#  ('Groundhog Uncut', 1, 18),
#  ('Gun Bonnie', 1, 25),
#  ('Gunfight Moon', 1, 24),
#  ('Gunfighter Mussolini', 1, 12),
#  ('Guys Falcon', 1, 9),
#  ('Half Outfield', 1, 26),
#  ('Hall Cassidy', 1, 16),
#  ('Halloween Nuts', 1, 10),
#  ('Hamlet Wisdom', 1, 14),
#  ('Identity Lover', 1, 13),
#  ('Handicap Boondock', 1, 28),
#  ('Hanging Deep', 1, 19),
#  ('Hanky October', 1, 26),
#  ('Hanover Galaxy', 1, 17),
#  ('Happiness United', 1, 6),
#  ('Hardly Robbers', 1, 4),
#  ('Harold French', 1, 8),
#  ('Harper Dying', 1, 20),
#  ('Harry Idaho', 1, 30),
#  ('Haunted Antitrust', 1, 6),
#  ('Haunting Pianist', 1, 22),
#  ('Hawk Chill', 1, 7),
#  ('Head Stranger', 1, 22),
#  ('Heartbreakers Bright', 1, 20),
#  ('Heaven Freedom', 1, 18),
#  ('Heavenly Gun', 1, 7),
#  ('Heavyweights Beast', 1, 23),
#  ('Hedwig Alter', 1, 12),
#  ('Hellfighters Sierra', 1, 20),
#  ('High Encino', 1, 22),
#  ('Highball Potter', 1, 21),
#  ('Hills Neighbors', 1, 25),
#  ('Hobbit Alien', 1, 31),
#  ('Holes Brannigan', 1, 15),
#  ('Holiday Games', 1, 15),
#  ('Hollow Jeopardy', 1, 10),
#  ('Hollywood Anonymous', 1, 13),
#  ('Holocaust Highball', 1, 17),
#  ('Holy Tadpole', 1, 9),
#  ('Home Pity', 1, 14),
#  ('Homeward Cider', 1, 16),
#  ('Homicide Peach', 1, 22),
#  ('Honey Ties', 1, 19),
#  ('Hook Chariots', 1, 13),
#  ('Idols Snatchers', 1, 30),
#  ('Hoosiers Birdcage', 1, 8),
#  ('Hope Tootsie', 1, 18),
#  ('Horn Working', 1, 24),
#  ('Horror Reign', 1, 27),
#  ('Hotel Happiness', 1, 9),
#  ('Hours Rage', 1, 19),
#  ('House Dynamite', 1, 23),
#  ('Human Graffiti', 1, 15),
#  ('Hunchback Impossible', 1, 20),
#  ('Hunger Roof', 1, 13),
#  ('Hunter Alter', 1, 5),
#  ('Hunting Musketeers', 1, 15),
#  ('Hurricane Affair', 1, 24),
#  ('Hustler Party', 1, 22),
#  ('Hyde Doctor', 1, 26),
#  ('Hysterical Grail', 1, 15),
#  ('Ice Crossing', 1, 24),
#  ('Idaho Love', 1, 17),
#  ('Igby Maker', 1, 19),
#  ('Illusion Amelie', 1, 15),
#  ('Image Princess', 1, 14),
#  ('Impact Aladdin', 1, 9),
#  ('Impossible Prejudice', 1, 14),
#  ('Inch Jet', 1, 18),
#  ('Independence Hotel', 1, 19),
#  ('Indian Love', 1, 16),
#  ('Informer Double', 1, 5),
#  ('Innocent Usual', 1, 26),
#  ('Insects Stone', 1, 18),
#  ('Insider Arizona', 1, 20),
#  ('Instinct Airport', 1, 18),
#  ('Intentions Empire', 1, 17),
#  ('Interview Liaisons', 1, 20),
#  ('Intolerable Intentions', 1, 9),
#  ('Intrigue Worst', 1, 20),
#  ('Invasion Cyclone', 1, 27),
#  ('Iron Moon', 1, 11),
#  ('Ishtar Rocketeer', 1, 7),
#  ('Island Exorcist', 1, 26),
#  ('Italian African', 1, 6),
#  ('Jacket Frisco', 1, 18),
#  ('Jade Bunch', 1, 18),
#  ('Japanese Run', 1, 6),
#  ('Jason Trap', 1, 24),
#  ('Jawbreaker Brooklyn', 1, 10),
#  ('Jaws Harry', 1, 14),
#  ('Jedi Beneath', 1, 19),
#  ('Jeepers Wedding', 1, 16),
#  ('Jekyll Frogmen', 1, 17),
#  ('Jeopardy Encino', 1, 10),
#  ('Jericho Mulan', 1, 17),
#  ('Jerk Paycheck', 1, 20),
#  ('Jersey Sassy', 1, 6),
#  ('Jet Neighbors', 1, 20),
#  ('Jingle Sagebrush', 1, 13),
#  ('Joon Northwest', 1, 17),
#  ('Juggler Hardly', 1, 32),
#  ('Jumanji Blade', 1, 8),
#  ('Jumping Wrath', 1, 24),
#  ('Jungle Closer', 1, 9),
#  ('Kane Exorcist', 1, 14),
#  ('Karate Moon', 1, 23),
#  ('Kick Savannah', 1, 20),
#  ('Killer Innocent', 1, 6),
#  ('King Evolution', 1, 9),
#  ('Kiss Glory', 1, 22),
#  ('Kissing Dolls', 1, 20),
#  ('Knock Warlock', 1, 24),
#  ('Kramer Chocolate', 1, 9),
#  ('Kwai Homeward', 1, 23),
#  ('Labyrinth League', 1, 15),
#  ('Rush Goodfellas', 1, 31),
#  ('Lady Stage', 1, 17),
#  ('Ladybugs Armageddon', 1, 6),
#  ('Lambs Cincinatti', 1, 10),
#  ('Language Cowboy', 1, 11),
#  ('Lawless Vision', 1, 17),
#  ('Lawrence Love', 1, 13),
#  ('League Hellfighters', 1, 17),
#  ('Leathernecks Dwarfs', 1, 7),
#  ('Lebowski Soldiers', 1, 21),
#  ('Legally Secretary', 1, 9),
#  ('Legend Jedi', 1, 9),
#  ('Lesson Cleopatra', 1, 7),
#  ('Liaisons Sweet', 1, 22),
#  ('Liberty Magnificent', 1, 12),
#  ('License Weekend', 1, 7),
#  ('Lies Treatment', 1, 27),
#  ('Life Twisted', 1, 10),
#  ('Lights Deer', 1, 8),
#  ('Mars Roman', 1, 19),
#  ('Lion Uncut', 1, 18),
#  ('Loathing Legally', 1, 27),
#  ('Lock Rear', 1, 16),
#  ('Lola Agent', 1, 24),
#  ('Lolita World', 1, 10),
#  ('Lonely Elephant', 1, 15),
#  ('Lord Arizona', 1, 11),
#  ('Lose Inch', 1, 27),
#  ('Loser Hustler', 1, 15),
#  ('Lost Bird', 1, 12),
#  ('Louisiana Harry', 1, 17),
#  ('Love Suicides', 1, 20),
#  ('Lovely Jingle', 1, 14),
#  ('Lover Truman', 1, 10),
#  ('Loverboy Attacks', 1, 12),
#  ('Luck Opus', 1, 10),
#  ('Lucky Flying', 1, 13),
#  ('Luke Mummy', 1, 7),
#  ('Mask Peach', 1, 17),
#  ('Lust Lock', 1, 15),
#  ('Madigan Dorado', 1, 10),
#  ('Madison Trap', 1, 15),
#  ('Madness Attacks', 1, 25),
#  ('Madre Gables', 1, 14),
#  ('Magic Mallrats', 1, 7),
#  ('Magnificent Chitty', 1, 8),
#  ('Magnolia Forrester', 1, 11),
#  ('Maguire Apache', 1, 9),
#  ('Maiden Home', 1, 24),
#  ('Majestic Floats', 1, 17),
#  ('Maker Gables', 1, 10),
#  ('Malkovich Pet', 1, 26),
#  ('Mallrats United', 1, 25),
#  ('Maltese Hope', 1, 22),
#  ('Manchurian Curtain', 1, 15),
#  ('Mannequin Worst', 1, 5),
#  ('Married Go', 1, 30),
#  ('Masked Bubble', 1, 20),
#  ('Massacre Usual', 1, 30),
#  ('Massage Image', 1, 12),
#  ('Matrix Snowman', 1, 9),
#  ('Maude Mod', 1, 8),
#  ('Meet Chocolate', 1, 12),
#  ('Memento Zoolander', 1, 13),
#  ('Menagerie Rushmore', 1, 7),
#  ('Mermaid Insects', 1, 16),
#  ('Metal Armageddon', 1, 25),
#  ('Metropolis Coma', 1, 26),
#  ('Microcosmos Paradise', 1, 13),
#  ('Midnight Westward', 1, 17),
#  ('Midsummer Groundhog', 1, 22),
#  ('Mighty Luck', 1, 12),
#  ('Mile Mulan', 1, 13),
#  ('Million Ace', 1, 20),
#  ('Minds Truman', 1, 20),
#  ('Mine Titans', 1, 19),
#  ('Minority Kiss', 1, 12),
#  ('Miracle Virtual', 1, 9),
#  ('Mission Zoolander', 1, 18),
#  ('Mixed Doors', 1, 4),
#  ('Mob Duffel', 1, 12),
#  ('Mockingbird Hollywood', 1, 24),
#  ('Mod Secretary', 1, 11),
#  ('Model Fish', 1, 15),
#  ('Modern Dorado', 1, 15),
#  ('Money Harold', 1, 20),
#  ('Monsoon Cause', 1, 9),
#  ('Monster Spartacus', 1, 15),
#  ('Monterey Labyrinth', 1, 13),
#  ('Montezuma Command', 1, 9),
#  ('Moon Bunch', 1, 29),
#  ('Moonshine Cabin', 1, 21),
#  ('Moonwalker Fool', 1, 13),
#  ('Mosquito Armageddon', 1, 15),
#  ('Mother Oleander', 1, 14),
#  ('Motions Details', 1, 16),
#  ('Moulin Wake', 1, 16),
#  ('Mourning Purple', 1, 21),
#  ('Movie Shakespeare', 1, 27),
#  ('Mulan Moon', 1, 13),
#  ('Mulholland Beast', 1, 7),
#  ('Mummy Creatures', 1, 16),
#  ('Murder Antitrust', 1, 23),
#  ('Muscle Bright', 1, 30),
#  ('Music Boondock', 1, 19),
#  ('Musketeers Wait', 1, 17),
#  ('Mussolini Spoilers', 1, 5),
#  ('Mystic Truman', 1, 10),
#  ('Name Detective', 1, 23),
#  ('Nash Chocolat', 1, 15),
#  ('National Story', 1, 19),
#  ('Natural Stock', 1, 13),
#  ('Necklace Outbreak', 1, 15),
#  ('Neighbors Charade', 1, 19),
#  ('Nemo Campus', 1, 14),
#  ('Network Peak', 1, 31),
#  ('Newsies Story', 1, 7),
#  ('Newton Labyrinth', 1, 17),
#  ('Nightmare Chill', 1, 25),
#  ('None Spiking', 1, 27),
#  ('Noon Papi', 1, 17),
#  ('North Tequila', 1, 11),
#  ('Northwest Polish', 1, 20),
#  ('Notorious Reunion', 1, 14),
#  ('Notting Speakeasy', 1, 10),
#  ('Novocaine Flight', 1, 19),
#  ('Nuts Ties', 1, 9),
#  ('October Submarine', 1, 11),
#  ('Odds Boogie', 1, 15),
#  ('Oklahoma Jumanji', 1, 6),
#  ('Oleander Clue', 1, 10),
#  ('Open African', 1, 21),
#  ('Operation Operation', 1, 27),
#  ('Opposite Necklace', 1, 13),
#  ('Opus Ice', 1, 11),
#  ('Orange Grapes', 1, 24),
#  ('Orient Closer', 1, 17),
#  ('Oscar Gold', 1, 25),
#  ('Others Soup', 1, 23),
#  ('Outbreak Divine', 1, 23),
#  ('Outfield Massacre', 1, 20),
#  ('Outlaw Hanky', 1, 14),
#  ('Oz Liaisons', 1, 24),
#  ('Pacific Amistad', 1, 24),
#  ('Packer Madigan', 1, 22),
#  ('Pajama Jawbreaker', 1, 14),
#  ('Panic Club', 1, 7),
#  ('Panky Submarine', 1, 15),
#  ('Panther Reds', 1, 15),
#  ('Papi Necklace', 1, 8),
#  ('Paradise Sabrina', 1, 18),
#  ('Paris Weekend', 1, 14),
#  ('Park Citizen', 1, 8),
#  ('Party Knock', 1, 13),
#  ('Past Suicides', 1, 13),
#  ('Paths Control', 1, 10),
#  ('Patient Sister', 1, 19),
#  ('Patriot Roman', 1, 16),
#  ('Patton Interview', 1, 23),
#  ('Paycheck Wait', 1, 16),
#  ('Peach Innocent', 1, 14),
#  ('Peak Forever', 1, 20),
#  ('Pelican Comforts', 1, 26),
#  ('Perfect Groove', 1, 17),
#  ('Personal Ladybugs', 1, 14),
#  ('Pet Haunting', 1, 8),
#  ('Phantom Glory', 1, 6),
#  ('Philadelphia Wife', 1, 23),
#  ('Pianist Outfield', 1, 21),
#  ('Pickup Driving', 1, 16),
#  ('Pilot Hoosiers', 1, 16),
#  ('Pinocchio Simon', 1, 20),
#  ('Pirates Roxanne', 1, 21),
#  ('Pittsburgh Hunchback', 1, 12),
#  ('Pity Bound', 1, 26),
#  ('Pizza Jumanji', 1, 7),
#  ('Platoon Instinct', 1, 9),
#  ('Pluto Oleander', 1, 16),
#  ('Pocus Pulp', 1, 26),
#  ('Polish Brooklyn', 1, 18),
#  ('Pollock Deliverance', 1, 18),
#  ('Pond Seattle', 1, 19),
#  ('Poseidon Forever', 1, 17),
#  ('Potluck Mixed', 1, 11),
#  ('Potter Connecticut', 1, 17),
#  ('Prejudice Oleander', 1, 20),
#  ('President Bang', 1, 7),
#  ('Pride Alamo', 1, 16),
#  ('Primary Glass', 1, 27),
#  ('Princess Giant', 1, 27),
#  ('Private Drop', 1, 5),
#  ('Prix Undefeated', 1, 11),
#  ('Pulp Beverly', 1, 30),
#  ('Punk Divorce', 1, 8),
#  ('Pure Runner', 1, 16),
#  ('Purple Movie', 1, 13),
#  ('Queen Luke', 1, 22),
#  ('Quest Mussolini', 1, 20),
#  ('Quills Bull', 1, 16),
#  ('Racer Egg', 1, 18),
#  ('Rage Games', 1, 19),
#  ('Raging Airplane', 1, 13),
#  ('Random Go', 1, 9),
#  ('Range Moonwalker', 1, 27),
#  ('Reap Unfaithful', 1, 16),
#  ('Rear Trading', 1, 17),
#  ('Rebel Airport', 1, 8),
#  ('Records Zorro', 1, 8),
#  ('Redemption Comforts', 1, 20),
#  ('Reds Pocus', 1, 9),
#  ('Reef Salute', 1, 11),
#  ('Reign Gentlemen', 1, 20),
#  ('Remember Diary', 1, 18),
#  ('Requiem Tycoon', 1, 19),
#  ('Reservoir Adaptation', 1, 10),
#  ('Resurrection Silverado', 1, 21),
#  ('Reunion Witches', 1, 20),
#  ('Rider Caddyshack', 1, 11),
#  ('Ridgemont Submarine', 1, 32),
#  ('Right Cranes', 1, 10),
#  ('Rings Heartbreakers', 1, 15),
#  ('River Outlaw', 1, 20),
#  ('Road Roxanne', 1, 19),
#  ('Robbers Joon', 1, 31),
#  ('Robbery Bright', 1, 13),
#  ('Rock Instinct', 1, 17),
#  ('Rocketeer Mother', 1, 33),
#  ('Rocky War', 1, 16),
#  ('Rollercoaster Bringing', 1, 10),
#  ('Roman Punk', 1, 24),
#  ('Room Roman', 1, 20),
#  ('Roots Remember', 1, 17),
#  ('Roses Treasure', 1, 28),
#  ('Rouge Squad', 1, 18),
#  ('Roxanne Rebel', 1, 19),
#  ('Rugrats Shakespeare', 1, 30),
#  ('Rules Human', 1, 16),
#  ('Run Pacific', 1, 10),
#  ('Runaway Tenenbaums', 1, 8),
#  ('Runner Madigan', 1, 8),
#  ('Rushmore Mermaid', 1, 6),
#  ('Sabrina Midnight', 1, 21),
#  ('Saddle Antitrust', 1, 14),
#  ('Sagebrush Clueless', 1, 16),
#  ('Saints Bride', 1, 8),
#  ('Salute Apollo', 1, 23),
#  ('Samurai Lion', 1, 25),
#  ('Santa Paris', 1, 11),
#  ('Sassy Packer', 1, 13),
#  ('Satisfaction Confidential', 1, 17),
#  ('Saturday Lambs', 1, 28),
#  ('Saturn Name', 1, 13),
#  ('Savannah Town', 1, 12),
#  ('Scalawag Duck', 1, 32),
#  ('Scarface Bang', 1, 18),
#  ('School Jacket', 1, 6),
#  ('Scissorhands Slums', 1, 15),
#  ('Ship Wonderland', 1, 15),
#  ('Scorpion Apollo', 1, 23),
#  ('Sea Virgin', 1, 22),
#  ('Seabiscuit Punk', 1, 26),
#  ('Searchers Wait', 1, 14),
#  ('Seattle Expecations', 1, 24),
#  ('Secret Groundhog', 1, 21),
#  ('Secretary Rouge', 1, 18),
#  ('Secrets Paradise', 1, 20),
#  ('Sense Greek', 1, 7),
#  ('Sensibility Rear', 1, 10),
#  ('Seven Swarm', 1, 5),
#  ('Shakespeare Saddle', 1, 22),
#  ('Shane Darkness', 1, 14),
#  ('Shanghai Tycoon', 1, 14),
#  ('Shawshank Bubble', 1, 19),
#  ('Shepherd Midsummer', 1, 25),
#  ('Shining Roses', 1, 8),
#  ('Shock Cabin', 1, 30),
#  ('Shootist Superfly', 1, 24),
#  ('Show Lord', 1, 25),
#  ('Shrek License', 1, 15),
#  ('Shrunk Divine', 1, 14),
#  ('Side Ark', 1, 12),
#  ('Siege Madre', 1, 15),
#  ('Sierra Divide', 1, 15),
#  ('Silence Kane', 1, 16),
#  ('Silverado Goldfinger', 1, 12),
#  ('Simon North', 1, 6),
#  ('Sinners Atlantis', 1, 22),
#  ('Slacker Liaisons', 1, 17),
#  ('Sleeping Suspects', 1, 24),
#  ('Sleepless Monsoon', 1, 20),
#  ('Sleepy Japanese', 1, 21),
#  ('Sleuth Orient', 1, 21),
#  ('Sling Luke', 1, 6),
#  ('Slipper Fidelity', 1, 16),
#  ('Slums Duck', 1, 24),
#  ('Smile Earring', 1, 10),
#  ('Smoking Barbarella', 1, 18),
#  ('Smoochy Control', 1, 12),
#  ('Snatch Slipper', 1, 22),
#  ('Snatchers Montezuma', 1, 9),
#  ('Snowman Rollercoaster', 1, 23),
#  ('Soldiers Evolution', 1, 8),
#  ('Something Duck', 1, 19),
#  ('Song Hedwig', 1, 11),
#  ('Sons Interview', 1, 15),
#  ('Sorority Queen', 1, 12),
#  ('Soup Wisdom', 1, 8),
#  ('South Wait', 1, 22),
#  ('Spartacus Cheaper', 1, 9),
#  ('Speakeasy Date', 1, 12),
#  ('Speed Suit', 1, 9),
#  ('Spice Sorority', 1, 20),
#  ('Spiking Element', 1, 13),
#  ('Spinal Rocky', 1, 13),
#  ('Spirit Flintstones', 1, 15),
#  ('Spirited Casualties', 1, 11),
#  ('Splash Gump', 1, 14),
#  ('Splendor Patton', 1, 21),
#  ('Spoilers Hellfighters', 1, 10),
#  ('Spy Mile', 1, 27),
#  ('Squad Fish', 1, 7),
#  ('Stage World', 1, 10),
#  ('Stagecoach Armageddon', 1, 26),
#  ('Stallion Sundance', 1, 7),
#  ('Stampede Disturbing', 1, 14),
#  ('Star Operation', 1, 21),
#  ('State Wasteland', 1, 13),
#  ('Steel Santa', 1, 23),
#  ('Steers Armageddon', 1, 15),
#  ('Stepmom Dream', 1, 20),
#  ('Sting Personal', 1, 21),
#  ('Stock Glass', 1, 14),
#  ('Stone Fire', 1, 11),
#  ('Storm Happiness', 1, 29),
#  ('Story Side', 1, 28),
#  ('Straight Hours', 1, 20),
#  ('Strangelove Desire', 1, 24),
#  ('Stranger Strangers', 1, 11),
#  ('Tights Dawn', 1, 26),
#  ('Strangers Graffiti', 1, 17),
#  ('Streak Ridgemont', 1, 16),
#  ('Streetcar Intentions', 1, 25),
#  ('Strictly Scarface', 1, 23),
#  ('Submarine Bed', 1, 15),
#  ('Sugar Wonka', 1, 17),
#  ('Suit Walls', 1, 21),
#  ('Summer Scarface', 1, 16),
#  ('Sun Confessions', 1, 25),
#  ('Sundance Invasion', 1, 19),
#  ('Sunrise League', 1, 24),
#  ('Sunset Racer', 1, 8),
#  ('Super Wyoming', 1, 13),
#  ('Superfly Trip', 1, 10),
#  ('Suspects Quills', 1, 30),
#  ('Swarm Gold', 1, 27),
#  ('Sweden Shining', 1, 18),
#  ('Timberland Sky', 1, 31),
#  ('Sweet Brotherhood', 1, 15),
#  ('Sweethearts Suspects', 1, 29),
#  ('Talented Homicide', 1, 29),
#  ('Tarzan Videotape', 1, 8),
#  ('Taxi Kick', 1, 17),
#  ('Teen Apollo', 1, 17),
#  ('Telegraph Voyage', 1, 27),
#  ('Telemark Heartbreakers', 1, 25),
#  ('Temple Attraction', 1, 12),
#  ('Tenenbaums Command', 1, 13),
#  ('Tequila Past', 1, 6),
#  ('Terminator Club', 1, 6),
#  ('Texas Watch', 1, 6),
#  ('Theory Mermaid', 1, 11),
#  ('Thief Pelican', 1, 19),
#  ('Thin Sagebrush', 1, 11),
#  ('Ties Hunger', 1, 11),
#  ('Titanic Boondock', 1, 23),
#  ('Titans Jerk', 1, 29),
#  ('Tomatoes Hellfighters', 1, 14),
#  ('Tomorrow Hustler', 1, 25),
#  ('Tootsie Pilot', 1, 15),
#  ('Torque Bound', 1, 27),
#  ('Tourist Pelican', 1, 22),
#  ('Towers Hurricane', 1, 11),
#  ('Town Ark', 1, 14),
#  ('Tracy Cider', 1, 26),
#  ('Trading Pinocchio', 1, 25),
#  ('Traffic Hobbit', 1, 5),
#  ('Train Bunch', 1, 4),
#  ('Trainspotting Strangers', 1, 11),
#  ('Tramp Others', 1, 20),
#  ('Translation Summer', 1, 15),
#  ('Trap Guys', 1, 16),
#  ('Treatment Jekyll', 1, 7),
#  ('Trip Newton', 1, 28),
#  ('Trojan Tomorrow', 1, 19),
#  ('Troopers Metal', 1, 14),
#  ('Trouble Date', 1, 23),
#  ('Truman Crazy', 1, 23),
#  ('Turn Star', 1, 14),
#  ('Tuxedo Mile', 1, 13),
#  ('Twisted Pirates', 1, 11),
#  ('Tycoon Gathering', 1, 12),
#  ('Unbreakable Karate', 1, 21),
#  ('Uncut Suicides', 1, 14),
#  ('Undefeated Dalmations', 1, 21),
#  ('Unfaithful Kill', 1, 8),
#  ('Unforgiven Zoolander', 1, 18),
#  ('United Pilot', 1, 17),
#  ('Untouchables Sunrise', 1, 8),
#  ('Uprising Uptown', 1, 16),
#  ('Uptown Young', 1, 12),
#  ('Usual Untouchables', 1, 13),
#  ('Vacation Boondock', 1, 21),
#  ('Valentine Vanishing', 1, 12),
#  ('Valley Packer', 1, 15),
#  ('Vampire Whale', 1, 12),
#  ('Vanilla Day', 1, 9),
#  ('Vanished Garden', 1, 7),
#  ('Vanishing Rocky', 1, 18),
#  ('Varsity Trip', 1, 16),
#  ('Velvet Terminator', 1, 26),
#  ('Vertigo Northwest', 1, 8),
#  ('Victory Academy', 1, 9),
#  ('Videotape Arsenic', 1, 29),
#  ('Vietnam Smoochy', 1, 15),
#  ('Virgin Daisy', 1, 17),
#  ('Virginian Pluto', 1, 29),
#  ('Virtual Spoilers', 1, 14),
#  ('Vision Torque', 1, 7),
#  ('Voice Peach', 1, 19),
#  ('Volcano Texas', 1, 22),
#  ('Voyage Legally', 1, 28),
#  ('Wagon Jaws', 1, 10),
#  ('Wait Cider', 1, 21),
#  ('Wanda Chamber', 1, 16),
#  ('War Notting', 1, 12),
#  ('Wardrobe Phantom', 1, 27),
#  ('Warlock Werewolf', 1, 6),
#  ('Wars Pluto', 1, 10),
#  ('Wash Heavenly', 1, 23),
#  ('Wasteland Divine', 1, 15),
#  ('Watch Tracy', 1, 16),
#  ('Waterfront Deliverance', 1, 17),
#  ('Watership Frontier', 1, 6),
#  ('Wedding Apollo', 1, 24),
#  ('Weekend Personal', 1, 18),
#  ('Werewolf Lola', 1, 14),
#  ('West Lion', 1, 16),
#  ('Westward Seabiscuit', 1, 26),
#  ('Whale Bikini', 1, 18),
#  ('Whisperer Giant', 1, 22),
#  ('Wife Turn', 1, 31),
#  ('Wild Apollo', 1, 6),
#  ('Willow Tracy', 1, 16),
#  ('Wind Phantom', 1, 23),
#  ('Window Side', 1, 12),
#  ('Wisdom Worker', 1, 9),
#  ('Witches Panic', 1, 30),
#  ('Wizard Coldblooded', 1, 16),
#  ('Wolves Desire', 1, 21),
#  ('Women Dorado', 1, 23),
#  ('Won Dares', 1, 9),
#  ('Wonderful Drop', 1, 9),
#  ('Wonderland Christmas', 1, 22),
#  ('Wonka Sea', 1, 18),
#  ('Words Hunter', 1, 16),
#  ('Worker Tarzan', 1, 15),
#  ('Working Microcosmos', 1, 25),
#  ('World Leathernecks', 1, 8),
#  ('Worst Banger', 1, 16),
#  ('Wrath Mile', 1, 14),
#  ('Wrong Behavior', 1, 20),
#  ('Wyoming Storm', 1, 13),
#  ('Yentl Idaho', 1, 23),
#  ('Young Language', 1, 7),
#  ('Youth Kick', 1, 6),
#  ('Zhivago Core', 1, 9),
#  ('Zoolander Fiction', 1, 17),
#  ('Zorro Ark', 1, 31)]

# %%
# %%sql
# SELECT distinct title, count(*)
# from film
# join inventory USING (film_id)
# join rental USING (inventory_id)
#     GROUP BY title
#     ORDER BY title
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 958 rows affected.
# [('Academy Dinosaur', 23),
#  ('Ace Goldfinger', 7),
#  ('Adaptation Holes', 12),
#  ('Affair Prejudice', 23),
#  ('African Egg', 12),
#  ('Agent Truman', 21),
#  ('Airplane Sierra', 15),
#  ('Airport Pollock', 18),
#  ('Alabama Devil', 12),
#  ('Aladdin Calendar', 23),
#  ('Alamo Videotape', 24),
#  ('Alaska Phantom', 26),
#  ('Alien Center', 22),
#  ('Ali Forever', 9),
#  ('Alley Evolution', 14),
#  ('Alone Trip', 18),
#  ('Alter Victory', 22),
#  ('Amadeus Holy', 21),
#  ('Amelie Hellfighters', 10),
#  ('American Circus', 22),
#  ('Amistad Midsummer', 21),
#  ('Anaconda Confessions', 21),
#  ('Analyze Hoosiers', 14),
#  ('Angels Life', 22),
#  ('Annie Identity', 22),
#  ('Anonymous Human', 13),
#  ('Anthem Luke', 15),
#  ('Antitrust Tomatoes', 10),
#  ('Anything Savannah', 9),
#  ('Apache Divine', 31),
#  ('Apocalypse Flamingos', 6),
#  ('Arabia Dogma', 13),
#  ('Arachnophobia Rollercoaster', 24),
#  ('Arizona Bang', 21),
#  ('Armageddon Lost', 21),
#  ('Army Flintstones', 16),
#  ('Artist Coldblooded', 16),
#  ('Atlantis Cause', 24),
#  ('Attacks Hate', 16),
#  ('Attraction Newton', 24),
#  ('Autumn Crow', 11),
#  ('Baby Hall', 8),
#  ('Backlash Undefeated', 19),
#  ('Badman Dawn', 21),
#  ('Baked Cleopatra', 16),
#  ('Balloon Homeward', 23),
#  ('Ballroom Mockingbird', 8),
#  ('Banger Pinocchio', 22),
#  ('Bang Kwai', 7),
#  ('Barbarella Streetcar', 25),
#  ('Barefoot Manchurian', 18),
#  ('Basic Easy', 21),
#  ('Beach Heartbreakers', 17),
#  ('Bear Graceland', 22),
#  ('Beast Hunchback', 11),
#  ('Beauty Grease', 22),
#  ('Bedazzled Married', 13),
#  ('Bed Highball', 6),
#  ('Beethoven Exorcist', 11),
#  ('Behavior Runaway', 13),
#  ('Beneath Rush', 10),
#  ('Berets Agent', 21),
#  ('Betrayed Rear', 15),
#  ('Beverly Outlaw', 21),
#  ('Bikini Borrowers', 17),
#  ('Bilko Anonymous', 13),
#  ('Bill Others', 19),
#  ('Bingo Talented', 29),
#  ('Birch Antitrust', 11),
#  ('Birdcage Casper', 9),
#  ('Bird Independence', 11),
#  ('Birds Perdition', 18),
#  ('Blackout Private', 27),
#  ('Blade Polish', 22),
#  ('Blanket Beverly', 12),
#  ('Blindness Gun', 14),
#  ('Blood Argonauts', 10),
#  ('Blues Instinct', 21),
#  ('Boiled Dares', 15),
#  ('Bonnie Holocaust', 16),
#  ('Boogie Amelie', 29),
#  ('Born Spinal', 12),
#  ('Borrowers Bedazzled', 22),
#  ('Boulevard Mob', 18),
#  ('Bound Cheaper', 24),
#  ('Bowfinger Gables', 11),
#  ('Brannigan Sunrise', 12),
#  ('Braveheart Human', 5),
#  ('Breakfast Goldfinger', 17),
#  ('Breaking Home', 13),
#  ('Bride Intrigue', 19),
#  ('Bright Encounters', 13),
#  ('Bringing Hysterical', 20),
#  ('Brooklyn Desert', 21),
#  ('Brotherhood Blanket', 26),
#  ('Bubble Grosse', 6),
#  ('Bucket Brotherhood', 34),
#  ('Bugsy Song', 11),
#  ('Bull Shawshank', 16),
#  ('Bulworth Commandments', 7),
#  ('Bunch Minds', 5),
#  ('Butterfly Chocolat', 30),
#  ('Cabin Flash', 15),
#  ('Caddyshack Jedi', 16),
#  ('Calendar Gunfight', 21),
#  ('California Birds', 12),
#  ('Camelot Vacation', 27),
#  ('Campus Remember', 19),
#  ('Candidate Perdition', 18),
#  ('Candles Grapes', 23),
#  ('Canyon Stock', 19),
#  ('Caper Motions', 24),
#  ('Caribbean Liberty', 9),
#  ('Carol Texas', 18),
#  ('Carrie Bunch', 23),
#  ('Casablanca Super', 16),
#  ('Casper Dragonfly', 8),
#  ('Cassidy Wyoming', 6),
#  ('Casualties Encino', 9),
#  ('Cat Coneheads', 30),
#  ('Cause Date', 21),
#  ('Celebrity Horn', 24),
#  ('Center Dinosaur', 24),
#  ('Chainsaw Uptown', 21),
#  ('Chamber Italian', 13),
#  ('Champion Flatliners', 13),
#  ('Chance Resurrection', 27),
#  ('Chaplin License', 8),
#  ('Charade Duffel', 15),
#  ('Chariots Conspiracy', 21),
#  ('Chasing Fight', 20),
#  ('Cheaper Clyde', 20),
#  ('Chicago North', 16),
#  ('Chicken Hellfighters', 22),
#  ('Chill Luck', 22),
#  ('Chisum Behavior', 13),
#  ('Chitty Lock', 8),
#  ('Chocolat Harry', 20),
#  ('Christmas Moonshine', 21),
#  ('Cider Desire', 19),
#  ('Cincinatti Whisperer', 13),
#  ('Circus Youth', 15),
#  ('Citizen Shrek', 13),
#  ('Clash Freddy', 25),
#  ('Cleopatra Devil', 18),
#  ('Clerks Angels', 7),
#  ('Clockwork Paradise', 10),
#  ('Clones Pinocchio', 19),
#  ('Closer Bang', 28),
#  ('Club Graffiti', 19),
#  ('Clue Grail', 7),
#  ('Clueless Bucket', 25),
#  ('Clyde Theory', 8),
#  ('Coast Rainbow', 21),
#  ('Coldblooded Darling', 16),
#  ('Color Philadelphia', 24),
#  ('Coma Head', 26),
#  ('Comancheros Enemy', 6),
#  ('Comforts Rush', 17),
#  ('Command Darling', 16),
#  ('Coneheads Smoochy', 25),
#  ('Confessions Maguire', 14),
#  ('Confidential Interview', 29),
#  ('Confused Candles', 17),
#  ('Congeniality Quest', 22),
#  ('Connecticut Tramp', 13),
#  ('Connection Microcosmos', 7),
#  ('Conquerer Nuts', 16),
#  ('Conspiracy Spirit', 5),
#  ('Contact Anonymous', 26),
#  ('Control Anthem', 7),
#  ('Conversation Downhill', 17),
#  ('Core Suit', 18),
#  ('Cowboy Doom', 7),
#  ('Craft Outfield', 16),
#  ('Cranes Reservoir', 11),
#  ('Crazy Home', 9),
#  ('Creatures Shakespeare', 16),
#  ('Creepers Kane', 14),
#  ('Crooked Frogmen', 23),
#  ('Crossroads Casualties', 21),
#  ('Crow Grease', 12),
#  ('Cruelty Unforgiven', 7),
#  ('Crusade Honey', 8),
#  ('Cupboard Sinners', 23),
#  ('Curtain Videotape', 27),
#  ('Cyclone Family', 15),
#  ('Daddy Pittsburgh', 13),
#  ('Daisy Menagerie', 16),
#  ('Dalmations Sweden', 20),
#  ('Dances None', 14),
#  ('Dancing Fever', 27),
#  ('Dangerous Uptown', 12),
#  ('Dares Pluto', 9),
#  ('Darkness War', 13),
#  ('Darko Dorado', 11),
#  ('Darling Breaking', 9),
#  ('Darn Forrester', 18),
#  ('Date Speed', 13),
#  ('Daughter Madigan', 9),
#  ('Dawn Pond', 18),
#  ('Day Unfaithful', 14),
#  ('Deceiver Betrayed', 21),
#  ('Deep Crusade', 14),
#  ('Deer Virginian', 29),
#  ('Desert Poseidon', 19),
#  ('Desire Alien', 8),
#  ('Desperate Trainspotting', 6),
#  ('Destination Jerk', 8),
#  ('Destiny Saturday', 16),
#  ('Details Packer', 19),
#  ('Detective Vision', 27),
#  ('Devil Desire', 15),
#  ('Diary Panic', 9),
#  ('Dinosaur Secretary', 20),
#  ('Dirty Ace', 15),
#  ('Disciple Mother', 19),
#  ('Disturbing Scarface', 26),
#  ('Divide Monster', 21),
#  ('Divine Resurrection', 15),
#  ('Divorce Shining', 7),
#  ('Doctor Grail', 7),
#  ('Dogma Family', 30),
#  ('Dolls Rage', 9),
#  ('Donnie Alley', 14),
#  ('Doom Dancing', 21),
#  ('Doors President', 19),
#  ('Dorado Notting', 27),
#  ('Double Wrath', 25),
#  ('Doubtfire Labyrinth', 10),
#  ('Downhill Enough', 25),
#  ('Dozen Lion', 7),
#  ('Dracula Crystal', 21),
#  ('Dragonfly Strangers', 18),
#  ('Dragon Squad', 11),
#  ('Dream Pickup', 22),
#  ('Drifter Commandments', 24),
#  ('Driver Annie', 18),
#  ('Driving Polish', 21),
#  ('Drop Waterfront', 9),
#  ('Drumline Cyclone', 11),
#  ('Drums Dynamite', 13),
#  ('Duck Racer', 6),
#  ('Dude Blindness', 16),
#  ('Duffel Apocalypse', 7),
#  ('Dumbo Lust', 6),
#  ('Durham Panky', 26),
#  ('Dwarfs Alter', 9),
#  ('Dying Maker', 17),
#  ('Dynamite Tarzan', 25),
#  ('Eagles Panky', 22),
#  ('Early Home', 7),
#  ('Earring Instinct', 19),
#  ('Earth Vision', 23),
#  ('Easy Gladiator', 23),
#  ('Edge Kissing', 15),
#  ('Effect Gladiator', 25),
#  ('Egg Igby', 21),
#  ('Egypt Tenenbaums', 17),
#  ('Element Freddy', 10),
#  ('Elephant Trojan', 14),
#  ('Elf Murder', 7),
#  ('Elizabeth Shane', 10),
#  ('Empire Malkovich', 21),
#  ('Encino Elf', 19),
#  ('Encounters Curtain', 19),
#  ('Ending Crowds', 11),
#  ('Enemy Odds', 29),
#  ('English Bulworth', 30),
#  ('Enough Raging', 18),
#  ('Entrapment Satisfaction', 15),
#  ('Escape Metropolis', 25),
#  ('Eve Resurrection', 7),
#  ('Everyone Craft', 13),
#  ('Evolution Alter', 12),
#  ('Excitement Eve', 21),
#  ('Exorcist Sting', 13),
#  ('Expecations Natural', 18),
#  ('Expendable Stallion', 28),
#  ('Express Lonely', 13),
#  ('Extraordinary Conquerer', 6),
#  ('Eyes Driving', 19),
#  ('Factory Dragon', 17),
#  ('Falcon Volume', 22),
#  ('Family Sweet', 29),
#  ('Fantasia Park', 19),
#  ('Fantasy Troopers', 26),
#  ('Fargo Gandhi', 24),
#  ('Fatal Haunted', 28),
#  ('Feathers Metal', 11),
#  ('Fellowship Autumn', 26),
#  ('Ferris Mother', 17),
#  ('Feud Frogmen', 25),
#  ('Fever Empire', 5),
#  ('Fiction Christmas', 19),
#  ('Fiddler Lost', 10),
#  ('Fidelity Devil', 21),
#  ('Fight Jawbreaker', 22),
#  ('Finding Anaconda', 12),
#  ('Fireball Philadelphia', 21),
#  ('Fire Wolves', 7),
#  ('Fish Opus', 25),
#  ('Flamingos Connecticut', 23),
#  ('Flash Wars', 13),
#  ('Flatliners Killer', 22),
#  ('Flight Lies', 12),
#  ('Flintstones Happiness', 17),
#  ('Flying Hook', 20),
#  ('Fool Mockingbird', 23),
#  ('Forever Candidate', 13),
#  ('Forrester Comancheros', 27),
#  ('Forrest Sons', 18),
#  ('Forward Temple', 32),
#  ('Freaky Pocus', 17),
#  ('Freddy Storm', 23),
#  ('Freedom Cleopatra', 5),
#  ('French Holiday', 17),
#  ('Frida Slipper', 11),
#  ('Frisco Forrest', 9),
#  ('Frogmen Breaking', 10),
#  ('Frontier Cabin', 6),
#  ('Frost Head', 30),
#  ('Fugitive Maguire', 11),
#  ('Full Flatliners', 5),
#  ('Fury Murder', 19),
#  ('Gables Metropolis', 19),
#  ('Galaxy Sweethearts', 18),
#  ('Games Bowfinger', 14),
#  ('Gandhi Kwai', 17),
#  ('Gangs Pride', 27),
#  ('Garden Island', 20),
#  ('Gaslight Crusade', 16),
#  ('Gathering Calendar', 11),
#  ('Gentlemen Stage', 23),
#  ('Ghostbusters Elf', 9),
#  ('Ghost Groundhog', 21),
#  ('Giant Troopers', 28),
#  ('Gilbert Pelican', 9),
#  ('Gilmore Boiled', 28),
#  ('Glass Dying', 14),
#  ('Gleaming Jawbreaker', 29),
#  ('Glory Tracy', 5),
#  ('Godfather Diary', 8),
#  ('Goldfinger Sensibility', 24),
#  ('Goldmine Tycoon', 27),
#  ('Gold River', 14),
#  ('Gone Trouble', 10),
#  ('Goodfellas Salute', 31),
#  ('Go Purple', 20),
#  ('Gorgeous Bingo', 19),
#  ('Gosford Donnie', 8),
#  ('Graceland Dynamite', 6),
#  ('Graduate Lord', 16),
#  ('Graffiti Love', 30),
#  ('Grail Frankenstein', 10),
#  ('Grapes Fury', 22),
#  ('Grease Youth', 21),
#  ('Greatest North', 29),
#  ('Greedy Roots', 14),
#  ('Greek Everyone', 17),
#  ('Grinch Massage', 14),
#  ('Grit Clockwork', 32),
#  ('Groove Fiction', 18),
#  ('Grosse Wonderful', 8),
#  ('Groundhog Uncut', 18),
#  ('Gun Bonnie', 25),
#  ('Gunfighter Mussolini', 12),
#  ('Gunfight Moon', 24),
#  ('Guys Falcon', 9),
#  ('Half Outfield', 26),
#  ('Hall Cassidy', 16),
#  ('Halloween Nuts', 10),
#  ('Hamlet Wisdom', 14),
#  ('Handicap Boondock', 28),
#  ('Hanging Deep', 19),
#  ('Hanky October', 26),
#  ('Hanover Galaxy', 17),
#  ('Happiness United', 6),
#  ('Hardly Robbers', 4),
#  ('Harold French', 8),
#  ('Harper Dying', 20),
#  ('Harry Idaho', 30),
#  ('Haunted Antitrust', 6),
#  ('Haunting Pianist', 22),
#  ('Hawk Chill', 7),
#  ('Head Stranger', 22),
#  ('Heartbreakers Bright', 20),
#  ('Heaven Freedom', 18),
#  ('Heavenly Gun', 7),
#  ('Heavyweights Beast', 23),
#  ('Hedwig Alter', 12),
#  ('Hellfighters Sierra', 20),
#  ('Highball Potter', 21),
#  ('High Encino', 22),
#  ('Hills Neighbors', 25),
#  ('Hobbit Alien', 31),
#  ('Holes Brannigan', 15),
#  ('Holiday Games', 15),
#  ('Hollow Jeopardy', 10),
#  ('Hollywood Anonymous', 13),
#  ('Holocaust Highball', 17),
#  ('Holy Tadpole', 9),
#  ('Home Pity', 14),
#  ('Homeward Cider', 16),
#  ('Homicide Peach', 22),
#  ('Honey Ties', 19),
#  ('Hook Chariots', 13),
#  ('Hoosiers Birdcage', 8),
#  ('Hope Tootsie', 18),
#  ('Horn Working', 24),
#  ('Horror Reign', 27),
#  ('Hotel Happiness', 9),
#  ('Hours Rage', 19),
#  ('House Dynamite', 23),
#  ('Human Graffiti', 15),
#  ('Hunchback Impossible', 20),
#  ('Hunger Roof', 13),
#  ('Hunter Alter', 5),
#  ('Hunting Musketeers', 15),
#  ('Hurricane Affair', 24),
#  ('Hustler Party', 22),
#  ('Hyde Doctor', 26),
#  ('Hysterical Grail', 15),
#  ('Ice Crossing', 24),
#  ('Idaho Love', 17),
#  ('Identity Lover', 13),
#  ('Idols Snatchers', 30),
#  ('Igby Maker', 19),
#  ('Illusion Amelie', 15),
#  ('Image Princess', 14),
#  ('Impact Aladdin', 9),
#  ('Impossible Prejudice', 14),
#  ('Inch Jet', 18),
#  ('Independence Hotel', 19),
#  ('Indian Love', 16),
#  ('Informer Double', 5),
#  ('Innocent Usual', 26),
#  ('Insects Stone', 18),
#  ('Insider Arizona', 20),
#  ('Instinct Airport', 18),
#  ('Intentions Empire', 17),
#  ('Interview Liaisons', 20),
#  ('Intolerable Intentions', 9),
#  ('Intrigue Worst', 20),
#  ('Invasion Cyclone', 27),
#  ('Iron Moon', 11),
#  ('Ishtar Rocketeer', 7),
#  ('Island Exorcist', 26),
#  ('Italian African', 6),
#  ('Jacket Frisco', 18),
#  ('Jade Bunch', 18),
#  ('Japanese Run', 6),
#  ('Jason Trap', 24),
#  ('Jawbreaker Brooklyn', 10),
#  ('Jaws Harry', 14),
#  ('Jedi Beneath', 19),
#  ('Jeepers Wedding', 16),
#  ('Jekyll Frogmen', 17),
#  ('Jeopardy Encino', 10),
#  ('Jericho Mulan', 17),
#  ('Jerk Paycheck', 20),
#  ('Jersey Sassy', 6),
#  ('Jet Neighbors', 20),
#  ('Jingle Sagebrush', 13),
#  ('Joon Northwest', 17),
#  ('Juggler Hardly', 32),
#  ('Jumanji Blade', 8),
#  ('Jumping Wrath', 24),
#  ('Jungle Closer', 9),
#  ('Kane Exorcist', 14),
#  ('Karate Moon', 23),
#  ('Kick Savannah', 20),
#  ('Killer Innocent', 6),
#  ('King Evolution', 9),
#  ('Kiss Glory', 22),
#  ('Kissing Dolls', 20),
#  ('Knock Warlock', 24),
#  ('Kramer Chocolate', 9),
#  ('Kwai Homeward', 23),
#  ('Labyrinth League', 15),
#  ('Ladybugs Armageddon', 6),
#  ('Lady Stage', 17),
#  ('Lambs Cincinatti', 10),
#  ('Language Cowboy', 11),
#  ('Lawless Vision', 17),
#  ('Lawrence Love', 13),
#  ('League Hellfighters', 17),
#  ('Leathernecks Dwarfs', 7),
#  ('Lebowski Soldiers', 21),
#  ('Legally Secretary', 9),
#  ('Legend Jedi', 9),
#  ('Lesson Cleopatra', 7),
#  ('Liaisons Sweet', 22),
#  ('Liberty Magnificent', 12),
#  ('License Weekend', 7),
#  ('Lies Treatment', 27),
#  ('Life Twisted', 10),
#  ('Lights Deer', 8),
#  ('Lion Uncut', 18),
#  ('Loathing Legally', 27),
#  ('Lock Rear', 16),
#  ('Lola Agent', 24),
#  ('Lolita World', 10),
#  ('Lonely Elephant', 15),
#  ('Lord Arizona', 11),
#  ('Lose Inch', 27),
#  ('Loser Hustler', 15),
#  ('Lost Bird', 12),
#  ('Louisiana Harry', 17),
#  ('Lovely Jingle', 14),
#  ('Loverboy Attacks', 12),
#  ('Lover Truman', 10),
#  ('Love Suicides', 20),
#  ('Luck Opus', 10),
#  ('Lucky Flying', 13),
#  ('Luke Mummy', 7),
#  ('Lust Lock', 15),
#  ('Madigan Dorado', 10),
#  ('Madison Trap', 15),
#  ('Madness Attacks', 25),
#  ('Madre Gables', 14),
#  ('Magic Mallrats', 7),
#  ('Magnificent Chitty', 8),
#  ('Magnolia Forrester', 11),
#  ('Maguire Apache', 9),
#  ('Maiden Home', 24),
#  ('Majestic Floats', 17),
#  ('Maker Gables', 10),
#  ('Malkovich Pet', 26),
#  ('Mallrats United', 25),
#  ('Maltese Hope', 22),
#  ('Manchurian Curtain', 15),
#  ('Mannequin Worst', 5),
#  ('Married Go', 30),
#  ('Mars Roman', 19),
#  ('Masked Bubble', 20),
#  ('Mask Peach', 17),
#  ('Massacre Usual', 30),
#  ('Massage Image', 12),
#  ('Matrix Snowman', 9),
#  ('Maude Mod', 8),
#  ('Meet Chocolate', 12),
#  ('Memento Zoolander', 13),
#  ('Menagerie Rushmore', 7),
#  ('Mermaid Insects', 16),
#  ('Metal Armageddon', 25),
#  ('Metropolis Coma', 26),
#  ('Microcosmos Paradise', 13),
#  ('Midnight Westward', 17),
#  ('Midsummer Groundhog', 22),
#  ('Mighty Luck', 12),
#  ('Mile Mulan', 13),
#  ('Million Ace', 20),
#  ('Minds Truman', 20),
#  ('Mine Titans', 19),
#  ('Minority Kiss', 12),
#  ('Miracle Virtual', 9),
#  ('Mission Zoolander', 18),
#  ('Mixed Doors', 4),
#  ('Mob Duffel', 12),
#  ('Mockingbird Hollywood', 24),
#  ('Model Fish', 15),
#  ('Modern Dorado', 15),
#  ('Mod Secretary', 11),
#  ('Money Harold', 20),
#  ('Monsoon Cause', 9),
#  ('Monster Spartacus', 15),
#  ('Monterey Labyrinth', 13),
#  ('Montezuma Command', 9),
#  ('Moon Bunch', 29),
#  ('Moonshine Cabin', 21),
#  ('Moonwalker Fool', 13),
#  ('Mosquito Armageddon', 15),
#  ('Mother Oleander', 14),
#  ('Motions Details', 16),
#  ('Moulin Wake', 16),
#  ('Mourning Purple', 21),
#  ('Movie Shakespeare', 27),
#  ('Mulan Moon', 13),
#  ('Mulholland Beast', 7),
#  ('Mummy Creatures', 16),
#  ('Murder Antitrust', 23),
#  ('Muscle Bright', 30),
#  ('Music Boondock', 19),
#  ('Musketeers Wait', 17),
#  ('Mussolini Spoilers', 5),
#  ('Mystic Truman', 10),
#  ('Name Detective', 23),
#  ('Nash Chocolat', 15),
#  ('National Story', 19),
#  ('Natural Stock', 13),
#  ('Necklace Outbreak', 15),
#  ('Neighbors Charade', 19),
#  ('Nemo Campus', 14),
#  ('Network Peak', 31),
#  ('Newsies Story', 7),
#  ('Newton Labyrinth', 17),
#  ('Nightmare Chill', 25),
#  ('None Spiking', 27),
#  ('Noon Papi', 17),
#  ('North Tequila', 11),
#  ('Northwest Polish', 20),
#  ('Notorious Reunion', 14),
#  ('Notting Speakeasy', 10),
#  ('Novocaine Flight', 19),
#  ('Nuts Ties', 9),
#  ('October Submarine', 11),
#  ('Odds Boogie', 15),
#  ('Oklahoma Jumanji', 6),
#  ('Oleander Clue', 10),
#  ('Open African', 21),
#  ('Operation Operation', 27),
#  ('Opposite Necklace', 13),
#  ('Opus Ice', 11),
#  ('Orange Grapes', 24),
#  ('Orient Closer', 17),
#  ('Oscar Gold', 25),
#  ('Others Soup', 23),
#  ('Outbreak Divine', 23),
#  ('Outfield Massacre', 20),
#  ('Outlaw Hanky', 14),
#  ('Oz Liaisons', 24),
#  ('Pacific Amistad', 24),
#  ('Packer Madigan', 22),
#  ('Pajama Jawbreaker', 14),
#  ('Panic Club', 7),
#  ('Panky Submarine', 15),
#  ('Panther Reds', 15),
#  ('Papi Necklace', 8),
#  ('Paradise Sabrina', 18),
#  ('Paris Weekend', 14),
#  ('Park Citizen', 8),
#  ('Party Knock', 13),
#  ('Past Suicides', 13),
#  ('Paths Control', 10),
#  ('Patient Sister', 19),
#  ('Patriot Roman', 16),
#  ('Patton Interview', 23),
#  ('Paycheck Wait', 16),
#  ('Peach Innocent', 14),
#  ('Peak Forever', 20),
#  ('Pelican Comforts', 26),
#  ('Perfect Groove', 17),
#  ('Personal Ladybugs', 14),
#  ('Pet Haunting', 8),
#  ('Phantom Glory', 6),
#  ('Philadelphia Wife', 23),
#  ('Pianist Outfield', 21),
#  ('Pickup Driving', 16),
#  ('Pilot Hoosiers', 16),
#  ('Pinocchio Simon', 20),
#  ('Pirates Roxanne', 21),
#  ('Pittsburgh Hunchback', 12),
#  ('Pity Bound', 26),
#  ('Pizza Jumanji', 7),
#  ('Platoon Instinct', 9),
#  ('Pluto Oleander', 16),
#  ('Pocus Pulp', 26),
#  ('Polish Brooklyn', 18),
#  ('Pollock Deliverance', 18),
#  ('Pond Seattle', 19),
#  ('Poseidon Forever', 17),
#  ('Potluck Mixed', 11),
#  ('Potter Connecticut', 17),
#  ('Prejudice Oleander', 20),
#  ('President Bang', 7),
#  ('Pride Alamo', 16),
#  ('Primary Glass', 27),
#  ('Princess Giant', 27),
#  ('Private Drop', 5),
#  ('Prix Undefeated', 11),
#  ('Pulp Beverly', 30),
#  ('Punk Divorce', 8),
#  ('Pure Runner', 16),
#  ('Purple Movie', 13),
#  ('Queen Luke', 22),
#  ('Quest Mussolini', 20),
#  ('Quills Bull', 16),
#  ('Racer Egg', 18),
#  ('Rage Games', 19),
#  ('Raging Airplane', 13),
#  ('Random Go', 9),
#  ('Range Moonwalker', 27),
#  ('Reap Unfaithful', 16),
#  ('Rear Trading', 17),
#  ('Rebel Airport', 8),
#  ('Records Zorro', 8),
#  ('Redemption Comforts', 20),
#  ('Reds Pocus', 9),
#  ('Reef Salute', 11),
#  ('Reign Gentlemen', 20),
#  ('Remember Diary', 18),
#  ('Requiem Tycoon', 19),
#  ('Reservoir Adaptation', 10),
#  ('Resurrection Silverado', 21),
#  ('Reunion Witches', 20),
#  ('Rider Caddyshack', 11),
#  ('Ridgemont Submarine', 32),
#  ('Right Cranes', 10),
#  ('Rings Heartbreakers', 15),
#  ('River Outlaw', 20),
#  ('Road Roxanne', 19),
#  ('Robbers Joon', 31),
#  ('Robbery Bright', 13),
#  ('Rocketeer Mother', 33),
#  ('Rock Instinct', 17),
#  ('Rocky War', 16),
#  ('Rollercoaster Bringing', 10),
#  ('Roman Punk', 24),
#  ('Room Roman', 20),
#  ('Roots Remember', 17),
#  ('Roses Treasure', 28),
#  ('Rouge Squad', 18),
#  ('Roxanne Rebel', 19),
#  ('Rugrats Shakespeare', 30),
#  ('Rules Human', 16),
#  ('Runaway Tenenbaums', 8),
#  ('Runner Madigan', 8),
#  ('Run Pacific', 10),
#  ('Rush Goodfellas', 31),
#  ('Rushmore Mermaid', 6),
#  ('Sabrina Midnight', 21),
#  ('Saddle Antitrust', 14),
#  ('Sagebrush Clueless', 16),
#  ('Saints Bride', 8),
#  ('Salute Apollo', 23),
#  ('Samurai Lion', 25),
#  ('Santa Paris', 11),
#  ('Sassy Packer', 13),
#  ('Satisfaction Confidential', 17),
#  ('Saturday Lambs', 28),
#  ('Saturn Name', 13),
#  ('Savannah Town', 12),
#  ('Scalawag Duck', 32),
#  ('Scarface Bang', 18),
#  ('School Jacket', 6),
#  ('Scissorhands Slums', 15),
#  ('Scorpion Apollo', 23),
#  ('Seabiscuit Punk', 26),
#  ('Searchers Wait', 14),
#  ('Seattle Expecations', 24),
#  ('Sea Virgin', 22),
#  ('Secretary Rouge', 18),
#  ('Secret Groundhog', 21),
#  ('Secrets Paradise', 20),
#  ('Sense Greek', 7),
#  ('Sensibility Rear', 10),
#  ('Seven Swarm', 5),
#  ('Shakespeare Saddle', 22),
#  ('Shane Darkness', 14),
#  ('Shanghai Tycoon', 14),
#  ('Shawshank Bubble', 19),
#  ('Shepherd Midsummer', 25),
#  ('Shining Roses', 8),
#  ('Ship Wonderland', 15),
#  ('Shock Cabin', 30),
#  ('Shootist Superfly', 24),
#  ('Show Lord', 25),
#  ('Shrek License', 15),
#  ('Shrunk Divine', 14),
#  ('Side Ark', 12),
#  ('Siege Madre', 15),
#  ('Sierra Divide', 15),
#  ('Silence Kane', 16),
#  ('Silverado Goldfinger', 12),
#  ('Simon North', 6),
#  ('Sinners Atlantis', 22),
#  ('Slacker Liaisons', 17),
#  ('Sleeping Suspects', 24),
#  ('Sleepless Monsoon', 20),
#  ('Sleepy Japanese', 21),
#  ('Sleuth Orient', 21),
#  ('Sling Luke', 6),
#  ('Slipper Fidelity', 16),
#  ('Slums Duck', 24),
#  ('Smile Earring', 10),
#  ('Smoking Barbarella', 18),
#  ('Smoochy Control', 12),
#  ('Snatchers Montezuma', 9),
#  ('Snatch Slipper', 22),
#  ('Snowman Rollercoaster', 23),
#  ('Soldiers Evolution', 8),
#  ('Something Duck', 19),
#  ('Song Hedwig', 11),
#  ('Sons Interview', 15),
#  ('Sorority Queen', 12),
#  ('Soup Wisdom', 8),
#  ('South Wait', 22),
#  ('Spartacus Cheaper', 9),
#  ('Speakeasy Date', 12),
#  ('Speed Suit', 9),
#  ('Spice Sorority', 20),
#  ('Spiking Element', 13),
#  ('Spinal Rocky', 13),
#  ('Spirited Casualties', 11),
#  ('Spirit Flintstones', 15),
#  ('Splash Gump', 14),
#  ('Splendor Patton', 21),
#  ('Spoilers Hellfighters', 10),
#  ('Spy Mile', 27),
#  ('Squad Fish', 7),
#  ('Stagecoach Armageddon', 26),
#  ('Stage World', 10),
#  ('Stallion Sundance', 7),
#  ('Stampede Disturbing', 14),
#  ('Star Operation', 21),
#  ('State Wasteland', 13),
#  ('Steel Santa', 23),
#  ('Steers Armageddon', 15),
#  ('Stepmom Dream', 20),
#  ('Sting Personal', 21),
#  ('Stock Glass', 14),
#  ('Stone Fire', 11),
#  ('Storm Happiness', 29),
#  ('Story Side', 28),
#  ('Straight Hours', 20),
#  ('Strangelove Desire', 24),
#  ('Strangers Graffiti', 17),
#  ('Stranger Strangers', 11),
#  ('Streak Ridgemont', 16),
#  ('Streetcar Intentions', 25),
#  ('Strictly Scarface', 23),
#  ('Submarine Bed', 15),
#  ('Sugar Wonka', 17),
#  ('Suit Walls', 21),
#  ('Summer Scarface', 16),
#  ('Sun Confessions', 25),
#  ('Sundance Invasion', 19),
#  ('Sunrise League', 24),
#  ('Sunset Racer', 8),
#  ('Superfly Trip', 10),
#  ('Super Wyoming', 13),
#  ('Suspects Quills', 30),
#  ('Swarm Gold', 27),
#  ('Sweden Shining', 18),
#  ('Sweet Brotherhood', 15),
#  ('Sweethearts Suspects', 29),
#  ('Talented Homicide', 29),
#  ('Tarzan Videotape', 8),
#  ('Taxi Kick', 17),
#  ('Teen Apollo', 17),
#  ('Telegraph Voyage', 27),
#  ('Telemark Heartbreakers', 25),
#  ('Temple Attraction', 12),
#  ('Tenenbaums Command', 13),
#  ('Tequila Past', 6),
#  ('Terminator Club', 6),
#  ('Texas Watch', 6),
#  ('Theory Mermaid', 11),
#  ('Thief Pelican', 19),
#  ('Thin Sagebrush', 11),
#  ('Ties Hunger', 11),
#  ('Tights Dawn', 26),
#  ('Timberland Sky', 31),
#  ('Titanic Boondock', 23),
#  ('Titans Jerk', 29),
#  ('Tomatoes Hellfighters', 14),
#  ('Tomorrow Hustler', 25),
#  ('Tootsie Pilot', 15),
#  ('Torque Bound', 27),
#  ('Tourist Pelican', 22),
#  ('Towers Hurricane', 11),
#  ('Town Ark', 14),
#  ('Tracy Cider', 26),
#  ('Trading Pinocchio', 25),
#  ('Traffic Hobbit', 5),
#  ('Train Bunch', 4),
#  ('Trainspotting Strangers', 11),
#  ('Tramp Others', 20),
#  ('Translation Summer', 15),
#  ('Trap Guys', 16),
#  ('Treatment Jekyll', 7),
#  ('Trip Newton', 28),
#  ('Trojan Tomorrow', 19),
#  ('Troopers Metal', 14),
#  ('Trouble Date', 23),
#  ('Truman Crazy', 23),
#  ('Turn Star', 14),
#  ('Tuxedo Mile', 13),
#  ('Twisted Pirates', 11),
#  ('Tycoon Gathering', 12),
#  ('Unbreakable Karate', 21),
#  ('Uncut Suicides', 14),
#  ('Undefeated Dalmations', 21),
#  ('Unfaithful Kill', 8),
#  ('Unforgiven Zoolander', 18),
#  ('United Pilot', 17),
#  ('Untouchables Sunrise', 8),
#  ('Uprising Uptown', 16),
#  ('Uptown Young', 12),
#  ('Usual Untouchables', 13),
#  ('Vacation Boondock', 21),
#  ('Valentine Vanishing', 12),
#  ('Valley Packer', 15),
#  ('Vampire Whale', 12),
#  ('Vanilla Day', 9),
#  ('Vanished Garden', 7),
#  ('Vanishing Rocky', 18),
#  ('Varsity Trip', 16),
#  ('Velvet Terminator', 26),
#  ('Vertigo Northwest', 8),
#  ('Victory Academy', 9),
#  ('Videotape Arsenic', 29),
#  ('Vietnam Smoochy', 15),
#  ('Virgin Daisy', 17),
#  ('Virginian Pluto', 29),
#  ('Virtual Spoilers', 14),
#  ('Vision Torque', 7),
#  ('Voice Peach', 19),
#  ('Volcano Texas', 22),
#  ('Voyage Legally', 28),
#  ('Wagon Jaws', 10),
#  ('Wait Cider', 21),
#  ('Wanda Chamber', 16),
#  ('Wardrobe Phantom', 27),
#  ('Warlock Werewolf', 6),
#  ('War Notting', 12),
#  ('Wars Pluto', 10),
#  ('Wash Heavenly', 23),
#  ('Wasteland Divine', 15),
#  ('Watch Tracy', 16),
#  ('Waterfront Deliverance', 17),
#  ('Watership Frontier', 6),
#  ('Wedding Apollo', 24),
#  ('Weekend Personal', 18),
#  ('Werewolf Lola', 14),
#  ('West Lion', 16),
#  ('Westward Seabiscuit', 26),
#  ('Whale Bikini', 18),
#  ('Whisperer Giant', 22),
#  ('Wife Turn', 31),
#  ('Wild Apollo', 6),
#  ('Willow Tracy', 16),
#  ('Window Side', 12),
#  ('Wind Phantom', 23),
#  ('Wisdom Worker', 9),
#  ('Witches Panic', 30),
#  ('Wizard Coldblooded', 16),
#  ('Wolves Desire', 21),
#  ('Women Dorado', 23),
#  ('Won Dares', 9),
#  ('Wonderful Drop', 9),
#  ('Wonderland Christmas', 22),
#  ('Wonka Sea', 18),
#  ('Words Hunter', 16),
#  ('Worker Tarzan', 15),
#  ('Working Microcosmos', 25),
#  ('World Leathernecks', 8),
#  ('Worst Banger', 16),
#  ('Wrath Mile', 14),
#  ('Wrong Behavior', 20),
#  ('Wyoming Storm', 13),
#  ('Yentl Idaho', 23),
#  ('Young Language', 7),
#  ('Youth Kick', 6),
#  ('Zhivago Core', 9),
#  ('Zoolander Fiction', 17),
#  ('Zorro Ark', 31)]

# %%
# %%sql
#
# select distinct title, total_count, top_ten_count
# from film f join (
#     SELECT title, MAX(rental_rate) as top_ten_count
#     FROM film join inventory using (film_id)
#     GROUP BY title
#     ORDER BY title, MAX(rental_rate) DESC
# ) as TableA USING (title)
#
#     join (
#     SELECT title, count(*) as total_count
#     FROM film join inventory using (film_id)
#         join rental using (inventory_id)
#     GROUP BY title
#     ORDER BY title
# ) as TableB using (title)
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 958 rows affected.
# [('Borrowers Bedazzled', 22, Decimal('0.99')),
#  ('Strangelove Desire', 24, Decimal('0.99')),
#  ('Iron Moon', 11, Decimal('4.99')),
#  ('Grosse Wonderful', 8, Decimal('4.99')),
#  ('Sagebrush Clueless', 16, Decimal('2.99')),
#  ('Lord Arizona', 11, Decimal('2.99')),
#  ('Language Cowboy', 11, Decimal('0.99')),
#  ('Northwest Polish', 20, Decimal('2.99')),
#  ('Paths Control', 10, Decimal('4.99')),
#  ('Mission Zoolander', 18, Decimal('4.99')),
#  ('Louisiana Harry', 17, Decimal('0.99')),
#  ('Escape Metropolis', 25, Decimal('2.99')),
#  ('Witches Panic', 30, Decimal('4.99')),
#  ('Human Graffiti', 15, Decimal('2.99')),
#  ('Untouchables Sunrise', 8, Decimal('2.99')),
#  ('Searchers Wait', 14, Decimal('2.99')),
#  ('Potter Connecticut', 17, Decimal('2.99')),
#  ('Wait Cider', 21, Decimal('0.99')),
#  ('Flash Wars', 13, Decimal('4.99')),
#  ('Connection Microcosmos', 7, Decimal('0.99')),
#  ('Antitrust Tomatoes', 10, Decimal('2.99')),
#  ('Pulp Beverly', 30, Decimal('2.99')),
#  ('Garden Island', 20, Decimal('4.99')),
#  ('State Wasteland', 13, Decimal('2.99')),
#  ('Academy Dinosaur', 23, Decimal('0.99')),
#  ('Rush Goodfellas', 31, Decimal('0.99')),
#  ('Gaslight Crusade', 16, Decimal('2.99')),
#  ('Greedy Roots', 14, Decimal('0.99')),
#  ('Bright Encounters', 13, Decimal('4.99')),
#  ('Daddy Pittsburgh', 13, Decimal('4.99')),
#  ('Bang Kwai', 7, Decimal('2.99')),
#  ('Roman Punk', 24, Decimal('0.99')),
#  ('Falcon Volume', 22, Decimal('4.99')),
#  ('Sierra Divide', 15, Decimal('0.99')),
#  ('Hustler Party', 22, Decimal('4.99')),
#  ('Blanket Beverly', 12, Decimal('2.99')),
#  ('Perfect Groove', 17, Decimal('2.99')),
#  ('Amadeus Holy', 21, Decimal('0.99')),
#  ('Airport Pollock', 18, Decimal('4.99')),
#  ('Joon Northwest', 17, Decimal('0.99')),
#  ('Seattle Expecations', 24, Decimal('4.99')),
#  ('Analyze Hoosiers', 14, Decimal('2.99')),
#  ('Sting Personal', 21, Decimal('4.99')),
#  ('Fugitive Maguire', 11, Decimal('4.99')),
#  ('Magnolia Forrester', 11, Decimal('0.99')),
#  ('Personal Ladybugs', 14, Decimal('0.99')),
#  ('Stagecoach Armageddon', 26, Decimal('4.99')),
#  ('Sorority Queen', 12, Decimal('0.99')),
#  ('Dances None', 14, Decimal('0.99')),
#  ('Conversation Downhill', 17, Decimal('4.99')),
#  ('Doom Dancing', 21, Decimal('0.99')),
#  ('Caper Motions', 24, Decimal('0.99')),
#  ('Streetcar Intentions', 25, Decimal('4.99')),
#  ('Sling Luke', 6, Decimal('0.99')),
#  ('Double Wrath', 25, Decimal('0.99')),
#  ('Peak Forever', 20, Decimal('4.99')),
#  ('Suspects Quills', 30, Decimal('2.99')),
#  ('Roots Remember', 17, Decimal('0.99')),
#  ('Gleaming Jawbreaker', 29, Decimal('2.99')),
#  ('Disciple Mother', 19, Decimal('0.99')),
#  ('Trainspotting Strangers', 11, Decimal('4.99')),
#  ('Neighbors Charade', 19, Decimal('0.99')),
#  ('Phantom Glory', 6, Decimal('2.99')),
#  ('Mockingbird Hollywood', 24, Decimal('0.99')),
#  ('Anthem Luke', 15, Decimal('4.99')),
#  ('Mourning Purple', 21, Decimal('0.99')),
#  ('Illusion Amelie', 15, Decimal('0.99')),
#  ('Juggler Hardly', 32, Decimal('0.99')),
#  ('Stage World', 10, Decimal('2.99')),
#  ('Godfather Diary', 8, Decimal('2.99')),
#  ('Squad Fish', 7, Decimal('2.99')),
#  ('Titans Jerk', 29, Decimal('4.99')),
#  ('Alter Victory', 22, Decimal('0.99')),
#  ('Alamo Videotape', 24, Decimal('0.99')),
#  ('Zorro Ark', 31, Decimal('4.99')),
#  ('Dorado Notting', 27, Decimal('4.99')),
#  ('Panky Submarine', 15, Decimal('4.99')),
#  ('Kiss Glory', 22, Decimal('4.99')),
#  ('Fire Wolves', 7, Decimal('4.99')),
#  ('Rider Caddyshack', 11, Decimal('2.99')),
#  ('Deceiver Betrayed', 21, Decimal('0.99')),
#  ('Papi Necklace', 8, Decimal('0.99')),
#  ('Vanilla Day', 9, Decimal('4.99')),
#  ('Slums Duck', 24, Decimal('0.99')),
#  ('Shrek License', 15, Decimal('2.99')),
#  ('Mars Roman', 19, Decimal('0.99')),
#  ('Forrester Comancheros', 27, Decimal('4.99')),
#  ('Swarm Gold', 27, Decimal('0.99')),
#  ('Gangs Pride', 27, Decimal('2.99')),
#  ('Kissing Dolls', 20, Decimal('4.99')),
#  ('Park Citizen', 8, Decimal('4.99')),
#  ('Coma Head', 26, Decimal('4.99')),
#  ('Young Language', 7, Decimal('0.99')),
#  ('Blood Argonauts', 10, Decimal('0.99')),
#  ('War Notting', 12, Decimal('4.99')),
#  ('Victory Academy', 9, Decimal('0.99')),
#  ('Robbers Joon', 31, Decimal('2.99')),
#  ('Finding Anaconda', 12, Decimal('0.99')),
#  ('Clerks Angels', 7, Decimal('4.99')),
#  ('Bringing Hysterical', 20, Decimal('2.99')),
#  ('Memento Zoolander', 13, Decimal('4.99')),
#  ('Elizabeth Shane', 10, Decimal('4.99')),
#  ('Tramp Others', 20, Decimal('0.99')),
#  ('Midsummer Groundhog', 22, Decimal('4.99')),
#  ('Gunfight Moon', 24, Decimal('0.99')),
#  ('Shawshank Bubble', 19, Decimal('4.99')),
#  ('Comancheros Enemy', 6, Decimal('0.99')),
#  ('West Lion', 16, Decimal('4.99')),
#  ('Feathers Metal', 11, Decimal('0.99')),
#  ('Purple Movie', 13, Decimal('2.99')),
#  ('High Encino', 22, Decimal('2.99')),
#  ('Sunset Racer', 8, Decimal('0.99')),
#  ('Princess Giant', 27, Decimal('2.99')),
#  ('Saddle Antitrust', 14, Decimal('2.99')),
#  ('Thief Pelican', 19, Decimal('4.99')),
#  ('Mosquito Armageddon', 15, Decimal('0.99')),
#  ('Inch Jet', 18, Decimal('4.99')),
#  ('Jericho Mulan', 17, Decimal('2.99')),
#  ('Divide Monster', 21, Decimal('2.99')),
#  ('Outbreak Divine', 23, Decimal('0.99')),
#  ('Ishtar Rocketeer', 7, Decimal('4.99')),
#  ('Harold French', 8, Decimal('0.99')),
#  ('Open African', 21, Decimal('4.99')),
#  ('Guys Falcon', 9, Decimal('4.99')),
#  ('Factory Dragon', 17, Decimal('0.99')),
#  ('Italian African', 6, Decimal('4.99')),
#  ('Invasion Cyclone', 27, Decimal('2.99')),
#  ('Wash Heavenly', 23, Decimal('4.99')),
#  ('Apocalypse Flamingos', 6, Decimal('4.99')),
#  ('Newsies Story', 7, Decimal('0.99')),
#  ('Groove Fiction', 18, Decimal('0.99')),
#  ('Goodfellas Salute', 31, Decimal('4.99')),
#  ('Carol Texas', 18, Decimal('2.99')),
#  ('Secret Groundhog', 21, Decimal('4.99')),
#  ('Holiday Games', 15, Decimal('4.99')),
#  ('Holes Brannigan', 15, Decimal('4.99')),
#  ('Independence Hotel', 19, Decimal('0.99')),
#  ('Citizen Shrek', 13, Decimal('0.99')),
#  ('Coldblooded Darling', 16, Decimal('4.99')),
#  ('Heavenly Gun', 7, Decimal('4.99')),
#  ('Egg Igby', 21, Decimal('2.99')),
#  ('License Weekend', 7, Decimal('2.99')),
#  ('Empire Malkovich', 21, Decimal('0.99')),
#  ('Caddyshack Jedi', 16, Decimal('0.99')),
#  ('Vanished Garden', 7, Decimal('0.99')),
#  ('Oklahoma Jumanji', 6, Decimal('0.99')),
#  ('Reds Pocus', 9, Decimal('4.99')),
#  ('Sinners Atlantis', 22, Decimal('2.99')),
#  ('Express Lonely', 13, Decimal('2.99')),
#  ('Lost Bird', 12, Decimal('2.99')),
#  ('Suit Walls', 21, Decimal('4.99')),
#  ('Love Suicides', 20, Decimal('0.99')),
#  ('Frogmen Breaking', 10, Decimal('0.99')),
#  ('Artist Coldblooded', 16, Decimal('2.99')),
#  ('Details Packer', 19, Decimal('4.99')),
#  ('Train Bunch', 4, Decimal('4.99')),
#  ('Hook Chariots', 13, Decimal('0.99')),
#  ('Dancing Fever', 27, Decimal('0.99')),
#  ('Cleopatra Devil', 18, Decimal('0.99')),
#  ('Spoilers Hellfighters', 10, Decimal('0.99')),
#  ('Novocaine Flight', 19, Decimal('0.99')),
#  ('Dangerous Uptown', 12, Decimal('4.99')),
#  ('Dalmations Sweden', 20, Decimal('0.99')),
#  ('Paradise Sabrina', 18, Decimal('2.99')),
#  ('School Jacket', 6, Decimal('4.99')),
#  ('Kane Exorcist', 14, Decimal('0.99')),
#  ('Hunchback Impossible', 20, Decimal('4.99')),
#  ('Wife Turn', 31, Decimal('4.99')),
#  ('Hanging Deep', 19, Decimal('4.99')),
#  ('Driver Annie', 18, Decimal('2.99')),
#  ('Clyde Theory', 8, Decimal('0.99')),
#  ('Madre Gables', 14, Decimal('2.99')),
#  ('Creepers Kane', 14, Decimal('4.99')),
#  ('Worker Tarzan', 15, Decimal('2.99')),
#  ('Bikini Borrowers', 17, Decimal('4.99')),
#  ('Loverboy Attacks', 12, Decimal('0.99')),
#  ('Alien Center', 22, Decimal('2.99')),
#  ('Maker Gables', 10, Decimal('0.99')),
#  ('Cheaper Clyde', 20, Decimal('0.99')),
#  ('Working Microcosmos', 25, Decimal('4.99')),
#  ('Show Lord', 25, Decimal('4.99')),
#  ('Lebowski Soldiers', 21, Decimal('2.99')),
#  ('Gathering Calendar', 11, Decimal('0.99')),
#  ('Raging Airplane', 13, Decimal('4.99')),
#  ('Bound Cheaper', 24, Decimal('0.99')),
#  ('Ridgemont Submarine', 32, Decimal('0.99')),
#  ('Uncut Suicides', 14, Decimal('2.99')),
#  ('Blackout Private', 27, Decimal('2.99')),
#  ('Coneheads Smoochy', 25, Decimal('4.99')),
#  ('Smile Earring', 10, Decimal('2.99')),
#  ('Dragon Squad', 11, Decimal('0.99')),
#  ('Flintstones Happiness', 17, Decimal('4.99')),
#  ('Strictly Scarface', 23, Decimal('2.99')),
#  ('Requiem Tycoon', 19, Decimal('4.99')),
#  ('Redemption Comforts', 20, Decimal('2.99')),
#  ('Minority Kiss', 12, Decimal('0.99')),
#  ('Hanover Galaxy', 17, Decimal('4.99')),
#  ('Trading Pinocchio', 25, Decimal('4.99')),
#  ('Japanese Run', 6, Decimal('0.99')),
#  ('Fool Mockingbird', 23, Decimal('4.99')),
#  ('Alabama Devil', 12, Decimal('2.99')),
#  ('Orange Grapes', 24, Decimal('0.99')),
#  ('Command Darling', 16, Decimal('4.99')),
#  ('Vanishing Rocky', 18, Decimal('2.99')),
#  ('Idols Snatchers', 30, Decimal('2.99')),
#  ('Day Unfaithful', 14, Decimal('4.99')),
#  ('League Hellfighters', 17, Decimal('4.99')),
#  ('Hills Neighbors', 25, Decimal('0.99')),
#  ('Cyclone Family', 15, Decimal('2.99')),
#  ('Bucket Brotherhood', 34, Decimal('4.99')),
#  ('Undefeated Dalmations', 21, Decimal('4.99')),
#  ('Tycoon Gathering', 12, Decimal('4.99')),
#  ('Splash Gump', 14, Decimal('0.99')),
#  ('Kick Savannah', 20, Decimal('0.99')),
#  ('Element Freddy', 10, Decimal('4.99')),
#  ('Scissorhands Slums', 15, Decimal('2.99')),
#  ('Bubble Grosse', 6, Decimal('4.99')),
#  ('Necklace Outbreak', 15, Decimal('0.99')),
#  ('Secrets Paradise', 20, Decimal('4.99')),
#  ('Lesson Cleopatra', 7, Decimal('0.99')),
#  ('Lights Deer', 8, Decimal('0.99')),
#  ('Trip Newton', 28, Decimal('4.99')),
#  ('Mixed Doors', 4, Decimal('2.99')),
#  ('Queen Luke', 22, Decimal('4.99')),
#  ('Maude Mod', 8, Decimal('0.99')),
#  ('Date Speed', 13, Decimal('0.99')),
#  ('Matrix Snowman', 9, Decimal('4.99')),
#  ('Braveheart Human', 5, Decimal('2.99')),
#  ('Flatliners Killer', 22, Decimal('2.99')),
#  ('Ties Hunger', 11, Decimal('4.99')),
#  ('Chamber Italian', 13, Decimal('4.99')),
#  ('Malkovich Pet', 26, Decimal('2.99')),
#  ('Honey Ties', 19, Decimal('0.99')),
#  ('Breakfast Goldfinger', 17, Decimal('4.99')),
#  ('Jaws Harry', 14, Decimal('2.99')),
#  ('Wonderful Drop', 9, Decimal('2.99')),
#  ('Pride Alamo', 16, Decimal('0.99')),
#  ('Wrong Behavior', 20, Decimal('2.99')),
#  ('Early Home', 7, Decimal('4.99')),
#  ('Scalawag Duck', 32, Decimal('4.99')),
#  ('Silverado Goldfinger', 12, Decimal('4.99')),
#  ('National Story', 19, Decimal('2.99')),
#  ('Mod Secretary', 11, Decimal('4.99')),
#  ('House Dynamite', 23, Decimal('2.99')),
#  ('Breaking Home', 13, Decimal('2.99')),
#  ('Jacket Frisco', 18, Decimal('2.99')),
#  ('Stallion Sundance', 7, Decimal('0.99')),
#  ('Rollercoaster Bringing', 10, Decimal('2.99')),
#  ('Darn Forrester', 18, Decimal('4.99')),
#  ('Candles Grapes', 23, Decimal('4.99')),
#  ('Monsoon Cause', 9, Decimal('4.99')),
#  ('Model Fish', 15, Decimal('4.99')),
#  ('Aladdin Calendar', 23, Decimal('4.99')),
#  ('Reservoir Adaptation', 10, Decimal('2.99')),
#  ('Lola Agent', 24, Decimal('4.99')),
#  ('Lambs Cincinatti', 10, Decimal('4.99')),
#  ('Intrigue Worst', 20, Decimal('0.99')),
#  ('Shining Roses', 8, Decimal('0.99')),
#  ('Knock Warlock', 24, Decimal('2.99')),
#  ('Giant Troopers', 28, Decimal('2.99')),
#  ('French Holiday', 17, Decimal('4.99')),
#  ('Halloween Nuts', 10, Decimal('2.99')),
#  ('Turn Star', 14, Decimal('2.99')),
#  ('Sea Virgin', 22, Decimal('2.99')),
#  ('Doors President', 19, Decimal('4.99')),
#  ('Voyage Legally', 28, Decimal('0.99')),
#  ('Hysterical Grail', 15, Decimal('4.99')),
#  ('Dragonfly Strangers', 18, Decimal('4.99')),
#  ('Ending Crowds', 11, Decimal('0.99')),
#  ('Madison Trap', 15, Decimal('2.99')),
#  ('Shock Cabin', 30, Decimal('2.99')),
#  ('Killer Innocent', 6, Decimal('2.99')),
#  ('Badman Dawn', 21, Decimal('2.99')),
#  ('Madigan Dorado', 10, Decimal('4.99')),
#  ('Intentions Empire', 17, Decimal('2.99')),
#  ('President Bang', 7, Decimal('4.99')),
#  ('Nemo Campus', 14, Decimal('2.99')),
#  ('Hunting Musketeers', 15, Decimal('2.99')),
#  ('Trap Guys', 16, Decimal('4.99')),
#  ('Zoolander Fiction', 17, Decimal('2.99')),
#  ('Blindness Gun', 14, Decimal('4.99')),
#  ('Home Pity', 14, Decimal('4.99')),
#  ('Gosford Donnie', 8, Decimal('4.99')),
#  ('Massacre Usual', 30, Decimal('4.99')),
#  ('Stock Glass', 14, Decimal('2.99')),
#  ('Sons Interview', 15, Decimal('2.99')),
#  ('Willow Tracy', 16, Decimal('2.99')),
#  ('Christmas Moonshine', 21, Decimal('0.99')),
#  ('Entrapment Satisfaction', 15, Decimal('0.99')),
#  ('Masked Bubble', 20, Decimal('0.99')),
#  ('Summer Scarface', 16, Decimal('0.99')),
#  ('Tomatoes Hellfighters', 14, Decimal('0.99')),
#  ('Pittsburgh Hunchback', 12, Decimal('4.99')),
#  ('Texas Watch', 6, Decimal('0.99')),
#  ('Virginian Pluto', 29, Decimal('0.99')),
#  ('Cat Coneheads', 30, Decimal('4.99')),
#  ('Primary Glass', 27, Decimal('0.99')),
#  ('Frida Slipper', 11, Decimal('2.99')),
#  ('Timberland Sky', 31, Decimal('0.99')),
#  ('Born Spinal', 12, Decimal('4.99')),
#  ('Rocky War', 16, Decimal('4.99')),
#  ('Attacks Hate', 16, Decimal('4.99')),
#  ('Encounters Curtain', 19, Decimal('0.99')),
#  ('Craft Outfield', 16, Decimal('0.99')),
#  ('Clue Grail', 7, Decimal('4.99')),
#  ('Chasing Fight', 20, Decimal('4.99')),
#  ('Vietnam Smoochy', 15, Decimal('0.99')),
#  ('Unforgiven Zoolander', 18, Decimal('0.99')),
#  ('Liberty Magnificent', 12, Decimal('2.99')),
#  ('Bride Intrigue', 19, Decimal('0.99')),
#  ('Cincinatti Whisperer', 13, Decimal('4.99')),
#  ('Ship Wonderland', 15, Decimal('2.99')),
#  ('Hellfighters Sierra', 20, Decimal('2.99')),
#  ('Closer Bang', 28, Decimal('4.99')),
#  ('Birds Perdition', 18, Decimal('4.99')),
#  ('Freedom Cleopatra', 5, Decimal('0.99')),
#  ('Volcano Texas', 22, Decimal('0.99')),
#  ('Army Flintstones', 16, Decimal('0.99')),
#  ('Evolution Alter', 12, Decimal('0.99')),
#  ('Montezuma Command', 9, Decimal('0.99')),
#  ('Wonderland Christmas', 22, Decimal('4.99')),
#  ('Butterfly Chocolat', 30, Decimal('0.99')),
#  ('Something Duck', 19, Decimal('4.99')),
#  ('North Tequila', 11, Decimal('4.99')),
#  ('Half Outfield', 26, Decimal('2.99')),
#  ('Terminator Club', 6, Decimal('4.99')),
#  ('Fight Jawbreaker', 22, Decimal('0.99')),
#  ('Fish Opus', 25, Decimal('2.99')),
#  ('Drumline Cyclone', 11, Decimal('0.99')),
#  ('Harper Dying', 20, Decimal('0.99')),
#  ('Lolita World', 10, Decimal('2.99')),
#  ('Hedwig Alter', 12, Decimal('2.99')),
#  ('Satisfaction Confidential', 17, Decimal('4.99')),
#  ('Steel Santa', 23, Decimal('4.99')),
#  ('Impact Aladdin', 9, Decimal('0.99')),
#  ('Theory Mermaid', 11, Decimal('0.99')),
#  ('Brotherhood Blanket', 26, Decimal('0.99')),
#  ('None Spiking', 27, Decimal('0.99')),
#  ('Resurrection Silverado', 21, Decimal('0.99')),
#  ('Vision Torque', 7, Decimal('0.99')),
#  ('Jekyll Frogmen', 17, Decimal('2.99')),
#  ('Behavior Runaway', 13, Decimal('4.99')),
#  ('Sleepless Monsoon', 20, Decimal('4.99')),
#  ('Lose Inch', 27, Decimal('0.99')),
#  ('Fever Empire', 5, Decimal('4.99')),
#  ('Beverly Outlaw', 21, Decimal('2.99')),
#  ('Notting Speakeasy', 10, Decimal('0.99')),
#  ('Cabin Flash', 15, Decimal('0.99')),
#  ('Crooked Frogmen', 23, Decimal('0.99')),
#  ('Charade Duffel', 15, Decimal('2.99')),
#  ('Trojan Tomorrow', 19, Decimal('2.99')),
#  ('Jawbreaker Brooklyn', 10, Decimal('0.99')),
#  ('Talented Homicide', 29, Decimal('0.99')),
#  ('Packer Madigan', 22, Decimal('0.99')),
#  ('Bed Highball', 6, Decimal('2.99')),
#  ('Modern Dorado', 15, Decimal('0.99')),
#  ('Bull Shawshank', 16, Decimal('0.99')),
#  ('Notorious Reunion', 14, Decimal('0.99')),
#  ('Clash Freddy', 25, Decimal('2.99')),
#  ('Cider Desire', 19, Decimal('2.99')),
#  ('Wisdom Worker', 9, Decimal('0.99')),
#  ('Intolerable Intentions', 9, Decimal('4.99')),
#  ('Drifter Commandments', 24, Decimal('4.99')),
#  ('Wizard Coldblooded', 16, Decimal('4.99')),
#  ('Apache Divine', 31, Decimal('4.99')),
#  ('Expendable Stallion', 28, Decimal('0.99')),
#  ('Dogma Family', 30, Decimal('4.99')),
#  ('Videotape Arsenic', 29, Decimal('4.99')),
#  ('Chill Luck', 22, Decimal('0.99')),
#  ('Taxi Kick', 17, Decimal('0.99')),
#  ('Wagon Jaws', 10, Decimal('2.99')),
#  ('Balloon Homeward', 23, Decimal('2.99')),
#  ('Wyoming Storm', 13, Decimal('4.99')),
#  ('Go Purple', 20, Decimal('0.99')),
#  ('Ali Forever', 9, Decimal('4.99')),
#  ('Vertigo Northwest', 8, Decimal('2.99')),
#  ('Pickup Driving', 16, Decimal('2.99')),
#  ('Temple Attraction', 12, Decimal('4.99')),
#  ('Forever Candidate', 13, Decimal('2.99')),
#  ('Samurai Lion', 25, Decimal('2.99')),
#  ('Devil Desire', 15, Decimal('4.99')),
#  ('Cupboard Sinners', 23, Decimal('2.99')),
#  ('Grail Frankenstein', 10, Decimal('2.99')),
#  ('Anonymous Human', 13, Decimal('0.99')),
#  ('Jedi Beneath', 19, Decimal('0.99')),
#  ('Past Suicides', 13, Decimal('4.99')),
#  ('Sweden Shining', 18, Decimal('4.99')),
#  ('Center Dinosaur', 24, Decimal('4.99')),
#  ('Leathernecks Dwarfs', 7, Decimal('2.99')),
#  ('Daughter Madigan', 9, Decimal('4.99')),
#  ('Virtual Spoilers', 14, Decimal('4.99')),
#  ('Beach Heartbreakers', 17, Decimal('2.99')),
#  ('Nuts Ties', 9, Decimal('4.99')),
#  ('Destination Jerk', 8, Decimal('0.99')),
#  ('Treatment Jekyll', 7, Decimal('0.99')),
#  ('Carrie Bunch', 23, Decimal('0.99')),
#  ('Clones Pinocchio', 19, Decimal('2.99')),
#  ('Flamingos Connecticut', 23, Decimal('4.99')),
#  ('Shanghai Tycoon', 14, Decimal('2.99')),
#  ('Dirty Ace', 15, Decimal('2.99')),
#  ('Bulworth Commandments', 7, Decimal('2.99')),
#  ('United Pilot', 17, Decimal('0.99')),
#  ('Haunting Pianist', 22, Decimal('0.99')),
#  ('Hobbit Alien', 31, Decimal('0.99')),
#  ('Weekend Personal', 18, Decimal('2.99')),
#  ('Candidate Perdition', 18, Decimal('2.99')),
#  ('Metal Armageddon', 25, Decimal('2.99')),
#  ('Voice Peach', 19, Decimal('0.99')),
#  ('Outfield Massacre', 20, Decimal('0.99')),
#  ('Moulin Wake', 16, Decimal('0.99')),
#  ('Shakespeare Saddle', 22, Decimal('2.99')),
#  ('Zhivago Core', 9, Decimal('0.99')),
#  ('Flight Lies', 12, Decimal('4.99')),
#  ('Vampire Whale', 12, Decimal('4.99')),
#  ('Valentine Vanishing', 12, Decimal('0.99')),
#  ('Greek Everyone', 17, Decimal('2.99')),
#  ('Spirited Casualties', 11, Decimal('0.99')),
#  ('Name Detective', 23, Decimal('4.99')),
#  ('Secretary Rouge', 18, Decimal('4.99')),
#  ('Graceland Dynamite', 6, Decimal('4.99')),
#  ('Divorce Shining', 7, Decimal('2.99')),
#  ('Frontier Cabin', 6, Decimal('4.99')),
#  ('Eagles Panky', 22, Decimal('4.99')),
#  ('Rings Heartbreakers', 15, Decimal('0.99')),
#  ('Chaplin License', 8, Decimal('2.99')),
#  ('Darkness War', 13, Decimal('2.99')),
#  ('Gone Trouble', 10, Decimal('2.99')),
#  ('Telemark Heartbreakers', 25, Decimal('2.99')),
#  ('Million Ace', 20, Decimal('4.99')),
#  ('Hotel Happiness', 9, Decimal('4.99')),
#  ('Bill Others', 19, Decimal('2.99')),
#  ('Sunrise League', 24, Decimal('4.99')),
#  ('Unfaithful Kill', 8, Decimal('2.99')),
#  ('Ghostbusters Elf', 9, Decimal('0.99')),
#  ('Werewolf Lola', 14, Decimal('4.99')),
#  ('Lion Uncut', 18, Decimal('0.99')),
#  ('Hope Tootsie', 18, Decimal('2.99')),
#  ('Savannah Town', 12, Decimal('0.99')),
#  ('Chariots Conspiracy', 21, Decimal('2.99')),
#  ('Robbery Bright', 13, Decimal('0.99')),
#  ('Tourist Pelican', 22, Decimal('4.99')),
#  ('Minds Truman', 20, Decimal('4.99')),
#  ('Ice Crossing', 24, Decimal('2.99')),
#  ('Story Side', 28, Decimal('0.99')),
#  ('Rocketeer Mother', 33, Decimal('0.99')),
#  ('River Outlaw', 20, Decimal('0.99')),
#  ('Sabrina Midnight', 21, Decimal('4.99')),
#  ('Confessions Maguire', 14, Decimal('4.99')),
#  ('Kramer Chocolate', 9, Decimal('2.99')),
#  ('Beast Hunchback', 11, Decimal('4.99')),
#  ('Majestic Floats', 17, Decimal('0.99')),
#  ('Chicken Hellfighters', 22, Decimal('0.99')),
#  ('Hunter Alter', 5, Decimal('2.99')),
#  ('Sweethearts Suspects', 29, Decimal('0.99')),
#  ('Musketeers Wait', 17, Decimal('4.99')),
#  ('Santa Paris', 11, Decimal('2.99')),
#  ('Muscle Bright', 30, Decimal('2.99')),
#  ('Valley Packer', 15, Decimal('0.99')),
#  ('Stepmom Dream', 20, Decimal('4.99')),
#  ('Pirates Roxanne', 21, Decimal('0.99')),
#  ('Campus Remember', 19, Decimal('2.99')),
#  ('Wardrobe Phantom', 27, Decimal('2.99')),
#  ('Glory Tracy', 5, Decimal('2.99')),
#  ('Color Philadelphia', 24, Decimal('2.99')),
#  ('African Egg', 12, Decimal('2.99')),
#  ('Loathing Legally', 27, Decimal('0.99')),
#  ('Doubtfire Labyrinth', 10, Decimal('4.99')),
#  ('Hanky October', 26, Decimal('2.99')),
#  ('Soldiers Evolution', 8, Decimal('4.99')),
#  ('Pollock Deliverance', 18, Decimal('2.99')),
#  ('Brooklyn Desert', 21, Decimal('4.99')),
#  ('Indian Love', 16, Decimal('0.99')),
#  ('Outlaw Hanky', 14, Decimal('4.99')),
#  ('Grease Youth', 21, Decimal('0.99')),
#  ('Cassidy Wyoming', 6, Decimal('2.99')),
#  ('Backlash Undefeated', 19, Decimal('4.99')),
#  ('Caribbean Liberty', 9, Decimal('4.99')),
#  ('Loser Hustler', 15, Decimal('4.99')),
#  ('Freaky Pocus', 17, Decimal('2.99')),
#  ('Innocent Usual', 26, Decimal('4.99')),
#  ('Groundhog Uncut', 18, Decimal('4.99')),
#  ('Poseidon Forever', 17, Decimal('4.99')),
#  ('Bonnie Holocaust', 16, Decimal('0.99')),
#  ('Grapes Fury', 22, Decimal('0.99')),
#  ('Congeniality Quest', 22, Decimal('0.99')),
#  ('Detective Vision', 27, Decimal('0.99')),
#  ('Basic Easy', 21, Decimal('2.99')),
#  ('Earth Vision', 23, Decimal('0.99')),
#  ('Disturbing Scarface', 26, Decimal('2.99')),
#  ('Anything Savannah', 9, Decimal('2.99')),
#  ('Rear Trading', 17, Decimal('0.99')),
#  ('Contact Anonymous', 26, Decimal('2.99')),
#  ('Polish Brooklyn', 18, Decimal('0.99')),
#  ('Holocaust Highball', 17, Decimal('0.99')),
#  ('Airplane Sierra', 15, Decimal('4.99')),
#  ('Run Pacific', 10, Decimal('0.99')),
#  ('Sense Greek', 7, Decimal('4.99')),
#  ('Enough Raging', 18, Decimal('2.99')),
#  ('Divine Resurrection', 15, Decimal('2.99')),
#  ('Rebel Airport', 8, Decimal('0.99')),
#  ('Fiction Christmas', 19, Decimal('0.99')),
#  ('Cause Date', 21, Decimal('2.99')),
#  ('Motions Details', 16, Decimal('0.99')),
#  ('Effect Gladiator', 25, Decimal('0.99')),
#  ('Annie Identity', 22, Decimal('0.99')),
#  ('Rage Games', 19, Decimal('4.99')),
#  ('Birdcage Casper', 9, Decimal('0.99')),
#  ('Words Hunter', 16, Decimal('2.99')),
#  ('Gunfighter Mussolini', 12, Decimal('2.99')),
#  ('Seabiscuit Punk', 26, Decimal('2.99')),
#  ('Crossroads Casualties', 21, Decimal('2.99')),
#  ('Saturday Lambs', 28, Decimal('4.99')),
#  ('Adaptation Holes', 12, Decimal('2.99')),
#  ('Troopers Metal', 14, Decimal('0.99')),
#  ('Yentl Idaho', 23, Decimal('4.99')),
#  ('Liaisons Sweet', 22, Decimal('4.99')),
#  ('Pinocchio Simon', 20, Decimal('4.99')),
#  ('Dinosaur Secretary', 20, Decimal('2.99')),
#  ('Comforts Rush', 17, Decimal('2.99')),
#  ('Galaxy Sweethearts', 18, Decimal('4.99')),
#  ('Hamlet Wisdom', 14, Decimal('2.99')),
#  ('Fury Murder', 19, Decimal('0.99')),
#  ('Amistad Midsummer', 21, Decimal('2.99')),
#  ('Conspiracy Spirit', 5, Decimal('2.99')),
#  ('Haunted Antitrust', 6, Decimal('4.99')),
#  ('Ferris Mother', 17, Decimal('2.99')),
#  ('Duffel Apocalypse', 7, Decimal('0.99')),
#  ('Pianist Outfield', 21, Decimal('0.99')),
#  ('Everyone Craft', 13, Decimal('0.99')),
#  ('Freddy Storm', 23, Decimal('4.99')),
#  ('Random Go', 9, Decimal('2.99')),
#  ('Blues Instinct', 21, Decimal('2.99')),
#  ('Elf Murder', 7, Decimal('4.99')),
#  ('Head Stranger', 22, Decimal('4.99')),
#  ('Insects Stone', 18, Decimal('0.99')),
#  ('Tomorrow Hustler', 25, Decimal('2.99')),
#  ('Connecticut Tramp', 13, Decimal('4.99')),
#  ('Smoochy Control', 12, Decimal('0.99')),
#  ('Saturn Name', 13, Decimal('4.99')),
#  ('World Leathernecks', 8, Decimal('0.99')),
#  ('Flying Hook', 20, Decimal('2.99')),
#  ('Sleepy Japanese', 21, Decimal('2.99')),
#  ('Shepherd Midsummer', 25, Decimal('0.99')),
#  ('Gentlemen Stage', 23, Decimal('2.99')),
#  ('Pet Haunting', 8, Decimal('0.99')),
#  ('Shane Darkness', 14, Decimal('2.99')),
#  ('Identity Lover', 13, Decimal('2.99')),
#  ('Shootist Superfly', 24, Decimal('0.99')),
#  ('Vacation Boondock', 21, Decimal('2.99')),
#  ('Gilbert Pelican', 9, Decimal('0.99')),
#  ('Patriot Roman', 16, Decimal('2.99')),
#  ('Metropolis Coma', 26, Decimal('2.99')),
#  ('Dude Blindness', 16, Decimal('4.99')),
#  ('Smoking Barbarella', 18, Decimal('0.99')),
#  ('Mussolini Spoilers', 5, Decimal('2.99')),
#  ('Holy Tadpole', 9, Decimal('0.99')),
#  ('Confidential Interview', 29, Decimal('4.99')),
#  ('Atlantis Cause', 24, Decimal('2.99')),
#  ('Spiking Element', 13, Decimal('2.99')),
#  ('Wild Apollo', 6, Decimal('0.99')),
#  ('Hollow Jeopardy', 10, Decimal('4.99')),
#  ('Wind Phantom', 23, Decimal('0.99')),
#  ('Range Moonwalker', 27, Decimal('4.99')),
#  ('Others Soup', 23, Decimal('2.99')),
#  ('Heartbreakers Bright', 20, Decimal('4.99')),
#  ('Bird Independence', 11, Decimal('4.99')),
#  ('Fantasy Troopers', 26, Decimal('0.99')),
#  ('Opus Ice', 11, Decimal('4.99')),
#  ('Lucky Flying', 13, Decimal('2.99')),
#  ('Image Princess', 14, Decimal('2.99')),
#  ('Traffic Hobbit', 5, Decimal('4.99')),
#  ('Panic Club', 7, Decimal('4.99')),
#  ('Quills Bull', 16, Decimal('4.99')),
#  ('Slipper Fidelity', 16, Decimal('0.99')),
#  ('Money Harold', 20, Decimal('2.99')),
#  ('Sleeping Suspects', 24, Decimal('4.99')),
#  ('Moonshine Cabin', 21, Decimal('4.99')),
#  ('Beethoven Exorcist', 11, Decimal('0.99')),
#  ('Shrunk Divine', 14, Decimal('2.99')),
#  ('Twisted Pirates', 11, Decimal('4.99')),
#  ('Pond Seattle', 19, Decimal('2.99')),
#  ('Dumbo Lust', 6, Decimal('0.99')),
#  ('Lock Rear', 16, Decimal('2.99')),
#  ('Horn Working', 24, Decimal('2.99')),
#  ('Baby Hall', 8, Decimal('4.99')),
#  ('Reign Gentlemen', 20, Decimal('2.99')),
#  ('Sundance Invasion', 19, Decimal('0.99')),
#  ('Velvet Terminator', 26, Decimal('4.99')),
#  ('Operation Operation', 27, Decimal('2.99')),
#  ('Wolves Desire', 21, Decimal('0.99')),
#  ('Crazy Home', 9, Decimal('2.99')),
#  ('Crow Grease', 12, Decimal('0.99')),
#  ('Potluck Mixed', 11, Decimal('2.99')),
#  ('Mother Oleander', 14, Decimal('0.99')),
#  ('Jeepers Wedding', 16, Decimal('2.99')),
#  ('Rock Instinct', 17, Decimal('0.99')),
#  ('Donnie Alley', 14, Decimal('0.99')),
#  ('Right Cranes', 10, Decimal('4.99')),
#  ('Instinct Airport', 18, Decimal('2.99')),
#  ('Racer Egg', 18, Decimal('2.99')),
#  ('Speed Suit', 9, Decimal('4.99')),
#  ('Soup Wisdom', 8, Decimal('0.99')),
#  ('Confused Candles', 17, Decimal('2.99')),
#  ('Pilot Hoosiers', 16, Decimal('2.99')),
#  ('Watch Tracy', 16, Decimal('0.99')),
#  ('Star Operation', 21, Decimal('2.99')),
#  ('Earring Instinct', 19, Decimal('0.99')),
#  ('Legend Jedi', 9, Decimal('0.99')),
#  ('Durham Panky', 26, Decimal('4.99')),
#  ('Armageddon Lost', 21, Decimal('0.99')),
#  ('American Circus', 22, Decimal('4.99')),
#  ('Silence Kane', 16, Decimal('0.99')),
#  ('Snowman Rollercoaster', 23, Decimal('0.99')),
#  ('Fiddler Lost', 10, Decimal('4.99')),
#  ('Rushmore Mermaid', 6, Decimal('2.99')),
#  ('Informer Double', 5, Decimal('4.99')),
#  ('Hurricane Affair', 24, Decimal('2.99')),
#  ('Nash Chocolat', 15, Decimal('2.99')),
#  ('Impossible Prejudice', 14, Decimal('4.99')),
#  ('Harry Idaho', 30, Decimal('4.99')),
#  ('Stone Fire', 11, Decimal('0.99')),
#  ('Ladybugs Armageddon', 6, Decimal('0.99')),
#  ('Newton Labyrinth', 17, Decimal('0.99')),
#  ('Glass Dying', 14, Decimal('0.99')),
#  ('Storm Happiness', 29, Decimal('0.99')),
#  ('Casper Dragonfly', 8, Decimal('4.99')),
#  ('Champion Flatliners', 13, Decimal('4.99')),
#  ('Family Sweet', 29, Decimal('0.99')),
#  ('Barefoot Manchurian', 18, Decimal('2.99')),
#  ('Graduate Lord', 16, Decimal('2.99')),
#  ('Unbreakable Karate', 21, Decimal('0.99')),
#  ('Snatchers Montezuma', 9, Decimal('2.99')),
#  ('Lady Stage', 17, Decimal('4.99')),
#  ('Homicide Peach', 22, Decimal('2.99')),
#  ('Sweet Brotherhood', 15, Decimal('2.99')),
#  ('King Evolution', 9, Decimal('4.99')),
#  ('Luck Opus', 10, Decimal('2.99')),
#  ('Core Suit', 18, Decimal('2.99')),
#  ('Scorpion Apollo', 23, Decimal('4.99')),
#  ('Runaway Tenenbaums', 8, Decimal('0.99')),
#  ('Duck Racer', 6, Decimal('2.99')),
#  ('Salute Apollo', 23, Decimal('2.99')),
#  ('Reef Salute', 11, Decimal('0.99')),
#  ('Enemy Odds', 29, Decimal('4.99')),
#  ('Bilko Anonymous', 13, Decimal('4.99')),
#  ('Maiden Home', 24, Decimal('4.99')),
#  ('Life Twisted', 10, Decimal('2.99')),
#  ('Translation Summer', 15, Decimal('0.99')),
#  ('Bear Graceland', 22, Decimal('2.99')),
#  ('Canyon Stock', 19, Decimal('0.99')),
#  ('Arizona Bang', 21, Decimal('2.99')),
#  ('Superfly Trip', 10, Decimal('0.99')),
#  ('Side Ark', 12, Decimal('0.99')),
#  ('Mighty Luck', 12, Decimal('2.99')),
#  ('Blade Polish', 22, Decimal('0.99')),
#  ('Manchurian Curtain', 15, Decimal('2.99')),
#  ('Scarface Bang', 18, Decimal('4.99')),
#  ('Jeopardy Encino', 10, Decimal('0.99')),
#  ('Pity Bound', 26, Decimal('4.99')),
#  ('Cranes Reservoir', 11, Decimal('2.99')),
#  ('Music Boondock', 19, Decimal('0.99')),
#  ('Spartacus Cheaper', 9, Decimal('4.99')),
#  ('Philadelphia Wife', 23, Decimal('4.99')),
#  ('Chitty Lock', 8, Decimal('2.99')),
#  ('Mulholland Beast', 7, Decimal('2.99')),
#  ('Games Bowfinger', 14, Decimal('4.99')),
#  ('Lust Lock', 15, Decimal('2.99')),
#  ('Sun Confessions', 25, Decimal('0.99')),
#  ('Deep Crusade', 14, Decimal('4.99')),
#  ('Conquerer Nuts', 16, Decimal('4.99')),
#  ('Drums Dynamite', 13, Decimal('0.99')),
#  ('Agent Truman', 21, Decimal('2.99')),
#  ('Seven Swarm', 5, Decimal('4.99')),
#  ('Frost Head', 30, Decimal('0.99')),
#  ('Expecations Natural', 18, Decimal('4.99')),
#  ('Reap Unfaithful', 16, Decimal('2.99')),
#  ('Mallrats United', 25, Decimal('0.99')),
#  ('Tootsie Pilot', 15, Decimal('0.99')),
#  ('Pacific Amistad', 24, Decimal('0.99')),
#  ('Gilmore Boiled', 28, Decimal('0.99')),
#  ('Egypt Tenenbaums', 17, Decimal('0.99')),
#  ('Paycheck Wait', 16, Decimal('4.99')),
#  ('Ghost Groundhog', 21, Decimal('4.99')),
#  ('Natural Stock', 13, Decimal('0.99')),
#  ('Clockwork Paradise', 10, Decimal('0.99')),
#  ('Telegraph Voyage', 27, Decimal('4.99')),
#  ('Arachnophobia Rollercoaster', 24, Decimal('2.99')),
#  ('Hall Cassidy', 16, Decimal('4.99')),
#  ('Downhill Enough', 25, Decimal('0.99')),
#  ('Mannequin Worst', 5, Decimal('2.99')),
#  ('Destiny Saturday', 16, Decimal('4.99')),
#  ('Uprising Uptown', 16, Decimal('2.99')),
#  ('Darling Breaking', 9, Decimal('4.99')),
#  ('Labyrinth League', 15, Decimal('2.99')),
#  ('Fargo Gandhi', 24, Decimal('2.99')),
#  ('Highball Potter', 21, Decimal('0.99')),
#  ('Goldfinger Sensibility', 24, Decimal('0.99')),
#  ('Extraordinary Conquerer', 6, Decimal('2.99')),
#  ('Dying Maker', 17, Decimal('4.99')),
#  ('Gold River', 14, Decimal('4.99')),
#  ('Patton Interview', 23, Decimal('2.99')),
#  ('Full Flatliners', 5, Decimal('2.99')),
#  ('Curtain Videotape', 27, Decimal('0.99')),
#  ('Tights Dawn', 26, Decimal('0.99')),
#  ('Mermaid Insects', 16, Decimal('4.99')),
#  ('Uptown Young', 12, Decimal('2.99')),
#  ('Varsity Trip', 16, Decimal('2.99')),
#  ('Oz Liaisons', 24, Decimal('2.99')),
#  ('Camelot Vacation', 27, Decimal('0.99')),
#  ('Betrayed Rear', 15, Decimal('4.99')),
#  ('Whisperer Giant', 22, Decimal('4.99')),
#  ('Hardly Robbers', 4, Decimal('2.99')),
#  ('Calendar Gunfight', 21, Decimal('4.99')),
#  ('Cruelty Unforgiven', 7, Decimal('0.99')),
#  ('Teen Apollo', 17, Decimal('4.99')),
#  ('Jumanji Blade', 8, Decimal('2.99')),
#  ('Insider Arizona', 20, Decimal('2.99')),
#  ('Gables Metropolis', 19, Decimal('0.99')),
#  ('Roxanne Rebel', 19, Decimal('0.99')),
#  ('Mob Duffel', 12, Decimal('0.99')),
#  ('Alaska Phantom', 26, Decimal('0.99')),
#  ('Saints Bride', 8, Decimal('2.99')),
#  ('Prix Undefeated', 11, Decimal('2.99')),
#  ('Slacker Liaisons', 17, Decimal('4.99')),
#  ('Window Side', 12, Decimal('2.99')),
#  ('Fidelity Devil', 21, Decimal('4.99')),
#  ('October Submarine', 11, Decimal('4.99')),
#  ('Daisy Menagerie', 16, Decimal('4.99')),
#  ('Spice Sorority', 20, Decimal('4.99')),
#  ('Fellowship Autumn', 26, Decimal('4.99')),
#  ('Greatest North', 29, Decimal('2.99')),
#  ('Bugsy Song', 11, Decimal('2.99')),
#  ('Odds Boogie', 15, Decimal('0.99')),
#  ('Monster Spartacus', 15, Decimal('2.99')),
#  ('Banger Pinocchio', 22, Decimal('0.99')),
#  ('Chicago North', 16, Decimal('4.99')),
#  ('Jerk Paycheck', 20, Decimal('2.99')),
#  ('Trouble Date', 23, Decimal('2.99')),
#  ('Berets Agent', 21, Decimal('2.99')),
#  ('Beneath Rush', 10, Decimal('0.99')),
#  ('Desire Alien', 8, Decimal('2.99')),
#  ('South Wait', 22, Decimal('2.99')),
#  ('Dozen Lion', 7, Decimal('4.99')),
#  ('Karate Moon', 23, Decimal('0.99')),
#  ('Feud Frogmen', 25, Decimal('0.99')),
#  ('Gandhi Kwai', 17, Decimal('0.99')),
#  ('Won Dares', 9, Decimal('2.99')),
#  ('Madness Attacks', 25, Decimal('0.99')),
#  ('Arabia Dogma', 13, Decimal('0.99')),
#  ('English Bulworth', 30, Decimal('0.99')),
#  ('Dolls Rage', 9, Decimal('2.99')),
#  ('Beauty Grease', 22, Decimal('4.99')),
#  ('Affair Prejudice', 23, Decimal('2.99')),
#  ('Drop Waterfront', 9, Decimal('4.99')),
#  ('Jason Trap', 24, Decimal('2.99')),
#  ('Dracula Crystal', 21, Decimal('0.99')),
#  ('Casualties Encino', 9, Decimal('4.99')),
#  ('Jingle Sagebrush', 13, Decimal('4.99')),
#  ('Birch Antitrust', 11, Decimal('4.99')),
#  ('Lies Treatment', 27, Decimal('4.99')),
#  ('Deer Virginian', 29, Decimal('2.99')),
#  ('Stampede Disturbing', 14, Decimal('0.99')),
#  ('Gorgeous Bingo', 19, Decimal('2.99')),
#  ('Miracle Virtual', 9, Decimal('2.99')),
#  ('Records Zorro', 8, Decimal('4.99')),
#  ('Creatures Shakespeare', 16, Decimal('0.99')),
#  ('Fantasia Park', 19, Decimal('2.99')),
#  ('Waterfront Deliverance', 17, Decimal('4.99')),
#  ('Party Knock', 13, Decimal('2.99')),
#  ('Luke Mummy', 7, Decimal('2.99')),
#  ('Nightmare Chill', 25, Decimal('4.99')),
#  ('Wanda Chamber', 16, Decimal('4.99')),
#  ('Network Peak', 31, Decimal('2.99')),
#  ('Spirit Flintstones', 15, Decimal('0.99')),
#  ('Rugrats Shakespeare', 30, Decimal('0.99')),
#  ('Alone Trip', 18, Decimal('0.99')),
#  ('Mummy Creatures', 16, Decimal('0.99')),
#  ('Spinal Rocky', 13, Decimal('2.99')),
#  ('Grit Clockwork', 32, Decimal('0.99')),
#  ('Steers Armageddon', 15, Decimal('4.99')),
#  ('Towers Hurricane', 11, Decimal('0.99')),
#  ('Submarine Bed', 15, Decimal('4.99')),
#  ('Road Roxanne', 19, Decimal('4.99')),
#  ('Roses Treasure', 28, Decimal('4.99')),
#  ('Circus Youth', 15, Decimal('2.99')),
#  ('Legally Secretary', 9, Decimal('4.99')),
#  ('Heavyweights Beast', 23, Decimal('4.99')),
#  ('Tracy Cider', 26, Decimal('0.99')),
#  ('Wars Pluto', 10, Decimal('2.99')),
#  ('Forward Temple', 32, Decimal('2.99')),
#  ('Wrath Mile', 14, Decimal('0.99')),
#  ('Sassy Packer', 13, Decimal('0.99')),
#  ('Graffiti Love', 30, Decimal('0.99')),
#  ('Brannigan Sunrise', 12, Decimal('4.99')),
#  ('Club Graffiti', 19, Decimal('0.99')),
#  ('Opposite Necklace', 13, Decimal('4.99')),
#  ('Maltese Hope', 22, Decimal('4.99')),
#  ('Encino Elf', 19, Decimal('0.99')),
#  ('Watership Frontier', 6, Decimal('0.99')),
#  ('Song Hedwig', 11, Decimal('0.99')),
#  ('Alley Evolution', 14, Decimal('2.99')),
#  ('Runner Madigan', 8, Decimal('0.99')),
#  ('Magic Mallrats', 7, Decimal('0.99')),
#  ('Grinch Massage', 14, Decimal('4.99')),
#  ('Fireball Philadelphia', 21, Decimal('0.99')),
#  ('Westward Seabiscuit', 26, Decimal('0.99')),
#  ('Bunch Minds', 5, Decimal('2.99')),
#  ('Driving Polish', 21, Decimal('4.99')),
#  ('Clueless Bucket', 25, Decimal('2.99')),
#  ('Goldmine Tycoon', 27, Decimal('0.99')),
#  ('Crusade Honey', 8, Decimal('2.99')),
#  ('Prejudice Oleander', 20, Decimal('4.99')),
#  ('Paris Weekend', 14, Decimal('2.99')),
#  ('Titanic Boondock', 23, Decimal('4.99')),
#  ('Hours Rage', 19, Decimal('0.99')),
#  ('Dares Pluto', 9, Decimal('2.99')),
#  ('Women Dorado', 23, Decimal('0.99')),
#  ('Bingo Talented', 29, Decimal('2.99')),
#  ('Married Go', 30, Decimal('2.99')),
#  ('Control Anthem', 7, Decimal('4.99')),
#  ('Maguire Apache', 9, Decimal('2.99')),
#  ('Casablanca Super', 16, Decimal('4.99')),
#  ('Hunger Roof', 13, Decimal('0.99')),
#  ('Lawless Vision', 17, Decimal('4.99')),
#  ('Orient Closer', 17, Decimal('2.99')),
#  ('Eyes Driving', 19, Decimal('2.99')),
#  ('Hoosiers Birdcage', 8, Decimal('2.99')),
#  ('Boogie Amelie', 29, Decimal('4.99')),
#  ('Angels Life', 22, Decimal('2.99')),
#  ('Wasteland Divine', 15, Decimal('2.99')),
#  ('Interview Liaisons', 20, Decimal('4.99')),
#  ('Massage Image', 12, Decimal('2.99')),
#  ('Baked Cleopatra', 16, Decimal('2.99')),
#  ('Torque Bound', 27, Decimal('4.99')),
#  ('Diary Panic', 9, Decimal('2.99')),
#  ('Private Drop', 5, Decimal('4.99')),
#  ('Attraction Newton', 24, Decimal('4.99')),
#  ('Pajama Jawbreaker', 14, Decimal('0.99')),
#  ('Handicap Boondock', 28, Decimal('0.99')),
#  ('Dwarfs Alter', 9, Decimal('2.99')),
#  ('Easy Gladiator', 23, Decimal('4.99')),
#  ('Streak Ridgemont', 16, Decimal('0.99')),
#  ('Siege Madre', 15, Decimal('0.99')),
#  ('Cowboy Doom', 7, Decimal('2.99')),
#  ('Bedazzled Married', 13, Decimal('0.99')),
#  ('Stranger Strangers', 11, Decimal('4.99')),
#  ('Pluto Oleander', 16, Decimal('4.99')),
#  ('Oleander Clue', 10, Decimal('0.99')),
#  ('Wedding Apollo', 24, Decimal('0.99')),
#  ('Midnight Westward', 17, Decimal('0.99')),
#  ('Warlock Werewolf', 6, Decimal('2.99')),
#  ('Mask Peach', 17, Decimal('2.99')),
#  ('Frisco Forrest', 9, Decimal('4.99')),
#  ('Tarzan Videotape', 8, Decimal('2.99')),
#  ('Lover Truman', 10, Decimal('2.99')),
#  ('Bowfinger Gables', 11, Decimal('4.99')),
#  ('Igby Maker', 19, Decimal('4.99')),
#  ('Pizza Jumanji', 7, Decimal('2.99')),
#  ('Eve Resurrection', 7, Decimal('4.99')),
#  ('Happiness United', 6, Decimal('2.99')),
#  ('Idaho Love', 17, Decimal('2.99')),
#  ('Quest Mussolini', 20, Decimal('2.99')),
#  ('Ace Goldfinger', 7, Decimal('4.99')),
#  ('Thin Sagebrush', 11, Decimal('4.99')),
#  ('Celebrity Horn', 24, Decimal('0.99')),
#  ('Panther Reds', 15, Decimal('4.99')),
#  ('Virgin Daisy', 17, Decimal('4.99')),
#  ('Fatal Haunted', 28, Decimal('2.99')),
#  ('Chisum Behavior', 13, Decimal('4.99')),
#  ('Chocolat Harry', 20, Decimal('0.99')),
#  ('Tuxedo Mile', 13, Decimal('2.99')),
#  ('Boulevard Mob', 18, Decimal('0.99')),
#  ('Patient Sister', 19, Decimal('0.99')),
#  ('Lonely Elephant', 15, Decimal('2.99')),
#  ('Whale Bikini', 18, Decimal('4.99')),
#  ('Town Ark', 14, Decimal('2.99')),
#  ('Speakeasy Date', 12, Decimal('2.99')),
#  ('Jersey Sassy', 6, Decimal('4.99')),
#  ('Movie Shakespeare', 27, Decimal('4.99')),
#  ('Worst Banger', 16, Decimal('2.99')),
#  ('Splendor Patton', 21, Decimal('0.99')),
#  ('Menagerie Rushmore', 7, Decimal('2.99')),
#  ('Dream Pickup', 22, Decimal('2.99')),
#  ('Lovely Jingle', 14, Decimal('2.99')),
#  ('Rules Human', 16, Decimal('4.99')),
#  ('Homeward Cider', 16, Decimal('0.99')),
#  ('Gun Bonnie', 25, Decimal('0.99')),
#  ('Jumping Wrath', 24, Decimal('0.99')),
#  ('Amelie Hellfighters', 10, Decimal('4.99')),
#  ('Lawrence Love', 13, Decimal('0.99')),
#  ('Jet Neighbors', 20, Decimal('4.99')),
#  ('Heaven Freedom', 18, Decimal('2.99')),
#  ('Monterey Labyrinth', 13, Decimal('0.99')),
#  ('Doctor Grail', 7, Decimal('2.99')),
#  ('California Birds', 12, Decimal('4.99')),
#  ('Room Roman', 20, Decimal('0.99')),
#  ('Autumn Crow', 11, Decimal('4.99')),
#  ('Strangers Graffiti', 17, Decimal('4.99')),
#  ('Peach Innocent', 14, Decimal('2.99')),
#  ('Ballroom Mockingbird', 8, Decimal('0.99')),
#  ('Desert Poseidon', 19, Decimal('4.99')),
#  ('Anaconda Confessions', 21, Decimal('0.99')),
#  ('Barbarella Streetcar', 25, Decimal('2.99')),
#  ('Microcosmos Paradise', 13, Decimal('2.99')),
#  ('Tequila Past', 6, Decimal('4.99')),
#  ('Jade Bunch', 18, Decimal('2.99')),
#  ('Hollywood Anonymous', 13, Decimal('0.99')),
#  ('Elephant Trojan', 14, Decimal('4.99')),
#  ('Chainsaw Uptown', 21, Decimal('0.99')),
#  ('Chance Resurrection', 27, Decimal('2.99')),
#  ('Pure Runner', 16, Decimal('2.99')),
#  ('Horror Reign', 27, Decimal('0.99')),
#  ('Straight Hours', 20, Decimal('0.99')),
#  ('Punk Divorce', 8, Decimal('4.99')),
#  ('Magnificent Chitty', 8, Decimal('2.99')),
#  ('Sleuth Orient', 21, Decimal('0.99')),
#  ('Hawk Chill', 7, Decimal('0.99')),
#  ('Wonka Sea', 18, Decimal('2.99')),
#  ('Remember Diary', 18, Decimal('2.99')),
#  ('Mile Mulan', 13, Decimal('0.99')),
#  ('Reunion Witches', 20, Decimal('0.99')),
#  ('Pocus Pulp', 26, Decimal('0.99')),
#  ('Jungle Closer', 9, Decimal('0.99')),
#  ('Spy Mile', 27, Decimal('2.99')),
#  ('Coast Rainbow', 21, Decimal('0.99')),
#  ('Excitement Eve', 21, Decimal('0.99')),
#  ('Exorcist Sting', 13, Decimal('2.99')),
#  ('Sugar Wonka', 17, Decimal('4.99')),
#  ('Boiled Dares', 15, Decimal('4.99')),
#  ('Tenenbaums Command', 13, Decimal('0.99')),
#  ('Simon North', 6, Decimal('0.99')),
#  ('Platoon Instinct', 9, Decimal('4.99')),
#  ('Edge Kissing', 15, Decimal('4.99')),
#  ('Meet Chocolate', 12, Decimal('2.99')),
#  ('Moonwalker Fool', 13, Decimal('4.99')),
#  ('Super Wyoming', 13, Decimal('4.99')),
#  ('Sensibility Rear', 10, Decimal('4.99')),
#  ('Pelican Comforts', 26, Decimal('4.99')),
#  ('Forrest Sons', 18, Decimal('2.99')),
#  ('Desperate Trainspotting', 6, Decimal('4.99')),
#  ('Oscar Gold', 25, Decimal('2.99')),
#  ('Mine Titans', 19, Decimal('4.99')),
#  ('Truman Crazy', 23, Decimal('4.99')),
#  ('Mystic Truman', 10, Decimal('0.99')),
#  ('Island Exorcist', 26, Decimal('2.99')),
#  ('Youth Kick', 6, Decimal('0.99')),
#  ('Dawn Pond', 18, Decimal('4.99')),
#  ('Rouge Squad', 18, Decimal('0.99')),
#  ('Dynamite Tarzan', 25, Decimal('0.99')),
#  ('Noon Papi', 17, Decimal('2.99')),
#  ('Mulan Moon', 13, Decimal('0.99')),
#  ('Moon Bunch', 29, Decimal('0.99')),
#  ('Snatch Slipper', 22, Decimal('4.99')),
#  ('Kwai Homeward', 23, Decimal('0.99')),
#  ('Hyde Doctor', 26, Decimal('2.99')),
#  ('Murder Antitrust', 23, Decimal('2.99')),
#  ('Darko Dorado', 11, Decimal('4.99')),
#  ('Usual Untouchables', 13, Decimal('4.99'))]

# %% [markdown]
# # 7
#
# ### List the city of rental stores, `store_id` and the movies that have not been rented from that store.
#
# **Note:** A video walk through for this challenging SQL is provided below.

# %%
# %%sql
# EXPLAIN
# SELECT c.city, s.store_id, f.title, f.film_id
# from store s
# JOIN address a USING (address_id)
# JOIN city c using (city_id)
# , film f
# WHERE NOT EXISTS(
#     SELECT 'Z'
#     FROM film f2 JOIN inventory i USING (film_id)
#     JOIN rental r USING (inventory_id)
#     JOIN payment p USING (rental_id, staff_id)
#     JOIN staff ss USING (staff_id)
#     WHERE f2.film_id = f.film_id
#     AND s.store_id = ss.store_id
# )
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 31 rows affected.
# [('Hash Anti Join  (cost=1296.26..1427.01 rows=1 width=32)',),
#  ('  Hash Cond: ((s.store_id = ss.store_id) AND (f.film_id = f2.film_id))',),
#  ('  ->  Nested Loop  (cost=1.32..107.07 rows=2000 width=32)',),
#  ('        ->  Seq Scan on film f  (cost=0.00..64.00 rows=1000 width=19)',),
#  ('        ->  Materialize  (cost=1.32..18.07 rows=2 width=13)',),
#  ('              ->  Nested Loop  (cost=1.32..18.06 rows=2 width=13)',),
#  ('                    ->  Hash Join  (cost=1.04..17.36 rows=2 width=6)',),
#  ('                          Hash Cond: (a.address_id = s.address_id)',),
#  ('                          ->  Seq Scan on address a  (cost=0.00..14.03 rows=603 width=6)',),
#  ('                          ->  Hash  (cost=1.02..1.02 rows=2 width=6)',),
#  ('                                ->  Seq Scan on store s  (cost=0.00..1.02 rows=2 width=6)',),
#  ('                    ->  Index Scan using city_pkey on city c  (cost=0.28..0.35 rows=1 width=13)',),
#  ('                          Index Cond: (city_id = a.city_id)',),
#  ('  ->  Hash  (cost=1185.47..1185.47 rows=7298 width=6)',),
#  ('        ->  Hash Join  (cost=756.72..1185.47 rows=7298 width=6)',),
#  ('              Hash Cond: (r.staff_id = ss.staff_id)',),
#  ('              ->  Hash Join  (cost=755.67..1124.68 rows=7298 width=8)',),
#  ('                    Hash Cond: (i.film_id = f2.film_id)',),
#  ('                    ->  Hash Join  (cost=679.17..1028.94 rows=7298 width=6)',),
#  ('                          Hash Cond: (r.inventory_id = i.inventory_id)',),
#  ('                          ->  Hash Join  (cost=551.10..881.69 rows=7298 width=8)',),
#  ('                                Hash Cond: ((p.rental_id = r.rental_id) AND (p.staff_id = r.staff_id))',),
#  ('                                ->  Seq Scan on payment p  (cost=0.00..253.96 rows=14596 width=6)',),
#  ('                                ->  Hash  (cost=310.44..310.44 rows=16044 width=10)',),
#  ('                                      ->  Seq Scan on rental r  (cost=0.00..310.44 rows=16044 width=10)',),
#  ('                          ->  Hash  (cost=70.81..70.81 rows=4581 width=6)',),
#  ('                                ->  Seq Scan on inventory i  (cost=0.00..70.81 rows=4581 width=6)',),
#  ('                    ->  Hash  (cost=64.00..64.00 rows=1000 width=4)',),
#  ('                          ->  Seq Scan on film f2  (cost=0.00..64.00 rows=1000 width=4)',),
#  ('              ->  Hash  (cost=1.02..1.02 rows=2 width=6)',),
#  ('                    ->  Seq Scan on staff ss  (cost=0.00..1.02 rows=2 width=6)',)]

# %%
# %%sql
# SELECT c.city, s.store_id, f.title, f.film_id
# from store s
# JOIN address a USING (address_id)
# JOIN city c using (city_id)
# , film f
# WHERE NOT EXISTS(
#     SELECT 'Z'
#     FROM film f2 JOIN inventory i USING (film_id)
#     JOIN rental r USING (inventory_id)
#     JOIN payment p USING (rental_id, staff_id)
#     JOIN staff ss USING (staff_id)
#     WHERE f2.film_id = f.film_id
#     AND s.store_id = ss.store_id
# )
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 145 rows affected.
# [('Lethbridge', 1, 'Grosse Wonderful', 384),
#  ('Lethbridge', 1, 'Alice Fantasia', 14),
#  ('Woodridge', 2, 'Alice Fantasia', 14),
#  ('Lethbridge', 1, 'Apollo Teen', 33),
#  ('Woodridge', 2, 'Apollo Teen', 33),
#  ('Lethbridge', 1, 'Argonauts Town', 36),
#  ('Woodridge', 2, 'Argonauts Town', 36),
#  ('Lethbridge', 1, 'Ark Ridgemont', 38),
#  ('Woodridge', 2, 'Ark Ridgemont', 38),
#  ('Lethbridge', 1, 'Arsenic Independence', 41),
#  ('Woodridge', 2, 'Arsenic Independence', 41),
#  ('Lethbridge', 1, 'Ballroom Mockingbird', 52),
#  ('Woodridge', 2, 'Blanket Beverly', 80),
#  ('Woodridge', 2, 'Blood Argonauts', 82),
#  ('Lethbridge', 1, 'Boondock Ballroom', 87),
#  ('Woodridge', 2, 'Boondock Ballroom', 87),
#  ('Lethbridge', 1, 'Braveheart Human', 94),
#  ('Woodridge', 2, 'Breakfast Goldfinger', 95),
#  ('Woodridge', 2, 'Bubble Grosse', 102),
#  ('Woodridge', 2, 'Bunch Minds', 107),
#  ('Lethbridge', 1, 'Butch Panther', 108),
#  ('Woodridge', 2, 'Butch Panther', 108),
#  ('Woodridge', 2, 'Casper Dragonfly', 124),
#  ('Woodridge', 2, 'Cassidy Wyoming', 125),
#  ('Lethbridge', 1, 'Catch Amistad', 128),
#  ('Woodridge', 2, 'Catch Amistad', 128),
#  ('Lethbridge', 1, 'Chinatown Gladiator', 144),
#  ('Woodridge', 2, 'Chinatown Gladiator', 144),
#  ('Lethbridge', 1, 'Chisum Behavior', 145),
#  ('Lethbridge', 1, 'Chocolate Duck', 148),
#  ('Woodridge', 2, 'Chocolate Duck', 148),
#  ('Lethbridge', 1, 'Circus Youth', 152),
#  ('Woodridge', 2, 'Comancheros Enemy', 168),
#  ('Lethbridge', 1, 'Commandments Express', 171),
#  ('Woodridge', 2, 'Commandments Express', 171),
#  ('Lethbridge', 1, 'Conspiracy Spirit', 180),
#  ('Lethbridge', 1, 'Control Anthem', 182),
#  ('Lethbridge', 1, 'Crossing Divorce', 192),
#  ('Woodridge', 2, 'Crossing Divorce', 192),
#  ('Lethbridge', 1, 'Crowds Telemark', 195),
#  ('Woodridge', 2, 'Crowds Telemark', 195),
#  ('Lethbridge', 1, 'Cruelty Unforgiven', 196),
#  ('Lethbridge', 1, 'Crystal Breaking', 198),
#  ('Woodridge', 2, 'Crystal Breaking', 198),
#  ('Lethbridge', 1, 'Dazed Punk', 217),
#  ('Woodridge', 2, 'Dazed Punk', 217),
#  ('Lethbridge', 1, 'Deliverance Mulholland', 221),
#  ('Woodridge', 2, 'Deliverance Mulholland', 221),
#  ('Lethbridge', 1, 'Dolls Rage', 240),
#  ('Woodridge', 2, 'Dwarfs Alter', 264),
#  ('Woodridge', 2, 'Ending Crowds', 283),
#  ('Woodridge', 2, 'Fever Empire', 310),
#  ('Lethbridge', 1, 'Fire Wolves', 316),
#  ('Lethbridge', 1, 'Firehouse Vietnam', 318),
#  ('Woodridge', 2, 'Firehouse Vietnam', 318),
#  ('Lethbridge', 1, 'Floats Garden', 325),
#  ('Woodridge', 2, 'Floats Garden', 325),
#  ('Lethbridge', 1, 'Frankenstein Stranger', 332),
#  ('Woodridge', 2, 'Frankenstein Stranger', 332),
#  ('Lethbridge', 1, 'Freedom Cleopatra', 335),
#  ('Lethbridge', 1, 'Gathering Calendar', 352),
#  ('Lethbridge', 1, 'Gladiator Westward', 359),
#  ('Woodridge', 2, 'Gladiator Westward', 359),
#  ('Lethbridge', 1, 'Glory Tracy', 362),
#  ('Woodridge', 2, 'Grail Frankenstein', 375),
#  ('Lethbridge', 1, 'Gump Date', 386),
#  ('Woodridge', 2, 'Gump Date', 386),
#  ('Lethbridge', 1, 'Hate Handicap', 404),
#  ('Woodridge', 2, 'Hate Handicap', 404),
#  ('Woodridge', 2, 'Heavenly Gun', 411),
#  ('Lethbridge', 1, 'Hocus Frida', 419),
#  ('Woodridge', 2, 'Hocus Frida', 419),
#  ('Lethbridge', 1, 'Jawbreaker Brooklyn', 477),
#  ('Lethbridge', 1, 'Kentuckian Giant', 495),
#  ('Woodridge', 2, 'Kentuckian Giant', 495),
#  ('Lethbridge', 1, 'Kill Brotherhood', 497),
#  ('Woodridge', 2, 'Kill Brotherhood', 497),
#  ('Lethbridge', 1, 'License Weekend', 520),
#  ('Lethbridge', 1, 'Lost Bird', 533),
#  ('Lethbridge', 1, 'Luck Opus', 539),
#  ('Woodridge', 2, 'Luck Opus', 539),
#  ('Lethbridge', 1, 'Magic Mallrats', 547),
#  ('Lethbridge', 1, 'Maguire Apache', 550),
#  ('Lethbridge', 1, 'Mannequin Worst', 558),
#  ('Woodridge', 2, 'Massage Image', 564),
#  ('Lethbridge', 1, 'Matrix Snowman', 565),
#  ('Lethbridge', 1, 'Mile Mulan', 577),
#  ('Woodridge', 2, 'Mixed Doors', 584),
#  ('Lethbridge', 1, 'Mulholland Beast', 605),
#  ('Lethbridge', 1, 'Muppet Mile', 607),
#  ('Woodridge', 2, 'Muppet Mile', 607),
#  ('Lethbridge', 1, 'Mussolini Spoilers', 612),
#  ('Woodridge', 2, 'Mussolini Spoilers', 612),
#  ('Lethbridge', 1, 'Order Betrayed', 642),
#  ('Woodridge', 2, 'Order Betrayed', 642),
#  ('Woodridge', 2, 'Panic Club', 653),
#  ('Lethbridge', 1, 'Paycheck Wait', 666),
#  ('Lethbridge', 1, 'Pearl Destiny', 669),
#  ('Woodridge', 2, 'Pearl Destiny', 669),
#  ('Lethbridge', 1, 'Perdition Fargo', 671),
#  ('Woodridge', 2, 'Perdition Fargo', 671),
#  ('Woodridge', 2, 'Phantom Glory', 675),
#  ('Woodridge', 2, 'Pizza Jumanji', 684),
#  ('Lethbridge', 1, 'Psycho Shrunk', 701),
#  ('Woodridge', 2, 'Psycho Shrunk', 701),
#  ('Lethbridge', 1, 'Raiders Antitrust', 712),
#  ('Woodridge', 2, 'Raiders Antitrust', 712),
#  ('Lethbridge', 1, 'Rainbow Shock', 713),
#  ('Woodridge', 2, 'Rainbow Shock', 713),
#  ('Woodridge', 2, 'Robbery Bright', 736),
#  ('Lethbridge', 1, 'Roof Champion', 742),
#  ('Woodridge', 2, 'Roof Champion', 742),
#  ('Lethbridge', 1, 'Runner Madigan', 752),
#  ('Lethbridge', 1, 'Sister Freddy', 801),
#  ('Woodridge', 2, 'Sister Freddy', 801),
#  ('Lethbridge', 1, 'Sky Miracle', 802),
#  ('Woodridge', 2, 'Sky Miracle', 802),
#  ('Woodridge', 2, 'Smoochy Control', 813),
#  ('Lethbridge', 1, 'Speed Suit', 826),
#  ('Lethbridge', 1, 'Stage World', 837),
#  ('Lethbridge', 1, 'Suicides Silence', 860),
#  ('Woodridge', 2, 'Suicides Silence', 860),
#  ('Woodridge', 2, 'Sweet Brotherhood', 872),
#  ('Lethbridge', 1, 'Tadpole Park', 874),
#  ('Woodridge', 2, 'Tadpole Park', 874),
#  ('Lethbridge', 1, 'Tequila Past', 883),
#  ('Woodridge', 2, 'Terminator Club', 884),
#  ('Lethbridge', 1, 'Texas Watch', 885),
#  ('Lethbridge', 1, 'Towers Hurricane', 899),
#  ('Woodridge', 2, 'Traffic Hobbit', 903),
#  ('Lethbridge', 1, 'Train Bunch', 904),
#  ('Lethbridge', 1, 'Treasure Command', 909),
#  ('Woodridge', 2, 'Treasure Command', 909),
#  ('Lethbridge', 1, 'Treatment Jekyll', 910),
#  ('Woodridge', 2, 'Vanished Garden', 935),
#  ('Lethbridge', 1, 'Villain Desperate', 943),
#  ('Woodridge', 2, 'Villain Desperate', 943),
#  ('Lethbridge', 1, 'Volume House', 950),
#  ('Woodridge', 2, 'Volume House', 950),
#  ('Lethbridge', 1, 'Wake Jaws', 954),
#  ('Woodridge', 2, 'Wake Jaws', 954),
#  ('Lethbridge', 1, 'Walls Artist', 955),
#  ('Woodridge', 2, 'Walls Artist', 955),
#  ('Woodridge', 2, 'Wild Apollo', 974),
#  ('Lethbridge', 1, 'Zhivago Core', 998)]

# %% [markdown]
# #### Helpful Hints
#   1. For the first hint watch only the first 5:57 of the video where the conceptual aspects of the task are discussed.
#   1. Then attempt to construct SQL based on the video explanation of the concept.
#   1. If you get stuck again, the remainder of the video after that looks directly at the SQL construction.
#
# [Helpful Hints](https://youtu.be/GyMODTEDfu4)

# %% [markdown]
# # SAVE YOUR NOTEBOOK
