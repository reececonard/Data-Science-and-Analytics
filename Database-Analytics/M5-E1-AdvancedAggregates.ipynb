# %% [markdown]
# # Advanced Aggregates
#
# Please remember to use the `EXPLAIN` before you execute a query to help avoid unnecessary load on the DBMS and indefinite waits by you for results.
#
# Therefore, for each question, we are providing a cell for the `EXPLAIN` as well as the final SQL.
#
#
# ## Our practice schema:
#
# We will use the DVD Rental database.
#
# A PDF of the _Entity-Relationship Diagrams_ (ERD) is available [here](https://web.dsa.missouri.edu/static/PDF/DVD_Rental_ERD2.pdf).
# Printing it out is recommended.
#
#
# **NOTE**: These queries are more complex that the others.
# If you get stuck on one, skip and come back to it later.
#
# **NOTE**: For this notebook, it is desired that you construct solutions using advanced aggregates and derived tables.

# %%
# %load_ext sql
# %sql postgres://dsa_ro_user:readonly@pgsql.dsa.lan/dvdrental
# Out:
# 'Connected: dsa_ro_user@dvdrental'

# %% [markdown]
# ### 1
# ### What is the average, variance, and standard deviation of the film length?

# %%
# %%sql
# EXPLAIN
# SELECT avg(length) as avg_length, var_pop(length) as var_length, stddev(length) as std_length
# from film;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 2 rows affected.
# [('Aggregate  (cost=71.51..71.52 rows=1 width=96)',),
#  ('  ->  Seq Scan on film  (cost=0.00..64.00 rows=1000 width=2)',)]

# %%
# %%sql
# SELECT avg(length) as avg_length, var_pop(length) as var_length, stddev(length) as std_length
# from film;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 1 rows affected.
# [(Decimal('115.2720000000000000'), Decimal('1632.6540160000000000'), Decimal('40.4263318185598470'))]

# %% [markdown]
# ### 2
# ### What is the average, variance, and standard deviation of the film length; broken down by film category.

# %%
# %%sql
# EXPLAIN
# SELECT name, avg(length) as avg_length, var_pop(length) as var_length, stddev(length) as std_length
# from film
# JOIN film_category
#   ON (film_category.film_id = film.film_id)
# JOIN category
#   ON (film_category.category_id = category.category_id)
# GROUP BY name
# ORDER BY name ASC;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 13 rows affected.
# [('Sort  (cost=110.41..110.45 rows=16 width=164)',),
#  ('  Sort Key: category.name',),
#  ('  ->  HashAggregate  (cost=109.81..110.09 rows=16 width=164)',),
#  ('        Group Key: category.name',),
#  ('        ->  Hash Join  (cost=77.86..99.81 rows=1000 width=70)',),
#  ('              Hash Cond: (film_category.category_id = category.category_id)',),
#  ('              ->  Hash Join  (cost=76.50..95.14 rows=1000 width=4)',),
#  ('                    Hash Cond: (film_category.film_id = film.film_id)',),
#  ('                    ->  Seq Scan on film_category  (cost=0.00..16.00 rows=1000 width=4)',),
#  ('                    ->  Hash  (cost=64.00..64.00 rows=1000 width=6)',),
#  ('                          ->  Seq Scan on film  (cost=0.00..64.00 rows=1000 width=6)',),
#  ('              ->  Hash  (cost=1.16..1.16 rows=16 width=72)',),
#  ('                    ->  Seq Scan on category  (cost=0.00..1.16 rows=16 width=72)',)]

# %%
# %%sql
# SELECT name, avg(length) as avg_length, var_pop(length) as var_length, stddev(length) as std_length
# from film
# JOIN film_category USING (film_id)
# JOIN category USING (category_id)
# GROUP BY name
# ORDER BY name ASC;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 16 rows affected.
# [('Action', Decimal('111.6093750000000000'), Decimal('1819.4880371093750000'), Decimal('42.9926598340132313')),
#  ('Animation', Decimal('111.0151515151515152'), Decimal('1696.9846189164370983'), Decimal('41.5101442371870661')),
#  ('Children', Decimal('109.8000000000000000'), Decimal('1475.8933333333333333'), Decimal('38.7415600431406374')),
#  ('Classics', Decimal('111.6666666666666667'), Decimal('1449.3450292397660819'), Decimal('38.4086733756347080')),
#  ('Comedy', Decimal('115.8275862068965517'), Decimal('1750.6254458977407848'), Decimal('42.2059021111829072')),
#  ('Documentary', Decimal('108.7500000000000000'), Decimal('1787.9816176470588235'), Decimal('42.5989191229984284')),
#  ('Drama', Decimal('120.8387096774193548'), Decimal('1631.6514047866805411'), Decimal('40.7234550163871544')),
#  ('Family', Decimal('114.7826086956521739'), Decimal('1501.1556395715185885'), Decimal('39.0285979481778401')),
#  ('Foreign', Decimal('121.6986301369863014'), Decimal('1836.4023268905986114'), Decimal('43.1498309934590491')),
#  ('Games', Decimal('127.8360655737704918'), Decimal('1241.7764041924213921'), Decimal('35.5312915272668975')),
#  ('Horror', Decimal('112.4821428571428571'), Decimal('1363.8925382653061224'), Decimal('37.2651389963271761')),
#  ('Music', Decimal('113.6470588235294118'), Decimal('1752.2675893886966551'), Decimal('42.2766240513178936')),
#  ('New', Decimal('111.1269841269841270'), Decimal('1490.7457797933988410'), Decimal('38.9203040399771301')),
#  ('Sci-Fi', Decimal('108.1967213114754098'), Decimal('1294.0596613813490997'), Decimal('36.2715773354891693')),
#  ('Sports', Decimal('128.2027027027027027'), Decimal('1772.1886413440467495'), Decimal('42.3847283591010775')),
#  ('Travel', Decimal('113.3157894736842105'), Decimal('1513.1634349030470914'), Decimal('39.2451807299484326'))]

# %% [markdown]
# [Helpful Hints Video](https://youtu.be/jy9H2KLI4Iw)

# %% [markdown]
# ### 3
# ### A movie's "cumulative rented duration" is the sum of all rentals from rental table.  What is the average _cumulative rented duration_ per store (inventory.store_id).

# %%
# %%sql
# EXPLAIN
# SELECT s.store_id, avg(x.cumulative) as avg_cumul_rented_duration
# from store s
# JOIN address USING (address_id)
# JOIN customer USING (address_id)
# NATURAL JOIN (
#     SELECT inventory_id, sum(r.return_date - r.rental_date) as cumulative
#     FROM rental r
#     WHERE r.rental_date IS NOT NULL
#     GROUP BY inventory_id) as x
# GROUP BY s.store_id;

# %%
# %%sql
# SELECT s.store_id, avg(x.cumulative) as avg_cumul_rented_duration
# from store s
# JOIN address USING (address_id)
# JOIN customer USING (address_id)
# NATURAL JOIN (
#     SELECT inventory_id, sum(r.return_date - r.rental_date) as cumulative
#     FROM rental r
#     WHERE r.rental_date IS NOT NULL
#     GROUP BY inventory_id) as x
# GROUP BY s.store_id;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 0 rows affected.
# []

# %%
# %%sql
# SELECT inventory_id, sum(r.return_date - r.rental_date) as cumulative
#     FROM rental r
#     WHERE r.rental_date IS NOT NULL
#     GROUP BY inventory_id
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 4580 rows affected.
# [(1489, datetime.timedelta(days=32, seconds=76740)),
#  (273, datetime.timedelta(days=32, seconds=70620)),
#  (3936, datetime.timedelta(days=9, seconds=67020)),
#  (2574, datetime.timedelta(days=30, seconds=10140)),
#  (951, datetime.timedelta(days=21, seconds=79620)),
#  (4326, datetime.timedelta(days=15, seconds=86340)),
#  (2614, datetime.timedelta(days=13, seconds=85080)),
#  (2520, datetime.timedelta(days=23, seconds=42600)),
#  (2466, datetime.timedelta(days=19, seconds=4800)),
#  (2196, datetime.timedelta(days=11, seconds=41100)),
#  (4321, datetime.timedelta(days=8, seconds=62460)),
#  (1750, datetime.timedelta(days=21, seconds=21120)),
#  (176, datetime.timedelta(days=27, seconds=6300)),
#  (576, datetime.timedelta(days=13, seconds=11820)),
#  (1003, datetime.timedelta(days=20, seconds=71160)),
#  (292, datetime.timedelta(days=13, seconds=43140)),
#  (1331, datetime.timedelta(days=15, seconds=33540)),
#  (2784, datetime.timedelta(days=3, seconds=16560)),
#  (663, datetime.timedelta(days=6, seconds=8880)),
#  (1552, datetime.timedelta(days=17, seconds=18720)),
#  (1589, datetime.timedelta(days=13, seconds=2640)),
#  (1811, datetime.timedelta(days=17, seconds=4980)),
#  (3725, datetime.timedelta(days=27, seconds=70920)),
#  (2204, datetime.timedelta(days=14, seconds=48420)),
#  (556, datetime.timedelta(days=23, seconds=14940)),
#  (1373, datetime.timedelta(days=20, seconds=28320)),
#  (764, datetime.timedelta(days=18, seconds=33360)),
#  (2469, datetime.timedelta(days=25, seconds=60780)),
#  (3762, datetime.timedelta(days=14, seconds=24840)),
#  (4116, datetime.timedelta(days=14, seconds=53520)),
#  (1268, datetime.timedelta(days=10, seconds=11040)),
#  (2749, datetime.timedelta(days=16, seconds=31500)),
#  (3641, datetime.timedelta(days=24, seconds=7080)),
#  (173, datetime.timedelta(days=17, seconds=25740)),
#  (4221, datetime.timedelta(days=11, seconds=6120)),
#  (2276, datetime.timedelta(days=31, seconds=66300)),
#  (876, datetime.timedelta(days=15, seconds=82920)),
#  (161, datetime.timedelta(days=23, seconds=76800)),
#  (3202, datetime.timedelta(days=10, seconds=16320)),
#  (113, datetime.timedelta(days=12, seconds=64740)),
#  (2172, datetime.timedelta(days=9, seconds=13920)),
#  (2983, datetime.timedelta(days=17, seconds=63360)),
#  (1595, datetime.timedelta(days=11, seconds=18900)),
#  (3097, datetime.timedelta(days=4, seconds=82080)),
#  (4519, datetime.timedelta(days=10, seconds=21180)),
#  (4095, datetime.timedelta(days=21, seconds=20100)),
#  (2990, datetime.timedelta(days=10, seconds=73740)),
#  (4289, datetime.timedelta(days=20, seconds=22980)),
#  (815, datetime.timedelta(days=30, seconds=5820)),
#  (1422, datetime.timedelta(days=14, seconds=30000)),
#  (1004, datetime.timedelta(days=8, seconds=81420)),
#  (3150, datetime.timedelta(days=24, seconds=4560)),
#  (2054, datetime.timedelta(days=15, seconds=2400)),
#  (2702, datetime.timedelta(days=11, seconds=40860)),
#  (57, datetime.timedelta(days=12, seconds=75600)),
#  (2404, datetime.timedelta(days=13, seconds=57840)),
#  (3837, datetime.timedelta(days=22, seconds=67500)),
#  (3071, datetime.timedelta(days=25, seconds=7500)),
#  (19, datetime.timedelta(days=18, seconds=60120)),
#  (1313, datetime.timedelta(days=21, seconds=52260)),
#  (2721, datetime.timedelta(days=19, seconds=8580)),
#  (4452, datetime.timedelta(days=20, seconds=85020)),
#  (824, datetime.timedelta(days=11, seconds=61200)),
#  (3834, datetime.timedelta(days=18, seconds=11340)),
#  (3460, datetime.timedelta(days=8, seconds=72540)),
#  (1262, datetime.timedelta(days=13, seconds=30780)),
#  (357, datetime.timedelta(days=11, seconds=28860)),
#  (2366, datetime.timedelta(days=16, seconds=3420)),
#  (769, datetime.timedelta(days=27, seconds=65640)),
#  (266, datetime.timedelta(days=21, seconds=17340)),
#  (2543, datetime.timedelta(days=10, seconds=69900)),
#  (1550, datetime.timedelta(days=25, seconds=23700)),
#  (1287, datetime.timedelta(days=26, seconds=61800)),
#  (3855, datetime.timedelta(days=21, seconds=53580)),
#  (3840, datetime.timedelta(days=17, seconds=28740)),
#  (307, datetime.timedelta(days=16, seconds=80820)),
#  (366, datetime.timedelta(days=16, seconds=37800)),
#  (3199, datetime.timedelta(days=11, seconds=22740)),
#  (91, datetime.timedelta(days=10, seconds=35820)),
#  (4078, datetime.timedelta(days=23, seconds=59880)),
#  (305, datetime.timedelta(days=13, seconds=9480)),
#  (743, datetime.timedelta(days=15, seconds=55920)),
#  (1484, datetime.timedelta(days=29, seconds=18180)),
#  (3986, datetime.timedelta(days=23, seconds=71160)),
#  (10, datetime.timedelta(days=17, seconds=8340)),
#  (1940, datetime.timedelta(days=18, seconds=66960)),
#  (3068, datetime.timedelta(days=11, seconds=1860)),
#  (3582, datetime.timedelta(days=15, seconds=62640)),
#  (2636, datetime.timedelta(days=21, seconds=68100)),
#  (1602, datetime.timedelta(days=21, seconds=79380)),
#  (2773, datetime.timedelta(days=14, seconds=13680)),
#  (823, datetime.timedelta(days=8, seconds=29520)),
#  (2544, datetime.timedelta(days=10, seconds=20820)),
#  (3494, datetime.timedelta(days=26, seconds=39420)),
#  (4356, datetime.timedelta(days=25, seconds=8220)),
#  (4314, datetime.timedelta(days=9, seconds=77100)),
#  (50, datetime.timedelta(days=21, seconds=22020)),
#  (13, datetime.timedelta(days=4, seconds=6720)),
#  (1319, datetime.timedelta(days=19, seconds=35100)),
#  (4197, datetime.timedelta(days=12, seconds=13320)),
#  (2, datetime.timedelta(days=29, seconds=74040)),
#  (4579, datetime.timedelta(days=20, seconds=6960)),
#  (1603, datetime.timedelta(days=6, seconds=960)),
#  (2770, datetime.timedelta(days=9, seconds=19080)),
#  (246, datetime.timedelta(days=19, seconds=43140)),
#  (3735, datetime.timedelta(days=7, seconds=780)),
#  (1942, datetime.timedelta(days=4, seconds=50940)),
#  (4474, datetime.timedelta(days=12, seconds=16080)),
#  (2857, datetime.timedelta(days=15, seconds=17220)),
#  (2799, datetime.timedelta(days=12, seconds=66360)),
#  (3497, datetime.timedelta(days=23, seconds=56580)),
#  (1522, datetime.timedelta(days=16, seconds=5700)),
#  (2140, datetime.timedelta(days=19, seconds=23880)),
#  (355, datetime.timedelta(days=8, seconds=1320)),
#  (1967, datetime.timedelta(days=25, seconds=18360)),
#  (2575, datetime.timedelta(days=35, seconds=37200)),
#  (3442, datetime.timedelta(days=20, seconds=62940)),
#  (2952, datetime.timedelta(days=10, seconds=24540)),
#  (3755, datetime.timedelta(days=11, seconds=75420)),
#  (1006, datetime.timedelta(days=4, seconds=8940)),
#  (2742, datetime.timedelta(days=18, seconds=18000)),
#  (2683, datetime.timedelta(days=11, seconds=17520)),
#  (3046, datetime.timedelta(days=33, seconds=80040)),
#  (453, datetime.timedelta(days=14, seconds=80040)),
#  (2099, datetime.timedelta(days=7, seconds=22680)),
#  (3530, datetime.timedelta(days=23, seconds=72600)),
#  (182, datetime.timedelta(days=31, seconds=22860)),
#  (528, datetime.timedelta(days=15, seconds=69180)),
#  (1950, datetime.timedelta(days=9, seconds=49440)),
#  (4351, datetime.timedelta(days=14, seconds=75960)),
#  (1549, datetime.timedelta(days=12, seconds=81840)),
#  (3463, datetime.timedelta(days=23, seconds=32640)),
#  (1474, datetime.timedelta(days=24, seconds=55620)),
#  (667, datetime.timedelta(days=27, seconds=47760)),
#  (1613, datetime.timedelta(days=21, seconds=14520)),
#  (4102, datetime.timedelta(days=8, seconds=12300)),
#  (3602, datetime.timedelta(days=12, seconds=85920)),
#  (481, datetime.timedelta(days=18, seconds=33600)),
#  (1804, datetime.timedelta(days=10, seconds=17520)),
#  (438, datetime.timedelta(days=21, seconds=780)),
#  (382, datetime.timedelta(days=12, seconds=8220)),
#  (2675, datetime.timedelta(days=13, seconds=5340)),
#  (378, datetime.timedelta(days=15, seconds=65820)),
#  (2526, datetime.timedelta(days=23, seconds=1200)),
#  (2579, datetime.timedelta(days=15, seconds=29340)),
#  (2073, datetime.timedelta(days=12, seconds=66780)),
#  (3717, datetime.timedelta(days=8, seconds=30840)),
#  (1349, datetime.timedelta(days=27, seconds=78240)),
#  (4199, datetime.timedelta(days=10, seconds=11340)),
#  (799, datetime.timedelta(days=15, seconds=31440)),
#  (3378, datetime.timedelta(days=21, seconds=24360)),
#  (4081, datetime.timedelta(days=14, seconds=83640)),
#  (1044, datetime.timedelta(days=24, seconds=22380)),
#  (3786, datetime.timedelta(days=20, seconds=18660)),
#  (3671, datetime.timedelta(days=4, seconds=24600)),
#  (4147, datetime.timedelta(days=24, seconds=31260)),
#  (1848, datetime.timedelta(days=20, seconds=65460)),
#  (589, datetime.timedelta(days=16, seconds=20160)),
#  (2925, datetime.timedelta(days=22, seconds=49380)),
#  (4150, datetime.timedelta(days=20, seconds=18120)),
#  (1167, datetime.timedelta(days=24, seconds=25260)),
#  (3702, datetime.timedelta(days=15, seconds=81480)),
#  (329, datetime.timedelta(days=12, seconds=37680)),
#  (682, datetime.timedelta(days=15, seconds=64680)),
#  (44, datetime.timedelta(days=11, seconds=31560)),
#  (3728, datetime.timedelta(days=19, seconds=79200)),
#  (1144, datetime.timedelta(days=17, seconds=85740)),
#  (2150, datetime.timedelta(days=11, seconds=2640)),
#  (3991, datetime.timedelta(days=13, seconds=60600)),
#  (3523, datetime.timedelta(days=10, seconds=1320)),
#  (1585, datetime.timedelta(days=22, seconds=12840)),
#  (2598, datetime.timedelta(days=35, seconds=6240)),
#  (2391, datetime.timedelta(days=17, seconds=42060)),
#  (3950, datetime.timedelta(days=13, seconds=19740)),
#  (1987, datetime.timedelta(days=19, seconds=72180)),
#  (1022, datetime.timedelta(days=22, seconds=69360)),
#  (2951, datetime.timedelta(days=25, seconds=19620)),
#  (944, datetime.timedelta(days=29, seconds=69780)),
#  (3035, datetime.timedelta(days=13, seconds=3180)),
#  (2601, datetime.timedelta(days=32, seconds=73500)),
#  (4371, datetime.timedelta(days=34, seconds=74220)),
#  (2760, datetime.timedelta(days=28, seconds=41580)),
#  (4430, datetime.timedelta(days=11, seconds=17580)),
#  (551, datetime.timedelta(days=12, seconds=5160)),
#  (948, datetime.timedelta(days=17, seconds=5460)),
#  (4028, datetime.timedelta(days=19, seconds=75300)),
#  (4429, datetime.timedelta(days=22, seconds=74340)),
#  (1540, datetime.timedelta(days=16, seconds=31380)),
#  (2540, datetime.timedelta(days=31, seconds=56160)),
#  (3107, datetime.timedelta(days=16, seconds=7020)),
#  (3882, datetime.timedelta(days=16, seconds=68460)),
#  (4533, datetime.timedelta(days=21, seconds=81540)),
#  (30, datetime.timedelta(days=30, seconds=70980)),
#  (521, datetime.timedelta(days=12, seconds=56280)),
#  (2828, datetime.timedelta(days=15, seconds=60300)),
#  (936, datetime.timedelta(days=19, seconds=77640)),
#  (981, datetime.timedelta(days=3, seconds=84840)),
#  (2149, datetime.timedelta(days=5, seconds=79980)),
#  (1334, datetime.timedelta(days=31, seconds=53400)),
#  (2465, datetime.timedelta(days=29, seconds=42240)),
#  (249, datetime.timedelta(days=34, seconds=17940)),
#  (255, datetime.timedelta(days=5, seconds=19440)),
#  (3308, datetime.timedelta(days=12, seconds=39720)),
#  (1678, datetime.timedelta(days=8, seconds=75720)),
#  (209, datetime.timedelta(days=8, seconds=71280)),
#  (296, datetime.timedelta(days=16, seconds=7020)),
#  (1747, datetime.timedelta(days=9, seconds=21300)),
#  (2538, datetime.timedelta(days=11, seconds=16020)),
#  (947, datetime.timedelta(days=11, seconds=23520)),
#  (1748, datetime.timedelta(days=17, seconds=76140)),
#  (972, datetime.timedelta(days=9, seconds=13800)),
#  (761, datetime.timedelta(days=24, seconds=34020)),
#  (3890, datetime.timedelta(days=19, seconds=12300)),
#  (2864, datetime.timedelta(days=17, seconds=3480)),
#  (1084, datetime.timedelta(days=28, seconds=71220)),
#  (90, datetime.timedelta(days=11, seconds=13320)),
#  (3374, datetime.timedelta(days=29, seconds=20160)),
#  (904, datetime.timedelta(days=17, seconds=13380)),
#  (2130, datetime.timedelta(days=3, seconds=5040)),
#  (3682, datetime.timedelta(days=22, seconds=22140)),
#  (4343, datetime.timedelta(days=17, seconds=18360)),
#  (3032, datetime.timedelta(days=26, seconds=76920)),
#  (3133, datetime.timedelta(days=23, seconds=46320)),
#  (3957, datetime.timedelta(days=11, seconds=74280)),
#  (4086, datetime.timedelta(days=22, seconds=27480)),
#  (4391, datetime.timedelta(days=6, seconds=83160)),
#  (4157, datetime.timedelta(days=12, seconds=75060)),
#  (524, datetime.timedelta(days=8, seconds=4020)),
#  (4096, datetime.timedelta(days=16, seconds=4500)),
#  (3311, datetime.timedelta(days=14, seconds=72600)),
#  (312, datetime.timedelta(days=23, seconds=66000)),
#  (3809, datetime.timedelta(days=11, seconds=79920)),
#  (862, datetime.timedelta(days=8, seconds=85260)),
#  (1185, datetime.timedelta(days=18, seconds=180)),
#  (494, datetime.timedelta(days=19, seconds=27840)),
#  (3300, datetime.timedelta(days=8, seconds=77820)),
#  (3689, datetime.timedelta(days=33, seconds=27660)),
#  (1265, datetime.timedelta(days=24, seconds=32280)),
#  (2906, datetime.timedelta(days=16, seconds=53820)),
#  (488, datetime.timedelta(days=19, seconds=36900)),
#  (2255, datetime.timedelta(days=18, seconds=84600)),
#  (4548, datetime.timedelta(days=12, seconds=82680)),
#  (1048, datetime.timedelta(days=8, seconds=20040)),
#  (1101, datetime.timedelta(days=29, seconds=40620)),
#  (360, datetime.timedelta(days=17, seconds=27000)),
#  (1770, datetime.timedelta(days=14, seconds=75060)),
#  (99, datetime.timedelta(days=24, seconds=63120)),
#  (629, datetime.timedelta(days=9, seconds=53160)),
#  (3057, datetime.timedelta(days=30, seconds=16800)),
#  (1215, datetime.timedelta(days=13, seconds=2940)),
#  (3688, datetime.timedelta(days=21, seconds=70200)),
#  (4194, datetime.timedelta(days=11, seconds=240)),
#  (4225, datetime.timedelta(days=20, seconds=12300)),
#  (3499, datetime.timedelta(days=18, seconds=58320)),
#  (3960, datetime.timedelta(days=3, seconds=59040)),
#  (2736, datetime.timedelta(days=27, seconds=79980)),
#  (2224, datetime.timedelta(days=16, seconds=21180)),
#  (2410, datetime.timedelta(days=22, seconds=3540)),
#  (442, datetime.timedelta(days=25, seconds=69600)),
#  (1238, datetime.timedelta(days=15, seconds=78600)),
#  (2254, datetime.timedelta(days=14, seconds=8940)),
#  (2866, datetime.timedelta(days=23, seconds=67560)),
#  (12, datetime.timedelta(days=5, seconds=72600)),
#  (2426, datetime.timedelta(days=10, seconds=71760)),
#  (1354, datetime.timedelta(days=12, seconds=85140)),
#  (4082, datetime.timedelta(days=8, seconds=17880)),
#  (2486, datetime.timedelta(days=29, seconds=35580)),
#  (1283, datetime.timedelta(days=23, seconds=70920)),
#  (1503, datetime.timedelta(days=14, seconds=8100)),
#  (2494, datetime.timedelta(days=10, seconds=77340)),
#  (899, datetime.timedelta(days=30, seconds=420)),
#  (2477, datetime.timedelta(days=3, seconds=38520)),
#  (935, datetime.timedelta(days=15, seconds=12900)),
#  (4459, datetime.timedelta(days=9, seconds=53280)),
#  (2498, datetime.timedelta(days=17, seconds=9780)),
#  (3495, datetime.timedelta(days=17, seconds=2400)),
#  (4173, datetime.timedelta(days=6, seconds=1680)),
#  (264, datetime.timedelta(days=18, seconds=61860)),
#  (4151, datetime.timedelta(days=8, seconds=68040)),
#  (2954, datetime.timedelta(days=4, seconds=72060)),
#  (384, datetime.timedelta(days=18, seconds=60780)),
#  (4433, datetime.timedelta(days=27, seconds=73440)),
#  (4487, datetime.timedelta(days=19, seconds=14940)),
#  (4155, datetime.timedelta(days=29, seconds=35160)),
#  (3737, datetime.timedelta(days=23, seconds=72660)),
#  (2475, datetime.timedelta(days=8, seconds=8820)),
#  (3274, datetime.timedelta(days=23, seconds=75000)),
#  (4537, datetime.timedelta(days=7, seconds=67440)),
#  (3659, datetime.timedelta(days=9, seconds=59100)),
#  (3675, datetime.timedelta(days=15, seconds=81660)),
#  (2894, datetime.timedelta(days=26, seconds=48000)),
#  (2535, datetime.timedelta(days=10, seconds=14640)),
#  (3583, datetime.timedelta(days=13, seconds=81360)),
#  (826, datetime.timedelta(days=22, seconds=83820)),
#  (2737, datetime.timedelta(days=7, seconds=82020)),
#  (431, datetime.timedelta(days=20, seconds=56460)),
#  (3505, datetime.timedelta(days=4, seconds=48540)),
#  (4114, datetime.timedelta(days=12, seconds=14940)),
#  (462, datetime.timedelta(days=24, seconds=48840)),
#  (2297, datetime.timedelta(days=3, seconds=27660)),
#  (4574, datetime.timedelta(days=19, seconds=84480)),
#  (855, datetime.timedelta(days=8, seconds=3120)),
#  (3339, datetime.timedelta(days=16, seconds=2280)),
#  (4581, datetime.timedelta(days=17, seconds=85200)),
#  (1615, datetime.timedelta(days=16, seconds=48480)),
#  (3780, datetime.timedelta(days=18, seconds=81000)),
#  (1397, datetime.timedelta(days=8, seconds=3420)),
#  (4291, datetime.timedelta(days=20, seconds=33000)),
#  (1564, datetime.timedelta(days=8, seconds=85080)),
#  (2126, datetime.timedelta(days=12, seconds=86100)),
#  (2160, datetime.timedelta(days=17, seconds=5580)),
#  (4032, datetime.timedelta(days=13, seconds=55500)),
#  (1579, datetime.timedelta(days=9, seconds=3960)),
#  (3987, datetime.timedelta(days=16, seconds=69840)),
#  (768, datetime.timedelta(days=17, seconds=24960)),
#  (2243, datetime.timedelta(days=10, seconds=18180)),
#  (838, datetime.timedelta(days=12, seconds=64740)),
#  (2817, datetime.timedelta(days=31, seconds=78000)),
#  (3905, datetime.timedelta(days=30, seconds=5880)),
#  (3130, datetime.timedelta(days=15, seconds=35100)),
#  (2292, datetime.timedelta(days=26, seconds=960)),
#  (2089, datetime.timedelta(days=14, seconds=72420)),
#  (1928, datetime.timedelta(days=25, seconds=48480)),
#  (3686, datetime.timedelta(days=18, seconds=73800)),
#  (88, datetime.timedelta(days=22, seconds=46740)),
#  (4295, datetime.timedelta(days=10, seconds=36360)),
#  (188, datetime.timedelta(days=5, seconds=67020)),
#  (461, datetime.timedelta(days=27, seconds=300)),
#  (3653, datetime.timedelta(days=8, seconds=62820)),
#  (240, datetime.timedelta(days=17, seconds=29640)),
#  (1878, datetime.timedelta(days=13, seconds=35520)),
#  (3871, datetime.timedelta(days=26, seconds=24060)),
#  (1467, datetime.timedelta(days=15, seconds=80340)),
#  (4232, datetime.timedelta(days=26, seconds=78540)),
#  (2155, datetime.timedelta(days=8, seconds=49380)),
#  (2792, datetime.timedelta(days=23, seconds=20100)),
#  (3549, datetime.timedelta(days=19, seconds=12240)),
#  (3908, datetime.timedelta(days=14, seconds=76140)),
#  (703, datetime.timedelta(days=18, seconds=51360)),
#  (226, datetime.timedelta(days=16, seconds=11940)),
#  (1161, datetime.timedelta(days=10, seconds=1980)),
#  (2413, datetime.timedelta(days=12, seconds=74460)),
#  (2428, datetime.timedelta(days=23, seconds=19560)),
#  (81, datetime.timedelta(days=6, seconds=75120)),
#  (3541, datetime.timedelta(days=19, seconds=50700)),
#  (2455, datetime.timedelta(days=7, seconds=77460)),
#  (4021, datetime.timedelta(days=24, seconds=18540)),
#  (204, datetime.timedelta(days=20, seconds=13320)),
#  (2153, datetime.timedelta(days=27, seconds=47220)),
#  (1021, datetime.timedelta(days=27, seconds=83580)),
#  (4396, datetime.timedelta(days=24, seconds=29100)),
#  (1165, datetime.timedelta(days=8, seconds=66960)),
#  (3406, datetime.timedelta(days=26, seconds=83820)),
#  (3753, datetime.timedelta(days=9, seconds=52860)),
#  (3342, datetime.timedelta(days=21, seconds=59640)),
#  (1429, datetime.timedelta(days=12, seconds=11580)),
#  (807, datetime.timedelta(days=27, seconds=67800)),
#  (2705, datetime.timedelta(days=12, seconds=37080)),
#  (361, datetime.timedelta(days=14, seconds=54480)),
#  (4254, datetime.timedelta(days=29, seconds=25140)),
#  (2971, datetime.timedelta(days=7, seconds=29280)),
#  (2227, datetime.timedelta(days=11, seconds=2820)),
#  (2865, datetime.timedelta(days=20, seconds=9120)),
#  (785, datetime.timedelta(days=20, seconds=56280)),
#  (444, datetime.timedelta(days=19, seconds=58800)),
#  (537, datetime.timedelta(days=15, seconds=63780)),
#  (1914, datetime.timedelta(days=23, seconds=4440)),
#  (1401, datetime.timedelta(days=16, seconds=1080)),
#  (4106, datetime.timedelta(days=21, seconds=50460)),
#  (343, datetime.timedelta(days=16, seconds=60)),
#  (2534, datetime.timedelta(days=15, seconds=13080)),
#  (3246, datetime.timedelta(days=17, seconds=81420)),
#  (4516, datetime.timedelta(days=19, seconds=20280)),
#  (3880, datetime.timedelta(days=11, seconds=31800)),
#  (3876, datetime.timedelta(days=11, seconds=70320)),
#  (4245, datetime.timedelta(days=4, seconds=16500)),
#  (2695, datetime.timedelta(days=22, seconds=29160)),
#  (2078, datetime.timedelta(days=23, seconds=74160)),
#  (722, datetime.timedelta(days=8, seconds=24060)),
#  (2474, datetime.timedelta(days=2, seconds=11640)),
#  (3861, datetime.timedelta(days=17, seconds=52440)),
#  (2288, datetime.timedelta(days=12, seconds=25800)),
#  (199, datetime.timedelta(days=14, seconds=59700)),
#  (369, datetime.timedelta(days=17, seconds=29940)),
#  (4477, datetime.timedelta(days=21, seconds=29520)),
#  (4198, datetime.timedelta(days=13, seconds=4500)),
#  (3783, datetime.timedelta(days=19, seconds=14100)),
#  (2010, datetime.timedelta(days=23, seconds=68340)),
#  (3632, datetime.timedelta(days=38, seconds=62400)),
#  (3350, datetime.timedelta(days=18, seconds=37680)),
#  (1142, datetime.timedelta(days=12, seconds=5460)),
#  (740, datetime.timedelta(days=16, seconds=85800)),
#  (2166, datetime.timedelta(days=13, seconds=8640)),
#  (2986, datetime.timedelta(days=6, seconds=77400)),
#  (230, datetime.timedelta(days=21, seconds=22260)),
#  (3621, datetime.timedelta(days=25, seconds=83520)),
#  (1663, datetime.timedelta(days=8, seconds=17820)),
#  (78, datetime.timedelta(days=25, seconds=2400)),
#  (573, datetime.timedelta(days=15, seconds=41700)),
#  (3865, datetime.timedelta(days=17, seconds=24840)),
#  (1998, datetime.timedelta(days=19, seconds=2940)),
#  (3792, datetime.timedelta(days=18, seconds=82620)),
#  (4029, datetime.timedelta(days=31, seconds=70680)),
#  (1451, datetime.timedelta(days=13, seconds=28020)),
#  (4169, datetime.timedelta(days=23, seconds=2160)),
#  (4483, datetime.timedelta(days=30, seconds=85140)),
#  (2816, datetime.timedelta(days=20, seconds=52860)),
#  (2881, datetime.timedelta(days=9, seconds=83580)),
#  (2007, datetime.timedelta(days=18, seconds=5220)),
#  (852, datetime.timedelta(days=5, seconds=21000)),
#  (2199, datetime.timedelta(days=16, seconds=84300)),
#  (1927, datetime.timedelta(days=12, seconds=61500)),
#  (611, datetime.timedelta(days=24, seconds=73380)),
#  (3772, datetime.timedelta(days=13, seconds=86040)),
#  (2354, datetime.timedelta(days=16, seconds=5640)),
#  (1246, datetime.timedelta(days=18, seconds=70440)),
#  (2175, datetime.timedelta(days=18, seconds=38400)),
#  (1852, datetime.timedelta(days=14, seconds=25200)),
#  (4292, datetime.timedelta(days=16, seconds=33540)),
#  (3879, datetime.timedelta(days=17, seconds=81540)),
#  (713, datetime.timedelta(days=2, seconds=1080)),
#  (1693, datetime.timedelta(days=13, seconds=71400)),
#  (3331, datetime.timedelta(days=17, seconds=79920)),
#  (1205, datetime.timedelta(days=11, seconds=75780)),
#  (448, datetime.timedelta(days=21, seconds=20940)),
#  (701, datetime.timedelta(days=20, seconds=78120)),
#  (4231, datetime.timedelta(days=24, seconds=42720)),
#  (4000, datetime.timedelta(days=26, seconds=27600)),
#  (1092, datetime.timedelta(days=5, seconds=22380)),
#  (3953, datetime.timedelta(days=2, seconds=65820)),
#  (2757, datetime.timedelta(days=14, seconds=68400)),
#  (3820, datetime.timedelta(days=6, seconds=84960)),
#  (3956, datetime.timedelta(days=20, seconds=360)),
#  (3082, datetime.timedelta(days=1, seconds=66780)),
#  (863, datetime.timedelta(days=22, seconds=8460)),
#  (2688, datetime.timedelta(days=23, seconds=6660)),
#  (3654, datetime.timedelta(days=13, seconds=5580)),
#  (1886, datetime.timedelta(days=27, seconds=31440)),
#  (4168, datetime.timedelta(days=33, seconds=75660)),
#  (289, datetime.timedelta(days=9, seconds=66660)),
#  (3000, datetime.timedelta(days=27, seconds=32100)),
#  (2450, datetime.timedelta(days=22, seconds=70920)),
#  (2762, datetime.timedelta(days=12, seconds=84240)),
#  (1400, datetime.timedelta(days=15, seconds=73980)),
#  (527, datetime.timedelta(days=23, seconds=73800)),
#  (1462, datetime.timedelta(days=19, seconds=62280)),
#  (3852, datetime.timedelta(days=7, seconds=80940)),
#  (3543, datetime.timedelta(days=27, seconds=68460)),
#  (627, datetime.timedelta(days=14, seconds=5400)),
#  (376, datetime.timedelta(days=17, seconds=8460)),
#  (4024, datetime.timedelta(days=15, seconds=35760)),
#  (147, datetime.timedelta(days=23, seconds=17340)),
#  (2963, datetime.timedelta(days=17, seconds=35700)),
#  (2067, datetime.timedelta(days=13, seconds=22680)),
#  (2711, datetime.timedelta(days=21, seconds=51120)),
#  (4370, datetime.timedelta(days=5, seconds=46380)),
#  (1941, datetime.timedelta(days=24, seconds=25800)),
#  (3019, datetime.timedelta(days=9, seconds=19200)),
#  (1470, datetime.timedelta(days=10, seconds=59760)),
#  (989, datetime.timedelta(days=25, seconds=46440)),
#  (3788, datetime.timedelta(days=12, seconds=79620)),
#  (2278, datetime.timedelta(days=19, seconds=26940)),
#  (3676, datetime.timedelta(days=7, seconds=27360)),
#  (535, datetime.timedelta(days=23, seconds=23760)),
#  (4335, datetime.timedelta(days=15, seconds=17160)),
#  (3720, datetime.timedelta(days=16, seconds=76860)),
#  (1159, datetime.timedelta(days=9, seconds=5700)),
#  (4301, datetime.timedelta(days=3, seconds=20700)),
#  (2117, datetime.timedelta(days=13, seconds=77580)),
#  (642, datetime.timedelta(days=11, seconds=11700)),
#  (3056, datetime.timedelta(days=15, seconds=64320)),
#  (3672, datetime.timedelta(days=22, seconds=83820)),
#  (3409, datetime.timedelta(days=11, seconds=38640)),
#  (2698, datetime.timedelta(days=19, seconds=21600)),
#  (725, datetime.timedelta(days=22, seconds=16080)),
#  (3117, datetime.timedelta(days=9, seconds=18660)),
#  (4107, datetime.timedelta(days=23, seconds=72060)),
#  (832, datetime.timedelta(days=9, seconds=61500)),
#  (1784, datetime.timedelta(days=6, seconds=2280)),
#  (1001, datetime.timedelta(days=9, seconds=33960)),
#  (3751, datetime.timedelta(days=7, seconds=74460)),
#  (3847, datetime.timedelta(days=15, seconds=68580)),
#  (1469, datetime.timedelta(days=24, seconds=22380)),
#  (2656, datetime.timedelta(days=30, seconds=80400)),
#  (4350, datetime.timedelta(days=13, seconds=50760)),
#  (2024, datetime.timedelta(days=12, seconds=82500)),
#  (2242, datetime.timedelta(days=19, seconds=18720)),
#  (3645, datetime.timedelta(days=14, seconds=76080)),
#  (3441, datetime.timedelta(days=14, seconds=65580)),
#  (1305, datetime.timedelta(days=20, seconds=54240)),
#  (2679, datetime.timedelta(days=20, seconds=48600)),
#  (4420, datetime.timedelta(days=32, seconds=61860)),
#  (2699, datetime.timedelta(days=19, seconds=8400)),
#  (3192, datetime.timedelta(days=2, seconds=83460)),
#  (1297, datetime.timedelta(days=10, seconds=7620)),
#  (3710, datetime.timedelta(days=9, seconds=13980)),
#  (1869, datetime.timedelta(days=13, seconds=52560)),
#  (4363, datetime.timedelta(days=18, seconds=75000)),
#  (4222, datetime.timedelta(days=7, seconds=54240)),
#  (2050, datetime.timedelta(days=10, seconds=69720)),
#  (3812, datetime.timedelta(days=22, seconds=84960)),
#  (1293, datetime.timedelta(days=19, seconds=72900)),
#  (2312, datetime.timedelta(days=25, seconds=62100)),
#  (3766, datetime.timedelta(days=10, seconds=74700)),
#  (2133, datetime.timedelta(days=2, seconds=73980)),
#  (3079, datetime.timedelta(days=15, seconds=53820)),
#  (3269, datetime.timedelta(days=17, seconds=13380)),
#  (158, datetime.timedelta(days=29, seconds=79080)),
#  (4115, datetime.timedelta(days=14, seconds=20640)),
#  (2943, datetime.timedelta(days=15, seconds=85320)),
#  (3796, datetime.timedelta(days=19, seconds=4380)),
#  (1588, datetime.timedelta(days=27, seconds=75480)),
#  (1783, datetime.timedelta(days=29, seconds=33960)),
#  (2939, datetime.timedelta(days=10, seconds=12540)),
#  (2305, datetime.timedelta(days=12, seconds=25980)),
#  (1180, datetime.timedelta(days=7, seconds=17280)),
#  (385, datetime.timedelta(days=18, seconds=78300)),
#  (3744, datetime.timedelta(days=24, seconds=57960)),
#  (4444, datetime.timedelta(days=28, seconds=62700)),
#  (2375, datetime.timedelta(days=21, seconds=15300)),
#  (3596, datetime.timedelta(days=19, seconds=38040)),
#  (544, datetime.timedelta(days=10, seconds=3420)),
#  (4262, datetime.timedelta(days=12, seconds=58380)),
#  (1631, datetime.timedelta(days=19, seconds=77820)),
#  (2120, datetime.timedelta(days=22, seconds=28320)),
#  (2163, datetime.timedelta(days=12, seconds=81840)),
#  (606, datetime.timedelta(days=8, seconds=77460)),
#  (4375, datetime.timedelta(days=15, seconds=180)),
#  (1667, datetime.timedelta(days=9, seconds=71040)),
#  (3669, datetime.timedelta(days=23, seconds=25140)),
#  (308, datetime.timedelta(days=17, seconds=67980)),
#  (3781, datetime.timedelta(days=5, seconds=83940)),
#  (2852, datetime.timedelta(days=23, seconds=75360)),
#  (614, datetime.timedelta(days=30, seconds=29820)),
#  (4421, datetime.timedelta(days=10, seconds=67080)),
#  (2712, datetime.timedelta(days=2, seconds=67740)),
#  (966, datetime.timedelta(days=9, seconds=76260)),
#  (1607, datetime.timedelta(days=18, seconds=33360)),
#  (4514, datetime.timedelta(days=16, seconds=42900)),
#  (1055, datetime.timedelta(days=18, seconds=3300)),
#  (3929, datetime.timedelta(days=18, seconds=78600)),
#  (3823, datetime.timedelta(days=20, seconds=65100)),
#  (2148, datetime.timedelta(days=10, seconds=16200)),
#  (4272, datetime.timedelta(days=19, seconds=15000)),
#  (2110, datetime.timedelta(days=16, seconds=69480)),
#  (1752, datetime.timedelta(days=4, seconds=9660)),
#  (846, datetime.timedelta(days=15, seconds=57180)),
#  (2982, datetime.timedelta(days=15, seconds=74880)),
#  (1642, datetime.timedelta(days=29, seconds=83460)),
#  (1580, datetime.timedelta(days=6, seconds=64980)),
#  (3925, datetime.timedelta(days=11, seconds=20760)),
#  (3344, datetime.timedelta(days=25, seconds=5640)),
#  (2907, datetime.timedelta(days=12, seconds=47100)),
#  (3455, datetime.timedelta(days=11, seconds=65580)),
#  (1554, datetime.timedelta(days=27, seconds=74880)),
#  (2431, datetime.timedelta(days=9, seconds=71040)),
#  (4299, datetime.timedelta(days=13, seconds=82440)),
#  (2606, datetime.timedelta(days=15, seconds=57600)),
#  (3239, datetime.timedelta(days=15, seconds=8100)),
#  (3010, datetime.timedelta(days=6, seconds=5640)),
#  (1799, datetime.timedelta(days=26, seconds=4800)),
#  (1509, datetime.timedelta(days=17, seconds=1860)),
#  (2075, datetime.timedelta(days=17, seconds=51840)),
#  (4044, datetime.timedelta(days=27, seconds=3720)),
#  (2124, datetime.timedelta(days=17, seconds=65340)),
#  (849, datetime.timedelta(days=13, seconds=51780)),
#  (2055, datetime.timedelta(days=18, seconds=81720)),
#  (1905, datetime.timedelta(days=23, seconds=74820)),
#  (1698, datetime.timedelta(days=9, seconds=74880)),
#  (919, datetime.timedelta(days=11, seconds=48720)),
#  (4255, datetime.timedelta(days=10, seconds=79320)),
#  (4347, datetime.timedelta(days=16, seconds=86220)),
#  (4424, datetime.timedelta(days=20, seconds=45240)),
#  (1894, datetime.timedelta(days=8, seconds=80520)),
#  (2841, datetime.timedelta(days=27, seconds=65040)),
#  (1673, datetime.timedelta(days=12, seconds=11400)),
#  (961, datetime.timedelta(days=14, seconds=4080)),
#  (3170, datetime.timedelta(days=18, seconds=54120)),
#  (4020, datetime.timedelta(days=21, seconds=70980)),
#  (2215, datetime.timedelta(days=16, seconds=67620)),
#  (2403, datetime.timedelta(days=18, seconds=1320)),
#  (269, datetime.timedelta(days=14, seconds=34560)),
#  (2311, datetime.timedelta(days=8, seconds=52440)),
#  (1728, datetime.timedelta(days=19, seconds=30300)),
#  (3743, datetime.timedelta(days=7, seconds=59940)),
#  (3585, datetime.timedelta(days=4, seconds=69000)),
#  (3507, datetime.timedelta(days=4, seconds=81420)),
#  (3818, datetime.timedelta(days=5, seconds=55380)),
#  (4546, datetime.timedelta(days=17, seconds=18720)),
#  (3787, datetime.timedelta(days=9, seconds=76620)),
#  (2592, datetime.timedelta(days=11, seconds=9420)),
#  (3191, datetime.timedelta(days=12, seconds=67860)),
#  (1444, datetime.timedelta(days=22, seconds=31020)),
#  (1090, datetime.timedelta(days=27, seconds=11460)),
#  (349, datetime.timedelta(days=8, seconds=72840)),
#  (2953, datetime.timedelta(days=3, seconds=54540)),
#  (2756, datetime.timedelta(days=26, seconds=59760)),
#  (766, datetime.timedelta(days=23, seconds=28440)),
#  (1978, datetime.timedelta(days=9, seconds=82080)),
#  (1789, datetime.timedelta(days=26, seconds=8280)),
#  (2065, datetime.timedelta(days=21, seconds=36240)),
#  (3426, datetime.timedelta(days=20, seconds=73500)),
#  (4480, datetime.timedelta(days=8, seconds=79920)),
#  (4051, datetime.timedelta(days=6, seconds=7140)),
#  (1024, datetime.timedelta(days=11, seconds=71100)),
#  (3849, datetime.timedelta(days=10, seconds=21180)),
#  (4464, datetime.timedelta(days=12, seconds=75900)),
#  (2690, datetime.timedelta(days=18, seconds=67140)),
#  (1954, datetime.timedelta(days=26, seconds=38340)),
#  (2826, datetime.timedelta(days=26, seconds=20820)),
#  (3453, datetime.timedelta(days=34, seconds=6780)),
#  (3941, datetime.timedelta(days=6, seconds=17880)),
#  (1028, datetime.timedelta(days=19, seconds=40020)),
#  (29, datetime.timedelta(days=19, seconds=52500)),
#  (3457, datetime.timedelta(days=9, seconds=71760)),
#  (4, datetime.timedelta(days=3, seconds=6720)),
#  (3318, datetime.timedelta(days=26, seconds=17880)),
#  (96, datetime.timedelta(days=18, seconds=12420)),
#  (844, datetime.timedelta(days=22, seconds=72900)),
#  (1039, datetime.timedelta(days=15, seconds=55500)),
#  (3473, datetime.timedelta(days=25, seconds=76080)),
#  (6, datetime.timedelta(days=17, seconds=12720)),
#  (1551, datetime.timedelta(days=20, seconds=65880)),
#  (1148, datetime.timedelta(days=4, seconds=61440)),
#  (2628, datetime.timedelta(days=29, seconds=53040)),
#  (2200, datetime.timedelta(days=7, seconds=13860)),
#  (3642, datetime.timedelta(days=25, seconds=76380)),
#  (4123, datetime.timedelta(days=9, seconds=75960)),
#  (3509, datetime.timedelta(days=18, seconds=69540)),
#  (4161, datetime.timedelta(days=9, seconds=9120)),
#  (1979, datetime.timedelta(days=16, seconds=62040)),
#  (1432, datetime.timedelta(days=19, seconds=85200)),
#  (1650, datetime.timedelta(days=5, seconds=77700)),
#  (66, datetime.timedelta(days=27, seconds=77520)),
#  (3940, datetime.timedelta(days=10, seconds=8340)),
#  (3501, datetime.timedelta(days=25, seconds=37740)),
#  (1919, datetime.timedelta(days=25, seconds=33300)),
#  (4079, datetime.timedelta(days=19, seconds=56520)),
#  (458, datetime.timedelta(days=27, seconds=83460)),
#  (368, datetime.timedelta(days=21, seconds=18780)),
#  (1970, datetime.timedelta(days=21, seconds=46620)),
#  (3364, datetime.timedelta(days=23, seconds=67740)),
#  (4333, datetime.timedelta(days=21, seconds=120)),
#  (1850, datetime.timedelta(days=31, seconds=67440)),
#  (538, datetime.timedelta(days=20, seconds=77880)),
#  (4369, datetime.timedelta(days=27, seconds=50760)),
#  (2470, datetime.timedelta(days=18, seconds=85140)),
#  (3050, datetime.timedelta(days=27, seconds=71340)),
#  (2023, datetime.timedelta(days=14)),
#  (2167, datetime.timedelta(days=9, seconds=81000)),
#  (2998, datetime.timedelta(days=14, seconds=7320)),
#  (2815, datetime.timedelta(days=20, seconds=50700)),
#  (872, datetime.timedelta(days=35, seconds=2100)),
#  (1140, datetime.timedelta(days=2, seconds=85560)),
#  (3058, datetime.timedelta(days=22, seconds=46920)),
#  (4531, datetime.timedelta(days=20, seconds=85080)),
#  (1054, datetime.timedelta(days=24, seconds=50640)),
#  (1965, datetime.timedelta(days=7, seconds=71040)),
#  (3461, datetime.timedelta(days=24, seconds=49740)),
#  (1005, datetime.timedelta(days=16, seconds=59280)),
#  (1449, datetime.timedelta(days=24, seconds=66660)),
#  (3009, datetime.timedelta(days=29, seconds=14460)),
#  (217, datetime.timedelta(days=16, seconds=32100)),
#  (4500, datetime.timedelta(days=18, seconds=67800)),
#  (3678, datetime.timedelta(days=17, seconds=63660)),
#  (4156, datetime.timedelta(days=15, seconds=57180)),
#  (3490, datetime.timedelta(days=12, seconds=84660)),
#  (3248, datetime.timedelta(days=13, seconds=2700)),
#  (2877, datetime.timedelta(days=23, seconds=86220)),
#  (1601, datetime.timedelta(days=9, seconds=21480)),
#  (3870, datetime.timedelta(days=12, seconds=19380)),
#  (1737, datetime.timedelta(days=14, seconds=30060)),
#  (2092, datetime.timedelta(days=10, seconds=13980)),
#  (2658, datetime.timedelta(days=9, seconds=64680)),
#  (2173, datetime.timedelta(days=9, seconds=62160)),
#  (3948, datetime.timedelta(days=20, seconds=7680)),
#  (1721, datetime.timedelta(days=29, seconds=39540)),
#  (2845, datetime.timedelta(days=17, seconds=73380)),
#  (931, datetime.timedelta(days=16, seconds=24000)),
#  (3125, datetime.timedelta(days=19, seconds=18420)),
#  (1706, datetime.timedelta(days=11, seconds=83520)),
#  (2444, datetime.timedelta(days=31, seconds=53580)),
#  (4068, datetime.timedelta(days=26, seconds=51840)),
#  (718, datetime.timedelta(days=15, seconds=79440)),
#  (3595, datetime.timedelta(days=31, seconds=18060)),
#  (1712, datetime.timedelta(days=5, seconds=79740)),
#  (1654, datetime.timedelta(days=23, seconds=84600)),
#  (1364, datetime.timedelta(days=33, seconds=63900)),
#  (3590, datetime.timedelta(days=15, seconds=63960)),
#  (1889, datetime.timedelta(days=12, seconds=27540)),
#  (1991, datetime.timedelta(days=15, seconds=59400)),
#  (229, datetime.timedelta(days=24, seconds=43920)),
#  (3668, datetime.timedelta(days=12, seconds=82140)),
#  (3906, datetime.timedelta(days=12, seconds=84420)),
#  (4137, datetime.timedelta(days=16, seconds=74100)),
#  (788, datetime.timedelta(days=8, seconds=84180)),
#  (2234, datetime.timedelta(days=10, seconds=20940)),
#  (3481, datetime.timedelta(days=30, seconds=25860)),
#  (2190, datetime.timedelta(days=11, seconds=18300)),
#  (4016, datetime.timedelta(days=15, seconds=67560)),
#  (2344, datetime.timedelta(days=15, seconds=75960)),
#  (900, datetime.timedelta(days=9, seconds=2220)),
#  (4508, datetime.timedelta(days=21, seconds=12780)),
#  (4229, datetime.timedelta(days=22, seconds=74280)),
#  (4010, datetime.timedelta(days=21, seconds=60780)),
#  (996, datetime.timedelta(days=19, seconds=34440)),
#  (762, datetime.timedelta(days=23, seconds=85680)),
#  (1197, datetime.timedelta(days=20, seconds=48060)),
#  (1063, datetime.timedelta(days=12, seconds=81120)),
#  (69, datetime.timedelta(days=5, seconds=20580)),
#  (4052, datetime.timedelta(days=18, seconds=27540)),
#  (2369, datetime.timedelta(days=9, seconds=85920)),
#  (3644, datetime.timedelta(days=24, seconds=83640)),
#  (2617, datetime.timedelta(days=23, seconds=6420)),
#  (1912, datetime.timedelta(days=9, seconds=73620)),
#  (4385, datetime.timedelta(days=10, seconds=31560)),
#  (2546, datetime.timedelta(days=16, seconds=63480)),
#  (2264, datetime.timedelta(days=24, seconds=86340)),
#  (782, datetime.timedelta(days=22, seconds=3360)),
#  (3587, datetime.timedelta(days=8, seconds=10380)),
#  (1514, datetime.timedelta(days=38, seconds=31680)),
#  (4268, datetime.timedelta(days=8, seconds=83040)),
#  (1338, datetime.timedelta(days=14, seconds=22560)),
#  (4193, datetime.timedelta(days=17, seconds=45120)),
#  (3100, datetime.timedelta(days=16, seconds=1500)),
#  (1359, datetime.timedelta(days=22, seconds=34080)),
#  (4060, datetime.timedelta(days=9, seconds=68700)),
#  (1079, datetime.timedelta(days=11, seconds=20460)),
#  (1445, datetime.timedelta(days=6, seconds=77460)),
#  (3701, datetime.timedelta(days=16, seconds=83400)),
#  (1141, datetime.timedelta(days=15, seconds=85200)),
#  (1329, datetime.timedelta(days=11, seconds=4260)),
#  (659, datetime.timedelta(days=18, seconds=54540)),
#  (279, datetime.timedelta(days=14, seconds=71880)),
#  (2238, datetime.timedelta(days=15, seconds=43320)),
#  (2233, datetime.timedelta(days=34, seconds=71040)),
#  (3584, datetime.timedelta(days=2, seconds=64920)),
#  (3588, datetime.timedelta(days=18, seconds=20100)),
#  (9, datetime.timedelta(days=3, seconds=4320)),
#  (1480, datetime.timedelta(days=17, seconds=71340)),
#  (1481, datetime.timedelta(days=19, seconds=73320)),
#  (3291, datetime.timedelta(days=11, seconds=63420)),
#  (565, datetime.timedelta(days=29, seconds=57480)),
#  (4087, datetime.timedelta(days=25, seconds=72660)),
#  (566, datetime.timedelta(days=3, seconds=15060)),
#  (592, datetime.timedelta(days=20, seconds=960)),
#  (4113, datetime.timedelta(days=12, seconds=59640)),
#  (4334, datetime.timedelta(days=6, seconds=66420)),
#  (553, datetime.timedelta(days=27, seconds=13320)),
#  (4438, datetime.timedelta(days=26, seconds=4920)),
#  (1640, datetime.timedelta(days=18, seconds=16500)),
#  (1520, datetime.timedelta(days=30, seconds=53640)),
#  (4285, datetime.timedelta(days=30, seconds=9360)),
#  (1968, datetime.timedelta(days=4, seconds=76080)),
#  (927, datetime.timedelta(days=16, seconds=75720)),
#  (3315, datetime.timedelta(days=15, seconds=25380)),
#  (2519, datetime.timedelta(days=12, seconds=57780)),
#  (398, datetime.timedelta(days=19, seconds=9600)),
#  (2510, datetime.timedelta(days=22, seconds=50940)),
#  (1233, datetime.timedelta(days=15, seconds=24780)),
#  (1732, datetime.timedelta(days=6, seconds=62520)),
#  (2641, datetime.timedelta(days=12, seconds=73620)),
#  (165, datetime.timedelta(days=23, seconds=57180)),
#  (2266, datetime.timedelta(days=1, seconds=73680)),
#  (2162, datetime.timedelta(days=14, seconds=300)),
#  (56, datetime.timedelta(days=17, seconds=75120)),
#  (4237, datetime.timedelta(days=20, seconds=79020)),
#  (3226, datetime.timedelta(days=16, seconds=63180)),
#  (4281, datetime.timedelta(days=23, seconds=74280)),
#  (3059, datetime.timedelta(days=9, seconds=49740)),
#  (820, datetime.timedelta(days=17, seconds=10680)),
#  (2231, datetime.timedelta(days=3, seconds=70320)),
#  (4118, datetime.timedelta(days=8, seconds=7920)),
#  (2427, datetime.timedelta(days=13, seconds=78780)),
#  (3522, datetime.timedelta(days=14, seconds=25800)),
#  (245, datetime.timedelta(days=28, seconds=16980)),
#  (2615, datetime.timedelta(days=11, seconds=18480)),
#  (3431, datetime.timedelta(days=22, seconds=36960)),
#  (2901, datetime.timedelta(days=10, seconds=67800)),
#  (1326, datetime.timedelta(days=20, seconds=63120)),
#  (3016, datetime.timedelta(days=21, seconds=69360)),
#  (2670, datetime.timedelta(days=7, seconds=78120)),
#  (1807, datetime.timedelta(days=12, seconds=81540)),
#  (1127, datetime.timedelta(days=19, seconds=58920)),
#  (1060, datetime.timedelta(days=14, seconds=65100)),
#  (2348, datetime.timedelta(days=14, seconds=84060)),
#  (1017, datetime.timedelta(days=22, seconds=64140)),
#  (484, datetime.timedelta(days=11, seconds=22680)),
#  (3558, datetime.timedelta(days=24, seconds=29760)),
#  (144, datetime.timedelta(days=15, seconds=82380)),
#  (1885, datetime.timedelta(days=27, seconds=27000)),
#  (1754, datetime.timedelta(days=9, seconds=24780)),
#  (1224, datetime.timedelta(days=27)),
#  (168, datetime.timedelta(days=18, seconds=82860)),
#  (4280, datetime.timedelta(days=14, seconds=51480)),
#  (3975, datetime.timedelta(days=31, seconds=74100)),
#  (3222, datetime.timedelta(days=9, seconds=9300)),
#  (2169, datetime.timedelta(days=19, seconds=6480)),
#  (1930, datetime.timedelta(days=27, seconds=5640)),
#  (2417, datetime.timedelta(days=32, seconds=780)),
#  (2868, datetime.timedelta(days=27, seconds=6300)),
#  (3747, datetime.timedelta(days=5, seconds=78180)),
#  (2625, datetime.timedelta(days=15, seconds=80340)),
#  (2499, datetime.timedelta(days=20, seconds=55860)),
#  (2497, datetime.timedelta(days=18, seconds=6840)),
#  (3084, datetime.timedelta(days=22, seconds=60180)),
#  (4534, datetime.timedelta(days=25, seconds=80040)),
#  (2886, datetime.timedelta(days=14, seconds=64620)),
#  (1859, datetime.timedelta(days=23, seconds=44400)),
#  (3444, datetime.timedelta(days=10, seconds=69480)),
#  (2729, datetime.timedelta(days=17, seconds=16800)),
#  (2058, datetime.timedelta(days=25, seconds=83820)),
#  (4121, datetime.timedelta(days=17, seconds=55680)),
#  (3414, datetime.timedelta(days=4, seconds=75780)),
#  (3763, datetime.timedelta(days=8, seconds=82980)),
#  (2718, datetime.timedelta(days=28, seconds=70500)),
#  (1035, datetime.timedelta(days=11, seconds=62580)),
#  (2217, datetime.timedelta(days=10, seconds=24300)),
#  (41, datetime.timedelta(days=18, seconds=3240)),
#  (3361, datetime.timedelta(days=20, seconds=77220)),
#  (4220, datetime.timedelta(days=20, seconds=38040)),
#  (32, datetime.timedelta(days=14, seconds=21960)),
#  (3184, datetime.timedelta(days=24, seconds=13620)),
#  (4293, datetime.timedelta(days=6, seconds=85680)),
#  (247, datetime.timedelta(days=21, seconds=30120)),
#  (3027, datetime.timedelta(days=13, seconds=70320)),
#  (423, datetime.timedelta(days=11, seconds=67080)),
#  (3329, datetime.timedelta(days=29, seconds=3780)),
#  (1881, datetime.timedelta(days=15, seconds=39180)),
#  (1621, datetime.timedelta(days=29, seconds=64560)),
#  (4560, datetime.timedelta(days=27, seconds=25980)),
#  (1182, datetime.timedelta(days=11, seconds=2220)),
#  (411, datetime.timedelta(days=13, seconds=76740)),
#  (2186, datetime.timedelta(days=12, seconds=65820)),
#  (672, datetime.timedelta(days=25, seconds=9180)),
#  (3267, datetime.timedelta(days=16, seconds=71700)),
#  (2083, datetime.timedelta(days=6, seconds=65040)),
#  (3387, datetime.timedelta(days=10, seconds=84720)),
#  (1454, datetime.timedelta(days=18, seconds=38220)),
#  (316, datetime.timedelta(days=20, seconds=55680)),
#  (3065, datetime.timedelta(days=13, seconds=10560)),
#  (4030, datetime.timedelta(days=34, seconds=14940)),
#  (1282, datetime.timedelta(days=13, seconds=85320)),
#  (256, datetime.timedelta(days=15, seconds=65520)),
#  (628, datetime.timedelta(days=4, seconds=72960)),
#  (3337, datetime.timedelta(days=9, seconds=75240)),
#  (3145, datetime.timedelta(days=13, seconds=65640)),
#  (1860, datetime.timedelta(days=6, seconds=75600)),
#  (422, datetime.timedelta(days=6, seconds=28800)),
#  (4415, datetime.timedelta(days=20, seconds=20700)),
#  (3268, datetime.timedelta(days=5, seconds=63120)),
#  (185, datetime.timedelta(days=19, seconds=17220)),
#  (215, datetime.timedelta(days=24, seconds=5220)),
#  (3993, datetime.timedelta(days=11, seconds=83100)),
#  (3148, datetime.timedelta(days=18, seconds=75120)),
#  (3502, datetime.timedelta(days=14, seconds=37020)),
#  (3581, datetime.timedelta(days=15, seconds=17460)),
#  (1526, datetime.timedelta(days=18, seconds=73440)),
#  (3850, datetime.timedelta(days=10, seconds=72060)),
#  (2759, datetime.timedelta(days=9, seconds=18300)),
#  (3106, datetime.timedelta(days=27, seconds=69240)),
#  (2253, datetime.timedelta(days=17, seconds=13920)),
#  (1541, datetime.timedelta(days=2, seconds=73320)),
#  (1531, datetime.timedelta(days=26, seconds=4020)),
#  (3797, datetime.timedelta(days=17, seconds=61500)),
#  (4014, datetime.timedelta(days=25, seconds=15540)),
#  (2607, datetime.timedelta(days=16, seconds=60420)),
#  (1671, datetime.timedelta(days=11, seconds=3360)),
#  (314, datetime.timedelta(days=33, seconds=2760)),
#  (1274, datetime.timedelta(days=12, seconds=52980)),
#  (426, datetime.timedelta(days=12, seconds=8400)),
#  (2808, datetime.timedelta(days=11, seconds=80700)),
#  (1805, datetime.timedelta(days=15, seconds=80340)),
#  (877, datetime.timedelta(days=15, seconds=22320)),
#  (3477, datetime.timedelta(days=20, seconds=59700)),
#  (4441, datetime.timedelta(days=32, seconds=37380)),
#  (2822, datetime.timedelta(days=9, seconds=600)),
#  (1113, datetime.timedelta(days=22, seconds=72720)),
#  (1317, datetime.timedelta(days=13, seconds=5580)),
#  (4257, datetime.timedelta(days=22, seconds=56820)),
#  (3135, datetime.timedelta(days=4, seconds=21960)),
#  (1702, datetime.timedelta(days=20, seconds=60960)),
#  (971, datetime.timedelta(days=32, seconds=4260)),
#  (1825, datetime.timedelta(days=14, seconds=68220)),
#  (2342, datetime.timedelta(days=26, seconds=11280)),
#  (1759, datetime.timedelta(days=12, seconds=33420)),
#  (1707, datetime.timedelta(days=19, seconds=73080)),
#  (941, datetime.timedelta(days=21, seconds=15600)),
#  (2761, datetime.timedelta(days=13, seconds=72240)),
#  (949, datetime.timedelta(days=30, seconds=28140)),
#  (2707, datetime.timedelta(days=23, seconds=85740)),
#  (2433, datetime.timedelta(days=9, seconds=64620)),
#  (135, datetime.timedelta(days=21, seconds=82440)),
#  (1064, datetime.timedelta(days=14, seconds=27840)),
#  (4267, datetime.timedelta(days=10, seconds=70980)),
#  (879, datetime.timedelta(days=11, seconds=41280)),
#  (1193, datetime.timedelta(days=12, seconds=77040)),
#  (3085, datetime.timedelta(days=17, seconds=66360)),
#  (2795, datetime.timedelta(days=21, seconds=33540)),
#  (1169, datetime.timedelta(days=7, seconds=70200)),
#  (3440, datetime.timedelta(days=8, seconds=28680)),
#  (1994, datetime.timedelta(days=18, seconds=8160)),
#  (1171, datetime.timedelta(days=5, seconds=52020)),
#  (3203, datetime.timedelta(days=26, seconds=83040)),
#  (1138, datetime.timedelta(days=17, seconds=68880)),
#  (239, datetime.timedelta(days=26, seconds=6900)),
#  (1353, datetime.timedelta(days=11, seconds=70080)),
#  (2418, datetime.timedelta(days=19, seconds=79200)),
#  (1688, datetime.timedelta(days=33, seconds=59100)),
#  (2495, datetime.timedelta(days=17, seconds=41340)),
#  (2937, datetime.timedelta(days=14, seconds=86040)),
#  (2946, datetime.timedelta(days=6, seconds=70260)),
#  (755, datetime.timedelta(days=27, seconds=22680)),
#  (1031, datetime.timedelta(days=17, seconds=17340)),
#  (1184, datetime.timedelta(days=17, seconds=57960)),
#  (1670, datetime.timedelta(days=29, seconds=72720)),
#  (4236, datetime.timedelta(days=23, seconds=27540)),
#  (15, datetime.timedelta(days=13, seconds=62760)),
#  (3013, datetime.timedelta(days=12, seconds=69480)),
#  (3914, datetime.timedelta(days=12, seconds=9600)),
#  (1865, datetime.timedelta(days=3, seconds=6780)),
#  (859, datetime.timedelta(days=13, seconds=26040)),
#  (1129, datetime.timedelta(days=19, seconds=8820)),
#  (842, datetime.timedelta(days=26, seconds=30720)),
#  (767, datetime.timedelta(days=1, seconds=67920)),
#  (2062, datetime.timedelta(days=18, seconds=8400)),
#  (1367, datetime.timedelta(days=8, seconds=55020)),
#  (244, datetime.timedelta(days=22, seconds=36060)),
#  (1192, datetime.timedelta(days=14, seconds=8760)),
#  (2206, datetime.timedelta(days=5, seconds=7440)),
#  (1124, datetime.timedelta(days=9, seconds=84420)),
#  (1717, datetime.timedelta(days=12, seconds=61380)),
#  (1243, datetime.timedelta(days=10, seconds=84780)),
#  (1738, datetime.timedelta(days=20, seconds=53160)),
#  (1725, datetime.timedelta(days=14, seconds=85680)),
#  (2584, datetime.timedelta(days=26, seconds=13740)),
#  (251, datetime.timedelta(days=22, seconds=26580)),
#  (2379, datetime.timedelta(days=10, seconds=13860)),
#  (960, datetime.timedelta(days=14, seconds=15840)),
#  (1516, datetime.timedelta(days=21, seconds=11340)),
#  (4495, datetime.timedelta(days=13, seconds=85800)),
#  (2464, datetime.timedelta(days=19, seconds=2220)),
#  (3802, datetime.timedelta(days=10, seconds=66540)),
#  (786, datetime.timedelta(days=32, seconds=39540)),
#  (2008, datetime.timedelta(days=33, seconds=9540)),
#  (3242, datetime.timedelta(days=29, seconds=6540)),
#  (3695, datetime.timedelta(days=9, seconds=79560)),
#  (2210, datetime.timedelta(days=13, seconds=25800)),
#  (3831, datetime.timedelta(days=2, seconds=52320)),
#  (804, datetime.timedelta(days=22, seconds=35940)),
#  (2947, datetime.timedelta(days=9, seconds=56040)),
#  (1934, datetime.timedelta(days=21, seconds=7860)),
#  (3548, datetime.timedelta(days=24, seconds=69360)),
#  (866, datetime.timedelta(days=6, seconds=78780)),
#  (2047, datetime.timedelta(days=23, seconds=49740)),
#  (4240, datetime.timedelta(days=11, seconds=65100)),
#  (1542, datetime.timedelta(days=13, seconds=70440)),
#  (991, datetime.timedelta(days=19, seconds=16020)),
#  (2844, datetime.timedelta(days=10, seconds=60780)),
#  (776, datetime.timedelta(days=18, seconds=6660)),
#  (2887, datetime.timedelta(days=28, seconds=18840)),
#  (3332, datetime.timedelta(days=30, seconds=180)),
#  (1636, datetime.timedelta(days=7, seconds=16860)),
#  (3348, datetime.timedelta(days=11, seconds=77940)),
#  (1121, datetime.timedelta(days=16, seconds=57900)),
#  (2493, datetime.timedelta(days=12, seconds=11580)),
#  (1882, datetime.timedelta(days=6, seconds=82440)),
#  (3895, datetime.timedelta(days=9, seconds=70800)),
#  (2262, datetime.timedelta(days=30, seconds=80400)),
#  (724, datetime.timedelta(days=15, seconds=21360)),
#  (3219, datetime.timedelta(days=20, seconds=80160)),
#  (1323, datetime.timedelta(days=16, seconds=9360)),
#  (1785, datetime.timedelta(days=30, seconds=16380)),
#  (2405, datetime.timedelta(days=9, seconds=56340)),
#  (372, datetime.timedelta(days=29, seconds=53100)),
#  (1714, datetime.timedelta(days=21, seconds=5100)),
#  (339, datetime.timedelta(days=27, seconds=54660)),
#  (2041, datetime.timedelta(days=22, seconds=84300)),
#  (2647, datetime.timedelta(days=15, seconds=59280)),
#  (2287, datetime.timedelta(days=17, seconds=68940)),
#  (3279, datetime.timedelta(days=27, seconds=7260)),
#  (1931, datetime.timedelta(days=5, seconds=23760)),
#  (2521, datetime.timedelta(days=6, seconds=74040)),
#  (591, datetime.timedelta(days=18, seconds=9720)),
#  (808, datetime.timedelta(days=12, seconds=8040)),
#  (3470, datetime.timedelta(days=24, seconds=82800)),
#  (4203, datetime.timedelta(days=24, seconds=10980)),
#  (3156, datetime.timedelta(days=14, seconds=59220)),
#  (3704, datetime.timedelta(days=34, seconds=78420)),
#  (4562, datetime.timedelta(days=12, seconds=59640)),
#  (1399, datetime.timedelta(days=26, seconds=31200)),
#  (4092, datetime.timedelta(days=19, seconds=70860)),
#  (2732, datetime.timedelta(days=31, seconds=59340)),
#  (857, datetime.timedelta(days=4, seconds=73500)),
#  (986, datetime.timedelta(days=12, seconds=81120)),
#  (20, datetime.timedelta(days=16, seconds=33480)),
#  (4489, datetime.timedelta(days=4, seconds=80040)),
#  (1341, datetime.timedelta(days=13, seconds=10020)),
#  (1074, datetime.timedelta(days=10, seconds=24540)),
#  (1999, datetime.timedelta(days=18, seconds=41520)),
#  ...]

# %% [markdown]
# [Helpful Hints Video](https://youtu.be/Scyn7exzUcY)

# %% [markdown]
# ### 4
# ### Which three categories of film have the highest average number of actors per film?

# %%
# %%sql
# EXPLAIN
# SELECT c.name, avg(x.count_actors) as avg_num_actors
# from category c
# NATURAL JOIN (
#     SELECT film_id, count(actor_id) as count_actors
#     from film_actor
#     JOIN film USING (film_id)
#     JOIN film_category USING (film_id)
#     JOIN category USING (category_id)
#     GROUP BY film_id
#     )  AS x
# GROUP BY c.name
# ORDER BY avg_num_actors DESC
# LIMIT 3;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 23 rows affected.
# [('Limit  (cost=600.95..600.96 rows=3 width=100)',),
#  ('  ->  Sort  (cost=600.95..600.99 rows=16 width=100)',),
#  ('        Sort Key: (avg((count(film_actor.actor_id)))) DESC',),
#  ('        ->  HashAggregate  (cost=600.54..600.74 rows=16 width=100)',),
#  ('              Group Key: c.name',),
#  ('              ->  Nested Loop  (cost=299.34..520.54 rows=16000 width=76)',),
#  ('                    ->  HashAggregate  (cost=299.34..309.34 rows=1000 width=12)',),
#  ('                          Group Key: film.film_id',),
#  ('                          ->  Hash Join  (cost=112.31..272.03 rows=5462 width=6)',),
#  ('                                Hash Cond: (film_actor.film_id = film.film_id)',),
#  ('                                ->  Seq Scan on film_actor  (cost=0.00..84.62 rows=5462 width=4)',),
#  ('                                ->  Hash  (cost=99.81..99.81 rows=1000 width=6)',),
#  ('                                      ->  Hash Join  (cost=77.86..99.81 rows=1000 width=6)',),
#  ('                                            Hash Cond: (film_category.category_id = category.category_id)',),
#  ('                                            ->  Hash Join  (cost=76.50..95.14 rows=1000 width=8)',),
#  ('                                                  Hash Cond: (film_category.film_id = film.film_id)',),
#  ('                                                  ->  Seq Scan on film_category  (cost=0.00..16.00 rows=1000 width=4)',),
#  ('                                                  ->  Hash  (cost=64.00..64.00 rows=1000 width=4)',),
#  ('                                                        ->  Seq Scan on film  (cost=0.00..64.00 rows=1000 width=4)',),
#  ('                                            ->  Hash  (cost=1.16..1.16 rows=16 width=4)',),
#  ('                                                  ->  Seq Scan on category  (cost=0.00..1.16 rows=16 width=4)',),
#  ('                    ->  Materialize  (cost=0.00..1.24 rows=16 width=68)',),
#  ('                          ->  Seq Scan on category c  (cost=0.00..1.16 rows=16 width=68)',)]

# %%
# %%sql
# SELECT c.name, avg(x.count_actors) as avg_num_actors
# from category c
# NATURAL JOIN (
#     SELECT film_id, count(actor_id) as count_actors
#     FROM film_actor
#     JOIN film USING (film_id)
#     JOIN film_category USING (film_id)
#     JOIN category USING (category_id)
#     GROUP BY film_id
#     )  AS x
# GROUP BY c.name
# ORDER BY avg_num_actors DESC
# LIMIT 3;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 3 rows affected.
# [('Games', Decimal('5.4784353059177533')),
#  ('Animation', Decimal('5.4784353059177533')),
#  ('Family', Decimal('5.4784353059177533'))]

# %% [markdown]
# ### 5
# ### For each staff member, list their average daily payment amount processed.

# %%
# %%sql
# EXPLAIN
# SELECT s.first_name, s.last_name, avg(x.sum_amount) as avg_daily_payment
# from staff s
# NATURAL JOIN (
#     SELECT p.payment_date::date, sum(p.amount) as sum_amount, p.staff_id
#     from payment p
#     group by payment_date::date, staff_id
#     ) as x
# GROUP BY s.first_name, s.last_name;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 11 rows affected.
# [('GroupAggregate  (cost=803.76..805.23 rows=2 width=248)',),
#  ('  Group Key: s.first_name, s.last_name',),
#  ('  ->  Sort  (cost=803.76..804.12 rows=144 width=248)',),
#  ('        Sort Key: s.first_name, s.last_name',),
#  ('        ->  Hash Join  (cost=400.96..798.60 rows=144 width=248)',),
#  ('              Hash Cond: (p.staff_id = s.staff_id)',),
#  ('              ->  HashAggregate  (cost=399.92..615.40 rows=14365 width=38)',),
#  ('                    Group Key: (p.payment_date)::date, p.staff_id',),
#  ('                    ->  Seq Scan on payment p  (cost=0.00..290.45 rows=14596 width=12)',),
#  ('              ->  Hash  (cost=1.02..1.02 rows=2 width=220)',),
#  ('                    ->  Seq Scan on staff s  (cost=0.00..1.02 rows=2 width=220)',)]

# %%
# %%sql
# SELECT s.first_name, s.last_name, avg(x.sum_amount) as avg_daily_payment
# from staff s
# NATURAL JOIN (
#     SELECT p.payment_date::date, sum(p.amount) as sum_amount, p.staff_id
#     from payment p
#     group by payment_date::date, staff_id
#     ) as x
# GROUP BY s.first_name, s.last_name;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 2 rows affected.
# [('Jon', 'Stephens', Decimal('970.6225000000000000')),
#  ('Mike', 'Hillyer', Decimal('945.3787500000000000'))]

# %% [markdown]
# ### 6
# ### What is the statistical correlation between film length and rental rate?

# %%
# %%sql
# EXPLAIN
# SELECT corr(length, rental_rate)
# FROM film;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 2 rows affected.
# [('Aggregate  (cost=71.50..71.51 rows=1 width=8)',),
#  ('  ->  Seq Scan on film  (cost=0.00..64.00 rows=1000 width=8)',)]

# %%
# %%sql
# SELECT corr(length, rental_rate)
# FROM film;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 1 rows affected.
# [(0.0297892586459086,)]

# %% [markdown]
# [Helpful Hints Video](https://youtu.be/3d2vgLn9KVs)

# %% [markdown]
# # Save your Notebook, then `File > Close and Halt`
