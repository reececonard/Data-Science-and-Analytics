# %% [markdown]
# # Window Functions
#
# Please remember to use the `EXPLAIN` before you execute a query to help avoid unnecessary load on the DBMS and indefinite waits by you for results.
#
# Therefore, for each question, we are providing a cell for the `EXPLAIN` as well as the final SQL.
#
#
# ## Our practice schema:
#
# We will use the same database as in the Day 1 practice.
#
# A PDF of the _Entity-Relationship Diagrams_ (ERD) is available [here](https://web.dsa.missouri.edu/static/PDF/DVD_Rental_ERD2.pdf).
# Printing it out is recommended.
#
#
# **NOTE**: These queries are more complex that the previous day's.
# If you get stuck on one, skip and come back to it later.
#
#
# **NOTE**: For this notebook, it is desired taht you construct solutions using Window Functions.

# %%
# %load_ext sql
# %sql postgres://dsa_ro_user:readonly@pgsql.dsa.lan/dvdrental
# Out:
# 'Connected: dsa_ro_user@dvdrental'

# %% [markdown]
# # 1
#
# ### For the following customers: list each movie they have rented, its `film.rental_duration`, and the comparison of the  `film.rental_duration` versus their average `rental` duration `(return_date  - rental_date)` as a column named `cmp`.
#
# Customer IDs:
#   * 318
#   * 110
#   * 281
#   * 61

# %%
# %%sql
# EXPLAIN
# SELECT r.customer_id, f.title, f.rental_duration, sum(f.rental_duration - x.i) as cmp
# from film f
# JOIN (
#     SELECT r.customer_id, avg(r.return_date::date - r.rental_date::date) as i
#     from rental r
#     JOIN inventory i USING (inventory_id)
#     WHERE r.customer IN (318, 110, 281, 61)
#     AND r.return_date IS NOT NULL
#     GROUP BY r.customer_id
# ) as x
# GROUP BY r.customer_id ;

# %%
# %%sql
# SELECT r.customer_id, f.title, f.rental_duration, sum(f.rental_duration - x.i) as cmp
# from film f
# JOIN (
#     SELECT r.customer_id, avg(r.return_date::date - r.rental_date::date) as i
#     from rental r
#     JOIN inventory i USING (inventory_id)
#     WHERE r.customer IN (318, 110, 281, 61)
#     AND r.return_date IS NOT NULL
#     GROUP BY r.customer_id
# ) as x
# GROUP BY r.customer_id ;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# (psycopg2.errors.SyntaxError) syntax error at or near ";"
# LINE 10: ) as x;
#                ^
#
# [SQL: SELECT r.customer_id, f.title, f.rental_duration, sum(f.rental_duration - x.i) as cmp
# from film f
# JOIN (
#     SELECT r.customer_id, avg(r.return_date::date - r.rental_date::date) as i
#     from rental r
#     JOIN inventory i USING (inventory_id)
#     WHERE r.customer IN (318, 110, 281, 61)
#     AND r.return_date IS NOT NULL
#     GROUP BY r.customer_id
# ) as x;]
# (Background on this error at: http://sqlalche.me/e/f405)

# %% [markdown]
# [Helpful Hints Video](https://youtu.be/cm1_d1qWLhg)
#
#
# ---
#
# # 2
#
# ### For each store (inventory.store_id), list the top three films that have been rented based on accumulated rental durations.
#
# Hint: Use the `rank()` function and a derived table

# %%
# %%sql
# EXPLAIN
# SELECT i.store_id, i.film_id, f.title, f.rental_duration, rank
# from film f
# JOIN (
#     SELECT store_id
#     , rank() OVER (PARTITION BY store_id ORDER BY rental_duration DESC)
#     , i.film_id, f.title, f.rental_duration
#     FROM inventory i
#     JOIN rental r USING (inventory_id)
#     WHERE r.return_date IS NOT NULL
#     GROUP BY i.store_id, i.film_id, f.title, f.rental_duration
# ) as x
# WHERE RANK <= 3;

# %%
# %%sql
# SELECT i.store_id, i.film_id, f.title, f.rental_duration, rank
# from film f
# JOIN (
#     SELECT store_id
#     , rank() OVER (PARTITION BY store_id ORDER BY rental_duration DESC)
#     , i.film_id, f.title, f.rental_duration
#     FROM inventory i
#     JOIN rental r USING (inventory_id)
#     WHERE r.return_date IS NOT NULL
#     GROUP BY i.store_id, i.film_id, f.title, f.rental_duration
# ) as x
# WHERE RANK <= 3;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# (psycopg2.errors.SyntaxError) syntax error at or near "WHERE"
# LINE 12: WHERE RANK <= 3;
#          ^
#
# [SQL: SELECT i.store_id, i.film_id, f.title, f.rental_duration, rank
# from film f
# JOIN (
#     SELECT store_id
#     , rank() OVER (PARTITION BY store_id ORDER BY rental_duration DESC)
#     , i.film_id, f.title, f.rental_duration
#     FROM inventory i
#     JOIN rental r USING (inventory_id)
#     WHERE r.return_date IS NOT NULL
#     GROUP BY i.store_id, i.film_id, f.title, f.rental_duration
# ) as x
# WHERE RANK <= 3;]
# (Background on this error at: http://sqlalche.me/e/f405)

# %%
# %%sql
# SELECT store_id, film_id, title, rental_duration, rank
# FROM (
#     SELECT i.store_id, i.film_id
#     , rank() OVER (PARTITION BY store_id ORDER BY rental_duration DESC)
#     , sum(r.return_date-r.rental_date) as duration
#     FROM inventory i
#     JOIN rental r USING (inventory_id)
#     JOIN film f USING (film_id)
#     WHERE r.return_date IS NOT NULL
#     GROUP BY i.store_id, i.film_id
# ) AS x
# GROUP BY
# WHERE RANK <= 3;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# (psycopg2.errors.GroupingError) column "f.rental_duration" must appear in the GROUP BY clause or be used in an aggregate function
# LINE 4:     , rank() OVER (PARTITION BY store_id ORDER BY rental_dur...
#                                                           ^
#
# [SQL: SELECT store_id, film_id, title, rental_duration, rank
# FROM (
#     SELECT i.store_id, i.film_id
#     , rank() OVER (PARTITION BY store_id ORDER BY rental_duration DESC)
#     , sum(r.return_date-r.rental_date) as duration
#     FROM inventory i
#     JOIN rental r USING (inventory_id)
#     JOIN film f USING (film_id)
#     WHERE r.return_date IS NOT NULL
#     GROUP BY i.store_id, i.film_id
# ) AS x
# WHERE RANK <= 3;]
# (Background on this error at: http://sqlalche.me/e/f405)

# %% [markdown]
# [Helpful Hints Video](https://youtu.be/COQem8x3kR4)
#
#
# ---
#
# # 3
#
# ### For each category, list the three longest movies

# %%
# %%sql
# EXPLAIN
# SELECT name, title, length, rank
# FROM (
#     SELECT name
#     , rank() OVER (PARTITION BY name ORDER BY length DESC)
#     , title, length
#     FROM film
#     JOIN film_category USING (film_id)
#     JOIN category USING (category_id)
# ) as x
# WHERE RANK <= 3;

# %%
# %%sql
# SELECT name, title, length, rank
# FROM (
#     SELECT name
#     , rank() OVER (PARTITION BY name ORDER BY length DESC)
#     , title, length
#     FROM film
#     JOIN film_category USING (film_id)
#     JOIN category USING (category_id)
# ) as x
# WHERE RANK <= 3;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 53 rows affected.
# [('Action', 'Worst Banger', 185, 1),
#  ('Action', 'Darn Forrester', 185, 1),
#  ('Action', 'Casualties Encino', 179, 3),
#  ('Animation', 'Pond Seattle', 185, 1),
#  ('Animation', 'Gangs Pride', 185, 1),
#  ('Animation', 'Theory Mermaid', 184, 3),
#  ('Animation', 'Sons Interview', 184, 3),
#  ('Children', 'Wrong Behavior', 178, 1),
#  ('Children', 'Fury Murder', 178, 1),
#  ('Children', 'Empire Malkovich', 177, 3),
#  ('Classics', 'Conspiracy Spirit', 184, 1),
#  ('Classics', 'Dracula Crystal', 176, 2),
#  ('Classics', 'Lights Deer', 174, 3),
#  ('Comedy', 'Control Anthem', 185, 1),
#  ('Comedy', 'Saturn Name', 182, 2),
#  ('Comedy', 'Searchers Wait', 182, 2),
#  ('Documentary', 'Young Language', 183, 1),
#  ('Documentary', 'Wife Turn', 183, 1),
#  ('Documentary', 'Cause Date', 179, 3),
#  ('Drama', 'Jacket Frisco', 181, 1),
#  ('Drama', 'Something Duck', 180, 2),
#  ('Drama', 'Slacker Liaisons', 179, 3),
#  ('Drama', 'Torque Bound', 179, 3),
#  ('Drama', 'Virgin Daisy', 179, 3),
#  ('Family', 'King Evolution', 184, 1),
#  ('Family', 'Baked Cleopatra', 182, 2),
#  ('Family', 'Manchurian Curtain', 177, 3),
#  ('Foreign', 'Crystal Breaking', 184, 1),
#  ('Foreign', 'Sorority Queen', 184, 1),
#  ('Foreign', 'Catch Amistad', 183, 3),
#  ('Games', 'Chicago North', 185, 1),
#  ('Games', 'Moonwalker Fool', 184, 2),
#  ('Games', 'Monsoon Cause', 182, 3),
#  ('Horror', 'Love Suicides', 181, 1),
#  ('Horror', 'Analyze Hoosiers', 181, 1),
#  ('Horror', 'Texas Watch', 179, 3),
#  ('Music', 'Home Pity', 185, 1),
#  ('Music', 'Scalawag Duck', 183, 2),
#  ('Music', 'Reds Pocus', 182, 3),
#  ('New', 'Frontier Cabin', 183, 1),
#  ('New', 'Wild Apollo', 181, 2),
#  ('New', 'Runaway Tenenbaums', 181, 2),
#  ('Sci-Fi', 'Soldiers Evolution', 185, 1),
#  ('Sci-Fi', 'Express Lonely', 178, 2),
#  ('Sci-Fi', 'Eyes Driving', 172, 3),
#  ('Sci-Fi', 'Connecticut Tramp', 172, 3),
#  ('Sports', 'Smoochy Control', 184, 1),
#  ('Sports', 'Records Zorro', 182, 2),
#  ('Sports', 'Star Operation', 181, 3),
#  ('Travel', 'Sweet Brotherhood', 185, 1),
#  ('Travel', 'Muscle Bright', 185, 1),
#  ('Travel', 'Kick Savannah', 179, 3),
#  ('Travel', 'Born Spinal', 179, 3)]

# %% [markdown]
# # 4
#
# ### For each customer, list their two shortest movie rentals.

# %%
# %%sql
# SELECT first_name, last_name, title, rank
# FROM (
#     SELECT last_name
#     , rank() OVER (PARTITION BY last_name ORDER BY (return_date-rental_date) ASC)
#     ,first_name, title
#     FROM customer
#     JOIN rental USING (customer_id)
#     JOIN inventory USING (inventory_id)
#     JOIN film USING (film_id)
# ) as x
# WHERE RANK <= 2
# ORDER BY first_name ASC;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 20 rows affected.
# [('Sort  (cost=2637.61..2650.98 rows=5348 width=36)',),
#  ('  Sort Key: x.first_name',),
#  ('  ->  Subquery Scan on x  (cost=1785.01..2306.44 rows=5348 width=36)',),
#  ('        Filter: (x.rank <= 2)',),
#  ('        ->  WindowAgg  (cost=1785.01..2105.89 rows=16044 width=36)',),
#  ('              ->  Sort  (cost=1785.01..1825.12 rows=16044 width=28)',),
#  ('                    Sort Key: customer.last_name, film.title DESC',),
#  ('                    ->  Hash Join  (cost=227.05..664.36 rows=16044 width=28)',),
#  ('                          Hash Cond: (inventory.film_id = film.film_id)',),
#  ('                          ->  Hash Join  (cost=150.55..545.57 rows=16044 width=15)',),
#  ('                                Hash Cond: (rental.inventory_id = inventory.inventory_id)',),
#  ('                                ->  Hash Join  (cost=22.48..375.33 rows=16044 width=17)',),
#  ('                                      Hash Cond: (rental.customer_id = customer.customer_id)',),
#  ('                                      ->  Seq Scan on rental  (cost=0.00..310.44 rows=16044 width=6)',),
#  ('                                      ->  Hash  (cost=14.99..14.99 rows=599 width=17)',),
#  ('                                            ->  Seq Scan on customer  (cost=0.00..14.99 rows=599 width=17)',),
#  ('                                ->  Hash  (cost=70.81..70.81 rows=4581 width=6)',),
#  ('                                      ->  Seq Scan on inventory  (cost=0.00..70.81 rows=4581 width=6)',),
#  ('                          ->  Hash  (cost=64.00..64.00 rows=1000 width=19)',),
#  ('                                ->  Seq Scan on film  (cost=0.00..64.00 rows=1000 width=19)',)]

# %%
# %%sql
# SELECT first_name, last_name, title, rank
# FROM (
#     SELECT last_name
#     , rank() OVER (PARTITION BY last_name ORDER BY (return_date-rental_date) ASC)
#     ,first_name, title
#     FROM customer
#     JOIN rental USING (customer_id)
#     JOIN inventory USING (inventory_id)
#     JOIN film USING (film_id)
# ) as x
# WHERE RANK <= 2
# ORDER BY first_name ASC;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 1198 rows affected.
# [('Aaron', 'Selby', 'Drumline Cyclone', 1),
#  ('Aaron', 'Selby', 'Liaisons Sweet', 2),
#  ('Adam', 'Gooch', 'Spiking Element', 1),
#  ('Adam', 'Gooch', 'Polish Brooklyn', 2),
#  ('Adrian', 'Clary', 'Volcano Texas', 1),
#  ('Adrian', 'Clary', 'Hollywood Anonymous', 2),
#  ('Agnes', 'Bishop', 'Lucky Flying', 1),
#  ('Agnes', 'Bishop', 'Igby Maker', 2),
#  ('Alan', 'Kahn', 'Holocaust Highball', 2),
#  ('Alan', 'Kahn', 'Roses Treasure', 1),
#  ('Albert', 'Crouse', 'Nash Chocolat', 2),
#  ('Albert', 'Crouse', 'Gathering Calendar', 1),
#  ('Alberto', 'Henning', 'Cat Coneheads', 1),
#  ('Alberto', 'Henning', 'Redemption Comforts', 2),
#  ('Alex', 'Gresham', 'Runner Madigan', 1),
#  ('Alex', 'Gresham', 'Gunfight Moon', 2),
#  ('Alexander', 'Fennell', 'Blues Instinct', 1),
#  ('Alexander', 'Fennell', 'Highball Potter', 1),
#  ('Alfred', 'Casillas', 'Creepers Kane', 2),
#  ('Alfred', 'Casillas', 'Berets Agent', 1),
#  ('Alfredo', 'Mcadams', 'Bedazzled Married', 1),
#  ('Alfredo', 'Mcadams', 'Boulevard Mob', 2),
#  ('Alice', 'Stewart', 'Random Go', 2),
#  ('Alice', 'Stewart', 'Witches Panic', 1),
#  ('Alicia', 'Mills', 'Primary Glass', 2),
#  ('Alicia', 'Mills', 'American Circus', 1),
#  ('Allan', 'Cornish', 'Cruelty Unforgiven', 2),
#  ('Allan', 'Cornish', 'Wolves Desire', 1),
#  ('Allen', 'Butterfield', 'Greedy Roots', 2),
#  ('Allen', 'Butterfield', 'Fantasy Troopers', 1),
#  ('Allison', 'Stanley', 'Lover Truman', 2),
#  ('Allison', 'Stanley', 'Glass Dying', 1),
#  ('Alma', 'Austin', 'Deceiver Betrayed', 2),
#  ('Alma', 'Austin', 'Brannigan Sunrise', 1),
#  ('Alvin', 'Deloach', 'Robbers Joon', 1),
#  ('Alvin', 'Deloach', 'Earth Vision', 2),
#  ('Amanda', 'Carter', 'Homeward Cider', 1),
#  ('Amanda', 'Carter', 'Model Fish', 2),
#  ('Amber', 'Dixon', 'Divine Resurrection', 1),
#  ('Amber', 'Dixon', 'Lose Inch', 2),
#  ('Amy', 'Lopez', 'Garden Island', 1),
#  ('Amy', 'Lopez', 'Lawless Vision', 2),
#  ('Ana', 'Bradley', 'Submarine Bed', 2),
#  ('Ana', 'Bradley', 'Streetcar Intentions', 1),
#  ('Andre', 'Rapp', 'Scorpion Apollo', 1),
#  ('Andre', 'Rapp', 'Games Bowfinger', 2),
#  ('Andrea', 'Henderson', 'Fidelity Devil', 2),
#  ('Andrea', 'Henderson', 'Mermaid Insects', 1),
#  ('Andrew', 'Purdy', 'Coldblooded Darling', 1),
#  ('Andrew', 'Purdy', 'Videotape Arsenic', 2),
#  ('Andy', 'Vanhorn', 'Earring Instinct', 2),
#  ('Andy', 'Vanhorn', 'River Outlaw', 1),
#  ('Angel', 'Barclay', 'Christmas Moonshine', 1),
#  ('Angel', 'Barclay', 'Gathering Calendar', 2),
#  ('Angela', 'Hernandez', 'Virgin Daisy', 1),
#  ('Angela', 'Hernandez', 'Amistad Midsummer', 2),
#  ('Anita', 'Morales', 'Pickup Driving', 2),
#  ('Anita', 'Morales', 'Rear Trading', 1),
#  ('Ann', 'Evans', 'Gangs Pride', 1),
#  ('Ann', 'Evans', 'Jason Trap', 2),
#  ('Anna', 'Hill', 'Forrester Comancheros', 1),
#  ('Anna', 'Hill', 'Lose Inch', 2),
#  ('Anne', 'Powell', 'Dying Maker', 1),
#  ('Anne', 'Powell', 'Hanky October', 2),
#  ('Annette', 'Olson', 'Loverboy Attacks', 2),
#  ('Annette', 'Olson', 'Shanghai Tycoon', 1),
#  ('Annie', 'Russell', 'Flying Hook', 1),
#  ('Annie', 'Russell', 'Lonely Elephant', 2),
#  ('Anthony', 'Schwab', 'Kramer Chocolate', 1),
#  ('Anthony', 'Schwab', 'Scarface Bang', 2),
#  ('Antonio', 'Meek', 'Window Side', 2),
#  ('Antonio', 'Meek', 'Hanging Deep', 1),
#  ('April', 'Burns', 'Karate Moon', 2),
#  ('April', 'Burns', 'Congeniality Quest', 1),
#  ('Arlene', 'Harvey', 'Lebowski Soldiers', 1),
#  ('Arlene', 'Harvey', 'Dorado Notting', 2),
#  ('Armando', 'Gruber', 'Maltese Hope', 1),
#  ('Armando', 'Gruber', 'Sabrina Midnight', 2),
#  ('Arnold', 'Havens', 'Hellfighters Sierra', 1),
#  ('Arnold', 'Havens', 'Family Sweet', 2),
#  ('Arthur', 'Simpkins', 'Desire Alien', 2),
#  ('Arthur', 'Simpkins', 'Grease Youth', 1),
#  ('Ashley', 'Richardson', 'Baby Hall', 2),
#  ('Ashley', 'Richardson', 'Bill Others', 1),
#  ('Audrey', 'Ray', 'Innocent Usual', 1),
#  ('Audrey', 'Ray', 'Goldfinger Sensibility', 2),
#  ('Austin', 'Cintron', 'Daisy Menagerie', 1),
#  ('Austin', 'Cintron', 'Zorro Ark', 2),
#  ('Barbara', 'Jones', 'Bedazzled Married', 2),
#  ('Barbara', 'Jones', 'Hoosiers Birdcage', 1),
#  ('Barry', 'Lovelace', 'Disciple Mother', 1),
#  ('Barry', 'Lovelace', 'Sweden Shining', 2),
#  ('Beatrice', 'Arnold', 'Pianist Outfield', 1),
#  ('Beatrice', 'Arnold', 'Right Cranes', 2),
#  ('Becky', 'Miles', 'Conquerer Nuts', 2),
#  ('Becky', 'Miles', 'Weekend Personal', 1),
#  ('Ben', 'Easter', 'Indian Love', 1),
#  ('Ben', 'Easter', 'Sugar Wonka', 2),
#  ('Benjamin', 'Varney', 'Secretary Rouge', 1),
#  ('Benjamin', 'Varney', 'Bikini Borrowers', 2),
#  ('Bernard', 'Colby', 'Sleepless Monsoon', 1),
#  ('Bernard', 'Colby', 'Sassy Packer', 2),
#  ('Bernice', 'Willis', 'Heavyweights Beast', 1),
#  ('Bernice', 'Willis', 'Oz Liaisons', 2),
#  ('Bertha', 'Ferguson', 'Rocky War', 1),
#  ('Bertha', 'Ferguson', 'Paradise Sabrina', 2),
#  ('Bessie', 'Morrison', 'Christmas Moonshine', 2),
#  ('Bessie', 'Morrison', 'Hobbit Alien', 1),
#  ('Beth', 'Franklin', 'Pluto Oleander', 1),
#  ('Beth', 'Franklin', 'Champion Flatliners', 2),
#  ('Betty', 'White', 'Brotherhood Blanket', 2),
#  ('Betty', 'White', 'Horn Working', 1),
#  ('Beverly', 'Brooks', 'Hours Rage', 1),
#  ('Beverly', 'Brooks', 'Interview Liaisons', 2),
#  ('Bill', 'Gavin', 'Outfield Massacre', 1),
#  ('Bill', 'Gavin', 'Intentions Empire', 2),
#  ('Billie', 'Horton', 'Seattle Expecations', 2),
#  ('Billie', 'Horton', 'Fool Mockingbird', 1),
#  ('Billy', 'Poulin', 'Impossible Prejudice', 2),
#  ('Billy', 'Poulin', 'Bound Cheaper', 1),
#  ('Bob', 'Pfeiffer', 'Voice Peach', 2),
#  ('Bob', 'Pfeiffer', 'Fugitive Maguire', 1),
#  ('Bobbie', 'Craig', 'Worker Tarzan', 2),
#  ('Bobbie', 'Craig', 'Park Citizen', 1),
#  ('Bobby', 'Boudreau', 'Coma Head', 1),
#  ('Bobby', 'Boudreau', 'Juggler Hardly', 2),
#  ('Bonnie', 'Hughes', 'Knock Warlock', 1),
#  ('Bonnie', 'Hughes', 'Tomorrow Hustler', 2),
#  ('Brad', 'Mccurdy', 'Wife Turn', 2),
#  ('Brad', 'Mccurdy', 'Lies Treatment', 1),
#  ('Bradley', 'Motley', 'Tarzan Videotape', 2),
#  ('Bradley', 'Motley', 'Saturday Lambs', 1),
#  ('Brandon', 'Huey', 'Mourning Purple', 1),
#  ('Brandon', 'Huey', 'Midsummer Groundhog', 2),
#  ('Brandy', 'Graves', 'Purple Movie', 2),
#  ('Brandy', 'Graves', 'Peak Forever', 1),
#  ('Brenda', 'Wright', 'Pacific Amistad', 1),
#  ('Brenda', 'Wright', 'Army Flintstones', 2),
#  ('Brent', 'Harkins', 'Casper Dragonfly', 2),
#  ('Brent', 'Harkins', 'Coma Head', 1),
#  ('Brett', 'Cornwell', 'Splendor Patton', 1),
#  ('Brett', 'Cornwell', 'Rocketeer Mother', 2),
#  ('Brian', 'Wyman', 'Sleepy Japanese', 2),
#  ('Brian', 'Wyman', 'Montezuma Command', 1),
#  ('Brittany', 'Riley', 'Soup Wisdom', 1),
#  ('Brittany', 'Riley', 'Jeepers Wedding', 2),
#  ('Bruce', 'Schwarz', 'Teen Apollo', 1),
#  ('Bruce', 'Schwarz', 'Jason Trap', 2),
#  ('Bryan', 'Hardison', 'Cider Desire', 2),
#  ('Bryan', 'Hardison', 'Telemark Heartbreakers', 1),
#  ('Byron', 'Box', 'Fargo Gandhi', 2),
#  ('Byron', 'Box', 'Homeward Cider', 1),
#  ('Calvin', 'Martel', 'Boiled Dares', 1),
#  ('Calvin', 'Martel', 'Blues Instinct', 2),
#  ('Carl', 'Artis', 'Graffiti Love', 2),
#  ('Carl', 'Artis', 'Yentl Idaho', 1),
#  ('Carla', 'Gutierrez', 'Giant Troopers', 2),
#  ('Carla', 'Gutierrez', 'Airplane Sierra', 1),
#  ('Carlos', 'Coughlin', 'Secret Groundhog', 2),
#  ('Carlos', 'Coughlin', 'Whisperer Giant', 1),
#  ('Carmen', 'Owens', 'Excitement Eve', 2),
#  ('Carmen', 'Owens', 'Lawrence Love', 1),
#  ('Carol', 'Garcia', 'Confessions Maguire', 1),
#  ('Carol', 'Garcia', 'Wife Turn', 2),
#  ('Carole', 'Barnett', 'Scarface Bang', 2),
#  ('Carole', 'Barnett', 'Island Exorcist', 1),
#  ('Caroline', 'Bowman', 'Killer Innocent', 2),
#  ('Caroline', 'Bowman', 'Resurrection Silverado', 1),
#  ('Carolyn', 'Perez', 'Metropolis Coma', 2),
#  ('Carolyn', 'Perez', 'Badman Dawn', 1),
#  ('Carrie', 'Porter', 'Jumping Wrath', 1),
#  ('Carrie', 'Porter', 'Gathering Calendar', 2),
#  ('Casey', 'Mena', 'Mine Titans', 2),
#  ('Casey', 'Mena', 'Handicap Boondock', 1),
#  ('Cassandra', 'Walters', 'Intentions Empire', 2),
#  ('Cassandra', 'Walters', 'Closer Bang', 1),
#  ('Catherine', 'Campbell', 'Montezuma Command', 2),
#  ('Catherine', 'Campbell', 'Hobbit Alien', 1),
#  ('Cathy', 'Spencer', 'Kick Savannah', 1),
#  ('Cathy', 'Spencer', 'Dying Maker', 2),
#  ('Cecil', 'Vines', 'Rage Games', 2),
#  ('Cecil', 'Vines', 'Invasion Cyclone', 1),
#  ('Chad', 'Carbone', 'Money Harold', 1),
#  ('Chad', 'Carbone', 'Deer Virginian', 2),
#  ('Charlene', 'Alvarez', 'Holiday Games', 2),
#  ('Charlene', 'Alvarez', 'Wizard Coldblooded', 1),
#  ('Charles', 'Kowalski', 'Modern Dorado', 2),
#  ('Charles', 'Kowalski', 'Drifter Commandments', 1),
#  ('Charlie', 'Bess', 'French Holiday', 2),
#  ('Charlie', 'Bess', 'Fiddler Lost', 1),
#  ('Charlotte', 'Hunter', 'Musketeers Wait', 2),
#  ('Charlotte', 'Hunter', 'Queen Luke', 1),
#  ('Cheryl', 'Murphy', 'Dragonfly Strangers', 1),
#  ('Cheryl', 'Murphy', 'Fatal Haunted', 2),
#  ('Chester', 'Benner', 'Personal Ladybugs', 1),
#  ('Chester', 'Benner', 'Patient Sister', 2),
#  ('Chris', 'Brothers', 'Swarm Gold', 1),
#  ('Chris', 'Brothers', 'Coma Head', 2),
#  ('Christian', 'Jung', 'Arabia Dogma', 1),
#  ('Christian', 'Jung', 'Attraction Newton', 2),
#  ('Christina', 'Ramirez', 'Expendable Stallion', 2),
#  ('Christina', 'Ramirez', 'Meet Chocolate', 1),
#  ('Christine', 'Roberts', 'Eagles Panky', 1),
#  ('Christine', 'Roberts', 'Contact Anonymous', 2),
#  ('Christopher', 'Greco', 'Roxanne Rebel', 1),
#  ('Christopher', 'Greco', 'Forever Candidate', 2),
#  ('Christy', 'Vargas', 'Clueless Bucket', 2),
#  ('Christy', 'Vargas', 'Louisiana Harry', 1),
#  ('Cindy', 'Fisher', 'Alien Center', 2),
#  ('Cindy', 'Fisher', 'Reunion Witches', 1),
#  ('Clara', 'Shaw', 'Million Ace', 2),
#  ('Clara', 'Shaw', 'Disciple Mother', 1),
#  ('Clarence', 'Gamez', 'Gilmore Boiled', 1),
#  ('Clarence', 'Gamez', 'Microcosmos Paradise', 2),
#  ('Claude', 'Herzog', 'Motions Details', 2),
#  ('Claude', 'Herzog', 'Gaslight Crusade', 1),
#  ('Claudia', 'Fuller', 'Uprising Uptown', 1),
#  ('Claudia', 'Fuller', 'Dude Blindness', 2),
#  ('Clayton', 'Barbee', 'Tenenbaums Command', 1),
#  ('Clayton', 'Barbee', 'Disciple Mother', 2),
#  ('Clifford', 'Bowens', 'Trip Newton', 2),
#  ('Clifford', 'Bowens', 'Kwai Homeward', 1),
#  ('Clifton', 'Malcolm', 'Canyon Stock', 2),
#  ('Clifton', 'Malcolm', 'Words Hunter', 1),
#  ('Clinton', 'Buford', 'Range Moonwalker', 2),
#  ('Clinton', 'Buford', 'Feud Frogmen', 1),
#  ('Clyde', 'Tobias', 'Reunion Witches', 1),
#  ('Clyde', 'Tobias', 'Bikini Borrowers', 2),
#  ('Cody', 'Nolen', 'Texas Watch', 1),
#  ('Cody', 'Nolen', 'Blade Polish', 2),
#  ('Colleen', 'Burton', 'Ferris Mother', 2),
#  ('Colleen', 'Burton', 'Conversation Downhill', 1),
#  ('Connie', 'Wallace', 'Brotherhood Blanket', 2),
#  ('Connie', 'Wallace', 'Rock Instinct', 1),
#  ('Constance', 'Reid', 'Connecticut Tramp', 1),
#  ('Constance', 'Reid', 'Masked Bubble', 2),
#  ('Corey', 'Hauser', 'Labyrinth League', 2),
#  ('Corey', 'Hauser', 'Divide Monster', 1),
#  ('Cory', 'Meehan', 'Wasteland Divine', 1),
#  ('Cory', 'Meehan', 'Window Side', 2),
#  ('Courtney', 'Day', 'Pride Alamo', 2),
#  ('Courtney', 'Day', 'Grapes Fury', 1),
#  ('Craig', 'Morrell', 'Apache Divine', 2),
#  ('Craig', 'Morrell', 'Banger Pinocchio', 1),
#  ('Crystal', 'Ford', 'Fireball Philadelphia', 1),
#  ('Crystal', 'Ford', 'Grease Youth', 2),
#  ('Curtis', 'Irby', 'Videotape Arsenic', 2),
#  ('Curtis', 'Irby', 'Trading Pinocchio', 1),
#  ('Cynthia', 'Young', 'Translation Summer', 2),
#  ('Cynthia', 'Young', 'Ice Crossing', 1),
#  ('Daisy', 'Bates', 'Casablanca Super', 1),
#  ('Daisy', 'Bates', 'Vampire Whale', 2),
#  ('Dale', 'Ratcliff', 'Kissing Dolls', 1),
#  ('Dale', 'Ratcliff', 'Berets Agent', 2),
#  ('Dan', 'Paine', 'Strictly Scarface', 1),
#  ('Dan', 'Paine', 'Image Princess', 2),
#  ('Dana', 'Hart', 'Louisiana Harry', 1),
#  ('Dana', 'Hart', 'Feud Frogmen', 2),
#  ('Daniel', 'Cabral', 'Airplane Sierra', 2),
#  ('Daniel', 'Cabral', 'Bringing Hysterical', 1),
#  ('Danielle', 'Daniels', 'Stallion Sundance', 1),
#  ('Danielle', 'Daniels', 'Dogma Family', 2),
#  ('Danny', 'Isom', 'Bucket Brotherhood', 1),
#  ('Danny', 'Isom', 'Tights Dawn', 2),
#  ('Darlene', 'Rose', 'Muscle Bright', 2),
#  ('Darlene', 'Rose', 'Remember Diary', 1),
#  ('Darrell', 'Power', 'Something Duck', 2),
#  ('Darrell', 'Power', 'Dracula Crystal', 1),
#  ('Darren', 'Windham', 'Runaway Tenenbaums', 2),
#  ('Darren', 'Windham', 'Kramer Chocolate', 1),
#  ('Darryl', 'Ashcraft', 'Goodfellas Salute', 1),
#  ('Darryl', 'Ashcraft', 'Grapes Fury', 2),
#  ('Daryl', 'Larue', 'Honey Ties', 2),
#  ('Daryl', 'Larue', 'Siege Madre', 1),
#  ('Dave', 'Gardiner', 'Speed Suit', 1),
#  ('Dave', 'Gardiner', 'Turn Star', 2),
#  ('David', 'Royal', 'Slipper Fidelity', 2),
#  ('David', 'Royal', 'Wolves Desire', 1),
#  ('Dawn', 'Sullivan', 'Luke Mummy', 2),
#  ('Dawn', 'Sullivan', 'Life Twisted', 1),
#  ('Dean', 'Sauer', 'Robbers Joon', 1),
#  ('Dean', 'Sauer', 'Monterey Labyrinth', 2),
#  ('Deanna', 'Byrd', 'Arabia Dogma', 1),
#  ('Deanna', 'Byrd', 'Jedi Beneath', 2),
#  ('Debbie', 'Reyes', 'Tenenbaums Command', 1),
#  ('Debbie', 'Reyes', 'Full Flatliners', 2),
#  ('Deborah', 'Walker', 'Spirit Flintstones', 1),
#  ('Deborah', 'Walker', 'Adaptation Holes', 2),
#  ('Debra', 'Nelson', 'Timberland Sky', 2),
#  ('Debra', 'Nelson', 'Maltese Hope', 1),
#  ('Delores', 'Hansen', 'Karate Moon', 1),
#  ('Delores', 'Hansen', 'Forever Candidate', 2),
#  ('Denise', 'Kelly', 'Escape Metropolis', 2),
#  ('Denise', 'Kelly', 'Secret Groundhog', 1),
#  ('Dennis', 'Gilman', 'Virginian Pluto', 1),
#  ('Dennis', 'Gilman', 'Gangs Pride', 2),
#  ('Derek', 'Blakely', 'Idaho Love', 2),
#  ('Derek', 'Blakely', 'Liberty Magnificent', 1),
#  ('Derrick', 'Bourque', 'Blackout Private', 1),
#  ('Derrick', 'Bourque', 'Magic Mallrats', 2),
#  ('Diana', 'Alexander', 'Virgin Daisy', 2),
#  ('Diana', 'Alexander', 'Rush Goodfellas', 1),
#  ('Diane', 'Collins', 'Pity Bound', 2),
#  ('Diane', 'Collins', 'Lawless Vision', 1),
#  ('Dianne', 'Shelton', 'Daisy Menagerie', 1),
#  ('Dianne', 'Shelton', 'Born Spinal', 2),
#  ('Dolores', 'Wagner', 'Fish Opus', 2),
#  ('Dolores', 'Wagner', 'Crooked Frogmen', 1),
#  ('Don', 'Bone', 'Birds Perdition', 2),
#  ('Don', 'Bone', 'Express Lonely', 1),
#  ('Donald', 'Mahon', 'Trojan Tomorrow', 1),
#  ('Donald', 'Mahon', 'Jedi Beneath', 2),
#  ('Donna', 'Thompson', 'Sweethearts Suspects', 2),
#  ('Donna', 'Thompson', 'Married Go', 1),
#  ('Dora', 'Medina', 'Cause Date', 2),
#  ('Dora', 'Medina', 'Bubble Grosse', 1),
#  ('Doris', 'Reed', 'South Wait', 2),
#  ('Doris', 'Reed', 'Labyrinth League', 1),
#  ('Dorothy', 'Taylor', 'Fury Murder', 1),
#  ('Dorothy', 'Taylor', 'Pacific Amistad', 2),
#  ('Douglas', 'Graf', 'Story Side', 1),
#  ('Douglas', 'Graf', 'Range Moonwalker', 2),
#  ('Duane', 'Tubbs', 'Gunfight Moon', 2),
#  ('Duane', 'Tubbs', 'Bugsy Song', 1),
#  ('Dustin', 'Gillette', 'Roses Treasure', 1),
#  ('Dustin', 'Gillette', 'Paris Weekend', 2),
#  ('Dwayne', 'Olvera', 'Talented Homicide', 2),
#  ('Dwayne', 'Olvera', 'Network Peak', 1),
#  ('Dwight', 'Lombardi', 'Dirty Ace', 2),
#  ('Dwight', 'Lombardi', 'Bucket Brotherhood', 1),
#  ('Earl', 'Shanks', 'Greedy Roots', 1),
#  ('Earl', 'Shanks', 'Luck Opus', 2),
#  ('Eddie', 'Tomlin', 'Outbreak Divine', 2),
#  ('Eddie', 'Tomlin', 'Hurricane Affair', 1),
#  ('Edgar', 'Rhoads', 'Fatal Haunted', 1),
#  ('Edgar', 'Rhoads', 'Hysterical Grail', 2),
#  ('Edith', 'Mcdonald', 'Betrayed Rear', 2),
#  ('Edith', 'Mcdonald', 'Talented Homicide', 1),
#  ('Edna', 'West', 'Atlantis Cause', 1),
#  ('Edna', 'West', 'Trip Newton', 2),
#  ('Eduardo', 'Hiatt', 'Roses Treasure', 2),
#  ('Eduardo', 'Hiatt', 'Daughter Madigan', 1),
#  ('Edward', 'Baugh', 'Chariots Conspiracy', 2),
#  ('Edward', 'Baugh', 'Born Spinal', 1),
#  ('Edwin', 'Burk', 'Breaking Home', 2),
#  ('Edwin', 'Burk', 'Secrets Paradise', 1),
#  ('Eileen', 'Carr', 'Drumline Cyclone', 1),
#  ('Eileen', 'Carr', 'Platoon Instinct', 2),
#  ('Elaine', 'Stevens', 'Magnolia Forrester', 1),
#  ('Elaine', 'Stevens', 'Jaws Harry', 2),
#  ('Eleanor', 'Hunt', 'Remember Diary', 2),
#  ('Eleanor', 'Hunt', 'Prejudice Oleander', 1),
#  ('Elizabeth', 'Brown', 'Head Stranger', 1),
#  ('Elizabeth', 'Brown', 'Patient Sister', 2),
#  ('Ella', 'Oliver', 'Rock Instinct', 2),
#  ('Ella', 'Oliver', 'Patient Sister', 1),
#  ('Ellen', 'Simpson', 'Celebrity Horn', 2),
#  ('Ellen', 'Simpson', 'Silence Kane', 1),
#  ('Elmer', 'Noe', 'Stranger Strangers', 1),
#  ('Elmer', 'Noe', 'Outbreak Divine', 2),
#  ('Elsie', 'Kelley', 'Clones Pinocchio', 2),
#  ('Elsie', 'Kelley', 'Zorro Ark', 1),
#  ('Emily', 'Diaz', 'Princess Giant', 2),
#  ('Emily', 'Diaz', 'Sorority Queen', 1),
#  ('Emma', 'Boyd', 'Arabia Dogma', 2),
#  ('Emma', 'Boyd', 'Sinners Atlantis', 1),
#  ('Enrique', 'Forsythe', 'Trading Pinocchio', 1),
#  ('Enrique', 'Forsythe', 'Doubtfire Labyrinth', 2),
#  ('Eric', 'Robert', 'Idols Snatchers', 2),
#  ('Eric', 'Robert', 'Sweet Brotherhood', 1),
#  ('Erica', 'Matthews', 'Caper Motions', 1),
#  ('Erica', 'Matthews', 'Coneheads Smoochy', 2),
#  ('Erik', 'Guillen', 'Metropolis Coma', 2),
#  ('Erik', 'Guillen', 'Indian Love', 1),
#  ('Erika', 'Pena', 'Double Wrath', 2),
#  ('Erika', 'Pena', 'Talented Homicide', 1),
#  ('Erin', 'Dunn', 'Intolerable Intentions', 2),
#  ('Erin', 'Dunn', 'Barefoot Manchurian', 1),
#  ('Ernest', 'Stepp', 'Steel Santa', 1),
#  ('Ernest', 'Stepp', 'Savannah Town', 2),
#  ('Esther', 'Crawford', 'Pride Alamo', 2),
#  ('Esther', 'Crawford', 'Cat Coneheads', 1),
#  ('Ethel', 'Webb', 'Stagecoach Armageddon', 1),
#  ('Ethel', 'Webb', 'Lady Stage', 2),
#  ('Eugene', 'Culpepper', 'Wizard Coldblooded', 1),
#  ('Eugene', 'Culpepper', 'Super Wyoming', 2),
#  ('Eva', 'Ramos', 'Blindness Gun', 1),
#  ('Eva', 'Ramos', 'Sleepy Japanese', 2),
#  ('Evelyn', 'Morgan', 'Mallrats United', 1),
#  ('Evelyn', 'Morgan', 'Grease Youth', 2),
#  ('Everett', 'Banda', 'Working Microcosmos', 1),
#  ('Everett', 'Banda', 'Egg Igby', 2),
#  ('Felicia', 'Sutton', 'Intrigue Worst', 1),
#  ('Felicia', 'Sutton', 'Bull Shawshank', 2),
#  ('Felix', 'Gaffney', 'Theory Mermaid', 2),
#  ('Felix', 'Gaffney', 'Clyde Theory', 1),
#  ('Fernando', 'Churchill', 'Happiness United', 2),
#  ('Fernando', 'Churchill', 'Wizard Coldblooded', 1),
#  ('Florence', 'Woods', 'Scalawag Duck', 1),
#  ('Florence', 'Woods', 'Peak Forever', 2),
#  ('Floyd', 'Gandy', 'Steel Santa', 1),
#  ('Floyd', 'Gandy', 'Cabin Flash', 2),
#  ('Frances', 'Parker', 'American Circus', 1),
#  ('Frances', 'Parker', 'Thief Pelican', 2),
#  ('Francis', 'Sikes', 'Natural Stock', 2),
#  ('Francis', 'Sikes', 'Hyde Doctor', 1),
#  ('Francisco', 'Skidmore', 'Velvet Terminator', 2),
#  ('Francisco', 'Skidmore', 'Apache Divine', 1),
#  ('Frank', 'Waggoner', 'Greatest North', 2),
#  ('Frank', 'Waggoner', 'Lonely Elephant', 1),
#  ('Franklin', 'Troutman', 'Balloon Homeward', 2),
#  ('Franklin', 'Troutman', 'Necklace Outbreak', 1),
#  ('Fred', 'Wheat', 'Half Outfield', 1),
#  ('Fred', 'Wheat', 'Butterfly Chocolat', 2),
#  ('Freddie', 'Duggan', 'Freaky Pocus', 2),
#  ('Freddie', 'Duggan', 'Cheaper Clyde', 1),
#  ('Frederick', 'Isbell', 'Rollercoaster Bringing', 2),
#  ('Frederick', 'Isbell', 'Operation Operation', 1),
#  ('Gabriel', 'Harder', 'Hunchback Impossible', 2),
#  ('Gabriel', 'Harder', 'Blackout Private', 1),
#  ('Gail', 'Knight', 'Tomorrow Hustler', 2),
#  ('Gail', 'Knight', 'Half Outfield', 1),
#  ('Gary', 'Coy', 'Shakespeare Saddle', 2),
#  ('Gary', 'Coy', 'Hedwig Alter', 1),
#  ('Gene', 'Sanborn', 'Sensibility Rear', 1),
#  ('Gene', 'Sanborn', 'Human Graffiti', 2),
#  ('George', 'Linton', 'Caddyshack Jedi', 2),
#  ('George', 'Linton', 'Strictly Scarface', 1),
#  ('Georgia', 'Jacobs', 'Mystic Truman', 1),
#  ('Georgia', 'Jacobs', 'Hyde Doctor', 2),
#  ('Gerald', 'Fultz', 'Requiem Tycoon', 1),
#  ('Gerald', 'Fultz', 'Confused Candles', 2),
#  ('Geraldine', 'Perkins', 'Money Harold', 1),
#  ('Geraldine', 'Perkins', 'Intrigue Worst', 2),
#  ('Gertrude', 'Castillo', 'Pocus Pulp', 2),
#  ('Gertrude', 'Castillo', 'Candidate Perdition', 1),
#  ('Gilbert', 'Sledge', 'Roxanne Rebel', 2),
#  ('Gilbert', 'Sledge', 'Sea Virgin', 1),
#  ('Gina', 'Williamson', 'Satisfaction Confidential', 2),
#  ('Gina', 'Williamson', 'Soldiers Evolution', 1),
#  ('Gladys', 'Hamilton', 'Robbery Bright', 2),
#  ('Gladys', 'Hamilton', 'Everyone Craft', 1),
#  ('Glen', 'Talbert', 'Amelie Hellfighters', 1),
#  ('Glen', 'Talbert', 'Quest Mussolini', 2),
#  ('Glenda', 'Frazier', 'Open African', 1),
#  ('Glenda', 'Frazier', 'Wife Turn', 2),
#  ('Glenn', 'Pullen', 'Caper Motions', 1),
#  ('Glenn', 'Pullen', 'Duffel Apocalypse', 2),
#  ('Gloria', 'Cook', 'Paradise Sabrina', 1),
#  ('Gloria', 'Cook', 'Lights Deer', 2),
#  ('Gordon', 'Allard', 'Games Bowfinger', 2),
#  ('Gordon', 'Allard', 'Searchers Wait', 1),
#  ('Grace', 'Ellis', 'Records Zorro', 2),
#  ('Grace', 'Ellis', 'Robbers Joon', 1),
#  ('Greg', 'Robins', 'Bride Intrigue', 1),
#  ('Greg', 'Robins', 'Hunger Roof', 2),
#  ('Gregory', 'Mauldin', 'Scalawag Duck', 2),
#  ('Gregory', 'Mauldin', 'Cat Coneheads', 1),
#  ('Guy', 'Brownlee', 'Shakespeare Saddle', 1),
#  ('Guy', 'Brownlee', 'Jekyll Frogmen', 2),
#  ('Gwendolyn', 'May', 'Cruelty Unforgiven', 2),
#  ('Gwendolyn', 'May', 'Dirty Ace', 1),
#  ('Harold', 'Martino', 'Coast Rainbow', 1),
#  ('Harold', 'Martino', 'Poseidon Forever', 2),
#  ('Harry', 'Arce', 'Hunchback Impossible', 2),
#  ('Harry', 'Arce', 'Spirit Flintstones', 1),
#  ('Harvey', 'Guajardo', 'Purple Movie', 2),
#  ('Harvey', 'Guajardo', 'Innocent Usual', 1),
#  ('Hazel', 'Warren', 'Hope Tootsie', 2),
#  ('Hazel', 'Warren', 'Waterfront Deliverance', 1),
#  ('Heather', 'Morris', 'Blackout Private', 2),
#  ('Heather', 'Morris', 'Midsummer Groundhog', 1),
#  ('Hector', 'Poindexter', 'Samurai Lion', 2),
#  ('Hector', 'Poindexter', 'Invasion Cyclone', 1),
#  ('Heidi', 'Larson', 'Story Side', 2),
#  ('Heidi', 'Larson', 'Clueless Bucket', 1),
#  ('Helen', 'Harris', 'Talented Homicide', 1),
#  ('Helen', 'Harris', 'Creepers Kane', 2),
#  ('Henry', 'Billingsley', 'Shootist Superfly', 2),
#  ('Henry', 'Billingsley', 'Crusade Honey', 1),
#  ('Herbert', 'Kruger', 'Darn Forrester', 1),
#  ('Herbert', 'Kruger', 'Lock Rear', 2),
#  ('Herman', 'Devore', 'Blade Polish', 2),
#  ('Herman', 'Devore', 'Hanover Galaxy', 1),
#  ('Hilda', 'Hopkins', 'Resurrection Silverado', 1),
#  ('Hilda', 'Hopkins', 'Disturbing Scarface', 2),
#  ('Holly', 'Fox', 'Titanic Boondock', 2),
#  ('Holly', 'Fox', 'Jacket Frisco', 1),
#  ('Howard', 'Fortner', 'Dinosaur Secretary', 2),
#  ('Howard', 'Fortner', 'Pickup Driving', 1),
#  ('Hugh', 'Waldrop', 'Groundhog Uncut', 2),
#  ('Hugh', 'Waldrop', 'License Weekend', 1),
#  ('Ian', 'Still', 'Fidelity Devil', 1),
#  ('Ian', 'Still', 'Carrie Bunch', 2),
#  ('Ida', 'Andrews', 'Beverly Outlaw', 1),
#  ('Ida', 'Andrews', 'Annie Identity', 2),
#  ('Irene', 'Price', 'Encounters Curtain', 1),
#  ('Irene', 'Price', 'Doom Dancing', 2),
#  ('Irma', 'Pearson', 'Room Roman', 1),
#  ('Irma', 'Pearson', 'Shepherd Midsummer', 2),
#  ('Isaac', 'Oglesby', 'Twisted Pirates', 1),
#  ('Isaac', 'Oglesby', 'School Jacket', 2),
#  ('Ivan', 'Cromwell', 'Straight Hours', 2),
#  ('Ivan', 'Cromwell', 'Temple Attraction', 1),
#  ('Jack', 'Foust', 'Wind Phantom', 2),
#  ('Jack', 'Foust', 'Gunfighter Mussolini', 1),
#  ('Jackie', 'Lynch', 'Song Hedwig', 1),
#  ('Jackie', 'Lynch', 'Zorro Ark', 2),
#  ('Jacob', 'Lance', 'Patient Sister', 2),
#  ('Jacob', 'Lance', 'Straight Hours', 1),
#  ('Jacqueline', 'Long', 'Bright Encounters', 2),
#  ('Jacqueline', 'Long', 'Massage Image', 1),
#  ('Jaime', 'Nettles', 'Fargo Gandhi', 1),
#  ('Jaime', 'Nettles', 'Unfaithful Kill', 2),
#  ('James', 'Gannon', 'Finding Anaconda', 2),
#  ('James', 'Gannon', 'Treatment Jekyll', 1),
#  ('Jamie', 'Rice', 'Gone Trouble', 2),
#  ('Jamie', 'Waugh', 'Dude Blindness', 2),
#  ('Jamie', 'Waugh', 'Analyze Hoosiers', 1),
#  ('Jamie', 'Rice', 'Amelie Hellfighters', 1),
#  ('Jane', 'Bennett', 'Voyage Legally', 1),
#  ('Jane', 'Bennett', 'Curtain Videotape', 2),
#  ('Janet', 'Phillips', 'Gun Bonnie', 1),
#  ('Janet', 'Phillips', 'Campus Remember', 2),
#  ('Janice', 'Ward', 'Apache Divine', 2),
#  ('Janice', 'Ward', 'Working Microcosmos', 1),
#  ('Jared', 'Ely', 'Expecations Natural', 2),
#  ('Jared', 'Ely', 'Island Exorcist', 1),
#  ('Jason', 'Morrissey', 'Sabrina Midnight', 1),
#  ('Jason', 'Morrissey', 'Scalawag Duck', 2),
#  ('Javier', 'Elrod', 'Reunion Witches', 2),
#  ('Javier', 'Elrod', 'Noon Papi', 1),
#  ('Jay', 'Robb', 'Jeopardy Encino', 2),
#  ('Jay', 'Robb', 'Dragonfly Strangers', 1),
#  ('Jean', 'Bell', 'Midsummer Groundhog', 2),
#  ('Jean', 'Bell', 'Wife Turn', 1),
#  ('Jeanette', 'Greene', 'Cupboard Sinners', 1),
#  ('Jeanette', 'Greene', 'Stock Glass', 2),
#  ('Jeanne', 'Lawson', 'League Hellfighters', 2),
#  ('Jeanne', 'Lawson', 'Show Lord', 1),
#  ('Jeff', 'East', 'Heaven Freedom', 1),
#  ('Jeff', 'East', 'Vampire Whale', 2),
#  ('Jeffery', 'Pinson', 'Island Exorcist', 2),
#  ('Jeffery', 'Pinson', 'Fugitive Maguire', 1),
#  ('Jeffrey', 'Spear', 'Rouge Squad', 2),
#  ('Jeffrey', 'Spear', 'Wolves Desire', 1),
#  ('Jennie', 'Terry', 'Fargo Gandhi', 1),
#  ('Jennie', 'Terry', 'Greedy Roots', 2),
#  ('Jennifer', 'Davis', 'English Bulworth', 1),
#  ('Jennifer', 'Davis', 'Splendor Patton', 2),
#  ('Jenny', 'Castro', 'Packer Madigan', 2),
#  ('Jenny', 'Castro', 'Sense Greek', 1),
#  ('Jeremy', 'Hurtado', 'Strangelove Desire', 1),
#  ('Jeremy', 'Hurtado', 'Lion Uncut', 2),
#  ('Jerome', 'Kenyon', 'Blackout Private', 1),
#  ('Jerome', 'Kenyon', 'Velvet Terminator', 2),
#  ('Jerry', 'Jordon', 'Stock Glass', 1),
#  ('Jerry', 'Jordon', 'Carrie Bunch', 2),
#  ('Jesse', 'Schilling', 'Mannequin Worst', 2),
#  ('Jesse', 'Schilling', 'Deer Virginian', 1),
#  ('Jessica', 'Hall', 'Dynamite Tarzan', 1),
#  ('Jessica', 'Hall', 'Head Stranger', 2),
#  ('Jessie', 'Banks', 'Cyclone Family', 2),
#  ('Jessie', 'Milam', 'Rouge Squad', 1),
#  ('Jessie', 'Milam', 'Jekyll Frogmen', 2),
#  ('Jessie', 'Banks', 'Idols Snatchers', 1),
#  ('Jesus', 'Mccartney', 'Lucky Flying', 2),
#  ('Jesus', 'Mccartney', 'Sleeping Suspects', 1),
#  ('Jill', 'Hawkins', 'Smoochy Control', 2),
#  ('Jill', 'Hawkins', 'Malkovich Pet', 1),
#  ('Jim', 'Rea', 'Chance Resurrection', 1),
#  ('Jim', 'Rea', 'Sinners Atlantis', 2),
#  ('Jimmie', 'Eggleston', 'Unforgiven Zoolander', 1),
#  ('Jimmie', 'Eggleston', 'Reef Salute', 2),
#  ('Jimmy', 'Schrader', 'Caddyshack Jedi', 1),
#  ('Jimmy', 'Schrader', 'Lies Treatment', 2),
#  ('Jo', 'Fowler', 'Annie Identity', 2),
#  ('Jo', 'Fowler', 'Telemark Heartbreakers', 1),
#  ('Joan', 'Cooper', 'Craft Outfield', 1),
#  ('Joan', 'Cooper', 'State Wasteland', 2),
#  ('Joann', 'Gardner', 'Jade Bunch', 2),
#  ('Joann', 'Gardner', 'Ballroom Mockingbird', 1),
#  ('Joanne', 'Robertson', 'Camelot Vacation', 2),
#  ('Joanne', 'Robertson', 'Angels Life', 1),
#  ('Joe', 'Gilliland', 'Model Fish', 2),
#  ('Joe', 'Gilliland', 'Vision Torque', 1),
#  ('Joel', 'Francisco', 'Story Side', 1),
#  ('Joel', 'Francisco', 'Insider Arizona', 2),
#  ('John', 'Farnsworth', 'Tomorrow Hustler', 1),
#  ('John', 'Farnsworth', 'Date Speed', 2),
#  ('Johnnie', 'Chisholm', 'Magnificent Chitty', 1),
#  ('Johnnie', 'Chisholm', 'Exorcist Sting', 2),
#  ('Johnny', 'Turpin', 'Smoochy Control', 2),
#  ('Johnny', 'Turpin', 'Graffiti Love', 1),
#  ('Jon', 'Wiles', 'Blackout Private', 1),
#  ('Jon', 'Wiles', 'Dinosaur Secretary', 2),
#  ('Jonathan', 'Scarborough', 'Steers Armageddon', 1),
#  ('Jonathan', 'Scarborough', 'Club Graffiti', 2),
#  ('Jordan', 'Archuleta', 'Heaven Freedom', 1),
#  ('Jordan', 'Archuleta', 'Giant Troopers', 2),
#  ('Jorge', 'Olivares', 'Doubtfire Labyrinth', 2),
#  ('Jorge', 'Olivares', 'Bilko Anonymous', 1),
#  ('Jose', 'Andrew', 'Opus Ice', 2),
#  ('Jose', 'Andrew', 'Slums Duck', 1),
#  ('Joseph', 'Joy', 'Bull Shawshank', 2),
#  ('Joseph', 'Joy', 'Behavior Runaway', 1),
#  ('Josephine', 'Gomez', 'Suspects Quills', 1),
#  ('Josephine', 'Gomez', 'Elephant Trojan', 2),
#  ('Joshua', 'Mark', 'Jacket Frisco', 1),
#  ('Joshua', 'Mark', 'Eagles Panky', 2),
#  ('Joy', 'George', 'Timberland Sky', 1),
#  ('Joy', 'George', 'Stallion Sundance', 2),
#  ('Joyce', 'Edwards', 'House Dynamite', 1),
#  ('Joyce', 'Edwards', 'Ridgemont Submarine', 2),
#  ('Juan', 'Fraley', 'Insider Arizona', 1),
#  ('Juan', 'Fraley', 'Victory Academy', 2),
#  ('Juanita', 'Mason', 'Midnight Westward', 2),
#  ('Juanita', 'Mason', 'Fiction Christmas', 1),
#  ('Judith', 'Cox', 'Graffiti Love', 1),
#  ('Judith', 'Cox', 'Masked Bubble', 2),
#  ('Judy', 'Gray', 'Flying Hook', 2),
#  ('Judy', 'Gray', 'Excitement Eve', 1),
#  ('Julia', 'Flores', 'Vertigo Northwest', 2),
#  ('Julia', 'Flores', 'Amadeus Holy', 1),
#  ('Julian', 'Vest', 'Divide Monster', 1),
#  ('Julian', 'Vest', 'Hanging Deep', 2),
#  ('Julie', 'Sanchez', 'Core Suit', 1),
#  ('Julie', 'Sanchez', 'Ferris Mother', 2),
#  ('Julio', 'Noland', 'Trojan Tomorrow', 1),
#  ('Julio', 'Noland', 'Idaho Love', 2),
#  ('June', 'Carroll', 'Horn Working', 2),
#  ('June', 'Carroll', 'Shakespeare Saddle', 1),
#  ('Justin', 'Ngo', 'Chicken Hellfighters', 2),
#  ('Justin', 'Ngo', 'Lose Inch', 1),
#  ('Karen', 'Jackson', 'Bowfinger Gables', 2),
#  ('Karen', 'Jackson', 'Stock Glass', 1),
#  ('Karl', 'Seal', 'Fidelity Devil', 1),
#  ('Karl', 'Seal', 'Insects Stone', 2),
#  ('Katherine', 'Rivera', 'Iron Moon', 1),
#  ('Katherine', 'Rivera', 'Fireball Philadelphia', 2),
#  ('Kathleen', 'Adams', 'Orange Grapes', 2),
#  ('Kathleen', 'Adams', 'Women Dorado', 1),
#  ('Kathryn', 'Coleman', 'Lord Arizona', 1),
#  ('Kathryn', 'Coleman', 'Heavyweights Beast', 2),
#  ('Kathy', 'James', 'Daisy Menagerie', 1),
#  ('Kathy', 'James', 'Scalawag Duck', 2),
#  ('Katie', 'Elliott', 'Instinct Airport', 1),
#  ('Katie', 'Elliott', 'Videotape Arsenic', 2),
#  ('Kay', 'Caldwell', 'Quills Bull', 2),
#  ('Kay', 'Caldwell', 'Clash Freddy', 1),
#  ('Keith', 'Rico', 'Club Graffiti', 1),
#  ('Keith', 'Rico', 'Scorpion Apollo', 2),
#  ('Kelly', 'Knott', 'Dragonfly Strangers', 2),
#  ('Kelly', 'Torres', 'Behavior Runaway', 1),
#  ('Kelly', 'Torres', 'Pinocchio Simon', 2),
#  ('Kelly', 'Knott', 'Drifter Commandments', 1),
#  ('Ken', 'Prewitt', 'Model Fish', 2),
#  ('Ken', 'Prewitt', 'Insider Arizona', 1),
#  ('Kenneth', 'Gooden', 'Idaho Love', 1),
#  ('Kenneth', 'Gooden', 'Legally Secretary', 2),
#  ('Kent', 'Arsenault', 'Blade Polish', 1),
#  ('Kent', 'Arsenault', 'Roman Punk', 2),
#  ('Kevin', 'Schuler', 'Factory Dragon', 2),
#  ('Kevin', 'Schuler', 'Durham Panky', 1),
#  ('Kim', 'Cruz', 'Trojan Tomorrow', 2),
#  ('Kim', 'Cruz', 'Rouge Squad', 1),
#  ('Kimberly', 'Lee', 'Liaisons Sweet', 1),
#  ('Kimberly', 'Lee', 'Beach Heartbreakers', 2),
#  ('Kirk', 'Stclair', 'Bingo Talented', 2),
#  ('Kirk', 'Stclair', 'Flying Hook', 1),
#  ('Kristen', 'Chavez', 'Nuts Ties', 2),
#  ('Kristen', 'Chavez', 'Rugrats Shakespeare', 1),
#  ('Kristin', 'Johnston', 'Enemy Odds', 2),
#  ('Kristin', 'Johnston', 'Alabama Devil', 1),
#  ('Kristina', 'Chambers', 'Show Lord', 1),
#  ('Kristina', 'Chambers', 'Strangers Graffiti', 2),
#  ('Kurt', 'Emmons', 'Dracula Crystal', 1),
#  ('Kurt', 'Emmons', 'Gaslight Crusade', 2),
#  ('Kyle', 'Spurlock', 'Driver Annie', 1),
#  ('Kyle', 'Spurlock', 'Room Roman', 2),
#  ('Lance', 'Pemberton', 'Hollywood Anonymous', 2),
#  ('Lance', 'Pemberton', 'Fight Jawbreaker', 1),
#  ('Larry', 'Thrasher', 'Wife Turn', 2),
#  ('Larry', 'Thrasher', 'Uptown Young', 1),
#  ('Laura', 'Rodriguez', 'Gunfight Moon', 2),
#  ('Laura', 'Rodriguez', 'Tarzan Videotape', 1),
#  ('Lauren', 'Hudson', 'Swarm Gold', 1),
#  ('Lauren', 'Hudson', 'Neighbors Charade', 2),
#  ('Laurie', 'Lawrence', 'Carrie Bunch', 1),
#  ('Laurie', 'Lawrence', 'Sorority Queen', 2),
#  ('Lawrence', 'Lawton', 'Quills Bull', 2),
#  ('Lawrence', 'Lawton', 'Whale Bikini', 1),
#  ('Leah', 'Curtis', 'Masked Bubble', 1),
#  ('Leah', 'Curtis', 'Redemption Comforts', 2),
#  ('Lee', 'Hawks', 'Room Roman', 1),
#  ('Lee', 'Hawks', 'Graffiti Love', 2),
#  ('Lena', 'Jensen', 'Velvet Terminator', 2),
#  ('Lena', 'Jensen', 'Jason Trap', 1),
#  ('Leo', 'Ebert', 'Sensibility Rear', 1),
#  ('Leo', 'Ebert', 'Forward Temple', 2),
#  ('Leon', 'Bostic', 'Notorious Reunion', 1),
#  ('Leon', 'Bostic', 'Cassidy Wyoming', 2),
#  ('Leona', 'Obrien', 'Wardrobe Phantom', 1),
#  ('Leona', 'Obrien', 'Graduate Lord', 2),
#  ('Leonard', 'Schofield', 'Wyoming Storm', 2),
#  ('Leonard', 'Schofield', 'Encounters Curtain', 1),
#  ('Leroy', 'Bustamante', 'Dances None', 2),
#  ('Leroy', 'Bustamante', 'Driver Annie', 1),
#  ('Leslie', 'Seward', 'Shrunk Divine', 2),
#  ('Leslie', 'Gordon', 'Lebowski Soldiers', 1),
#  ('Leslie', 'Gordon', 'Ridgemont Submarine', 2),
#  ('Leslie', 'Seward', 'Stampede Disturbing', 1),
#  ('Lester', 'Kraus', 'Monterey Labyrinth', 1),
#  ('Lester', 'Kraus', 'Shining Roses', 2),
#  ('Lewis', 'Lyman', 'Holiday Games', 1),
#  ('Lewis', 'Lyman', 'Joon Northwest', 2),
#  ('Lillian', 'Griffin', 'Open African', 2),
#  ('Lillian', 'Griffin', 'Sea Virgin', 1),
#  ('Lillie', 'Kim', 'Operation Operation', 1),
#  ('Lillie', 'Kim', 'Something Duck', 2),
#  ('Linda', 'Williams', 'Boogie Amelie', 1),
#  ('Linda', 'Williams', 'Goldmine Tycoon', 2),
#  ('Lisa', 'Anderson', 'Pianist Outfield', 2),
#  ('Lisa', 'Anderson', 'Human Graffiti', 1),
#  ('Lloyd', 'Dowd', 'Horror Reign', 1),
#  ('Lloyd', 'Dowd', 'Vietnam Smoochy', 2),
#  ('Lois', 'Butler', 'Detective Vision', 2),
#  ('Lois', 'Butler', 'Robbers Joon', 1),
#  ('Lonnie', 'Tirado', 'Novocaine Flight', 1),
#  ('Lonnie', 'Tirado', 'Caribbean Liberty', 2),
#  ('Loretta', 'Carpenter', 'Wars Pluto', 1),
#  ('Loretta', 'Carpenter', 'Labyrinth League', 2),
#  ('Lori', 'Wood', 'Redemption Comforts', 1),
#  ('Lori', 'Wood', 'Karate Moon', 2),
#  ('Lorraine', 'Stephens', 'Birds Perdition', 2),
#  ('Lorraine', 'Stephens', 'Creepers Kane', 1),
#  ('Louis', 'Leone', 'Circus Youth', 1),
#  ('Louis', 'Leone', 'Exorcist Sting', 2),
#  ('Louise', 'Jenkins', 'Games Bowfinger', 1),
#  ('Louise', 'Jenkins', 'Blackout Private', 2),
#  ('Lucille', 'Holmes', 'Sweet Brotherhood', 1),
#  ('Lucille', 'Holmes', 'Phantom Glory', 2),
#  ('Lucy', 'Wheeler', 'Sun Confessions', 2),
#  ('Lucy', 'Wheeler', 'Maker Gables', 1),
#  ('Luis', 'Yanez', 'War Notting', 2),
#  ('Luis', 'Yanez', 'Holes Brannigan', 1),
#  ('Lydia', 'Burke', 'Road Roxanne', 1),
#  ('Lydia', 'Burke', 'Voice Peach', 2),
#  ('Lynn', 'Payne', 'Valley Packer', 1),
#  ('Lynn', 'Payne', 'Pity Bound', 2),
#  ('Mabel', 'Holland', 'Outbreak Divine', 1),
#  ('Mabel', 'Holland', 'Donnie Alley', 2),
#  ('Mae', 'Fletcher', 'Escape Metropolis', 1),
#  ('Mae', 'Fletcher', 'Bingo Talented', 2),
#  ('Manuel', 'Murrell', 'Beauty Grease', 1),
#  ('Manuel', 'Murrell', 'Mermaid Insects', 2),
#  ('Marc', 'Outlaw', 'Room Roman', 1),
#  ('Marc', 'Outlaw', 'Towers Hurricane', 2),
#  ('Marcia', 'Dean', 'Intolerable Intentions', 1),
#  ('Marcia', 'Dean', 'Dragonfly Strangers', 2),
#  ('Marcus', 'Hidalgo', 'Closer Bang', 1),
#  ('Marcus', 'Hidalgo', 'Bilko Anonymous', 2),
#  ('Margaret', 'Moore', 'Color Philadelphia', 1),
#  ('Margaret', 'Moore', 'Blood Argonauts', 2),
#  ('Margie', 'Wade', 'Phantom Glory', 2),
#  ('Margie', 'Wade', 'Mighty Luck', 1),
#  ('Maria', 'Miller', 'Forrester Comancheros', 1),
#  ('Maria', 'Miller', 'Bucket Brotherhood', 2),
#  ('Marian', 'Mendoza', 'Dream Pickup', 2),
#  ('Marian', 'Mendoza', 'Married Go', 1),
#  ('Marie', 'Turner', 'Moonshine Cabin', 2),
#  ('Marie', 'Turner', 'Wonka Sea', 1),
#  ('Marilyn', 'Ross', 'Karate Moon', 2),
#  ('Marilyn', 'Ross', 'Breakfast Goldfinger', 1),
#  ('Mario', 'Cheatham', 'Attraction Newton', 2),
#  ('Mario', 'Cheatham', 'Range Moonwalker', 1),
#  ('Marion', 'Ocampo', 'Scarface Bang', 1),
#  ('Marion', 'Snyder', 'Cabin Flash', 2),
#  ('Marion', 'Snyder', 'Spice Sorority', 1),
#  ('Marion', 'Ocampo', 'Grinch Massage', 2),
#  ('Marjorie', 'Tucker', 'Reign Gentlemen', 1),
#  ('Marjorie', 'Tucker', 'Miracle Virtual', 2),
#  ('Mark', 'Rinehart', 'Towers Hurricane', 1),
#  ('Mark', 'Rinehart', 'Won Dares', 2),
#  ('Marlene', 'Welch', 'Uncut Suicides', 2),
#  ('Marlene', 'Welch', 'Apache Divine', 1),
#  ('Marsha', 'Douglas', 'Candles Grapes', 1),
#  ('Marsha', 'Douglas', 'Shepherd Midsummer', 2),
#  ('Marshall', 'Thorn', 'Witches Panic', 1),
#  ('Marshall', 'Thorn', 'Slums Duck', 2),
#  ('Martha', 'Gonzalez', 'Sundance Invasion', 1),
#  ('Martha', 'Gonzalez', 'Music Boondock', 2),
#  ('Martin', 'Bales', 'Runner Madigan', 2),
#  ('Martin', 'Bales', 'Frost Head', 1),
#  ('Marvin', 'Yee', 'Freedom Cleopatra', 1),
#  ('Marvin', 'Yee', 'Rage Games', 2),
#  ('Mary', 'Smith', 'Frost Head', 2),
#  ('Mary', 'Smith', 'Unforgiven Zoolander', 1),
#  ('Mathew', 'Bolin', 'Blindness Gun', 1),
#  ('Mathew', 'Bolin', 'Talented Homicide', 2),
#  ('Matthew', 'Mahan', 'Coast Rainbow', 2),
#  ('Matthew', 'Mahan', 'Kissing Dolls', 1),
#  ('Mattie', 'Hoffman', 'Conquerer Nuts', 2),
#  ('Mattie', 'Hoffman', 'Chicken Hellfighters', 1),
#  ('Maureen', 'Little', 'Flying Hook', 2),
#  ('Maureen', 'Little', 'Taxi Kick', 1),
#  ('Maurice', 'Crawley', 'Northwest Polish', 2),
#  ('Maurice', 'Crawley', 'Musketeers Wait', 1),
#  ('Max', 'Pitt', 'Streetcar Intentions', 2),
#  ('Max', 'Pitt', 'Lambs Cincinatti', 1),
#  ('Maxine', 'Silva', 'Lambs Cincinatti', 1),
#  ('Maxine', 'Silva', 'Raging Airplane', 2),
#  ('Megan', 'Palmer', 'Affair Prejudice', 1),
#  ('Megan', 'Palmer', 'Trip Newton', 2),
#  ('Melanie', 'Armstrong', 'Paths Control', 1),
#  ('Melanie', 'Armstrong', 'Stage World', 2),
#  ('Melinda', 'Fernandez', 'Kiss Glory', 2),
#  ('Melinda', 'Fernandez', 'Patton Interview', 1),
#  ('Melissa', 'King', 'Behavior Runaway', 2),
#  ('Melissa', 'King', 'Harry Idaho', 1),
#  ('Melvin', 'Ellington', 'Grapes Fury', 1),
#  ('Melvin', 'Ellington', 'Wonderland Christmas', 2),
#  ('Michael', 'Silverman', 'Hedwig Alter', 1),
#  ('Michael', 'Silverman', 'Expecations Natural', 2),
#  ('Micheal', 'Forman', 'Opposite Necklace', 2),
#  ('Micheal', 'Forman', 'Spirit Flintstones', 1),
#  ('Michele', 'Grant', 'Lust Lock', 2),
#  ('Michele', 'Grant', 'Rear Trading', 1),
#  ('Michelle', 'Clark', 'Brooklyn Desert', 2),
#  ('Michelle', 'Clark', 'Goodfellas Salute', 1),
#  ('Miguel', 'Betancourt', 'Wanda Chamber', 1),
#  ('Miguel', 'Betancourt', 'Contact Anonymous', 2),
#  ('Mike', 'Way', 'Turn Star', 1),
#  ('Mike', 'Way', 'Frida Slipper', 2),
#  ('Mildred', 'Bailey', 'Seabiscuit Punk', 1),
#  ('Mildred', 'Bailey', 'Super Wyoming', 2),
#  ('Milton', 'Howland', 'Driver Annie', 2),
#  ('Milton', 'Howland', 'Mask Peach', 1),
#  ('Minnie', 'Romero', 'Storm Happiness', 1),
#  ('Minnie', 'Romero', 'Citizen Shrek', 2),
#  ('Miriam', 'Mckinney', 'Chill Luck', 1),
#  ('Miriam', 'Mckinney', 'Horror Reign', 2),
#  ('Misty', 'Lambert', 'Beethoven Exorcist', 1),
#  ('Misty', 'Lambert', 'Ali Forever', 2),
#  ('Mitchell', 'Westmoreland', 'Spiking Element', 1),
#  ('Mitchell', 'Westmoreland', 'Story Side', 2),
#  ('Monica', 'Hicks', 'Charade Duffel', 2),
#  ('Monica', 'Hicks', 'Mulan Moon', 1),
#  ('Morris', 'Mccarter', 'Anaconda Confessions', 1),
#  ('Morris', 'Mccarter', 'Breakfast Goldfinger', 2),
#  ('Myrtle', 'Fleming', 'Outfield Massacre', 2),
#  ('Myrtle', 'Fleming', 'Muscle Bright', 1),
#  ('Nancy', 'Thomas', 'Volcano Texas', 1),
#  ('Nancy', 'Thomas', 'Notting Speakeasy', 2),
#  ('Naomi', 'Jennings', 'Slacker Liaisons', 1),
#  ('Naomi', 'Jennings', 'Punk Divorce', 2),
#  ('Natalie', 'Meyer', 'Autumn Crow', 1),
#  ('Natalie', 'Meyer', 'Shanghai Tycoon', 2),
#  ('Nathan', 'Runyon', 'Wrath Mile', 2),
#  ('Nathan', 'Runyon', 'Scalawag Duck', 1),
#  ('Nathaniel', 'Adam', 'Tramp Others', 2),
#  ('Nathaniel', 'Adam', 'Poseidon Forever', 1),
#  ('Neil', 'Renner', 'Orient Closer', 1),
#  ('Neil', 'Renner', 'Massage Image', 2),
#  ('Nellie', 'Garrett', 'Basic Easy', 2),
#  ('Nellie', 'Garrett', 'Birds Perdition', 1),
#  ('Nelson', 'Christenson', 'Summer Scarface', 1),
#  ('Nelson', 'Christenson', 'Homicide Peach', 2),
#  ('Nicholas', 'Barfield', 'Soup Wisdom', 1),
#  ('Nicholas', 'Barfield', 'Falcon Volume', 2),
#  ('Nicole', 'Peterson', 'Queen Luke', 1),
#  ('Nicole', 'Peterson', 'Salute Apollo', 2),
#  ('Nina', 'Soto', 'Escape Metropolis', 2),
#  ('Nina', 'Soto', 'Torque Bound', 1),
#  ('Nora', 'Herrera', 'Opposite Necklace', 1),
#  ('Nora', 'Herrera', 'Wedding Apollo', 2),
#  ('Norma', 'Gonzales', 'Prix Undefeated', 1),
#  ('Norma', 'Gonzales', 'Island Exorcist', 2),
#  ('Norman', 'Currier', 'Loser Hustler', 1),
#  ('Norman', 'Currier', 'Crazy Home', 2),
#  ('Olga', 'Jimenez', 'Videotape Arsenic', 1),
#  ('Olga', 'Jimenez', 'Titans Jerk', 2),
#  ('Oscar', 'Aquino', 'National Story', 1),
#  ('Oscar', 'Aquino', 'Hope Tootsie', 2),
#  ('Pamela', 'Baker', 'Cider Desire', 1),
#  ('Pamela', 'Baker', 'Armageddon Lost', 2),
#  ('Patricia', 'Johnson', 'Doors President', 2),
#  ('Patricia', 'Johnson', 'Rugrats Shakespeare', 1),
#  ('Patrick', 'Newsom', 'Mask Peach', 1),
#  ('Patrick', 'Newsom', 'Temple Attraction', 2),
#  ('Patsy', 'Davidson', 'Dances None', 2),
#  ('Patsy', 'Davidson', 'Scalawag Duck', 1),
#  ('Paul', 'Trout', 'Jingle Sagebrush', 1),
#  ('Paul', 'Trout', 'Sleepless Monsoon', 2),
#  ('Paula', 'Bryant', 'Patient Sister', 2),
#  ('Paula', 'Bryant', 'Innocent Usual', 1),
#  ('Pauline', 'Henry', 'Pity Bound', 2),
#  ('Pauline', 'Henry', 'Dancing Fever', 1),
#  ('Pearl', 'Garza', 'Speakeasy Date', 1),
#  ('Pearl', 'Garza', 'Blackout Private', 2),
#  ('Pedro', 'Chestnut', 'Independence Hotel', 1),
#  ('Pedro', 'Chestnut', 'Mars Roman', 2),
#  ('Peggy', 'Myers', 'Pulp Beverly', 2),
#  ('Peggy', 'Myers', 'Canyon Stock', 1),
#  ('Penny', 'Neal', 'Ferris Mother', 2),
#  ('Penny', 'Neal', 'Orient Closer', 1),
#  ('Perry', 'Swafford', 'Song Hedwig', 1),
#  ('Perry', 'Swafford', 'Agent Truman', 2),
#  ('Peter', 'Menard', 'Bright Encounters', 2),
#  ('Peter', 'Menard', 'Drifter Commandments', 1),
#  ('Philip', 'Causey', 'Mockingbird Hollywood', 2),
#  ('Philip', 'Causey', 'Wash Heavenly', 1),
#  ('Phillip', 'Holm', 'Annie Identity', 1),
#  ('Phillip', 'Holm', 'Cause Date', 2),
#  ('Phyllis', 'Foster', 'Airplane Sierra', 1),
#  ('Phyllis', 'Foster', 'Lovely Jingle', 2),
#  ('Priscilla', 'Lowe', 'Stock Glass', 1),
#  ('Priscilla', 'Lowe', 'Pond Seattle', 2),
#  ('Rachel', 'Barnes', 'Married Go', 1),
#  ('Rachel', 'Barnes', 'Graffiti Love', 2),
#  ('Rafael', 'Abney', 'Wanda Chamber', 1),
#  ('Rafael', 'Abney', 'Blackout Private', 2),
#  ('Ralph', 'Madrigal', 'Tracy Cider', 2),
#  ('Ralph', 'Madrigal', 'Midnight Westward', 1),
#  ('Ramon', 'Choate', 'Party Knock', 2),
#  ('Ramon', 'Choate', 'Quest Mussolini', 1),
#  ('Ramona', 'Hale', 'Sleeping Suspects', 1),
#  ('Ramona', 'Hale', 'Attraction Newton', 2),
#  ('Randall', 'Neumann', 'Nightmare Chill', 2),
#  ('Randall', 'Neumann', 'Fantasia Park', 1),
#  ('Randy', 'Gaither', 'Poseidon Forever', 2),
#  ('Randy', 'Gaither', 'Liaisons Sweet', 1),
#  ('Raul', 'Fortier', 'Galaxy Sweethearts', 1),
#  ('Raul', 'Fortier', 'Saddle Antitrust', 2),
#  ('Ray', 'Houle', 'Papi Necklace', 1),
#  ('Ray', 'Houle', 'Resurrection Silverado', 2),
#  ('Raymond', 'Mcwhorter', 'Godfather Diary', 2),
#  ('Raymond', 'Mcwhorter', 'Undefeated Dalmations', 1),
#  ('Rebecca', 'Scott', 'Minds Truman', 2),
#  ('Rebecca', 'Scott', 'Snatchers Montezuma', 1),
#  ('Regina', 'Berry', 'Dwarfs Alter', 2),
#  ('Regina', 'Berry', 'Rock Instinct', 1),
#  ('Reginald', 'Kinder', 'Sorority Queen', 1),
#  ('Reginald', 'Kinder', 'Reign Gentlemen', 2),
#  ('Rene', 'Mcalister', 'Timberland Sky', 2),
#  ('Rene', 'Mcalister', 'Bowfinger Gables', 1),
#  ('Renee', 'Lane', 'Instinct Airport', 1),
#  ('Renee', 'Lane', 'Outbreak Divine', 2),
#  ('Rhonda', 'Kennedy', 'Holiday Games', 2),
#  ('Rhonda', 'Kennedy', 'Oz Liaisons', 1),
#  ('Ricardo', 'Meador', 'Undefeated Dalmations', 1),
#  ('Ricardo', 'Meador', 'Baked Cleopatra', 2),
#  ('Richard', 'Mccrary', 'Zorro Ark', 1),
#  ('Richard', 'Mccrary', 'Hanover Galaxy', 2),
#  ('Rick', 'Mattox', 'Money Harold', 1),
#  ('Rick', 'Mattox', 'Pride Alamo', 2),
#  ('Ricky', 'Shelby', 'Muscle Bright', 2),
#  ('Ricky', 'Shelby', 'Mod Secretary', 1),
#  ('Rita', 'Graham', 'Scalawag Duck', 2),
#  ('Rita', 'Graham', 'Racer Egg', 1),
#  ('Robert', 'Baughman', 'Towers Hurricane', 1),
#  ('Robert', 'Baughman', 'Image Princess', 2),
#  ('Roberta', 'Harper', 'Virgin Daisy', 2),
#  ('Roberta', 'Harper', 'Blackout Private', 1),
#  ('Roberto', 'Vu', 'Maltese Hope', 1),
#  ('Roberto', 'Vu', 'Sea Virgin', 2),
#  ('Robin', 'Hayes', 'Requiem Tycoon', 1),
#  ('Robin', 'Hayes', 'Adaptation Holes', 2),
#  ('Rodney', 'Moeller', 'Curtain Videotape', 1),
#  ('Rodney', 'Moeller', 'Cupboard Sinners', 2),
#  ('Roger', 'Quintanilla', 'Wisdom Worker', 1),
#  ('Roger', 'Quintanilla', 'Beauty Grease', 2),
#  ('Roland', 'South', 'Hellfighters Sierra', 1),
#  ('Roland', 'South', 'Clockwork Paradise', 2),
#  ('Ron', 'Deluca', 'Newton Labyrinth', 1),
#  ('Ron', 'Deluca', 'South Wait', 2),
#  ('Ronald', 'Weiner', 'Grapes Fury', 2),
#  ('Ronald', 'Weiner', 'Forward Temple', 1),
#  ('Ronnie', 'Ricketts', 'Superfly Trip', 2),
#  ('Ronnie', 'Ricketts', 'Panther Reds', 1),
#  ('Rosa', 'Reynolds', 'Snatchers Montezuma', 1),
#  ('Rosa', 'Reynolds', 'Galaxy Sweethearts', 2),
#  ('Rose', 'Howard', 'Hobbit Alien', 1),
#  ('Rose', 'Howard', 'Teen Apollo', 2),
#  ('Rosemary', 'Schmidt', 'Lion Uncut', 2),
#  ('Rosemary', 'Schmidt', 'Destiny Saturday', 1),
#  ('Ross', 'Grey', 'Fantasia Park', 2),
#  ('Ross', 'Grey', 'Kissing Dolls', 1),
#  ('Roy', 'Whiting', 'Usual Untouchables', 1),
#  ('Roy', 'Whiting', 'Chance Resurrection', 2),
#  ('Ruben', 'Geary', 'Affair Prejudice', 1),
#  ('Ruben', 'Geary', 'Salute Apollo', 2),
#  ('Ruby', 'Washington', 'Lebowski Soldiers', 1),
#  ('Ruby', 'Washington', 'Haunting Pianist', 2),
#  ('Russell', 'Brinson', 'Ferris Mother', 2),
#  ('Russell', 'Brinson', 'Horn Working', 1),
#  ('Ruth', 'Martinez', 'Streetcar Intentions', 1),
#  ('Ruth', 'Martinez', 'Talented Homicide', 2),
#  ('Ryan', 'Salisbury', 'Head Stranger', 1),
#  ('Ryan', 'Salisbury', 'Teen Apollo', 2),
#  ...]

# %% [markdown]
# # 5
#
# ### List the quartile statististics of the movie lengths, grouped by release year.

# %%
# %%sql
# EXPLAIN
# SELECT
#   release_year,
#   percentile_cont(array[0.25, 0.5, 0.75]) WITHIN GROUP (ORDER BY length)
# FROM film
# GROUP BY release_year

# %%
# %%sql
# SELECT
#   release_year,
#   percentile_cont(array[0.25, 0.5, 0.75]) WITHIN GROUP (ORDER BY length)
# FROM film
# GROUP BY release_year
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 1 rows affected.
# [(2006, [80.0, 114.0, 149.25])]

# %% [markdown]
# # Save your notebook, then `File > Close and Halt`
